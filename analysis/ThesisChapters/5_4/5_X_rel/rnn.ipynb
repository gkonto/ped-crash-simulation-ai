# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [round(2 * value - 1, 5) for value in scaled_values]
    
    return mapped_values

def calculate_trajectory_relative_change(trajectory):
    relative_change = []
    for i in range(1, len(trajectory)):
        delta = trajectory[i] - trajectory[i - 1]
        relative_change.append(round(delta, 5))
    return relative_change


##### RELATIVE CHANGE!@!!
def calculate_relative_change(row):
    row["Head_X_Coordinate"] = calculate_trajectory_relative_change(row["Head_X_Coordinate"])
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])

    row["Head_Y_Coordinate"] = calculate_trajectory_relative_change(row["Head_Y_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])

    row["Head_Z_Coordinate"] = calculate_trajectory_relative_change(row["Head_Z_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])

    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [-0.81439, -0.81439, -0.81439, -0.81439, -0.81...
# 1     [-0.36815, -0.36815, -0.36815, -0.36815, -0.36...
# 2     [-0.70066, -0.70066, -0.70066, -0.70066, -0.70...
# 3     [-0.80447, -0.80447, -0.80447, -0.80447, -0.80...
# 4     [-0.73389, -0.73389, -0.73389, -0.73389, -0.73...
# ...                                                 ...
# 1181  [-0.84062, -0.84062, -0.84062, -0.84062, -0.84...
# 1182  [-0.86507, -0.86507, -0.86507, -0.86507, -0.86...
# 1183  [-0.76039, -0.76039, -0.76039, -0.76039, -0.76...
# 1184  [-0.52933, -0.52933, -0.52933, -0.52933, -0.52...
# 1185  [-0.37837, -0.37837, -0.37837, -0.37837, -0.37...
#
#                                       Head_Y_Coordinate  \
# 0     [-0.13686, -0.13686, -0.13686, -0.13686, -0.13...
# 1     [0.97764, 0.97764, 0.97764, 0.97764, 0.97764, ...
# 2     [0.96859, 0.96859, 0.96859, 0.96859, 0.96859, ...
# 3     [0.15051, 0.15051, 0.15051, 0.15051, 0.15051, ...
# 4     [-0.17017, -0.17017, -0.17017, -0.17017, -0.17...
# ...                                                 ...
# 1181  [-0.32965, -0.32965, -0.32965, -0.32965, -0.32...
# 1182  [-0.98875, -0.98875, -0.98875, -0.98875, -0.98...
# 1183  [0.23726, 0.23726, 0.23726, 0.23726, 0.23726, ...
# 1184  [-0.97187, -0.97187, -0.97187, -0.97187, -0.97...
# 1185  [0.13679, 0.13679, 0.13679, 0.13679, 0.13679, ...
#
#                                       Head_Z_Coordinate
# 0     [0.7931, 0.79049, 0.7931, 0.79075, 0.78788, 0....
# 1     [0.80407, 0.80289, 0.80407, 0.80301, 0.8017, 0...
# 2     [0.79766, 0.79573, 0.79766, 0.79592, 0.7938, 0...
# 3     [0.83689, 0.83412, 0.83689, 0.83439, 0.83135, ...
# 4     [0.86008, 0.85817, 0.86008, 0.85837, 0.85627, ...
# ...                                                 ...
# 1181  [0.79464, 0.79316, 0.79464, 0.79331, 0.79168, ...
# 1182  [0.58186, 0.57949, 0.58186, 0.57973, 0.57713, ...
# 1183  [0.85618, 0.85414, 0.85618, 0.85434, 0.85209, ...
# 1184  [0.75842, 0.75713, 0.75842, 0.75726, 0.75584, ...
# 1185  [0.78873, 0.78752, 0.78873, 0.78764, 0.78631, ...
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 300): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 300): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 300): print("Error!!")
# Out:
# Checking rows:   0%|          | 0/1186 [00:00<?, ?row/s]
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 5276.50row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0             -0.81439           -0.13686            0.79310
# 1             -0.81439           -0.13686            0.79049
# 2             -0.81439           -0.13686            0.79310
# 3             -0.81439           -0.13686            0.79075
# 4             -0.81439           -0.13686            0.78788
# ..                 ...                ...                ...
# 296            0.98040           -0.77139            0.97048
# 297            0.98655           -0.76954            0.98041
# 298            0.99309           -0.76830            0.99060
# 299            1.00000           -0.76892            1.00000
# 300           -0.36815            0.97764            0.80407
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 75, 11) (711, 75, 1)
# (237, 75, 11) (237, 75, 1)
# (238, 75, 11) (238, 75, 1)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 1, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 1)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 75)             │         2,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 1)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,707 (584.79 KB)
#  Trainable params: 149,707 (584.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_X_rel\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 0.4482 - root_mean_squared_error: 0.6293 - val_loss: 0.4276 - val_root_mean_squared_error: 0.6133
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.4126 - root_mean_squared_error: 0.6012 - val_loss: 0.4038 - val_root_mean_squared_error: 0.5945
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.3878 - root_mean_squared_error: 0.5811 - val_loss: 0.3872 - val_root_mean_squared_error: 0.5813
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.3619 - root_mean_squared_error: 0.5593 - val_loss: 0.3629 - val_root_mean_squared_error: 0.5610
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.3527 - root_mean_squared_error: 0.5520 - val_loss: 0.3374 - val_root_mean_squared_error: 0.5388
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.3220 - root_mean_squared_error: 0.5245 - val_loss: 0.2996 - val_root_mean_squared_error: 0.5034
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.2888 - root_mean_squared_error: 0.4928 - val_loss: 0.2696 - val_root_mean_squared_error: 0.4738
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.2610 - root_mean_squared_error: 0.4648 - val_loss: 0.2431 - val_root_mean_squared_error: 0.4459
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.2303 - root_mean_squared_error: 0.4315 - val_loss: 0.2206 - val_root_mean_squared_error: 0.4209
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.2117 - root_mean_squared_error: 0.4105 - val_loss: 0.1979 - val_root_mean_squared_error: 0.3942
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1907 - root_mean_squared_error: 0.3852 - val_loss: 0.1786 - val_root_mean_squared_error: 0.3699
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1726 - root_mean_squared_error: 0.3620 - val_loss: 0.1628 - val_root_mean_squared_error: 0.3490
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1547 - root_mean_squared_error: 0.3375 - val_loss: 0.1484 - val_root_mean_squared_error: 0.3289
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1453 - root_mean_squared_error: 0.3244 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3133
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.1323 - root_mean_squared_error: 0.3049 - val_loss: 0.1283 - val_root_mean_squared_error: 0.2992
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.1234 - root_mean_squared_error: 0.2911 - val_loss: 0.1202 - val_root_mean_squared_error: 0.2866
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1197 - root_mean_squared_error: 0.2860 - val_loss: 0.1151 - val_root_mean_squared_error: 0.2788
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1126 - root_mean_squared_error: 0.2746 - val_loss: 0.1097 - val_root_mean_squared_error: 0.2702
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.1057 - root_mean_squared_error: 0.2630 - val_loss: 0.1061 - val_root_mean_squared_error: 0.2646
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.1037 - root_mean_squared_error: 0.2604 - val_loss: 0.1034 - val_root_mean_squared_error: 0.2608
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1006 - root_mean_squared_error: 0.2557 - val_loss: 0.1013 - val_root_mean_squared_error: 0.2580
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1000 - root_mean_squared_error: 0.2557 - val_loss: 0.0990 - val_root_mean_squared_error: 0.2549
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0964 - root_mean_squared_error: 0.2499 - val_loss: 0.0967 - val_root_mean_squared_error: 0.2516
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0911 - root_mean_squared_error: 0.2405 - val_loss: 0.0938 - val_root_mean_squared_error: 0.2471
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0887 - root_mean_squared_error: 0.2367 - val_loss: 0.0942 - val_root_mean_squared_error: 0.2490
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0888 - root_mean_squared_error: 0.2383 - val_loss: 0.0908 - val_root_mean_squared_error: 0.2435
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0862 - root_mean_squared_error: 0.2339 - val_loss: 0.0903 - val_root_mean_squared_error: 0.2437
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0871 - root_mean_squared_error: 0.2372 - val_loss: 0.0886 - val_root_mean_squared_error: 0.2412
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0824 - root_mean_squared_error: 0.2285 - val_loss: 0.0863 - val_root_mean_squared_error: 0.2377
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0814 - root_mean_squared_error: 0.2275 - val_loss: 0.0862 - val_root_mean_squared_error: 0.2388
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0819 - root_mean_squared_error: 0.2299 - val_loss: 0.0857 - val_root_mean_squared_error: 0.2388
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0777 - root_mean_squared_error: 0.2218 - val_loss: 0.0831 - val_root_mean_squared_error: 0.2345
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0789 - root_mean_squared_error: 0.2256 - val_loss: 0.0827 - val_root_mean_squared_error: 0.2347
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0751 - root_mean_squared_error: 0.2184 - val_loss: 0.0811 - val_root_mean_squared_error: 0.2325
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0771 - root_mean_squared_error: 0.2241 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2324
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0772 - root_mean_squared_error: 0.2254 - val_loss: 0.0817 - val_root_mean_squared_error: 0.2361
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0723 - root_mean_squared_error: 0.2155 - val_loss: 0.0784 - val_root_mean_squared_error: 0.2301
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0734 - root_mean_squared_error: 0.2192 - val_loss: 0.0778 - val_root_mean_squared_error: 0.2299
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0721 - root_mean_squared_error: 0.2172 - val_loss: 0.0778 - val_root_mean_squared_error: 0.2309
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0709 - root_mean_squared_error: 0.2157 - val_loss: 0.0760 - val_root_mean_squared_error: 0.2280
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0705 - root_mean_squared_error: 0.2159 - val_loss: 0.0762 - val_root_mean_squared_error: 0.2294
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0685 - root_mean_squared_error: 0.2121 - val_loss: 0.0782 - val_root_mean_squared_error: 0.2348
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0656 - root_mean_squared_error: 0.2064 - val_loss: 0.0755 - val_root_mean_squared_error: 0.2298
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.0665 - root_mean_squared_error: 0.2096 - val_loss: 0.0747 - val_root_mean_squared_error: 0.2290
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.0672 - root_mean_squared_error: 0.2121 - val_loss: 0.0740 - val_root_mean_squared_error: 0.2285
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0646 - root_mean_squared_error: 0.2070 - val_loss: 0.0741 - val_root_mean_squared_error: 0.2296
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0627 - root_mean_squared_error: 0.2035 - val_loss: 0.0722 - val_root_mean_squared_error: 0.2262
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0639 - root_mean_squared_error: 0.2074 - val_loss: 0.0731 - val_root_mean_squared_error: 0.2291
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0629 - root_mean_squared_error: 0.2058 - val_loss: 0.0712 - val_root_mean_squared_error: 0.2258
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0641 - root_mean_squared_error: 0.2097 - val_loss: 0.0722 - val_root_mean_squared_error: 0.2290
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0623 - root_mean_squared_error: 0.2064 - val_loss: 0.0726 - val_root_mean_squared_error: 0.2306
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0654 - root_mean_squared_error: 0.2145 - val_loss: 0.0724 - val_root_mean_squared_error: 0.2310
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0607 - root_mean_squared_error: 0.2044 - val_loss: 0.0705 - val_root_mean_squared_error: 0.2275
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0621 - root_mean_squared_error: 0.2085 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2254
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - loss: 0.0608 - root_mean_squared_error: 0.2062 - val_loss: 0.0695 - val_root_mean_squared_error: 0.2269
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0591 - root_mean_squared_error: 0.2029 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2256
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0576 - root_mean_squared_error: 0.2001 - val_loss: 0.0696 - val_root_mean_squared_error: 0.2287
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0594 - root_mean_squared_error: 0.2054 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2258
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0558 - root_mean_squared_error: 0.1971 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2284
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.0555 - root_mean_squared_error: 0.1971 - val_loss: 0.0672 - val_root_mean_squared_error: 0.2255
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0557 - root_mean_squared_error: 0.1985 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2267
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0550 - root_mean_squared_error: 0.1975 - val_loss: 0.0667 - val_root_mean_squared_error: 0.2258
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0559 - root_mean_squared_error: 0.2006 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2290
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0590 - root_mean_squared_error: 0.2088 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2265
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0531 - root_mean_squared_error: 0.1949 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2256
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0525 - root_mean_squared_error: 0.1940 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2264
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.0508 - root_mean_squared_error: 0.1902 - val_loss: 0.0638 - val_root_mean_squared_error: 0.2224
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - loss: 0.0522 - root_mean_squared_error: 0.1947 - val_loss: 0.0643 - val_root_mean_squared_error: 0.2242
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0519 - root_mean_squared_error: 0.1945 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2307
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0534 - root_mean_squared_error: 0.1991 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2239
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0501 - root_mean_squared_error: 0.1913 - val_loss: 0.0632 - val_root_mean_squared_error: 0.2234
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0520 - root_mean_squared_error: 0.1968 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2297
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.0500 - root_mean_squared_error: 0.1923 - val_loss: 0.0618 - val_root_mean_squared_error: 0.2213
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0531 - root_mean_squared_error: 0.2007 - val_loss: 0.0614 - val_root_mean_squared_error: 0.2209
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0494 - root_mean_squared_error: 0.1919 - val_loss: 0.0620 - val_root_mean_squared_error: 0.2228
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0519 - root_mean_squared_error: 0.1990 - val_loss: 0.0620 - val_root_mean_squared_error: 0.2232
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0481 - root_mean_squared_error: 0.1898 - val_loss: 0.0603 - val_root_mean_squared_error: 0.2199
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.0465 - root_mean_squared_error: 0.1859 - val_loss: 0.0616 - val_root_mean_squared_error: 0.2233
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0491 - root_mean_squared_error: 0.1936 - val_loss: 0.0615 - val_root_mean_squared_error: 0.2236
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0487 - root_mean_squared_error: 0.1929 - val_loss: 0.0614 - val_root_mean_squared_error: 0.2237
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0504 - root_mean_squared_error: 0.1976 - val_loss: 0.0599 - val_root_mean_squared_error: 0.2208
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0484 - root_mean_squared_error: 0.1931 - val_loss: 0.0602 - val_root_mean_squared_error: 0.2221
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0466 - root_mean_squared_error: 0.1889 - val_loss: 0.0593 - val_root_mean_squared_error: 0.2204
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0463 - root_mean_squared_error: 0.1888 - val_loss: 0.0607 - val_root_mean_squared_error: 0.2239
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0463 - root_mean_squared_error: 0.1893 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2191
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0475 - root_mean_squared_error: 0.1928 - val_loss: 0.0620 - val_root_mean_squared_error: 0.2277
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0464 - root_mean_squared_error: 0.1904 - val_loss: 0.0598 - val_root_mean_squared_error: 0.2231
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0469 - root_mean_squared_error: 0.1921 - val_loss: 0.0598 - val_root_mean_squared_error: 0.2235
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0486 - root_mean_squared_error: 0.1971 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2272
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0478 - root_mean_squared_error: 0.1954 - val_loss: 0.0600 - val_root_mean_squared_error: 0.2247
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0450 - root_mean_squared_error: 0.1885 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2196
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0459 - root_mean_squared_error: 0.1912 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2302
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0451 - root_mean_squared_error: 0.1896 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2221
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0450 - root_mean_squared_error: 0.1897 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2234
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0459 - root_mean_squared_error: 0.1924 - val_loss: 0.0569 - val_root_mean_squared_error: 0.2195
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0431 - root_mean_squared_error: 0.1853 - val_loss: 0.0578 - val_root_mean_squared_error: 0.2218
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0431 - root_mean_squared_error: 0.1858 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2227
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0429 - root_mean_squared_error: 0.1855 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2249
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0455 - root_mean_squared_error: 0.1927 - val_loss: 0.0573 - val_root_mean_squared_error: 0.2215
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0438 - root_mean_squared_error: 0.1888 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2237
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0424 - root_mean_squared_error: 0.1854 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2181
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0407 - root_mean_squared_error: 0.1810 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2151
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0411 - root_mean_squared_error: 0.1824 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2220
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0429 - root_mean_squared_error: 0.1875 - val_loss: 0.0539 - val_root_mean_squared_error: 0.2153
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0415 - root_mean_squared_error: 0.1842 - val_loss: 0.0531 - val_root_mean_squared_error: 0.2137
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0415 - root_mean_squared_error: 0.1843 - val_loss: 0.0536 - val_root_mean_squared_error: 0.2149
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0406 - root_mean_squared_error: 0.1824 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2196
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0398 - root_mean_squared_error: 0.1802 - val_loss: 0.0552 - val_root_mean_squared_error: 0.2192
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0404 - root_mean_squared_error: 0.1822 - val_loss: 0.0526 - val_root_mean_squared_error: 0.2133
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0399 - root_mean_squared_error: 0.1812 - val_loss: 0.0547 - val_root_mean_squared_error: 0.2185
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0386 - root_mean_squared_error: 0.1780 - val_loss: 0.0536 - val_root_mean_squared_error: 0.2161
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0372 - root_mean_squared_error: 0.1743 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2166
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0390 - root_mean_squared_error: 0.1796 - val_loss: 0.0532 - val_root_mean_squared_error: 0.2157
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0389 - root_mean_squared_error: 0.1796 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2151
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0390 - root_mean_squared_error: 0.1801 - val_loss: 0.0551 - val_root_mean_squared_error: 0.2205
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0396 - root_mean_squared_error: 0.1819 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2174
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0387 - root_mean_squared_error: 0.1798 - val_loss: 0.0531 - val_root_mean_squared_error: 0.2163
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0379 - root_mean_squared_error: 0.1779 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2156
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0379 - root_mean_squared_error: 0.1781 - val_loss: 0.0542 - val_root_mean_squared_error: 0.2193
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0379 - root_mean_squared_error: 0.1782 - val_loss: 0.0506 - val_root_mean_squared_error: 0.2111
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0362 - root_mean_squared_error: 0.1737 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2157
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0365 - root_mean_squared_error: 0.1747 - val_loss: 0.0519 - val_root_mean_squared_error: 0.2144
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0370 - root_mean_squared_error: 0.1764 - val_loss: 0.0531 - val_root_mean_squared_error: 0.2175
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0367 - root_mean_squared_error: 0.1758 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2087
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0394 - root_mean_squared_error: 0.1835 - val_loss: 0.0536 - val_root_mean_squared_error: 0.2190
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0363 - root_mean_squared_error: 0.1752 - val_loss: 0.0505 - val_root_mean_squared_error: 0.2118
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0358 - root_mean_squared_error: 0.1739 - val_loss: 0.0516 - val_root_mean_squared_error: 0.2148
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0364 - root_mean_squared_error: 0.1756 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2131
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0352 - root_mean_squared_error: 0.1725 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2133
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0366 - root_mean_squared_error: 0.1767 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2185
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0350 - root_mean_squared_error: 0.1723 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2120
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0351 - root_mean_squared_error: 0.1729 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2101
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0361 - root_mean_squared_error: 0.1759 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2124
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0341 - root_mean_squared_error: 0.1704 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2104
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0346 - root_mean_squared_error: 0.1720 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2132
# Epoch 136/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0383 - root_mean_squared_error: 0.1826 - val_loss: 0.0503 - val_root_mean_squared_error: 0.2131
# Epoch 137/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0365 - root_mean_squared_error: 0.1777 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2078
# Epoch 138/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0362 - root_mean_squared_error: 0.1769 - val_loss: 0.0485 - val_root_mean_squared_error: 0.2090
# Epoch 139/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0365 - root_mean_squared_error: 0.1779 - val_loss: 0.0499 - val_root_mean_squared_error: 0.2124
# Epoch 140/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0358 - root_mean_squared_error: 0.1762 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2106
# Epoch 141/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 0.0346 - root_mean_squared_error: 0.1729 - val_loss: 0.0526 - val_root_mean_squared_error: 0.2191
# Epoch 142/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - loss: 0.0352 - root_mean_squared_error: 0.1749 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2108
# Epoch 143/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0347 - root_mean_squared_error: 0.1735 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2109
# Epoch 144/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0346 - root_mean_squared_error: 0.1734 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2126
# Epoch 145/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0343 - root_mean_squared_error: 0.1728 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2113
# Epoch 146/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.0325 - root_mean_squared_error: 0.1676 - val_loss: 0.0507 - val_root_mean_squared_error: 0.2151
# Epoch 147/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0333 - root_mean_squared_error: 0.1701 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2082
# Epoch 148/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0338 - root_mean_squared_error: 0.1716 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2106
# Epoch 149/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0334 - root_mean_squared_error: 0.1708 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2095
# Epoch 150/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0324 - root_mean_squared_error: 0.1677 - val_loss: 0.0467 - val_root_mean_squared_error: 0.2061
# Epoch 151/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0297 - root_mean_squared_error: 0.1596 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2099
# Epoch 152/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0324 - root_mean_squared_error: 0.1680 - val_loss: 0.0474 - val_root_mean_squared_error: 0.2082
# Epoch 153/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0327 - root_mean_squared_error: 0.1692 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2072
# Epoch 154/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0322 - root_mean_squared_error: 0.1678 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2087
# Epoch 155/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0315 - root_mean_squared_error: 0.1657 - val_loss: 0.0465 - val_root_mean_squared_error: 0.2063
# Epoch 156/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0317 - root_mean_squared_error: 0.1664 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2051
# Epoch 157/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0317 - root_mean_squared_error: 0.1666 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2101
# Epoch 158/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0306 - root_mean_squared_error: 0.1633 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2115
# Epoch 159/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0339 - root_mean_squared_error: 0.1731 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2058
# Epoch 160/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0314 - root_mean_squared_error: 0.1661 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2036
# Epoch 161/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0311 - root_mean_squared_error: 0.1652 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2063
# Epoch 162/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0317 - root_mean_squared_error: 0.1673 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2067
# Epoch 163/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0324 - root_mean_squared_error: 0.1695 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2082
# Epoch 164/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0303 - root_mean_squared_error: 0.1631 - val_loss: 0.0457 - val_root_mean_squared_error: 0.2050
# Epoch 165/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0323 - root_mean_squared_error: 0.1694 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2082
# Epoch 166/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0308 - root_mean_squared_error: 0.1650 - val_loss: 0.0474 - val_root_mean_squared_error: 0.2094
# Epoch 167/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0309 - root_mean_squared_error: 0.1655 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2089
# Epoch 168/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0299 - root_mean_squared_error: 0.1622 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2033
# Epoch 169/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0298 - root_mean_squared_error: 0.1623 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2046
# Epoch 170/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0325 - root_mean_squared_error: 0.1705 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2018
# Epoch 171/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0302 - root_mean_squared_error: 0.1637 - val_loss: 0.0489 - val_root_mean_squared_error: 0.2134
# Epoch 172/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0331 - root_mean_squared_error: 0.1723 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2079
# Epoch 173/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0333 - root_mean_squared_error: 0.1729 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2117
# Epoch 174/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0315 - root_mean_squared_error: 0.1679 - val_loss: 0.0483 - val_root_mean_squared_error: 0.2121
# Epoch 175/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0335 - root_mean_squared_error: 0.1737 - val_loss: 0.0485 - val_root_mean_squared_error: 0.2126
# Epoch 176/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0320 - root_mean_squared_error: 0.1695 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2029
# Epoch 177/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0318 - root_mean_squared_error: 0.1690 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2079
# Epoch 178/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0318 - root_mean_squared_error: 0.1693 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2096
# Epoch 179/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0303 - root_mean_squared_error: 0.1647 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2055
# Epoch 180/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0310 - root_mean_squared_error: 0.1670 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2059
# Epoch 181/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0286 - root_mean_squared_error: 0.1594 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2061
# Epoch 182/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0300 - root_mean_squared_error: 0.1640 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2110
# Epoch 183/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0306 - root_mean_squared_error: 0.1659 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2068
# Epoch 184/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.0311 - root_mean_squared_error: 0.1675 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2049
# Epoch 185/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0296 - root_mean_squared_error: 0.1629 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2039
# Epoch 186/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0285 - root_mean_squared_error: 0.1598 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2040
# Epoch 187/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0294 - root_mean_squared_error: 0.1626 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2012
# Epoch 188/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0295 - root_mean_squared_error: 0.1628 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2046
# Epoch 189/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0269 - root_mean_squared_error: 0.1548 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2052
# Epoch 190/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0290 - root_mean_squared_error: 0.1617 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2055
# Epoch 191/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.0277 - root_mean_squared_error: 0.1575 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2019
# Epoch 192/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0276 - root_mean_squared_error: 0.1574 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2024
# Epoch 193/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0296 - root_mean_squared_error: 0.1635 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2065
# Epoch 194/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0277 - root_mean_squared_error: 0.1578 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2039
# Epoch 195/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0317 - root_mean_squared_error: 0.1700 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2083
# Epoch 196/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0301 - root_mean_squared_error: 0.1655 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2038
# Epoch 197/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0279 - root_mean_squared_error: 0.1586 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2030
# Epoch 198/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0257 - root_mean_squared_error: 0.1517 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2042
# Epoch 199/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0286 - root_mean_squared_error: 0.1610 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2062
# Epoch 200/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 0.0281 - root_mean_squared_error: 0.1594 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2059
# Epoch 201/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.0277 - root_mean_squared_error: 0.1583 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2024
# Epoch 202/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0296 - root_mean_squared_error: 0.1642 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2021
# Epoch 203/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0281 - root_mean_squared_error: 0.1596 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2019
# Epoch 204/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0275 - root_mean_squared_error: 0.1579 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2062
# Epoch 205/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0291 - root_mean_squared_error: 0.1629 - val_loss: 0.0440 - val_root_mean_squared_error: 0.2035
# Epoch 206/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0276 - root_mean_squared_error: 0.1584 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2048
# Epoch 207/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0279 - root_mean_squared_error: 0.1592 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2020
# Epoch 208/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0271 - root_mean_squared_error: 0.1567 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2068
# Epoch 209/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0290 - root_mean_squared_error: 0.1627 - val_loss: 0.0424 - val_root_mean_squared_error: 0.1999
# Epoch 210/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0285 - root_mean_squared_error: 0.1612 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2088
# Epoch 211/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0292 - root_mean_squared_error: 0.1637 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2024
# Epoch 212/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0259 - root_mean_squared_error: 0.1531 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2038
# Epoch 213/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0273 - root_mean_squared_error: 0.1578 - val_loss: 0.0503 - val_root_mean_squared_error: 0.2190
# Epoch 214/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0274 - root_mean_squared_error: 0.1581 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2024
# Epoch 215/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0269 - root_mean_squared_error: 0.1566 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2037
# Epoch 216/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 0.0268 - root_mean_squared_error: 0.1562 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2019
# Epoch 217/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0263 - root_mean_squared_error: 0.1545 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2035
# Epoch 218/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0252 - root_mean_squared_error: 0.1511 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2059
# Epoch 219/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0267 - root_mean_squared_error: 0.1560 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2075
# Epoch 220/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0251 - root_mean_squared_error: 0.1510 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2079
# Epoch 221/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0265 - root_mean_squared_error: 0.1556 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2023
# Epoch 222/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0253 - root_mean_squared_error: 0.1517 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2060
# Epoch 223/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0310 - root_mean_squared_error: 0.1693 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2135
# Epoch 224/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0312 - root_mean_squared_error: 0.1703 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2036
# Epoch 225/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0297 - root_mean_squared_error: 0.1658 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2055
# Epoch 226/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.0283 - root_mean_squared_error: 0.1616 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2058
# Epoch 227/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0293 - root_mean_squared_error: 0.1648 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2050
# Epoch 228/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0282 - root_mean_squared_error: 0.1614 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2030
# Epoch 229/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0265 - root_mean_squared_error: 0.1560 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2026

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0456 - root_mean_squared_error: 0.2075
# Test Loss: [0.04404084384441376, 0.20387989282608032]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_X_rel\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()

# %%
# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_test)

# Example for the first sample in the dataset
sample_index = 4
initial_seq = X_test[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_test[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
#plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
#plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
