# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - η διαφορα του με το 5_XYZ_only_norm ειναι οτι to normalization εχει boundaries για καθε row.
# - Σε αυτο θα βρω τα συνολικα xminmax, yminmax, zminmax και θα χρησιμοποιησω αυτα.

# %% [markdown]
# # Generate Dataframe

# %%
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df.iloc[0]
# Out:
# Id                                                                                          0
# Path                                        C:\Users\geork\projects\AIThesis\datasets\2024...
# CarProfile                                                                                FCR
# Velocity                                                                                  100
# Translation                                                                              -200
# Rotation                                                                                    0
# Position                                                                              initial
# HIC15_max                                                                              86.843
# HIC36_max                                                                             136.373
# Head_Z_Acceleration_abs_max                                                            36.081
# Head_X_Acceleration_abs_max                                                             7.578
# Head_Y_Acceleration_abs_max                                                            17.539
# BrIC_abs_max                                                                             0.92
# Chest_Resultant_Acceleration_max                                                       34.882
# Chest_Resultant_Acceleration_CLIP3ms_max                                               28.117
# Head_X_Coordinate                           [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# Head_Y_Coordinate                           [-288.045, -288.045, -288.045, -288.045, -288....
# Head_Z_Coordinate                           [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# Name: 0, dtype: object

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
from car_profile_expand import expand_car_profiles
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"
             ]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 9925.33row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#labels = ["Head_X_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0              220.000           -288.045           1575.416
# 1              220.000           -288.045           1575.411
# 2              220.000           -288.045           1575.396
# 3              220.000           -288.045           1575.391
# 4              220.000           -288.045           1575.377
# ..                 ...                ...                ...
# 296           2724.310           -409.036            947.462
# 297           2738.592           -410.063            948.136
# 298           2752.923           -411.087            948.848
# 299           2767.306           -412.109            949.599
# 300           2781.744           -413.132            950.386
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
train_df.shape

# To train_df einai (711, 11)
# Kapoies apo tis times tou 11 einai listes me 300 stoixeia.
# Out:
# (711, 11)

# %% [markdown]
# # From Dataframe to Numpy Array

# %% [markdown]
# ## Split Numpy Arrays

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])
    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 125

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (711, 75, 11), y_train shape: (711, 125, 3)

# %%
X_train[0]
X_train[0][0]
X_train.shape
# Out:
# (711, 75, 11)

# %% [markdown]
# ## Calculate Relative Changes

# %%
# Assuming X has shape (711, 75, 11)
def calculate_relative_change_X(X):
    # Split the dataset into two parts: unchanged features and XYZ columns
    features = X[:, :, :-3]  # First 8 columns (unchanged)
    xyz = X[:, :, -3:]  # Last 3 columns (XYZ)

    # Calculate the relative change for XYZ coordinates
    # Shape will be (n_samples, timesteps-1, 3)
    xyz_relative = np.diff(xyz, axis=1)

    # Since np.diff reduces the timestep dimension by 1, we need to pad the first timestep for XYZ
    # We can pad the first timestep with zeros (no relative change at the first timestep)
    zero_padding = np.zeros((X.shape[0], 1, 3))
    xyz_relative = np.concatenate((zero_padding, xyz_relative), axis=1)

    # Combine unchanged features and the new relative XYZ values
    # Shape will be (n_samples, timesteps, 11)
    X_transformed = np.concatenate((features, xyz_relative), axis=2)

    return X_transformed

import numpy as np

def revert_relative_change_X(X_relative, initial_xyz):
    """
    Reverts the relative changes for the last 3 columns (XYZ) to their original absolute values.
    
    Parameters:
    X_relative: np.ndarray
        Input data with relative changes in the last 3 columns (shape: n_samples, timesteps, 11).
    initial_xyz: np.ndarray
        The initial XYZ values (absolute values) at t=0 (shape: n_samples, 3).
    
    Returns:
    X_original: np.ndarray
        The dataset with the last 3 columns (XYZ) reverted to absolute values (shape: n_samples, timesteps, 11).
    """
    # Split the dataset into two parts: unchanged features and relative XYZ columns
    features = X_relative[:, :, :-3]  # First 8 columns (unchanged)
    xyz_relative = X_relative[:, :, -3:]  # Last 3 columns (XYZ relative changes)

    # Initialize an array to store the absolute XYZ values
    n_samples, timesteps, _ = X_relative.shape
    xyz_absolute = np.zeros((n_samples, timesteps, 3))

    # Set the first timestep to the initial absolute XYZ values
    
    xyz_absolute[:, 0, :] = initial_xyz

    # Rebuild the absolute XYZ values by accumulating the relative changes
    for t in range(1, timesteps):
        xyz_absolute[:, t, :] = xyz_absolute[:, t-1, :] + xyz_relative[:, t, :]

    # Combine unchanged features with the reconstructed absolute XYZ values
    X_original = np.concatenate((features, xyz_absolute), axis=2)

    return X_original


def calculate_relative_change_y(y):
    xyz_relative = np.diff(y, axis=1)
    zero_padding = np.zeros((y.shape[0], 1, y.shape[2]))
    y_relative = np.concatenate((zero_padding, xyz_relative), axis=1)
    return y_relative

import numpy as np

def revert_relative_change_y(y_relative, initial_xyz):
    """
    Reverts the relative changes for the test data to their original absolute values.
    
    Parameters:
    y_relative: np.ndarray
        Input test data with relative changes (shape: n_samples, timesteps, 3).
    initial_xyz: np.ndarray
        The initial XYZ values (absolute values) at t=0 (shape: n_samples, 3).
    
    Returns:
    y_absolute: np.ndarray
        The test data with reverted absolute XYZ values (shape: n_samples, timesteps, 3).
    """
    # Initialize an array to store the absolute XYZ values
    n_samples, timesteps, n_features = y_relative.shape
    y_absolute = np.zeros((n_samples, timesteps, n_features))

    # Set the first timestep to the initial absolute XYZ values
    y_absolute[:, 0, :] = initial_xyz

    # Rebuild the absolute XYZ values by accumulating the relative changes
    for t in range(1, timesteps):
        y_absolute[:, t, :] = y_absolute[:, t-1, :] + y_relative[:, t, :]

    return y_absolute

# %%
print(f"min/max X_train[:, :, -3]: {X_train[:, :, -3].min()}/{X_train[:, :, -3].max()}")
print(f"min/max X_train[:, :, -2]: {X_train[:, :, -2].min()}/{X_train[:, :, -2].max()}")
print(f"min/max X_train[:, :, -1]: {X_train[:, :, -1].min()}/{X_train[:, :, -1].max()}")

X_train_rel = calculate_relative_change_X(X_train)
X_test_rel = calculate_relative_change_X(X_test)
X_val_rel   = calculate_relative_change_X(X_val)

print(f"min/max X_train[:, :, -3]: {X_train_rel[:, :, -3].min()}/{X_train_rel[:, :, -3].max()}")
print(f"min/max X_train[:, :, -2]: {X_train_rel[:, :, -2].min()}/{X_train_rel[:, :, -2].max()}")
print(f"min/max X_train[:, :, -1]: {X_train_rel[:, :, -1].min()}/{X_train_rel[:, :, -1].max()}")

print(f"min/max y_train[:, :, -3]: {y_train[:, :, -3].min()}/{y_train[:, :, -3].max()}")
print(f"min/max y_train[:, :, -2]: {y_train[:, :, -2].min()}/{y_train[:, :, -2].max()}")
print(f"min/max y_train[:, :, -1]: {y_train[:, :, -1].min()}/{y_train[:, :, -1].max()}")

y_train_rel = calculate_relative_change_y(y_train)
y_test_rel = calculate_relative_change_y(y_test)
y_val_rel  = calculate_relative_change_y(y_val)

print(f"min/max y_train[:, :, -3]: {y_train_rel[:, :, -3].min()}/{y_train_rel[:, :, -3].max()}")
print(f"min/max y_train[:, :, -2]: {y_train_rel[:, :, -2].min()}/{y_train_rel[:, :, -2].max()}")
print(f"min/max y_train[:, :, -1]: {y_train_rel[:, :, -1].min()}/{y_train_rel[:, :, -1].max()}")
# Out:
# min/max X_train[:, :, -3]: 55.897/464.892
# min/max X_train[:, :, -2]: -488.226/575.557
# min/max X_train[:, :, -1]: 1178.524/1577.81
# min/max X_train[:, :, -3]: -6.581000000000017/12.510999999999967
# min/max X_train[:, :, -2]: -6.209999999999999/5.605000000000018
# min/max X_train[:, :, -1]: -13.857999999999947/0.65300000000002
# min/max y_train[:, :, -3]: 11.751/1979.768
# min/max y_train[:, :, -2]: -649.235/856.436
# min/max y_train[:, :, -1]: 909.385/1624.29
# min/max y_train[:, :, -3]: -6.73599999999999/18.153999999999996
# min/max y_train[:, :, -2]: -6.425000000000011/5.877999999999986
# min/max y_train[:, :, -1]: -18.007000000000062/14.666000000000167

# %% [markdown]
# ## Normalization preprocessing related

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def feature_wise_normalization(array):
    # Normalize each feature across all samples and timesteps
    n_samples, n_timesteps, n_features = array.shape
    scalers = []
    array_normalized = array.copy()
    
    for feature in range(n_features):
        scaler = MinMaxScaler(feature_range=(-1, 1))
        array_reshaped = array[:, :, feature].reshape(-1, 1)  # Flatten to 2D (n_samples * n_timesteps, 1)
        array_normalized[:, :, feature] = scaler.fit_transform(array_reshaped).reshape(n_samples, n_timesteps)
        scalers.append(scaler)
    
    return array_normalized, scalers

def transform_feature_wise_data(array, scalers):
    n_samples, n_timesteps, n_features = array.shape
    array_normalized = array.copy()

    for feature in range(n_features):
        scaler = scalers[feature]
        array_reshaped = array[:, :, feature].reshape(-1, 1)  # Flatten to 2D (n_samples * n_timesteps, 1)
        array_normalized[:, :, feature] = scaler.transform(array_reshaped).reshape(n_samples, n_timesteps)
    
    return array_normalized

def inverse_transform_feature_wise_data(array_normalized, scalers):
    n_samples, n_timesteps, n_features = array_normalized.shape
    array = array_normalized.copy()

    for feature in range(n_features):
        scaler = scalers[feature]
        array_reshaped = array_normalized[:, :, feature].reshape(-1, 1)  # Flatten to 2D (n_samples * n_timesteps, 1)
        array[:, :, feature] = scaler.inverse_transform(array_reshaped).reshape(n_samples, n_timesteps)
    
    return array


def normalization_across_time(array):
    # Normalize each feature over all time steps
    n_samples, n_timesteps, n_features = array.shape
    array_flat = array.reshape(-1, n_features)  # Flattening to (711*75, 11)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    array_flat_normalized = scaler.fit_transform(array_flat)
    array_normalized = array_flat_normalized.reshape(n_samples, n_timesteps, n_features)
    return array_normalized, scaler

def transform_data(array, scaler):
    n_samples, n_timesteps, n_features = array.shape
    array_flat = array.reshape(-1, n_features)  # Flattening to (number_of_samples*number_of_timesteps, number_of_features)
    array_flat_normalized = scaler.transform(array_flat)
    array_normalized = array_flat_normalized.reshape(n_samples, n_timesteps, n_features)
    return array_normalized

def inverse_transform_data(array_normalized, scaler):
    n_samples, n_timesteps, n_features = array_normalized.shape
    array_flat_normalized = array_normalized.reshape(-1, n_features)  # Flatten to (n_samples * n_timesteps, n_features)
    array_flat = scaler.inverse_transform(array_flat_normalized)  # Inverse transform
    array = array_flat.reshape(n_samples, n_timesteps, n_features)  # Reshape back to (n_samples, n_timesteps, n_features)
    return array

# %%
X_train_scaled, x_scaler = feature_wise_normalization(X_train_rel)
X_val_scaled = transform_feature_wise_data(X_val_rel, x_scaler)
X_test_scaled = transform_feature_wise_data(X_test_rel, x_scaler)

# %%
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\\x_scaler.save"
joblib.dump(x_scaler, scaler_filename)
# Out:
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\\x_scaler.save']

# %%
# Scaling test values
print(y_train.shape)
y_train_scaled, y_scaler = feature_wise_normalization(y_train_rel)
y_val_scaled = transform_feature_wise_data(y_val_rel, y_scaler)
y_test_scaled = transform_feature_wise_data(y_test_rel, y_scaler)
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\\y_scaler.save"
joblib.dump(y_scaler, scaler_filename)
# Out:
# (711, 125, 3)
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\\y_scaler.save']

# %% [markdown]
# # Training

# %%
X_train_final, y_train_final = X_train_scaled, y_train_scaled
X_val_final, y_val_final = X_val_scaled, y_val_scaled
X_test_final, y_test_final = X_test_scaled, y_test_scaled

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

outpunum = y_train.shape[-1]

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, activation="relu", return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, activation="relu", return_sequences=True))
#model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128, return_sequences=True))  # Third LSTM layer
model.add(LSTM(64, activation="relu"))

#model.add(Dropout(0.2))  # Dropout for regularization
#model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(32, activation="relu"))  # Dense layer with L2 regularization
model.add(Dense(next_steps * outpunum, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, outpunum)))  # Reshape to match the target output shape (10, outpunum)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 75, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 375)            │        12,375 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 125, 3)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,967 (808.46 KB)
#  Trainable params: 206,967 (808.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(f"X_train_scaled.shape: {X_train_final.shape} y_train_scaled.shape: {y_train_final.shape}")
# Out:
# X_train_scaled.shape: (711, 75, 11) y_train_scaled.shape: (711, 125, 3)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

def warmup_schedule(epoch, lr):
    warmup_epochs = 30
    max_lr = 0.0001
    if epoch < warmup_epochs:
        return lr + (max_lr / warmup_epochs)
    return max_lr

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\\model12.keras", save_best_only=True)

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(warmup_schedule)

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.000001), metrics=[RootMeanSquaredError()])

history = model.fit(X_train_final, y_train_final, validation_data=(X_val_final, y_val_final), 
          epochs=100000, 
          callbacks=[cp, 
                     es,
                     lr_scheduler
                     ])
# Out:
# Epoch 1/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - loss: 0.1041 - root_mean_squared_error: 0.3226 - val_loss: 0.1051 - val_root_mean_squared_error: 0.3242 - learning_rate: 4.3333e-06
# Epoch 2/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1042 - root_mean_squared_error: 0.3228 - val_loss: 0.1049 - val_root_mean_squared_error: 0.3240 - learning_rate: 7.6667e-06
# Epoch 3/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1036 - root_mean_squared_error: 0.3218 - val_loss: 0.1047 - val_root_mean_squared_error: 0.3236 - learning_rate: 1.1000e-05
# Epoch 4/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1031 - root_mean_squared_error: 0.3211 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3232 - learning_rate: 1.4333e-05
# Epoch 5/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1032 - root_mean_squared_error: 0.3212 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3226 - learning_rate: 1.7667e-05
# Epoch 6/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1042 - root_mean_squared_error: 0.3227 - val_loss: 0.1035 - val_root_mean_squared_error: 0.3217 - learning_rate: 2.1000e-05
# Epoch 7/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1012 - root_mean_squared_error: 0.3181 - val_loss: 0.1023 - val_root_mean_squared_error: 0.3199 - learning_rate: 2.4333e-05
# Epoch 8/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1006 - root_mean_squared_error: 0.3172 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3162 - learning_rate: 2.7667e-05
# Epoch 9/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0973 - root_mean_squared_error: 0.3120 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3099 - learning_rate: 3.1000e-05
# Epoch 10/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0938 - root_mean_squared_error: 0.3062 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3026 - learning_rate: 3.4333e-05
# Epoch 11/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0884 - root_mean_squared_error: 0.2972 - val_loss: 0.0868 - val_root_mean_squared_error: 0.2946 - learning_rate: 3.7667e-05
# Epoch 12/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0862 - root_mean_squared_error: 0.2936 - val_loss: 0.0817 - val_root_mean_squared_error: 0.2859 - learning_rate: 4.1000e-05
# Epoch 13/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0798 - root_mean_squared_error: 0.2825 - val_loss: 0.0765 - val_root_mean_squared_error: 0.2766 - learning_rate: 4.4333e-05
# Epoch 14/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0740 - root_mean_squared_error: 0.2721 - val_loss: 0.0714 - val_root_mean_squared_error: 0.2673 - learning_rate: 4.7667e-05
# Epoch 15/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2586 - learning_rate: 5.1000e-05
# Epoch 16/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0647 - root_mean_squared_error: 0.2544 - val_loss: 0.0627 - val_root_mean_squared_error: 0.2504 - learning_rate: 5.4333e-05
# Epoch 17/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458 - val_loss: 0.0593 - val_root_mean_squared_error: 0.2435 - learning_rate: 5.7667e-05
# Epoch 18/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0575 - root_mean_squared_error: 0.2397 - val_loss: 0.0564 - val_root_mean_squared_error: 0.2375 - learning_rate: 6.1000e-05
# Epoch 19/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0549 - root_mean_squared_error: 0.2344 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2325 - learning_rate: 6.4333e-05
# Epoch 20/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289 - learning_rate: 6.7667e-05
# Epoch 21/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0508 - val_root_mean_squared_error: 0.2254 - learning_rate: 7.1000e-05
# Epoch 22/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0492 - root_mean_squared_error: 0.2217 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2229 - learning_rate: 7.4333e-05
# Epoch 23/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0497 - root_mean_squared_error: 0.2229 - val_loss: 0.0489 - val_root_mean_squared_error: 0.2212 - learning_rate: 7.7667e-05
# Epoch 24/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0466 - root_mean_squared_error: 0.2159 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2195 - learning_rate: 8.1000e-05
# Epoch 25/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0485 - root_mean_squared_error: 0.2202 - val_loss: 0.0475 - val_root_mean_squared_error: 0.2180 - learning_rate: 8.4333e-05
# Epoch 26/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0475 - root_mean_squared_error: 0.2179 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164 - learning_rate: 8.7667e-05
# Epoch 27/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0464 - root_mean_squared_error: 0.2154 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150 - learning_rate: 9.1000e-05
# Epoch 28/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0451 - root_mean_squared_error: 0.2124 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2148 - learning_rate: 9.4333e-05
# Epoch 29/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0448 - root_mean_squared_error: 0.2116 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114 - learning_rate: 9.7667e-05
# Epoch 30/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0437 - root_mean_squared_error: 0.2091 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2087 - learning_rate: 1.0100e-04
# Epoch 31/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0414 - root_mean_squared_error: 0.2035 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2060 - learning_rate: 1.0000e-04
# Epoch 32/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035 - learning_rate: 1.0000e-04
# Epoch 33/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0394 - root_mean_squared_error: 0.1986 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2002 - learning_rate: 1.0000e-04
# Epoch 34/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0375 - root_mean_squared_error: 0.1936 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1958 - learning_rate: 1.0000e-04
# Epoch 35/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0370 - root_mean_squared_error: 0.1924 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1942 - learning_rate: 1.0000e-04
# Epoch 36/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0338 - root_mean_squared_error: 0.1839 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892 - learning_rate: 1.0000e-04
# Epoch 37/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0335 - root_mean_squared_error: 0.1831 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1869 - learning_rate: 1.0000e-04
# Epoch 38/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854 - learning_rate: 1.0000e-04
# Epoch 39/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1813 - learning_rate: 1.0000e-04
# Epoch 40/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0308 - root_mean_squared_error: 0.1754 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1765 - learning_rate: 1.0000e-04
# Epoch 41/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0300 - root_mean_squared_error: 0.1731 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1755 - learning_rate: 1.0000e-04
# Epoch 42/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1726 - learning_rate: 1.0000e-04
# Epoch 43/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709 - learning_rate: 1.0000e-04
# Epoch 44/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703 - learning_rate: 1.0000e-04
# Epoch 45/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640 - learning_rate: 1.0000e-04
# Epoch 46/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0248 - root_mean_squared_error: 0.1573 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1626 - learning_rate: 1.0000e-04
# Epoch 47/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1623 - learning_rate: 1.0000e-04
# Epoch 48/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0241 - root_mean_squared_error: 0.1554 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1586 - learning_rate: 1.0000e-04
# Epoch 49/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1570 - learning_rate: 1.0000e-04
# Epoch 50/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548 - learning_rate: 1.0000e-04
# Epoch 51/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530 - learning_rate: 1.0000e-04
# Epoch 52/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1531 - learning_rate: 1.0000e-04
# Epoch 53/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497 - learning_rate: 1.0000e-04
# Epoch 54/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1503 - learning_rate: 1.0000e-04
# Epoch 55/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486 - learning_rate: 1.0000e-04
# Epoch 56/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473 - learning_rate: 1.0000e-04
# Epoch 57/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1468 - learning_rate: 1.0000e-04
# Epoch 58/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455 - learning_rate: 1.0000e-04
# Epoch 59/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468 - learning_rate: 1.0000e-04
# Epoch 60/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1450 - learning_rate: 1.0000e-04
# Epoch 61/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433 - learning_rate: 1.0000e-04
# Epoch 62/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1420 - learning_rate: 1.0000e-04
# Epoch 63/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1418 - learning_rate: 1.0000e-04
# Epoch 64/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1409 - learning_rate: 1.0000e-04
# Epoch 65/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1405 - learning_rate: 1.0000e-04
# Epoch 66/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389 - learning_rate: 1.0000e-04
# Epoch 67/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1385 - learning_rate: 1.0000e-04
# Epoch 68/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377 - learning_rate: 1.0000e-04
# Epoch 69/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372 - learning_rate: 1.0000e-04
# Epoch 70/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359 - learning_rate: 1.0000e-04
# Epoch 71/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1355 - learning_rate: 1.0000e-04
# Epoch 72/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347 - learning_rate: 1.0000e-04
# Epoch 73/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1349 - learning_rate: 1.0000e-04
# Epoch 74/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343 - learning_rate: 1.0000e-04
# Epoch 75/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1337 - learning_rate: 1.0000e-04
# Epoch 76/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1321 - learning_rate: 1.0000e-04
# Epoch 77/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320 - learning_rate: 1.0000e-04
# Epoch 78/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320 - learning_rate: 1.0000e-04
# Epoch 79/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311 - learning_rate: 1.0000e-04
# Epoch 80/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310 - learning_rate: 1.0000e-04
# Epoch 81/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1304 - learning_rate: 1.0000e-04
# Epoch 82/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - learning_rate: 1.0000e-04
# Epoch 83/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1294 - learning_rate: 1.0000e-04
# Epoch 84/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306 - learning_rate: 1.0000e-04
# Epoch 85/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284 - learning_rate: 1.0000e-04
# Epoch 86/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276 - learning_rate: 1.0000e-04
# Epoch 87/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273 - learning_rate: 1.0000e-04
# Epoch 88/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1271 - learning_rate: 1.0000e-04
# Epoch 89/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1267 - learning_rate: 1.0000e-04
# Epoch 90/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1267 - learning_rate: 1.0000e-04
# Epoch 91/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258 - learning_rate: 1.0000e-04
# Epoch 92/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251 - learning_rate: 1.0000e-04
# Epoch 93/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1255 - learning_rate: 1.0000e-04
# Epoch 94/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263 - learning_rate: 1.0000e-04
# Epoch 95/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245 - learning_rate: 1.0000e-04
# Epoch 96/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244 - learning_rate: 1.0000e-04
# Epoch 97/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1237 - learning_rate: 1.0000e-04
# Epoch 98/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238 - learning_rate: 1.0000e-04
# Epoch 99/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1239 - learning_rate: 1.0000e-04
# Epoch 100/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1236 - learning_rate: 1.0000e-04
# Epoch 101/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - learning_rate: 1.0000e-04
# Epoch 102/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216 - learning_rate: 1.0000e-04
# Epoch 103/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220 - learning_rate: 1.0000e-04
# Epoch 104/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207 - learning_rate: 1.0000e-04
# Epoch 105/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210 - learning_rate: 1.0000e-04
# Epoch 106/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195 - learning_rate: 1.0000e-04
# Epoch 107/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198 - learning_rate: 1.0000e-04
# Epoch 108/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201 - learning_rate: 1.0000e-04
# Epoch 109/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191 - learning_rate: 1.0000e-04
# Epoch 110/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1190 - learning_rate: 1.0000e-04
# Epoch 111/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180 - learning_rate: 1.0000e-04
# Epoch 112/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179 - learning_rate: 1.0000e-04
# Epoch 113/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166 - learning_rate: 1.0000e-04
# Epoch 114/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179 - learning_rate: 1.0000e-04
# Epoch 115/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192 - learning_rate: 1.0000e-04
# Epoch 116/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167 - learning_rate: 1.0000e-04
# Epoch 117/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156 - learning_rate: 1.0000e-04
# Epoch 118/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159 - learning_rate: 1.0000e-04
# Epoch 119/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152 - learning_rate: 1.0000e-04
# Epoch 120/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145 - learning_rate: 1.0000e-04
# Epoch 121/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0114 - root_mean_squared_error: 0.1065 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158 - learning_rate: 1.0000e-04
# Epoch 122/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156 - learning_rate: 1.0000e-04
# Epoch 123/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0115 - root_mean_squared_error: 0.1070 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134 - learning_rate: 1.0000e-04
# Epoch 124/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138 - learning_rate: 1.0000e-04
# Epoch 125/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145 - learning_rate: 1.0000e-04
# Epoch 126/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136 - learning_rate: 1.0000e-04
# Epoch 127/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133 - learning_rate: 1.0000e-04
# Epoch 128/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137 - learning_rate: 1.0000e-04
# Epoch 129/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124 - learning_rate: 1.0000e-04
# Epoch 130/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.0106 - root_mean_squared_error: 0.1032 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115 - learning_rate: 1.0000e-04
# Epoch 131/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124 - learning_rate: 1.0000e-04
# Epoch 132/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104 - learning_rate: 1.0000e-04
# Epoch 133/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113 - learning_rate: 1.0000e-04
# Epoch 134/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109 - learning_rate: 1.0000e-04
# Epoch 135/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097 - learning_rate: 1.0000e-04
# Epoch 136/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1120 - learning_rate: 1.0000e-04
# Epoch 137/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111 - learning_rate: 1.0000e-04
# Epoch 138/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122 - learning_rate: 1.0000e-04
# Epoch 139/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095 - learning_rate: 1.0000e-04
# Epoch 140/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0096 - root_mean_squared_error: 0.0977 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086 - learning_rate: 1.0000e-04
# Epoch 141/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085 - learning_rate: 1.0000e-04
# Epoch 142/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0096 - root_mean_squared_error: 0.0982 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097 - learning_rate: 1.0000e-04
# Epoch 143/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072 - learning_rate: 1.0000e-04
# Epoch 144/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080 - learning_rate: 1.0000e-04
# Epoch 145/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066 - learning_rate: 1.0000e-04
# Epoch 146/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063 - learning_rate: 1.0000e-04
# Epoch 147/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083 - learning_rate: 1.0000e-04
# Epoch 148/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054 - learning_rate: 1.0000e-04
# Epoch 149/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063 - learning_rate: 1.0000e-04
# Epoch 150/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1069 - learning_rate: 1.0000e-04
# Epoch 151/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063 - learning_rate: 1.0000e-04
# Epoch 152/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045 - learning_rate: 1.0000e-04
# Epoch 153/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056 - learning_rate: 1.0000e-04
# Epoch 154/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042 - learning_rate: 1.0000e-04
# Epoch 155/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0090 - root_mean_squared_error: 0.0946 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050 - learning_rate: 1.0000e-04
# Epoch 156/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1056 - learning_rate: 1.0000e-04
# Epoch 157/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043 - learning_rate: 1.0000e-04
# Epoch 158/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037 - learning_rate: 1.0000e-04
# Epoch 159/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040 - learning_rate: 1.0000e-04
# Epoch 160/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030 - learning_rate: 1.0000e-04
# Epoch 161/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017 - learning_rate: 1.0000e-04
# Epoch 162/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040 - learning_rate: 1.0000e-04
# Epoch 163/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054 - learning_rate: 1.0000e-04
# Epoch 164/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1026 - learning_rate: 1.0000e-04
# Epoch 165/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014 - learning_rate: 1.0000e-04
# Epoch 166/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023 - learning_rate: 1.0000e-04
# Epoch 167/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019 - learning_rate: 1.0000e-04
# Epoch 168/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004 - learning_rate: 1.0000e-04
# Epoch 169/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002 - learning_rate: 1.0000e-04
# Epoch 170/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003 - learning_rate: 1.0000e-04
# Epoch 171/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003 - learning_rate: 1.0000e-04
# Epoch 172/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007 - learning_rate: 1.0000e-04
# Epoch 173/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008 - learning_rate: 1.0000e-04
# Epoch 174/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011 - learning_rate: 1.0000e-04
# Epoch 175/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021 - learning_rate: 1.0000e-04
# Epoch 176/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011 - learning_rate: 1.0000e-04
# Epoch 177/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016 - learning_rate: 1.0000e-04
# Epoch 178/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986 - learning_rate: 1.0000e-04
# Epoch 179/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994 - learning_rate: 1.0000e-04
# Epoch 180/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000 - learning_rate: 1.0000e-04
# Epoch 181/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0081 - root_mean_squared_error: 0.0897 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034 - learning_rate: 1.0000e-04
# Epoch 182/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000 - learning_rate: 1.0000e-04
# Epoch 183/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993 - learning_rate: 1.0000e-04
# Epoch 184/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006 - learning_rate: 1.0000e-04
# Epoch 185/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994 - learning_rate: 1.0000e-04
# Epoch 186/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006 - learning_rate: 1.0000e-04
# Epoch 187/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988 - learning_rate: 1.0000e-04
# Epoch 188/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996 - learning_rate: 1.0000e-04

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test_final, y_test_final)
print(f'Test Loss: {test_loss}')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0119 - root_mean_squared_error: 0.1088
# Test Loss: [0.011475099250674248, 0.10712189227342606]

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test5\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 4))
    
    # Plot the true and predicted values on the first subplot
    axs[0].plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    axs[0].plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    axs[0].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[0].set_title(f'True vs Predicted Values for {coordinate_name}')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel(f'{coordinate_name} Value')
    axs[0].legend()
    
    # Example of another plot (e.g., residuals or difference between predicted and true values)
    original_timeseries = np.array(row[coordinate_name])
    axs[1].plot(range(len(original_timeseries)), original_timeseries, label="Timeseries")
    axs[1].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[1].set_title(f'Original {coordinate_name} trajectory')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel(f'{coordinate_name} Value')
    axs[1].legend()

        # Extract the initial sequence from the DataFrame

# %%
# Assuming model is trained and X_train, y_train are defined
def scale_with(sequence, y_scaler):
    print(f"Shape: {sequence.shape}")
    return y_scaler.transform(sequence)

# %%
# One coordinate prediction
sample_index = 4

predictions_scaled = model.predict(X_test_scaled)

if y_train.shape[-1] == 1:
    #predictions_scaled = model.predict(X_test_scaled)
    #print(predictions_scaled.shape)
    #print(predictions_scaled[0])
    initial_seq = X_test[sample_index, :, -2]
    print(f"initial seq shape: {initial_seq.shape}")
    initial_seq = initial_seq.reshape((75, 1))
    print(f"initial seq shape: {initial_seq.shape}")
    initial_seq_scaled = scale_with(initial_seq, y_scaler)
    true_values = y_test_scaled[sample_index, :, :]  # True values
    predicted_values = predictions_scaled[sample_index, :, :]  # Predicted values
    # # Plot for Head_X_Coordinate
    plot_predictions3(initial_seq_scaled[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_Y_Coordinate', test_df.iloc[sample_index])
else:
    X_test_inv_scaled = inverse_transform_feature_wise_data(X_test_scaled, x_scaler)
    X_test_inv_rel = revert_relative_change_y(X_test_inv_scaled, X_test[sample_index][0])

    y_test_inv_scaled = inverse_transform_feature_wise_data(y_test_scaled, y_scaler)
    y_test_inv_rel = revert_relative_change_y(y_test_inv_scaled, y_test[sample_index][0])

    prediction_inv_scaled = inverse_transform_feature_wise_data(predictions_scaled, y_scaler)
    predictions_inv_rel = revert_relative_change_y(prediction_inv_scaled, y_test[sample_index][0])

    plot_predictions3(X_test_inv_rel[sample_index, :, -3], y_test_inv_rel[sample_index, :, 0], predictions_inv_rel[sample_index, :, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])
    # # # # Plot for Head_Y_Coordinate
    plot_predictions3(X_test_inv_rel[sample_index, :, -2], y_test_inv_rel[sample_index, :, 1], predictions_inv_rel[sample_index, :, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])
    # # # # Plot for Head_Z_Coordinate
    plot_predictions3(X_test_inv_rel[sample_index, :, -1], y_test_inv_rel[sample_index, :, 2], predictions_inv_rel[sample_index, :, 2], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step
