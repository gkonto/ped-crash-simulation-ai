# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - η διαφορα του με το 5_XYZ_only_norm ειναι οτι to normalization εχει boundaries για καθε row.
# - Σε αυτο θα βρω τα συνολικα xminmax, yminmax, zminmax και θα χρησιμοποιησω αυτα.

# %% [markdown]
# # Check 5_XYZ_only_norm2_1.
#
# ## I used tanh and wanted scaling [-1, 1]

# %%
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows:   0%|          | 0/1186 [00:00<?, ?row/s]
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 5486.14row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0              220.000           -288.045           1575.416
# 1              220.000           -288.045           1575.411
# 2              220.000           -288.045           1575.396
# 3              220.000           -288.045           1575.391
# 4              220.000           -288.045           1575.377
# ..                 ...                ...                ...
# 296           2724.310           -409.036            947.462
# 297           2738.592           -410.063            948.136
# 298           2752.923           -411.087            948.848
# 299           2767.306           -412.109            949.599
# 300           2781.744           -413.132            950.386
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
train_df.shape
# Out:
# (711, 11)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])
    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 125

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

# %%
from pprint import pprint
print(train_df.iloc[0]["Head_Y_Coordinate"][:75])
print(X_train[0, :, -2])
# Out:
# [243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.637, 243.639, 243.643, 243.651, 243.662, 243.679, 243.694, 243.702, 243.704, 243.699, 243.682, 243.651, 243.607, 243.552, 243.486, 243.409, 243.325, 243.237, 243.152, 243.072, 243.004, 242.955, 242.929, 242.929, 242.953, 242.992, 243.033, 243.06, 243.06, 243.023, 242.939, 242.804, 242.618, 242.381, 242.092, 241.754, 241.372, 240.944, 240.475, 239.959, 239.396, 238.784, 238.13, 237.442, 236.723, 235.978, 235.218, 234.448, 233.674, 232.897, 232.124, 231.357, 230.593, 229.832, 229.068, 228.303, 227.532, 226.755]
# [243.637 243.637 243.637 243.637 243.637 243.637 243.637 243.637 243.637
#  243.637 243.637 243.637 243.637 243.637 243.637 243.637 243.637 243.637
#  243.639 243.643 243.651 243.662 243.679 243.694 243.702 243.704 243.699
#  243.682 243.651 243.607 243.552 243.486 243.409 243.325 243.237 243.152
#  243.072 243.004 242.955 242.929 242.929 242.953 242.992 243.033 243.06
#  243.06  243.023 242.939 242.804 242.618 242.381 242.092 241.754 241.372
#  240.944 240.475 239.959 239.396 238.784 238.13  237.442 236.723 235.978
#  235.218 234.448 233.674 232.897 232.124 231.357 230.593 229.832 229.068
#  228.303 227.532 226.755]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Reshape to 2D (flatten the last dimension)

X_train_reshaped = X_train.reshape(-1, X_train.shape[2])

# Apply the scaler (you can also use MinMaxScaler here)
x_scaler = MinMaxScaler(feature_range=(-1, 1))
X_train_scaled = x_scaler.fit_transform(X_train_reshaped)
# Reshape back to 3D (711, 75, 11)
X_train_scaled = X_train_scaled.reshape(X_train.shape)
# Now X_train_scaled is normalized
X_train_scaled.shape
# Out:
# (711, 75, 11)

# %%
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_2\\x_scaler.save"
joblib.dump(x_scaler, scaler_filename)
# Out:
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_2\\x_scaler.save']

# %%
X_val_reshaped = X_val.reshape(-1, X_val.shape[2])
X_val_scaled = x_scaler.transform(X_val_reshaped)
X_val_scaled = X_val_scaled.reshape(X_val.shape)

X_test_reshaped = X_test.reshape(-1, X_test.shape[2])
X_test_scaled = x_scaler.transform(X_test_reshaped)
X_test_scaled = X_test_scaled.reshape(X_test.shape)

# %%
# Scaling test values

y_train_reshaped = y_train.reshape(-1, y_train.shape[2])

# Apply the scaler (you can also use MinMaxScaler here)
y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_train_scaled = y_scaler.fit_transform(y_train_reshaped)
# Reshape back to 3D (711, 75, 11)
y_train_scaled = y_train_scaled.reshape(y_train.shape)
# Now X_train_scaled is normalized

import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_2\\y_scaler.save"
joblib.dump(y_scaler, scaler_filename)

y_val_reshaped = y_val.reshape(-1, y_val.shape[2])
y_val_scaled = y_scaler.transform(y_val_reshaped)
y_val_scaled = y_val_scaled.reshape(y_val.shape)

y_test_reshaped = y_test.reshape(-1, y_test.shape[2])
y_test_scaled = y_scaler.transform(y_test_reshaped)
y_test_scaled = y_test_scaled.reshape(y_test.shape)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
#model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
#model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 3, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 75, 64)         │        19,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 375)            │        12,375 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 125, 3)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,775 (526.46 KB)
#  Trainable params: 134,775 (526.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_2\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train_scaled, y_train_scaled, validation_data=(X_val_scaled, y_val_scaled), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - loss: 0.2954 - root_mean_squared_error: 0.4957 - val_loss: 0.3009 - val_root_mean_squared_error: 0.5026
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.2921 - root_mean_squared_error: 0.4940 - val_loss: 0.2864 - val_root_mean_squared_error: 0.4895
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.2644 - root_mean_squared_error: 0.4668 - val_loss: 0.2576 - val_root_mean_squared_error: 0.4606
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.2353 - root_mean_squared_error: 0.4360 - val_loss: 0.2222 - val_root_mean_squared_error: 0.4218
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.2059 - root_mean_squared_error: 0.4023 - val_loss: 0.1910 - val_root_mean_squared_error: 0.3845
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1742 - root_mean_squared_error: 0.3623 - val_loss: 0.1644 - val_root_mean_squared_error: 0.3497
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1486 - root_mean_squared_error: 0.3267 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3203
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1331 - root_mean_squared_error: 0.3036 - val_loss: 0.1270 - val_root_mean_squared_error: 0.2947
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.1189 - root_mean_squared_error: 0.2811 - val_loss: 0.1145 - val_root_mean_squared_error: 0.2743
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.1072 - root_mean_squared_error: 0.2611 - val_loss: 0.1052 - val_root_mean_squared_error: 0.2586
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 0.1008 - root_mean_squared_error: 0.2503 - val_loss: 0.0974 - val_root_mean_squared_error: 0.2448
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0922 - root_mean_squared_error: 0.2345 - val_loss: 0.0915 - val_root_mean_squared_error: 0.2343
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0894 - root_mean_squared_error: 0.2301 - val_loss: 0.0871 - val_root_mean_squared_error: 0.2268
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0822 - root_mean_squared_error: 0.2161 - val_loss: 0.0832 - val_root_mean_squared_error: 0.2199
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - loss: 0.0796 - root_mean_squared_error: 0.2119 - val_loss: 0.0796 - val_root_mean_squared_error: 0.2136
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0769 - root_mean_squared_error: 0.2075 - val_loss: 0.0767 - val_root_mean_squared_error: 0.2086
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0750 - root_mean_squared_error: 0.2050 - val_loss: 0.0741 - val_root_mean_squared_error: 0.2044
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0690 - root_mean_squared_error: 0.1920 - val_loss: 0.0722 - val_root_mean_squared_error: 0.2018
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0671 - root_mean_squared_error: 0.1891 - val_loss: 0.0699 - val_root_mean_squared_error: 0.1981
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0657 - root_mean_squared_error: 0.1877 - val_loss: 0.0683 - val_root_mean_squared_error: 0.1960
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0642 - root_mean_squared_error: 0.1858 - val_loss: 0.0662 - val_root_mean_squared_error: 0.1925
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0625 - root_mean_squared_error: 0.1831 - val_loss: 0.0648 - val_root_mean_squared_error: 0.1909
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0608 - root_mean_squared_error: 0.1804 - val_loss: 0.0628 - val_root_mean_squared_error: 0.1874
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0576 - root_mean_squared_error: 0.1736 - val_loss: 0.0614 - val_root_mean_squared_error: 0.1857
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0587 - root_mean_squared_error: 0.1786 - val_loss: 0.0599 - val_root_mean_squared_error: 0.1835
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0562 - root_mean_squared_error: 0.1733 - val_loss: 0.0581 - val_root_mean_squared_error: 0.1803
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0541 - root_mean_squared_error: 0.1692 - val_loss: 0.0576 - val_root_mean_squared_error: 0.1806
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0530 - root_mean_squared_error: 0.1679 - val_loss: 0.0555 - val_root_mean_squared_error: 0.1764
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0513 - root_mean_squared_error: 0.1646 - val_loss: 0.0540 - val_root_mean_squared_error: 0.1738
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0509 - root_mean_squared_error: 0.1652 - val_loss: 0.0525 - val_root_mean_squared_error: 0.1712
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0484 - root_mean_squared_error: 0.1592 - val_loss: 0.0509 - val_root_mean_squared_error: 0.1680
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0478 - root_mean_squared_error: 0.1589 - val_loss: 0.0502 - val_root_mean_squared_error: 0.1675
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0470 - root_mean_squared_error: 0.1582 - val_loss: 0.0495 - val_root_mean_squared_error: 0.1669
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0448 - root_mean_squared_error: 0.1526 - val_loss: 0.0484 - val_root_mean_squared_error: 0.1653
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0438 - root_mean_squared_error: 0.1513 - val_loss: 0.0468 - val_root_mean_squared_error: 0.1618
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0423 - root_mean_squared_error: 0.1477 - val_loss: 0.0459 - val_root_mean_squared_error: 0.1606
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0424 - root_mean_squared_error: 0.1498 - val_loss: 0.0449 - val_root_mean_squared_error: 0.1589
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0414 - root_mean_squared_error: 0.1479 - val_loss: 0.0437 - val_root_mean_squared_error: 0.1564
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0401 - root_mean_squared_error: 0.1448 - val_loss: 0.0426 - val_root_mean_squared_error: 0.1544
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0387 - root_mean_squared_error: 0.1414 - val_loss: 0.0418 - val_root_mean_squared_error: 0.1532
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0391 - root_mean_squared_error: 0.1443 - val_loss: 0.0413 - val_root_mean_squared_error: 0.1530
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0375 - root_mean_squared_error: 0.1404 - val_loss: 0.0402 - val_root_mean_squared_error: 0.1505
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0368 - root_mean_squared_error: 0.1393 - val_loss: 0.0406 - val_root_mean_squared_error: 0.1531
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0360 - root_mean_squared_error: 0.1378 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1485
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0347 - root_mean_squared_error: 0.1344 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1505
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0350 - root_mean_squared_error: 0.1368 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1466
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0346 - root_mean_squared_error: 0.1369 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1447
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0330 - root_mean_squared_error: 0.1320 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1430
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0324 - root_mean_squared_error: 0.1311 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1403
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0319 - root_mean_squared_error: 0.1307 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1397
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0314 - root_mean_squared_error: 0.1300 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1418
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0299 - root_mean_squared_error: 0.1249 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1381
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0303 - root_mean_squared_error: 0.1278 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1400
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0304 - root_mean_squared_error: 0.1297 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1368
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0289 - root_mean_squared_error: 0.1249 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1354
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0283 - root_mean_squared_error: 0.1234 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1334
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0282 - root_mean_squared_error: 0.1240 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1317
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0277 - root_mean_squared_error: 0.1230 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1309
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0271 - root_mean_squared_error: 0.1219 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1297
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0269 - root_mean_squared_error: 0.1218 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1297
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0259 - root_mean_squared_error: 0.1187 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1291
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0249 - root_mean_squared_error: 0.1155 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1270
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 0.0244 - root_mean_squared_error: 0.1144 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1251
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0243 - root_mean_squared_error: 0.1149 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1231
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0230 - root_mean_squared_error: 0.1104 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1223
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0232 - root_mean_squared_error: 0.1119 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1209
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0227 - root_mean_squared_error: 0.1108 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1195
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0215 - root_mean_squared_error: 0.1063 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1171
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0220 - root_mean_squared_error: 0.1093 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1197
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0220 - root_mean_squared_error: 0.1103 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1247
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0213 - root_mean_squared_error: 0.1081 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1156
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0205 - root_mean_squared_error: 0.1050 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1136
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0203 - root_mean_squared_error: 0.1049 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1135
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0198 - root_mean_squared_error: 0.1034 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1102
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0190 - root_mean_squared_error: 0.1002 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1081
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0194 - root_mean_squared_error: 0.1027 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1100
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0183 - root_mean_squared_error: 0.0985 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1069
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0184 - root_mean_squared_error: 0.0997 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1070
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0178 - root_mean_squared_error: 0.0974 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1064
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0177 - root_mean_squared_error: 0.0977 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1037
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0169 - root_mean_squared_error: 0.0940 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1039
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0172 - root_mean_squared_error: 0.0965 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1022
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0167 - root_mean_squared_error: 0.0947 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1013
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.0163 - root_mean_squared_error: 0.0931 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1019
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - loss: 0.0158 - root_mean_squared_error: 0.0912 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1031
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0164 - root_mean_squared_error: 0.0953 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1061
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 0.0166 - root_mean_squared_error: 0.0969 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1027
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0165 - root_mean_squared_error: 0.0969 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1073
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0155 - root_mean_squared_error: 0.0921 - val_loss: 0.0163 - val_root_mean_squared_error: 0.0969
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0150 - root_mean_squared_error: 0.0900 - val_loss: 0.0161 - val_root_mean_squared_error: 0.0968
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0147 - root_mean_squared_error: 0.0891 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0941
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0143 - root_mean_squared_error: 0.0876 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0940
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0137 - root_mean_squared_error: 0.0849 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0948
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0140 - root_mean_squared_error: 0.0872 - val_loss: 0.0149 - val_root_mean_squared_error: 0.0928
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0138 - root_mean_squared_error: 0.0864 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0924
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0133 - root_mean_squared_error: 0.0844 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0930
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0135 - root_mean_squared_error: 0.0862 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0917
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0132 - root_mean_squared_error: 0.0847 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0920
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0131 - root_mean_squared_error: 0.0848 - val_loss: 0.0141 - val_root_mean_squared_error: 0.0911
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0130 - root_mean_squared_error: 0.0848 - val_loss: 0.0139 - val_root_mean_squared_error: 0.0901
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0127 - root_mean_squared_error: 0.0833 - val_loss: 0.0141 - val_root_mean_squared_error: 0.0918
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0131 - root_mean_squared_error: 0.0862 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0908
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0127 - root_mean_squared_error: 0.0847 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0890
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 0.0122 - root_mean_squared_error: 0.0819 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0881
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0118 - root_mean_squared_error: 0.0802 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0881
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0118 - root_mean_squared_error: 0.0807 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0891
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0118 - root_mean_squared_error: 0.0813 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0882
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 179ms/step - loss: 0.0114 - root_mean_squared_error: 0.0792 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0879
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0119 - root_mean_squared_error: 0.0825 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0878
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0115 - root_mean_squared_error: 0.0806 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0870
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0111 - root_mean_squared_error: 0.0787 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0858
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0110 - root_mean_squared_error: 0.0785 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0846
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0108 - root_mean_squared_error: 0.0779 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0847
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0108 - root_mean_squared_error: 0.0778 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0852
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0106 - root_mean_squared_error: 0.0773 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0849
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0104 - root_mean_squared_error: 0.0764 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0847
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0104 - root_mean_squared_error: 0.0765 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0850
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0102 - root_mean_squared_error: 0.0760 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0874
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0106 - root_mean_squared_error: 0.0791 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0850
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0102 - root_mean_squared_error: 0.0765 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0842
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0102 - root_mean_squared_error: 0.0771 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0836
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0100 - root_mean_squared_error: 0.0762 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0825
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0100 - root_mean_squared_error: 0.0767 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0851
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0098 - root_mean_squared_error: 0.0759 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0834
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - loss: 0.0097 - root_mean_squared_error: 0.0751 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0817
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0095 - root_mean_squared_error: 0.0744 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0821
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0094 - root_mean_squared_error: 0.0741 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0821
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0093 - root_mean_squared_error: 0.0733 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0812
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0095 - root_mean_squared_error: 0.0750 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0815
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.0092 - root_mean_squared_error: 0.0738 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0806
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0092 - root_mean_squared_error: 0.0737 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0827
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0092 - root_mean_squared_error: 0.0741 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0808
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0096 - root_mean_squared_error: 0.0769 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0845
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0094 - root_mean_squared_error: 0.0761 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0807
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0090 - root_mean_squared_error: 0.0739 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0818
# Epoch 136/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0090 - root_mean_squared_error: 0.0737 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0796
# Epoch 137/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0086 - root_mean_squared_error: 0.0716 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0807
# Epoch 138/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.0085 - root_mean_squared_error: 0.0715 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0793
# Epoch 139/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0084 - root_mean_squared_error: 0.0705 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0796
# Epoch 140/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0083 - root_mean_squared_error: 0.0704 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0791
# Epoch 141/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0084 - root_mean_squared_error: 0.0711 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0798
# Epoch 142/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0087 - root_mean_squared_error: 0.0733 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0829
# Epoch 143/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0092 - root_mean_squared_error: 0.0773 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0824
# Epoch 144/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0086 - root_mean_squared_error: 0.0737 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0796
# Epoch 145/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0081 - root_mean_squared_error: 0.0706 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0785
# Epoch 146/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0080 - root_mean_squared_error: 0.0700 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0770
# Epoch 147/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0079 - root_mean_squared_error: 0.0690 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0773
# Epoch 148/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0078 - root_mean_squared_error: 0.0691 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0770
# Epoch 149/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0080 - root_mean_squared_error: 0.0701 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0761
# Epoch 150/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0075 - root_mean_squared_error: 0.0670 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0771
# Epoch 151/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0078 - root_mean_squared_error: 0.0697 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0776
# Epoch 152/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0077 - root_mean_squared_error: 0.0686 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0764
# Epoch 153/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0075 - root_mean_squared_error: 0.0679 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0764
# Epoch 154/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0076 - root_mean_squared_error: 0.0687 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0775
# Epoch 155/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0074 - root_mean_squared_error: 0.0673 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0773
# Epoch 156/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0077 - root_mean_squared_error: 0.0698 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0772
# Epoch 157/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0075 - root_mean_squared_error: 0.0682 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0762
# Epoch 158/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0074 - root_mean_squared_error: 0.0679 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0762
# Epoch 159/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0075 - root_mean_squared_error: 0.0688 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0776
# Epoch 160/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0078 - root_mean_squared_error: 0.0710 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0783
# Epoch 161/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0078 - root_mean_squared_error: 0.0718 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0822
# Epoch 162/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0088 - root_mean_squared_error: 0.0782 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0801
# Epoch 163/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0080 - root_mean_squared_error: 0.0730 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0778
# Epoch 164/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0077 - root_mean_squared_error: 0.0711 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0773
# Epoch 165/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0075 - root_mean_squared_error: 0.0703 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0806
# Epoch 166/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0076 - root_mean_squared_error: 0.0707 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0790
# Epoch 167/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0075 - root_mean_squared_error: 0.0708 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0781
# Epoch 168/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0074 - root_mean_squared_error: 0.0696 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0765
# Epoch 169/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0071 - root_mean_squared_error: 0.0677 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0771
# Epoch 170/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.0070 - root_mean_squared_error: 0.0670 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0748
# Epoch 171/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0071 - root_mean_squared_error: 0.0681 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0752
# Epoch 172/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.0068 - root_mean_squared_error: 0.0664 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0744
# Epoch 173/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.0067 - root_mean_squared_error: 0.0656 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0745
# Epoch 174/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0070 - root_mean_squared_error: 0.0676 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0740
# Epoch 175/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.0069 - root_mean_squared_error: 0.0669 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0746
# Epoch 176/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0069 - root_mean_squared_error: 0.0671 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0744
# Epoch 177/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.0066 - root_mean_squared_error: 0.0655 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0760
# Epoch 178/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0070 - root_mean_squared_error: 0.0684 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0768
# Epoch 179/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.0071 - root_mean_squared_error: 0.0694 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0753
# Epoch 180/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.0069 - root_mean_squared_error: 0.0678 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0753
# Epoch 181/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0068 - root_mean_squared_error: 0.0675 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0761
# Epoch 182/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0066 - root_mean_squared_error: 0.0661 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0751
# Epoch 183/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0069 - root_mean_squared_error: 0.0681 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0756
# Epoch 184/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0070 - root_mean_squared_error: 0.0694 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0746
# Epoch 185/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0065 - root_mean_squared_error: 0.0657 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0747
# Epoch 186/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0063 - root_mean_squared_error: 0.0641 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0745
# Epoch 187/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - loss: 0.0066 - root_mean_squared_error: 0.0662 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0736
# Epoch 188/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - loss: 0.0064 - root_mean_squared_error: 0.0651 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0746
# Epoch 189/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0065 - root_mean_squared_error: 0.0658 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0735
# Epoch 190/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0064 - root_mean_squared_error: 0.0654 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0750
# Epoch 191/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0064 - root_mean_squared_error: 0.0655 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0730
# Epoch 192/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0064 - root_mean_squared_error: 0.0653 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0738
# Epoch 193/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0064 - root_mean_squared_error: 0.0656 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0768
# Epoch 194/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0067 - root_mean_squared_error: 0.0681 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0753
# Epoch 195/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.0065 - root_mean_squared_error: 0.0670 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0746
# Epoch 196/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0063 - root_mean_squared_error: 0.0655 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0746
# Epoch 197/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0062 - root_mean_squared_error: 0.0648 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0733
# Epoch 198/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0061 - root_mean_squared_error: 0.0642 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0753
# Epoch 199/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0063 - root_mean_squared_error: 0.0655 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0742
# Epoch 200/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0061 - root_mean_squared_error: 0.0643 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0733
# Epoch 201/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.0059 - root_mean_squared_error: 0.0629 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0773
# Epoch 202/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0063 - root_mean_squared_error: 0.0659 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0792
# Epoch 203/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0069 - root_mean_squared_error: 0.0705 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0760
# Epoch 204/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.0064 - root_mean_squared_error: 0.0667 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0750
# Epoch 205/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0060 - root_mean_squared_error: 0.0637 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0727
# Epoch 206/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0059 - root_mean_squared_error: 0.0631 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0740
# Epoch 207/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0061 - root_mean_squared_error: 0.0649 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0733
# Epoch 208/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0061 - root_mean_squared_error: 0.0649 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0743
# Epoch 209/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0061 - root_mean_squared_error: 0.0647 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0730
# Epoch 210/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0059 - root_mean_squared_error: 0.0638 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0715
# Epoch 211/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0057 - root_mean_squared_error: 0.0622 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0714
# Epoch 212/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0058 - root_mean_squared_error: 0.0626 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0715
# Epoch 213/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0057 - root_mean_squared_error: 0.0620 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0700
# Epoch 214/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0057 - root_mean_squared_error: 0.0625 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0712
# Epoch 215/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0056 - root_mean_squared_error: 0.0617 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0720
# Epoch 216/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0057 - root_mean_squared_error: 0.0622 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0712
# Epoch 217/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0055 - root_mean_squared_error: 0.0607 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0708
# Epoch 218/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0062 - root_mean_squared_error: 0.0666 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0726
# Epoch 219/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0065 - root_mean_squared_error: 0.0684 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0792
# Epoch 220/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0065 - root_mean_squared_error: 0.0689 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0720
# Epoch 221/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0063 - root_mean_squared_error: 0.0672 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0716
# Epoch 222/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0056 - root_mean_squared_error: 0.0620 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0701
# Epoch 223/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0055 - root_mean_squared_error: 0.0614 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0694
# Epoch 224/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0056 - root_mean_squared_error: 0.0618 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0692
# Epoch 225/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0056 - root_mean_squared_error: 0.0619 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0702
# Epoch 226/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0054 - root_mean_squared_error: 0.0607 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0699
# Epoch 227/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0055 - root_mean_squared_error: 0.0617 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0696
# Epoch 228/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0055 - root_mean_squared_error: 0.0617 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0701
# Epoch 229/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0059 - root_mean_squared_error: 0.0648 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0704
# Epoch 230/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0058 - root_mean_squared_error: 0.0637 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0701
# Epoch 231/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0059 - root_mean_squared_error: 0.0647 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0708
# Epoch 232/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0055 - root_mean_squared_error: 0.0614 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0700
# Epoch 233/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0054 - root_mean_squared_error: 0.0608 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0718
# Epoch 234/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0055 - root_mean_squared_error: 0.0619 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0718
# Epoch 235/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0052 - root_mean_squared_error: 0.0596 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0682
# Epoch 236/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0050 - root_mean_squared_error: 0.0580 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0693
# Epoch 237/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0052 - root_mean_squared_error: 0.0591 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0690
# Epoch 238/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0052 - root_mean_squared_error: 0.0592 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0687
# Epoch 239/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0051 - root_mean_squared_error: 0.0584 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0679
# Epoch 240/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0052 - root_mean_squared_error: 0.0601 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0673
# Epoch 241/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0050 - root_mean_squared_error: 0.0580 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0674
# Epoch 242/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0049 - root_mean_squared_error: 0.0571 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0688
# Epoch 243/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0048 - root_mean_squared_error: 0.0565 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0698
# Epoch 244/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0051 - root_mean_squared_error: 0.0587 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0672
# Epoch 245/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0051 - root_mean_squared_error: 0.0590 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0767
# Epoch 246/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0071 - root_mean_squared_error: 0.0740 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0722
# Epoch 247/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.0057 - root_mean_squared_error: 0.0645 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0697
# Epoch 248/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - loss: 0.0054 - root_mean_squared_error: 0.0618 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0682
# Epoch 249/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0050 - root_mean_squared_error: 0.0584 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0673
# Epoch 250/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.0047 - root_mean_squared_error: 0.0564 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0680
# Epoch 251/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.0050 - root_mean_squared_error: 0.0587 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0665
# Epoch 252/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0048 - root_mean_squared_error: 0.0569 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0663
# Epoch 253/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0048 - root_mean_squared_error: 0.0566 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0697
# Epoch 254/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - loss: 0.0048 - root_mean_squared_error: 0.0573 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0680
# Epoch 255/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0048 - root_mean_squared_error: 0.0572 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0659
# Epoch 256/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0047 - root_mean_squared_error: 0.0564 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0664
# Epoch 257/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0048 - root_mean_squared_error: 0.0570 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0662
# Epoch 258/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - loss: 0.0047 - root_mean_squared_error: 0.0567 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0673
# Epoch 259/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0046 - root_mean_squared_error: 0.0559 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0673
# Epoch 260/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0046 - root_mean_squared_error: 0.0554 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0674
# Epoch 261/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0046 - root_mean_squared_error: 0.0557 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0662
# Epoch 262/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0046 - root_mean_squared_error: 0.0553 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0669
# Epoch 263/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0048 - root_mean_squared_error: 0.0579 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0658
# Epoch 264/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0045 - root_mean_squared_error: 0.0551 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0672
# Epoch 265/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0046 - root_mean_squared_error: 0.0557 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0657
# Epoch 266/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0046 - root_mean_squared_error: 0.0561 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0657
# Epoch 267/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - loss: 0.0046 - root_mean_squared_error: 0.0559 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0664
# Epoch 268/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - loss: 0.0045 - root_mean_squared_error: 0.0551 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0649
# Epoch 269/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0045 - root_mean_squared_error: 0.0548 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0664
# Epoch 270/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0050 - root_mean_squared_error: 0.0596 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0696
# Epoch 271/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0048 - root_mean_squared_error: 0.0579 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0688
# Epoch 272/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0047 - root_mean_squared_error: 0.0570 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0664
# Epoch 273/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0046 - root_mean_squared_error: 0.0558 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0654
# Epoch 274/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0043 - root_mean_squared_error: 0.0539 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0668
# Epoch 275/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0043 - root_mean_squared_error: 0.0536 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0640
# Epoch 276/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0043 - root_mean_squared_error: 0.0536 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0653
# Epoch 277/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0044 - root_mean_squared_error: 0.0544 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0663
# Epoch 278/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0044 - root_mean_squared_error: 0.0544 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0679
# Epoch 279/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.0045 - root_mean_squared_error: 0.0557 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0660
# Epoch 280/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0043 - root_mean_squared_error: 0.0539 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0641
# Epoch 281/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0043 - root_mean_squared_error: 0.0541 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0637
# Epoch 282/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0043 - root_mean_squared_error: 0.0535 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0649
# Epoch 283/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0043 - root_mean_squared_error: 0.0541 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0639
# Epoch 284/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0041 - root_mean_squared_error: 0.0524 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0650
# Epoch 285/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0043 - root_mean_squared_error: 0.0535 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0657
# Epoch 286/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0045 - root_mean_squared_error: 0.0556 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0689
# Epoch 287/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0045 - root_mean_squared_error: 0.0558 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0673
# Epoch 288/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0044 - root_mean_squared_error: 0.0545 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0657
# Epoch 289/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0044 - root_mean_squared_error: 0.0548 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0644
# Epoch 290/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0046 - root_mean_squared_error: 0.0571 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0723
# Epoch 291/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0051 - root_mean_squared_error: 0.0615 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0705
# Epoch 292/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0049 - root_mean_squared_error: 0.0597 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0850
# Epoch 293/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0064 - root_mean_squared_error: 0.0710 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0743
# Epoch 294/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0051 - root_mean_squared_error: 0.0617 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0716
# Epoch 295/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0045 - root_mean_squared_error: 0.0564 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0670
# Epoch 296/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - loss: 0.0045 - root_mean_squared_error: 0.0563 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0668
# Epoch 297/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0049 - root_mean_squared_error: 0.0595 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0749
# Epoch 298/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.0072 - root_mean_squared_error: 0.0760 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0816
# Epoch 299/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0059 - root_mean_squared_error: 0.0679 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0732
# Epoch 300/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0052 - root_mean_squared_error: 0.0621 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0700
# Epoch 301/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0049 - root_mean_squared_error: 0.0598 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0699

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test_scaled, y_test_scaled)
print(f'Test Loss: {test_loss}')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0072 - root_mean_squared_error: 0.0762
# Test Loss: [0.007221679203212261, 0.07625369727611542]

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_2\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 4))
    
    # Plot the true and predicted values on the first subplot
    axs[0].plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    axs[0].plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    axs[0].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[0].set_title(f'True vs Predicted Values for {coordinate_name}')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel(f'{coordinate_name} Value')
    axs[0].legend()
    
    # Example of another plot (e.g., residuals or difference between predicted and true values)
    original_timeseries = np.array(row[coordinate_name])
    axs[1].plot(range(len(original_timeseries)), original_timeseries, label="Timeseries")
    axs[1].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[1].set_title(f'Original {coordinate_name} trajectory')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel(f'{coordinate_name} Value')
    axs[1].legend()

        # Extract the initial sequence from the DataFrame

# %%
# Assuming model is trained and X_train, y_train are defined
def scale_with(sequence, y_scaler):
    print(sequence.shape)
    return y_scaler.transform(sequence)

# Make predictions
predictions_scaled = model.predict(X_test_scaled)

# Example for the first sample in the dataset
sample_index = 3
initial_seq = X_test[sample_index, :, -3:]  # Last 3 features are the coordinates
print(initial_seq.shape)
initial_seq_scaled = scale_with(initial_seq, y_scaler)
true_values = y_test_scaled[sample_index, :, :]  # True values
predicted_values_scaled = predictions_scaled[sample_index, :, :]  # Predicted values
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq_scaled[:, 0], true_values[:, 0], predicted_values_scaled[:, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq_scaled[:, 1], true_values[:, 1], predicted_values_scaled[:, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq_scaled[:, 2], true_values[:, 2], predicted_values_scaled[:, 2], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
# (75, 3)
# (75, 3)
