# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [round(2 * value - 1, 5) for value in scaled_values]
    
    return mapped_values

def calculate_trajectory_relative_change(trajectory):
    relative_change = []
    for i in range(1, len(trajectory)):
        delta = trajectory[i] - trajectory[i - 1]
        relative_change.append(round(delta, 5))
    return relative_change


##### RELATIVE CHANGE!@!!
def calculate_relative_change(row):
    row["Head_X_Coordinate"] = calculate_trajectory_relative_change(row["Head_X_Coordinate"])
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])

    row["Head_Y_Coordinate"] = calculate_trajectory_relative_change(row["Head_Y_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])

    row["Head_Z_Coordinate"] = calculate_trajectory_relative_change(row["Head_Z_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])

    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [-0.81439, -0.81439, -0.81439, -0.81439, -0.81...
# 1     [-0.36815, -0.36815, -0.36815, -0.36815, -0.36...
# 2     [-0.70066, -0.70066, -0.70066, -0.70066, -0.70...
# 3     [-0.80447, -0.80447, -0.80447, -0.80447, -0.80...
# 4     [-0.73389, -0.73389, -0.73389, -0.73389, -0.73...
# ...                                                 ...
# 1181  [-0.84062, -0.84062, -0.84062, -0.84062, -0.84...
# 1182  [-0.86507, -0.86507, -0.86507, -0.86507, -0.86...
# 1183  [-0.76039, -0.76039, -0.76039, -0.76039, -0.76...
# 1184  [-0.52933, -0.52933, -0.52933, -0.52933, -0.52...
# 1185  [-0.37837, -0.37837, -0.37837, -0.37837, -0.37...
#
#                                       Head_Y_Coordinate  \
# 0     [-0.13686, -0.13686, -0.13686, -0.13686, -0.13...
# 1     [0.97764, 0.97764, 0.97764, 0.97764, 0.97764, ...
# 2     [0.96859, 0.96859, 0.96859, 0.96859, 0.96859, ...
# 3     [0.15051, 0.15051, 0.15051, 0.15051, 0.15051, ...
# 4     [-0.17017, -0.17017, -0.17017, -0.17017, -0.17...
# ...                                                 ...
# 1181  [-0.32965, -0.32965, -0.32965, -0.32965, -0.32...
# 1182  [-0.98875, -0.98875, -0.98875, -0.98875, -0.98...
# 1183  [0.23726, 0.23726, 0.23726, 0.23726, 0.23726, ...
# 1184  [-0.97187, -0.97187, -0.97187, -0.97187, -0.97...
# 1185  [0.13679, 0.13679, 0.13679, 0.13679, 0.13679, ...
#
#                                       Head_Z_Coordinate
# 0     [0.7931, 0.79049, 0.7931, 0.79075, 0.78788, 0....
# 1     [0.80407, 0.80289, 0.80407, 0.80301, 0.8017, 0...
# 2     [0.79766, 0.79573, 0.79766, 0.79592, 0.7938, 0...
# 3     [0.83689, 0.83412, 0.83689, 0.83439, 0.83135, ...
# 4     [0.86008, 0.85817, 0.86008, 0.85837, 0.85627, ...
# ...                                                 ...
# 1181  [0.79464, 0.79316, 0.79464, 0.79331, 0.79168, ...
# 1182  [0.58186, 0.57949, 0.58186, 0.57973, 0.57713, ...
# 1183  [0.85618, 0.85414, 0.85618, 0.85434, 0.85209, ...
# 1184  [0.75842, 0.75713, 0.75842, 0.75726, 0.75584, ...
# 1185  [0.78873, 0.78752, 0.78873, 0.78764, 0.78631, ...
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 300): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 300): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 300): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 6811.95row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0             -0.81439           -0.13686            0.79310
# 1             -0.81439           -0.13686            0.79049
# 2             -0.81439           -0.13686            0.79310
# 3             -0.81439           -0.13686            0.79075
# 4             -0.81439           -0.13686            0.78788
# ..                 ...                ...                ...
# 296            0.98040           -0.77139            0.97048
# 297            0.98655           -0.76954            0.98041
# 298            0.99309           -0.76830            0.99060
# 299            1.00000           -0.76892            1.00000
# 300           -0.36815            0.97764            0.80407
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        #df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 75, 11) (711, 75, 1)
# (237, 75, 11) (237, 75, 1)
# (238, 75, 11) (238, 75, 1)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 1, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 1)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 75)             │         2,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 1)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,707 (584.79 KB)
#  Trainable params: 149,707 (584.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Z_rel\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 206ms/step - loss: 0.6133 - root_mean_squared_error: 0.7499 - val_loss: 0.5883 - val_root_mean_squared_error: 0.7336
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.5770 - root_mean_squared_error: 0.7259 - val_loss: 0.5284 - val_root_mean_squared_error: 0.6921
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.5189 - root_mean_squared_error: 0.6853 - val_loss: 0.4893 - val_root_mean_squared_error: 0.6638
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.4840 - root_mean_squared_error: 0.6599 - val_loss: 0.4648 - val_root_mean_squared_error: 0.6457
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.4589 - root_mean_squared_error: 0.6412 - val_loss: 0.4422 - val_root_mean_squared_error: 0.6285
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.4459 - root_mean_squared_error: 0.6316 - val_loss: 0.4182 - val_root_mean_squared_error: 0.6097
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.4141 - root_mean_squared_error: 0.6065 - val_loss: 0.3856 - val_root_mean_squared_error: 0.5830
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.3937 - root_mean_squared_error: 0.5900 - val_loss: 0.3639 - val_root_mean_squared_error: 0.5646
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.3770 - root_mean_squared_error: 0.5762 - val_loss: 0.3475 - val_root_mean_squared_error: 0.5505
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.3501 - root_mean_squared_error: 0.5529 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5389
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.3388 - root_mean_squared_error: 0.5431 - val_loss: 0.3224 - val_root_mean_squared_error: 0.5283
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - loss: 0.3285 - root_mean_squared_error: 0.5342 - val_loss: 0.3085 - val_root_mean_squared_error: 0.5156
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.3145 - root_mean_squared_error: 0.5214 - val_loss: 0.2977 - val_root_mean_squared_error: 0.5056
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.3061 - root_mean_squared_error: 0.5138 - val_loss: 0.2848 - val_root_mean_squared_error: 0.4931
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.2990 - root_mean_squared_error: 0.5074 - val_loss: 0.2807 - val_root_mean_squared_error: 0.4895
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.2924 - root_mean_squared_error: 0.5014 - val_loss: 0.2678 - val_root_mean_squared_error: 0.4767
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.2744 - root_mean_squared_error: 0.4836 - val_loss: 0.2585 - val_root_mean_squared_error: 0.4674
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.2714 - root_mean_squared_error: 0.4811 - val_loss: 0.2531 - val_root_mean_squared_error: 0.4621
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.2600 - root_mean_squared_error: 0.4696 - val_loss: 0.2463 - val_root_mean_squared_error: 0.4552
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.2588 - root_mean_squared_error: 0.4688 - val_loss: 0.2447 - val_root_mean_squared_error: 0.4540
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.2580 - root_mean_squared_error: 0.4685 - val_loss: 0.2378 - val_root_mean_squared_error: 0.4469
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.2513 - root_mean_squared_error: 0.4617 - val_loss: 0.2352 - val_root_mean_squared_error: 0.4445
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.2491 - root_mean_squared_error: 0.4600 - val_loss: 0.2325 - val_root_mean_squared_error: 0.4419
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.2428 - root_mean_squared_error: 0.4534 - val_loss: 0.2297 - val_root_mean_squared_error: 0.4393
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.2426 - root_mean_squared_error: 0.4537 - val_loss: 0.2260 - val_root_mean_squared_error: 0.4355
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.2392 - root_mean_squared_error: 0.4506 - val_loss: 0.2259 - val_root_mean_squared_error: 0.4359
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2376 - root_mean_squared_error: 0.4492 - val_loss: 0.2241 - val_root_mean_squared_error: 0.4344
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.2323 - root_mean_squared_error: 0.4438 - val_loss: 0.2288 - val_root_mean_squared_error: 0.4402
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.2318 - root_mean_squared_error: 0.4437 - val_loss: 0.2272 - val_root_mean_squared_error: 0.4388
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2301 - root_mean_squared_error: 0.4423 - val_loss: 0.2199 - val_root_mean_squared_error: 0.4309
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.2302 - root_mean_squared_error: 0.4427 - val_loss: 0.2123 - val_root_mean_squared_error: 0.4225
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.2329 - root_mean_squared_error: 0.4463 - val_loss: 0.2169 - val_root_mean_squared_error: 0.4283
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2297 - root_mean_squared_error: 0.4430 - val_loss: 0.2176 - val_root_mean_squared_error: 0.4296
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.2241 - root_mean_squared_error: 0.4371 - val_loss: 0.2213 - val_root_mean_squared_error: 0.4343
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.2277 - root_mean_squared_error: 0.4417 - val_loss: 0.2124 - val_root_mean_squared_error: 0.4243
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.2250 - root_mean_squared_error: 0.4390 - val_loss: 0.2156 - val_root_mean_squared_error: 0.4285
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.2176 - root_mean_squared_error: 0.4310 - val_loss: 0.2129 - val_root_mean_squared_error: 0.4258
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.2249 - root_mean_squared_error: 0.4398 - val_loss: 0.2088 - val_root_mean_squared_error: 0.4215
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.2264 - root_mean_squared_error: 0.4419 - val_loss: 0.2144 - val_root_mean_squared_error: 0.4284
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.2233 - root_mean_squared_error: 0.4387 - val_loss: 0.2108 - val_root_mean_squared_error: 0.4246
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.2203 - root_mean_squared_error: 0.4357 - val_loss: 0.2094 - val_root_mean_squared_error: 0.4233
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.2224 - root_mean_squared_error: 0.4384 - val_loss: 0.2048 - val_root_mean_squared_error: 0.4183
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.2205 - root_mean_squared_error: 0.4366 - val_loss: 0.2080 - val_root_mean_squared_error: 0.4224
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.2130 - root_mean_squared_error: 0.4283 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4217
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.2102 - root_mean_squared_error: 0.4255 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4199
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.2063 - root_mean_squared_error: 0.4212 - val_loss: 0.2061 - val_root_mean_squared_error: 0.4213
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.2063 - root_mean_squared_error: 0.4215 - val_loss: 0.2147 - val_root_mean_squared_error: 0.4318
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.2110 - root_mean_squared_error: 0.4275 - val_loss: 0.2071 - val_root_mean_squared_error: 0.4232
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.2096 - root_mean_squared_error: 0.4262 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4241
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.2098 - root_mean_squared_error: 0.4267 - val_loss: 0.2087 - val_root_mean_squared_error: 0.4257
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.2054 - root_mean_squared_error: 0.4220 - val_loss: 0.2034 - val_root_mean_squared_error: 0.4199
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - loss: 0.1936 - root_mean_squared_error: 0.4079 - val_loss: 0.2036 - val_root_mean_squared_error: 0.4205
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.1987 - root_mean_squared_error: 0.4146 - val_loss: 0.2006 - val_root_mean_squared_error: 0.4172
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.2051 - root_mean_squared_error: 0.4225 - val_loss: 0.2015 - val_root_mean_squared_error: 0.4186
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1984 - root_mean_squared_error: 0.4149 - val_loss: 0.2005 - val_root_mean_squared_error: 0.4177
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.2036 - root_mean_squared_error: 0.4214 - val_loss: 0.2035 - val_root_mean_squared_error: 0.4215
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.2019 - root_mean_squared_error: 0.4197 - val_loss: 0.2037 - val_root_mean_squared_error: 0.4222
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.1950 - root_mean_squared_error: 0.4117 - val_loss: 0.2076 - val_root_mean_squared_error: 0.4270
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.2047 - root_mean_squared_error: 0.4236 - val_loss: 0.2039 - val_root_mean_squared_error: 0.4229
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.1906 - root_mean_squared_error: 0.4070 - val_loss: 0.2002 - val_root_mean_squared_error: 0.4188
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - loss: 0.1932 - root_mean_squared_error: 0.4105 - val_loss: 0.1951 - val_root_mean_squared_error: 0.4130
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - loss: 0.1828 - root_mean_squared_error: 0.3976 - val_loss: 0.2050 - val_root_mean_squared_error: 0.4251
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1859 - root_mean_squared_error: 0.4019 - val_loss: 0.1988 - val_root_mean_squared_error: 0.4181
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.1947 - root_mean_squared_error: 0.4132 - val_loss: 0.1937 - val_root_mean_squared_error: 0.4122
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.1959 - root_mean_squared_error: 0.4148 - val_loss: 0.1890 - val_root_mean_squared_error: 0.4067
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.1859 - root_mean_squared_error: 0.4028 - val_loss: 0.1937 - val_root_mean_squared_error: 0.4127
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.1905 - root_mean_squared_error: 0.4088 - val_loss: 0.1948 - val_root_mean_squared_error: 0.4143
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.1867 - root_mean_squared_error: 0.4044 - val_loss: 0.1936 - val_root_mean_squared_error: 0.4132
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - loss: 0.1829 - root_mean_squared_error: 0.4000 - val_loss: 0.1963 - val_root_mean_squared_error: 0.4167
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 420ms/step - loss: 0.1898 - root_mean_squared_error: 0.4088 - val_loss: 0.1928 - val_root_mean_squared_error: 0.4127
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 439ms/step - loss: 0.1871 - root_mean_squared_error: 0.4056 - val_loss: 0.1964 - val_root_mean_squared_error: 0.4173
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 398ms/step - loss: 0.1860 - root_mean_squared_error: 0.4046 - val_loss: 0.1927 - val_root_mean_squared_error: 0.4131
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 387ms/step - loss: 0.1868 - root_mean_squared_error: 0.4058 - val_loss: 0.1923 - val_root_mean_squared_error: 0.4128
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 444ms/step - loss: 0.1843 - root_mean_squared_error: 0.4031 - val_loss: 0.1893 - val_root_mean_squared_error: 0.4094
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - loss: 0.1790 - root_mean_squared_error: 0.3967 - val_loss: 0.1862 - val_root_mean_squared_error: 0.4059
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 0.1811 - root_mean_squared_error: 0.3996 - val_loss: 0.1852 - val_root_mean_squared_error: 0.4048
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - loss: 0.1781 - root_mean_squared_error: 0.3960 - val_loss: 0.1866 - val_root_mean_squared_error: 0.4068
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 323ms/step - loss: 0.1759 - root_mean_squared_error: 0.3934 - val_loss: 0.1829 - val_root_mean_squared_error: 0.4024
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - loss: 0.1814 - root_mean_squared_error: 0.4006 - val_loss: 0.1826 - val_root_mean_squared_error: 0.4023
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.1729 - root_mean_squared_error: 0.3901 - val_loss: 0.1801 - val_root_mean_squared_error: 0.3994
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.1770 - root_mean_squared_error: 0.3955 - val_loss: 0.1827 - val_root_mean_squared_error: 0.4028
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1701 - root_mean_squared_error: 0.3869 - val_loss: 0.1874 - val_root_mean_squared_error: 0.4088
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1764 - root_mean_squared_error: 0.3952 - val_loss: 0.1826 - val_root_mean_squared_error: 0.4031
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.1796 - root_mean_squared_error: 0.3994 - val_loss: 0.1851 - val_root_mean_squared_error: 0.4065
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.1761 - root_mean_squared_error: 0.3952 - val_loss: 0.1876 - val_root_mean_squared_error: 0.4097
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1675 - root_mean_squared_error: 0.3842 - val_loss: 0.1866 - val_root_mean_squared_error: 0.4087
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.1721 - root_mean_squared_error: 0.3905 - val_loss: 0.1836 - val_root_mean_squared_error: 0.4052
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.1709 - root_mean_squared_error: 0.3892 - val_loss: 0.1888 - val_root_mean_squared_error: 0.4118
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - loss: 0.1753 - root_mean_squared_error: 0.3949 - val_loss: 0.1866 - val_root_mean_squared_error: 0.4093
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.1681 - root_mean_squared_error: 0.3861 - val_loss: 0.1816 - val_root_mean_squared_error: 0.4033
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.1647 - root_mean_squared_error: 0.3816 - val_loss: 0.1811 - val_root_mean_squared_error: 0.4028
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.1702 - root_mean_squared_error: 0.3890 - val_loss: 0.1969 - val_root_mean_squared_error: 0.4222
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.1736 - root_mean_squared_error: 0.3936 - val_loss: 0.1820 - val_root_mean_squared_error: 0.4043
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 477ms/step - loss: 0.1734 - root_mean_squared_error: 0.3934 - val_loss: 0.1844 - val_root_mean_squared_error: 0.4075
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - loss: 0.1717 - root_mean_squared_error: 0.3915 - val_loss: 0.1815 - val_root_mean_squared_error: 0.4041
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 387ms/step - loss: 0.1693 - root_mean_squared_error: 0.3886 - val_loss: 0.1819 - val_root_mean_squared_error: 0.4048
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 377ms/step - loss: 0.1720 - root_mean_squared_error: 0.3923 - val_loss: 0.1849 - val_root_mean_squared_error: 0.4086
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 364ms/step - loss: 0.1635 - root_mean_squared_error: 0.3816 - val_loss: 0.1818 - val_root_mean_squared_error: 0.4050
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 354ms/step - loss: 0.1608 - root_mean_squared_error: 0.3781 - val_loss: 0.1865 - val_root_mean_squared_error: 0.4108
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - loss: 0.1686 - root_mean_squared_error: 0.3884 - val_loss: 0.1887 - val_root_mean_squared_error: 0.4137

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 0.1743 - root_mean_squared_error: 0.3920
# Test Loss: [0.18087656795978546, 0.4003627598285675]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 694ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Z_rel\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()

# %%
# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_test)

# Example for the first sample in the dataset
sample_index = 2
initial_seq = X_test[sample_index, :, -3:]  # Last 3 features are the coordinates
print(initial_seq.shape)
true_values = y_test[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
# Plot for Head_X_Coordinate
#plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
#plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])
#plot_predictions3(initial_seq[:, 1], true_values[:, 0], predicted_values[:, 0], 'Head_Y_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 0], predicted_values[:, 0], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 717ms/step
# (75, 3)

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
