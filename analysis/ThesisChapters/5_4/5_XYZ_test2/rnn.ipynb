# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - η διαφορα του με το 5_XYZ_only_norm ειναι οτι to normalization εχει boundaries για καθε row.
# - Σε αυτο θα βρω τα συνολικα xminmax, yminmax, zminmax και θα χρησιμοποιησω αυτα.

# %% [markdown]
# # Generate Dataframe

# %%
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df.iloc[0]
# Out:
# Id                                                                                          0
# Path                                        C:\Users\geork\projects\AIThesis\datasets\2024...
# CarProfile                                                                                FCR
# Velocity                                                                                  100
# Translation                                                                              -200
# Rotation                                                                                    0
# Position                                                                              initial
# HIC15_max                                                                              86.843
# HIC36_max                                                                             136.373
# Head_Z_Acceleration_abs_max                                                            36.081
# Head_X_Acceleration_abs_max                                                             7.578
# Head_Y_Acceleration_abs_max                                                            17.539
# BrIC_abs_max                                                                             0.92
# Chest_Resultant_Acceleration_max                                                       34.882
# Chest_Resultant_Acceleration_CLIP3ms_max                                               28.117
# Head_X_Coordinate                           [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# Head_Y_Coordinate                           [-288.045, -288.045, -288.045, -288.045, -288....
# Head_Z_Coordinate                           [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# Name: 0, dtype: object

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
from car_profile_expand import expand_car_profiles
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"
             ]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 6946.07row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#labels = ["Head_X_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0              220.000           -288.045           1575.416
# 1              220.000           -288.045           1575.411
# 2              220.000           -288.045           1575.396
# 3              220.000           -288.045           1575.391
# 4              220.000           -288.045           1575.377
# ..                 ...                ...                ...
# 296           2724.310           -409.036            947.462
# 297           2738.592           -410.063            948.136
# 298           2752.923           -411.087            948.848
# 299           2767.306           -412.109            949.599
# 300           2781.744           -413.132            950.386
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
train_df.shape

# To train_df einai (711, 11)
# Kapoies apo tis times tou 11 einai listes me 300 stoixeia.
# Out:
# (711, 11)

# %% [markdown]
# # From Dataframe to Numpy Array

# %% [markdown]
# ## Split Numpy Arrays

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])
    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 125

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (711, 75, 11), y_train shape: (711, 125, 3)

# %%
X_train[0]
X_train[0][0]
X_train.shape
# Out:
# (711, 75, 11)

# %% [markdown]
# ## Calculate Relative Changes

# %%
# Assuming X has shape (711, 75, 11)
def calculate_relative_change_X(X):
    # Split the dataset into two parts: unchanged features and XYZ columns
    features = X[:, :, :-3]  # First 8 columns (unchanged)
    xyz = X[:, :, -3:]  # Last 3 columns (XYZ)

    # Calculate the relative change for XYZ coordinates
    # Shape will be (n_samples, timesteps-1, 3)
    xyz_relative = np.diff(xyz, axis=1)

    # Since np.diff reduces the timestep dimension by 1, we need to pad the first timestep for XYZ
    # We can pad the first timestep with zeros (no relative change at the first timestep)
    zero_padding = np.zeros((X.shape[0], 1, 3))
    xyz_relative = np.concatenate((zero_padding, xyz_relative), axis=1)

    # Combine unchanged features and the new relative XYZ values
    # Shape will be (n_samples, timesteps, 11)
    X_transformed = np.concatenate((features, xyz_relative), axis=2)

    return X_transformed

import numpy as np

def revert_relative_change_X(X_relative, initial_xyz):
    """
    Reverts the relative changes for the last 3 columns (XYZ) to their original absolute values.
    
    Parameters:
    X_relative: np.ndarray
        Input data with relative changes in the last 3 columns (shape: n_samples, timesteps, 11).
    initial_xyz: np.ndarray
        The initial XYZ values (absolute values) at t=0 (shape: n_samples, 3).
    
    Returns:
    X_original: np.ndarray
        The dataset with the last 3 columns (XYZ) reverted to absolute values (shape: n_samples, timesteps, 11).
    """
    # Split the dataset into two parts: unchanged features and relative XYZ columns
    features = X_relative[:, :, :-3]  # First 8 columns (unchanged)
    xyz_relative = X_relative[:, :, -3:]  # Last 3 columns (XYZ relative changes)

    # Initialize an array to store the absolute XYZ values
    n_samples, timesteps, _ = X_relative.shape
    xyz_absolute = np.zeros((n_samples, timesteps, 3))

    # Set the first timestep to the initial absolute XYZ values
    
    xyz_absolute[:, 0, :] = initial_xyz

    # Rebuild the absolute XYZ values by accumulating the relative changes
    for t in range(1, timesteps):
        xyz_absolute[:, t, :] = xyz_absolute[:, t-1, :] + xyz_relative[:, t, :]

    # Combine unchanged features with the reconstructed absolute XYZ values
    X_original = np.concatenate((features, xyz_absolute), axis=2)

    return X_original


def calculate_relative_change_y(y):
    xyz_relative = np.diff(y, axis=1)
    zero_padding = np.zeros((y.shape[0], 1, y.shape[2]))
    y_relative = np.concatenate((zero_padding, xyz_relative), axis=1)
    return y_relative

import numpy as np

def revert_relative_change_y(y_relative, initial_xyz):
    """
    Reverts the relative changes for the test data to their original absolute values.
    
    Parameters:
    y_relative: np.ndarray
        Input test data with relative changes (shape: n_samples, timesteps, 3).
    initial_xyz: np.ndarray
        The initial XYZ values (absolute values) at t=0 (shape: n_samples, 3).
    
    Returns:
    y_absolute: np.ndarray
        The test data with reverted absolute XYZ values (shape: n_samples, timesteps, 3).
    """
    # Initialize an array to store the absolute XYZ values
    n_samples, timesteps, n_features = y_relative.shape
    y_absolute = np.zeros((n_samples, timesteps, n_features))

    # Set the first timestep to the initial absolute XYZ values
    y_absolute[:, 0, :] = initial_xyz

    # Rebuild the absolute XYZ values by accumulating the relative changes
    for t in range(1, timesteps):
        y_absolute[:, t, :] = y_absolute[:, t-1, :] + y_relative[:, t, :]

    return y_absolute

# %%
print(f"min/max X_train[:, :, -3]: {X_train[:, :, -3].min()}/{X_train[:, :, -3].max()}")
print(f"min/max X_train[:, :, -2]: {X_train[:, :, -2].min()}/{X_train[:, :, -2].max()}")
print(f"min/max X_train[:, :, -1]: {X_train[:, :, -1].min()}/{X_train[:, :, -1].max()}")

X_train_rel = calculate_relative_change_X(X_train)
X_test_rel = calculate_relative_change_X(X_test)
X_val_rel   = calculate_relative_change_X(X_val)

print(f"min/max X_train[:, :, -3]: {X_train_rel[:, :, -3].min()}/{X_train_rel[:, :, -3].max()}")
print(f"min/max X_train[:, :, -2]: {X_train_rel[:, :, -2].min()}/{X_train_rel[:, :, -2].max()}")
print(f"min/max X_train[:, :, -1]: {X_train_rel[:, :, -1].min()}/{X_train_rel[:, :, -1].max()}")

print(f"min/max y_train[:, :, -3]: {y_train[:, :, -3].min()}/{y_train[:, :, -3].max()}")
print(f"min/max y_train[:, :, -2]: {y_train[:, :, -2].min()}/{y_train[:, :, -2].max()}")
print(f"min/max y_train[:, :, -1]: {y_train[:, :, -1].min()}/{y_train[:, :, -1].max()}")

y_train_rel = calculate_relative_change_y(y_train)
y_test_rel = calculate_relative_change_y(y_test)
y_val_rel  = calculate_relative_change_y(y_val)

print(f"min/max y_train[:, :, -3]: {y_train_rel[:, :, -3].min()}/{y_train_rel[:, :, -3].max()}")
print(f"min/max y_train[:, :, -2]: {y_train_rel[:, :, -2].min()}/{y_train_rel[:, :, -2].max()}")
print(f"min/max y_train[:, :, -1]: {y_train_rel[:, :, -1].min()}/{y_train_rel[:, :, -1].max()}")
# Out:
# min/max X_train[:, :, -3]: 55.897/464.892
# min/max X_train[:, :, -2]: -488.226/575.557
# min/max X_train[:, :, -1]: 1178.524/1577.81
# min/max X_train[:, :, -3]: -6.581000000000017/12.510999999999967
# min/max X_train[:, :, -2]: -6.209999999999999/5.605000000000018
# min/max X_train[:, :, -1]: -13.857999999999947/0.65300000000002
# min/max y_train[:, :, -3]: 11.751/1979.768
# min/max y_train[:, :, -2]: -649.235/856.436
# min/max y_train[:, :, -1]: 909.385/1624.29
# min/max y_train[:, :, -3]: -6.73599999999999/18.153999999999996
# min/max y_train[:, :, -2]: -6.425000000000011/5.877999999999986
# min/max y_train[:, :, -1]: -18.007000000000062/14.666000000000167

# %% [markdown]
# ## Normalization preprocessing related

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def feature_wise_normalizaton(X):
    n_samples, n_timesteps, n_features = X.shape
    scalers = [StandardScaler() for _ in range(n_features)]
    X_normalized = np.zeros_like(X)
    for i in range(n_features):
        feature_data = X[:, :, i].reshape(-1, 1)
        X_normalized[:, :, i] = scalers[i].fit_transform(feature_data).reshape(n_samples, n_timesteps)
    return X_normalized, scalers

def normalization_across_time(array):
    # Normalize each feature over all time steps
    n_samples, n_timesteps, n_features = array.shape
    array_flat = array.reshape(-1, n_features)  # Flattening to (711*75, 11)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    array_flat_normalized = scaler.fit_transform(array_flat)
    array_normalized = array_flat_normalized.reshape(n_samples, n_timesteps, n_features)
    return array_normalized, scaler

def transform_data(array, scaler):
    n_samples, n_timesteps, n_features = array.shape
    array_flat = array.reshape(-1, n_features)  # Flattening to (number_of_samples*number_of_timesteps, number_of_features)
    array_flat_normalized = scaler.transform(array_flat)
    array_normalized = array_flat_normalized.reshape(n_samples, n_timesteps, n_features)
    return array_normalized

def inverse_transform_data(array_normalized, scaler):
    n_samples, n_timesteps, n_features = array_normalized.shape
    array_flat_normalized = array_normalized.reshape(-1, n_features)  # Flatten to (n_samples * n_timesteps, n_features)
    array_flat = scaler.inverse_transform(array_flat_normalized)  # Inverse transform
    array = array_flat.reshape(n_samples, n_timesteps, n_features)  # Reshape back to (n_samples, n_timesteps, n_features)
    return array

# %%
X_train_scaled, x_scaler = normalization_across_time(X_train_rel)
X_val_scaled = transform_data(X_val_rel, x_scaler)
X_test_scaled = transform_data(X_test_rel, x_scaler)

# %%
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\\x_scaler.save"
joblib.dump(x_scaler, scaler_filename)
# Out:
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\\x_scaler.save']

# %%
# Scaling test values
print(y_train.shape)
y_train_scaled, y_scaler = normalization_across_time(y_train_rel)
y_val_scaled = transform_data(y_val_rel, y_scaler)
y_test_scaled = transform_data(y_test_rel, y_scaler)
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\\y_scaler.save"
joblib.dump(y_scaler, scaler_filename)
# Out:
# (711, 125, 3)
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\\y_scaler.save']

# %% [markdown]
# # Training

# %%
X_train_final, y_train_final = X_train_scaled, y_train_scaled
X_val_final, y_val_final = X_val_scaled, y_val_scaled
X_test_final, y_test_final = X_test_scaled, y_test_scaled

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

outpunum = y_train.shape[-1]

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, activation="relu", return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, activation="relu", return_sequences=True))
#model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128, return_sequences=True))  # Third LSTM layer
model.add(LSTM(64, activation="relu"))

#model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * outpunum, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, outpunum)))  # Reshape to match the target output shape (10, outpunum)


model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_22                │ (None, 75, 64)         │        11,264 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_51 (LSTM)                  │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_52 (LSTM)                  │ (None, 75, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_53 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 375)            │        12,375 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_17 (Reshape)            │ (None, 125, 3)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 206,967 (808.46 KB)
#  Trainable params: 206,967 (808.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(f"X_train_scaled.shape: {X_train_final.shape} y_train_scaled.shape: {y_train_final.shape}")
# Out:
# X_train_scaled.shape: (711, 75, 11) y_train_scaled.shape: (711, 125, 3)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

def warmup_schedule(epoch, lr):
    warmup_epochs = 30
    max_lr = 0.0001
    if epoch < warmup_epochs:
        return lr + (max_lr / warmup_epochs)
    return max_lr

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\\model12.keras", save_best_only=True)

es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(warmup_schedule)

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.000001), metrics=[RootMeanSquaredError()])

history = model.fit(X_train_final, y_train_final, validation_data=(X_val_final, y_val_final), 
          epochs=100000, 
          callbacks=[cp, 
                     es,
                     lr_scheduler
                     ])
# Out:
# Epoch 1/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 205ms/step - loss: 0.1483 - root_mean_squared_error: 0.3260 - val_loss: 0.1471 - val_root_mean_squared_error: 0.3242 - learning_rate: 4.3333e-06
# Epoch 2/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1463 - root_mean_squared_error: 0.3230 - val_loss: 0.1469 - val_root_mean_squared_error: 0.3240 - learning_rate: 7.6667e-06
# Epoch 3/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1449 - root_mean_squared_error: 0.3209 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3236 - learning_rate: 1.1000e-05
# Epoch 4/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 329ms/step - loss: 0.1453 - root_mean_squared_error: 0.3217 - val_loss: 0.1461 - val_root_mean_squared_error: 0.3232 - learning_rate: 1.4333e-05
# Epoch 5/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 360ms/step - loss: 0.1447 - root_mean_squared_error: 0.3211 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3227 - learning_rate: 1.7667e-05
# Epoch 6/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 339ms/step - loss: 0.1453 - root_mean_squared_error: 0.3224 - val_loss: 0.1448 - val_root_mean_squared_error: 0.3218 - learning_rate: 2.1000e-05
# Epoch 7/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.1437 - root_mean_squared_error: 0.3202 - val_loss: 0.1434 - val_root_mean_squared_error: 0.3201 - learning_rate: 2.4333e-05
# Epoch 8/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.1419 - root_mean_squared_error: 0.3179 - val_loss: 0.1413 - val_root_mean_squared_error: 0.3173 - learning_rate: 2.7667e-05
# Epoch 9/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - loss: 0.1405 - root_mean_squared_error: 0.3161 - val_loss: 0.1385 - val_root_mean_squared_error: 0.3133 - learning_rate: 3.1000e-05
# Epoch 10/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - loss: 0.1360 - root_mean_squared_error: 0.3095 - val_loss: 0.1350 - val_root_mean_squared_error: 0.3084 - learning_rate: 3.4333e-05
# Epoch 11/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.1320 - root_mean_squared_error: 0.3036 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3022 - learning_rate: 3.7667e-05
# Epoch 12/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - loss: 0.1289 - root_mean_squared_error: 0.2992 - val_loss: 0.1261 - val_root_mean_squared_error: 0.2950 - learning_rate: 4.1000e-05
# Epoch 13/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.1247 - root_mean_squared_error: 0.2929 - val_loss: 0.1207 - val_root_mean_squared_error: 0.2866 - learning_rate: 4.4333e-05
# Epoch 14/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - loss: 0.1192 - root_mean_squared_error: 0.2841 - val_loss: 0.1151 - val_root_mean_squared_error: 0.2775 - learning_rate: 4.7667e-05
# Epoch 15/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - loss: 0.1131 - root_mean_squared_error: 0.2741 - val_loss: 0.1092 - val_root_mean_squared_error: 0.2677 - learning_rate: 5.1000e-05
# Epoch 16/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - loss: 0.1072 - root_mean_squared_error: 0.2642 - val_loss: 0.1037 - val_root_mean_squared_error: 0.2581 - learning_rate: 5.4333e-05
# Epoch 17/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - loss: 0.1028 - root_mean_squared_error: 0.2567 - val_loss: 0.0989 - val_root_mean_squared_error: 0.2499 - learning_rate: 5.7667e-05
# Epoch 18/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 318ms/step - loss: 0.0980 - root_mean_squared_error: 0.2483 - val_loss: 0.0944 - val_root_mean_squared_error: 0.2419 - learning_rate: 6.1000e-05
# Epoch 19/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - loss: 0.0935 - root_mean_squared_error: 0.2404 - val_loss: 0.0906 - val_root_mean_squared_error: 0.2353 - learning_rate: 6.4333e-05
# Epoch 20/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - loss: 0.0885 - root_mean_squared_error: 0.2311 - val_loss: 0.0874 - val_root_mean_squared_error: 0.2298 - learning_rate: 6.7667e-05
# Epoch 21/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.0865 - root_mean_squared_error: 0.2281 - val_loss: 0.0848 - val_root_mean_squared_error: 0.2254 - learning_rate: 7.1000e-05
# Epoch 22/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0836 - root_mean_squared_error: 0.2232 - val_loss: 0.0827 - val_root_mean_squared_error: 0.2223 - learning_rate: 7.4333e-05
# Epoch 23/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - loss: 0.0808 - root_mean_squared_error: 0.2182 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2188 - learning_rate: 7.7667e-05
# Epoch 24/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - loss: 0.0799 - root_mean_squared_error: 0.2177 - val_loss: 0.0788 - val_root_mean_squared_error: 0.2164 - learning_rate: 8.1000e-05
# Epoch 25/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.0759 - root_mean_squared_error: 0.2099 - val_loss: 0.0771 - val_root_mean_squared_error: 0.2141 - learning_rate: 8.4333e-05
# Epoch 26/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - loss: 0.0758 - root_mean_squared_error: 0.2114 - val_loss: 0.0753 - val_root_mean_squared_error: 0.2115 - learning_rate: 8.7667e-05
# Epoch 27/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - loss: 0.0739 - root_mean_squared_error: 0.2087 - val_loss: 0.0742 - val_root_mean_squared_error: 0.2106 - learning_rate: 9.1000e-05
# Epoch 28/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 207ms/step - loss: 0.0742 - root_mean_squared_error: 0.2110 - val_loss: 0.0720 - val_root_mean_squared_error: 0.2071 - learning_rate: 9.4333e-05
# Epoch 29/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0718 - root_mean_squared_error: 0.2069 - val_loss: 0.0702 - val_root_mean_squared_error: 0.2044 - learning_rate: 9.7667e-05
# Epoch 30/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - loss: 0.0696 - root_mean_squared_error: 0.2035 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2017 - learning_rate: 1.0100e-04
# Epoch 31/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0674 - root_mean_squared_error: 0.1997 - val_loss: 0.0667 - val_root_mean_squared_error: 0.1994 - learning_rate: 1.0000e-04
# Epoch 32/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0672 - root_mean_squared_error: 0.2011 - val_loss: 0.0657 - val_root_mean_squared_error: 0.1985 - learning_rate: 1.0000e-04
# Epoch 33/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.0643 - root_mean_squared_error: 0.1953 - val_loss: 0.0638 - val_root_mean_squared_error: 0.1952 - learning_rate: 1.0000e-04
# Epoch 34/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.0629 - root_mean_squared_error: 0.1933 - val_loss: 0.0620 - val_root_mean_squared_error: 0.1922 - learning_rate: 1.0000e-04
# Epoch 35/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.0625 - root_mean_squared_error: 0.1940 - val_loss: 0.0602 - val_root_mean_squared_error: 0.1892 - learning_rate: 1.0000e-04
# Epoch 36/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0587 - root_mean_squared_error: 0.1855 - val_loss: 0.0590 - val_root_mean_squared_error: 0.1875 - learning_rate: 1.0000e-04
# Epoch 37/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0581 - root_mean_squared_error: 0.1856 - val_loss: 0.0568 - val_root_mean_squared_error: 0.1834 - learning_rate: 1.0000e-04
# Epoch 38/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0564 - root_mean_squared_error: 0.1824 - val_loss: 0.0557 - val_root_mean_squared_error: 0.1819 - learning_rate: 1.0000e-04
# Epoch 39/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0551 - root_mean_squared_error: 0.1805 - val_loss: 0.0540 - val_root_mean_squared_error: 0.1786 - learning_rate: 1.0000e-04
# Epoch 40/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.0533 - root_mean_squared_error: 0.1770 - val_loss: 0.0532 - val_root_mean_squared_error: 0.1779 - learning_rate: 1.0000e-04
# Epoch 41/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0515 - root_mean_squared_error: 0.1733 - val_loss: 0.0508 - val_root_mean_squared_error: 0.1725 - learning_rate: 1.0000e-04
# Epoch 42/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0494 - root_mean_squared_error: 0.1686 - val_loss: 0.0495 - val_root_mean_squared_error: 0.1700 - learning_rate: 1.0000e-04
# Epoch 43/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.0483 - root_mean_squared_error: 0.1668 - val_loss: 0.0478 - val_root_mean_squared_error: 0.1665 - learning_rate: 1.0000e-04
# Epoch 44/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - loss: 0.0465 - root_mean_squared_error: 0.1628 - val_loss: 0.0472 - val_root_mean_squared_error: 0.1661 - learning_rate: 1.0000e-04
# Epoch 45/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - loss: 0.0459 - root_mean_squared_error: 0.1625 - val_loss: 0.0451 - val_root_mean_squared_error: 0.1612 - learning_rate: 1.0000e-04
# Epoch 46/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 323ms/step - loss: 0.0443 - root_mean_squared_error: 0.1589 - val_loss: 0.0443 - val_root_mean_squared_error: 0.1602 - learning_rate: 1.0000e-04
# Epoch 47/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - loss: 0.0429 - root_mean_squared_error: 0.1558 - val_loss: 0.0430 - val_root_mean_squared_error: 0.1574 - learning_rate: 1.0000e-04
# Epoch 48/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - loss: 0.0415 - root_mean_squared_error: 0.1527 - val_loss: 0.0425 - val_root_mean_squared_error: 0.1570 - learning_rate: 1.0000e-04
# Epoch 49/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 359ms/step - loss: 0.0412 - root_mean_squared_error: 0.1532 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1547 - learning_rate: 1.0000e-04
# Epoch 50/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 365ms/step - loss: 0.0397 - root_mean_squared_error: 0.1495 - val_loss: 0.0400 - val_root_mean_squared_error: 0.1515 - learning_rate: 1.0000e-04
# Epoch 51/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 383ms/step - loss: 0.0392 - root_mean_squared_error: 0.1492 - val_loss: 0.0392 - val_root_mean_squared_error: 0.1502 - learning_rate: 1.0000e-04
# Epoch 52/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 397ms/step - loss: 0.0385 - root_mean_squared_error: 0.1482 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1490 - learning_rate: 1.0000e-04
# Epoch 53/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 399ms/step - loss: 0.0368 - root_mean_squared_error: 0.1437 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1471 - learning_rate: 1.0000e-04
# Epoch 54/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 414ms/step - loss: 0.0356 - root_mean_squared_error: 0.1405 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1450 - learning_rate: 1.0000e-04
# Epoch 55/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 402ms/step - loss: 0.0346 - root_mean_squared_error: 0.1383 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1449 - learning_rate: 1.0000e-04
# Epoch 56/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 403ms/step - loss: 0.0346 - root_mean_squared_error: 0.1395 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1419 - learning_rate: 1.0000e-04
# Epoch 57/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 413ms/step - loss: 0.0329 - root_mean_squared_error: 0.1347 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1399 - learning_rate: 1.0000e-04
# Epoch 58/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 421ms/step - loss: 0.0328 - root_mean_squared_error: 0.1352 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1428 - learning_rate: 1.0000e-04
# Epoch 59/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 414ms/step - loss: 0.0319 - root_mean_squared_error: 0.1332 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1383 - learning_rate: 1.0000e-04
# Epoch 60/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - loss: 0.0313 - root_mean_squared_error: 0.1319 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1355 - learning_rate: 1.0000e-04
# Epoch 61/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 349ms/step - loss: 0.0305 - root_mean_squared_error: 0.1300 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1349 - learning_rate: 1.0000e-04
# Epoch 62/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - loss: 0.0299 - root_mean_squared_error: 0.1290 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1339 - learning_rate: 1.0000e-04
# Epoch 63/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 493ms/step - loss: 0.0293 - root_mean_squared_error: 0.1278 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1325 - learning_rate: 1.0000e-04
# Epoch 64/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 354ms/step - loss: 0.0285 - root_mean_squared_error: 0.1258 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1325 - learning_rate: 1.0000e-04
# Epoch 65/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - loss: 0.0278 - root_mean_squared_error: 0.1238 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1322 - learning_rate: 1.0000e-04
# Epoch 66/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - loss: 0.0275 - root_mean_squared_error: 0.1239 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1288 - learning_rate: 1.0000e-04
# Epoch 67/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 363ms/step - loss: 0.0267 - root_mean_squared_error: 0.1217 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1293 - learning_rate: 1.0000e-04
# Epoch 68/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 349ms/step - loss: 0.0272 - root_mean_squared_error: 0.1246 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1274 - learning_rate: 1.0000e-04
# Epoch 69/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - loss: 0.0260 - root_mean_squared_error: 0.1207 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1277 - learning_rate: 1.0000e-04
# Epoch 70/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - loss: 0.0257 - root_mean_squared_error: 0.1205 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1269 - learning_rate: 1.0000e-04
# Epoch 71/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0254 - root_mean_squared_error: 0.1201 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1268 - learning_rate: 1.0000e-04
# Epoch 72/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - loss: 0.0249 - root_mean_squared_error: 0.1192 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1247 - learning_rate: 1.0000e-04
# Epoch 73/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 339ms/step - loss: 0.0247 - root_mean_squared_error: 0.1192 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1242 - learning_rate: 1.0000e-04
# Epoch 74/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - loss: 0.0241 - root_mean_squared_error: 0.1176 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1250 - learning_rate: 1.0000e-04
# Epoch 75/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - loss: 0.0240 - root_mean_squared_error: 0.1180 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1234 - learning_rate: 1.0000e-04
# Epoch 76/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 347ms/step - loss: 0.0236 - root_mean_squared_error: 0.1172 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1238 - learning_rate: 1.0000e-04
# Epoch 77/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 354ms/step - loss: 0.0232 - root_mean_squared_error: 0.1164 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1241 - learning_rate: 1.0000e-04
# Epoch 78/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - loss: 0.0227 - root_mean_squared_error: 0.1149 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1223 - learning_rate: 1.0000e-04
# Epoch 79/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0226 - root_mean_squared_error: 0.1157 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1217 - learning_rate: 1.0000e-04
# Epoch 80/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0220 - root_mean_squared_error: 0.1135 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1222 - learning_rate: 1.0000e-04
# Epoch 81/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.0219 - root_mean_squared_error: 0.1141 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1212 - learning_rate: 1.0000e-04
# Epoch 82/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - loss: 0.0218 - root_mean_squared_error: 0.1145 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1196 - learning_rate: 1.0000e-04
# Epoch 83/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 341ms/step - loss: 0.0219 - root_mean_squared_error: 0.1155 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1203 - learning_rate: 1.0000e-04
# Epoch 84/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 323ms/step - loss: 0.0208 - root_mean_squared_error: 0.1113 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1201 - learning_rate: 1.0000e-04
# Epoch 85/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.0211 - root_mean_squared_error: 0.1135 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1196 - learning_rate: 1.0000e-04
# Epoch 86/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0210 - root_mean_squared_error: 0.1136 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1191 - learning_rate: 1.0000e-04
# Epoch 87/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.0208 - root_mean_squared_error: 0.1136 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1189 - learning_rate: 1.0000e-04
# Epoch 88/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - loss: 0.0198 - root_mean_squared_error: 0.1099 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1179 - learning_rate: 1.0000e-04
# Epoch 89/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - loss: 0.0199 - root_mean_squared_error: 0.1112 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1180 - learning_rate: 1.0000e-04
# Epoch 90/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - loss: 0.0190 - root_mean_squared_error: 0.1074 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1183 - learning_rate: 1.0000e-04
# Epoch 91/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - loss: 0.0198 - root_mean_squared_error: 0.1118 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1168 - learning_rate: 1.0000e-04
# Epoch 92/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.0196 - root_mean_squared_error: 0.1118 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1166 - learning_rate: 1.0000e-04
# Epoch 93/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0189 - root_mean_squared_error: 0.1091 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1188 - learning_rate: 1.0000e-04
# Epoch 94/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 283ms/step - loss: 0.0190 - root_mean_squared_error: 0.1101 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1174 - learning_rate: 1.0000e-04
# Epoch 95/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0191 - root_mean_squared_error: 0.1110 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1169 - learning_rate: 1.0000e-04
# Epoch 96/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - loss: 0.0185 - root_mean_squared_error: 0.1090 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1157 - learning_rate: 1.0000e-04
# Epoch 97/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - loss: 0.0184 - root_mean_squared_error: 0.1089 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1171 - learning_rate: 1.0000e-04
# Epoch 98/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - loss: 0.0183 - root_mean_squared_error: 0.1094 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1160 - learning_rate: 1.0000e-04
# Epoch 99/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - loss: 0.0176 - root_mean_squared_error: 0.1064 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1151 - learning_rate: 1.0000e-04
# Epoch 100/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 341ms/step - loss: 0.0178 - root_mean_squared_error: 0.1080 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1144 - learning_rate: 1.0000e-04
# Epoch 101/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - loss: 0.0173 - root_mean_squared_error: 0.1062 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1141 - learning_rate: 1.0000e-04
# Epoch 102/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - loss: 0.0174 - root_mean_squared_error: 0.1070 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1154 - learning_rate: 1.0000e-04
# Epoch 103/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - loss: 0.0177 - root_mean_squared_error: 0.1088 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1156 - learning_rate: 1.0000e-04
# Epoch 104/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - loss: 0.0170 - root_mean_squared_error: 0.1061 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1164 - learning_rate: 1.0000e-04
# Epoch 105/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - loss: 0.0172 - root_mean_squared_error: 0.1078 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1145 - learning_rate: 1.0000e-04
# Epoch 106/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 347ms/step - loss: 0.0166 - root_mean_squared_error: 0.1052 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1142 - learning_rate: 1.0000e-04
# Epoch 107/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0161 - root_mean_squared_error: 0.1036 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1131 - learning_rate: 1.0000e-04
# Epoch 108/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - loss: 0.0163 - root_mean_squared_error: 0.1046 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1132 - learning_rate: 1.0000e-04
# Epoch 109/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - loss: 0.0167 - root_mean_squared_error: 0.1070 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1121 - learning_rate: 1.0000e-04
# Epoch 110/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - loss: 0.0163 - root_mean_squared_error: 0.1057 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1119 - learning_rate: 1.0000e-04
# Epoch 111/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0158 - root_mean_squared_error: 0.1037 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1127 - learning_rate: 1.0000e-04
# Epoch 112/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0160 - root_mean_squared_error: 0.1050 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1124 - learning_rate: 1.0000e-04
# Epoch 113/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - loss: 0.0155 - root_mean_squared_error: 0.1029 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1114 - learning_rate: 1.0000e-04
# Epoch 114/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0154 - root_mean_squared_error: 0.1029 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1128 - learning_rate: 1.0000e-04
# Epoch 115/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0153 - root_mean_squared_error: 0.1029 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1129 - learning_rate: 1.0000e-04
# Epoch 116/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.0156 - root_mean_squared_error: 0.1047 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1135 - learning_rate: 1.0000e-04
# Epoch 117/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.0152 - root_mean_squared_error: 0.1031 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1111 - learning_rate: 1.0000e-04
# Epoch 118/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - loss: 0.0149 - root_mean_squared_error: 0.1018 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1109 - learning_rate: 1.0000e-04
# Epoch 119/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.0149 - root_mean_squared_error: 0.1022 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1098 - learning_rate: 1.0000e-04
# Epoch 120/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - loss: 0.0141 - root_mean_squared_error: 0.0987 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1098 - learning_rate: 1.0000e-04
# Epoch 121/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 353ms/step - loss: 0.0147 - root_mean_squared_error: 0.1019 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1097 - learning_rate: 1.0000e-04
# Epoch 122/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - loss: 0.0145 - root_mean_squared_error: 0.1013 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1089 - learning_rate: 1.0000e-04
# Epoch 123/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - loss: 0.0144 - root_mean_squared_error: 0.1012 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1099 - learning_rate: 1.0000e-04
# Epoch 124/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 0.0151 - root_mean_squared_error: 0.1049 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1090 - learning_rate: 1.0000e-04
# Epoch 125/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.0144 - root_mean_squared_error: 0.1017 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1081 - learning_rate: 1.0000e-04
# Epoch 126/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0138 - root_mean_squared_error: 0.0992 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1080 - learning_rate: 1.0000e-04
# Epoch 127/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - loss: 0.0140 - root_mean_squared_error: 0.1005 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1080 - learning_rate: 1.0000e-04
# Epoch 128/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - loss: 0.0137 - root_mean_squared_error: 0.0991 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1078 - learning_rate: 1.0000e-04
# Epoch 129/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - loss: 0.0137 - root_mean_squared_error: 0.0995 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1077 - learning_rate: 1.0000e-04
# Epoch 130/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - loss: 0.0134 - root_mean_squared_error: 0.0982 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1070 - learning_rate: 1.0000e-04
# Epoch 131/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - loss: 0.0134 - root_mean_squared_error: 0.0985 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1067 - learning_rate: 1.0000e-04
# Epoch 132/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - loss: 0.0134 - root_mean_squared_error: 0.0988 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1076 - learning_rate: 1.0000e-04
# Epoch 133/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.0130 - root_mean_squared_error: 0.0972 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1068 - learning_rate: 1.0000e-04
# Epoch 134/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.0130 - root_mean_squared_error: 0.0972 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1058 - learning_rate: 1.0000e-04
# Epoch 135/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0132 - root_mean_squared_error: 0.0984 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1058 - learning_rate: 1.0000e-04
# Epoch 136/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.0129 - root_mean_squared_error: 0.0970 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1058 - learning_rate: 1.0000e-04
# Epoch 137/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.0126 - root_mean_squared_error: 0.0960 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1050 - learning_rate: 1.0000e-04
# Epoch 138/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - loss: 0.0124 - root_mean_squared_error: 0.0953 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1065 - learning_rate: 1.0000e-04
# Epoch 139/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0126 - root_mean_squared_error: 0.0962 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1042 - learning_rate: 1.0000e-04
# Epoch 140/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0121 - root_mean_squared_error: 0.0942 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1044 - learning_rate: 1.0000e-04
# Epoch 141/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 323ms/step - loss: 0.0120 - root_mean_squared_error: 0.0936 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1043 - learning_rate: 1.0000e-04
# Epoch 142/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - loss: 0.0119 - root_mean_squared_error: 0.0935 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1037 - learning_rate: 1.0000e-04
# Epoch 143/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0122 - root_mean_squared_error: 0.0952 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1048 - learning_rate: 1.0000e-04
# Epoch 144/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.0122 - root_mean_squared_error: 0.0953 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1052 - learning_rate: 1.0000e-04
# Epoch 145/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0117 - root_mean_squared_error: 0.0927 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1036 - learning_rate: 1.0000e-04
# Epoch 146/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.0121 - root_mean_squared_error: 0.0951 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1026 - learning_rate: 1.0000e-04
# Epoch 147/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 0.0114 - root_mean_squared_error: 0.0914 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1025 - learning_rate: 1.0000e-04
# Epoch 148/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - loss: 0.0117 - root_mean_squared_error: 0.0936 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1023 - learning_rate: 1.0000e-04
# Epoch 149/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - loss: 0.0117 - root_mean_squared_error: 0.0938 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1041 - learning_rate: 1.0000e-04
# Epoch 150/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - loss: 0.0125 - root_mean_squared_error: 0.0980 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1042 - learning_rate: 1.0000e-04
# Epoch 151/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.0120 - root_mean_squared_error: 0.0958 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1032 - learning_rate: 1.0000e-04
# Epoch 152/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.0110 - root_mean_squared_error: 0.0904 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1016 - learning_rate: 1.0000e-04
# Epoch 153/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - loss: 0.0110 - root_mean_squared_error: 0.0907 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1020 - learning_rate: 1.0000e-04
# Epoch 154/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - loss: 0.0111 - root_mean_squared_error: 0.0911 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1015 - learning_rate: 1.0000e-04
# Epoch 155/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - loss: 0.0109 - root_mean_squared_error: 0.0904 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1008 - learning_rate: 1.0000e-04
# Epoch 156/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 346ms/step - loss: 0.0111 - root_mean_squared_error: 0.0916 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0996 - learning_rate: 1.0000e-04
# Epoch 157/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - loss: 0.0108 - root_mean_squared_error: 0.0899 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0995 - learning_rate: 1.0000e-04
# Epoch 158/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - loss: 0.0108 - root_mean_squared_error: 0.0903 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1002 - learning_rate: 1.0000e-04
# Epoch 159/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0103 - root_mean_squared_error: 0.0877 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0997 - learning_rate: 1.0000e-04
# Epoch 160/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.0104 - root_mean_squared_error: 0.0883 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1001 - learning_rate: 1.0000e-04
# Epoch 161/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - loss: 0.0104 - root_mean_squared_error: 0.0884 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1005 - learning_rate: 1.0000e-04
# Epoch 162/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0104 - root_mean_squared_error: 0.0886 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0997 - learning_rate: 1.0000e-04
# Epoch 163/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.0104 - root_mean_squared_error: 0.0885 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0984 - learning_rate: 1.0000e-04
# Epoch 164/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - loss: 0.0098 - root_mean_squared_error: 0.0852 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0985 - learning_rate: 1.0000e-04
# Epoch 165/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - loss: 0.0101 - root_mean_squared_error: 0.0871 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0994 - learning_rate: 1.0000e-04
# Epoch 166/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - loss: 0.0100 - root_mean_squared_error: 0.0871 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0982 - learning_rate: 1.0000e-04
# Epoch 167/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0097 - root_mean_squared_error: 0.0852 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0976 - learning_rate: 1.0000e-04
# Epoch 168/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0097 - root_mean_squared_error: 0.0855 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1011 - learning_rate: 1.0000e-04
# Epoch 169/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0101 - root_mean_squared_error: 0.0880 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0987 - learning_rate: 1.0000e-04
# Epoch 170/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0097 - root_mean_squared_error: 0.0854 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0977 - learning_rate: 1.0000e-04
# Epoch 171/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0097 - root_mean_squared_error: 0.0857 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0977 - learning_rate: 1.0000e-04
# Epoch 172/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0096 - root_mean_squared_error: 0.0855 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0972 - learning_rate: 1.0000e-04
# Epoch 173/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.0091 - root_mean_squared_error: 0.0827 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0972 - learning_rate: 1.0000e-04
# Epoch 174/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0093 - root_mean_squared_error: 0.0840 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0959 - learning_rate: 1.0000e-04
# Epoch 175/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0091 - root_mean_squared_error: 0.0830 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0959 - learning_rate: 1.0000e-04
# Epoch 176/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0092 - root_mean_squared_error: 0.0835 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0953 - learning_rate: 1.0000e-04
# Epoch 177/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - loss: 0.0096 - root_mean_squared_error: 0.0858 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0965 - learning_rate: 1.0000e-04
# Epoch 178/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.0090 - root_mean_squared_error: 0.0825 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0947 - learning_rate: 1.0000e-04
# Epoch 179/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0091 - root_mean_squared_error: 0.0834 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0952 - learning_rate: 1.0000e-04
# Epoch 180/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0088 - root_mean_squared_error: 0.0815 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0947 - learning_rate: 1.0000e-04
# Epoch 181/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - loss: 0.0092 - root_mean_squared_error: 0.0838 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0950 - learning_rate: 1.0000e-04
# Epoch 182/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - loss: 0.0087 - root_mean_squared_error: 0.0810 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0947 - learning_rate: 1.0000e-04
# Epoch 183/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.0089 - root_mean_squared_error: 0.0823 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0952 - learning_rate: 1.0000e-04
# Epoch 184/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0089 - root_mean_squared_error: 0.0826 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0944 - learning_rate: 1.0000e-04
# Epoch 185/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - loss: 0.0087 - root_mean_squared_error: 0.0811 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0944 - learning_rate: 1.0000e-04
# Epoch 186/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.0084 - root_mean_squared_error: 0.0795 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0957 - learning_rate: 1.0000e-04
# Epoch 187/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.0087 - root_mean_squared_error: 0.0818 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0948 - learning_rate: 1.0000e-04
# Epoch 188/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0087 - root_mean_squared_error: 0.0814 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0944 - learning_rate: 1.0000e-04
# Epoch 189/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 283ms/step - loss: 0.0086 - root_mean_squared_error: 0.0811 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0947 - learning_rate: 1.0000e-04
# Epoch 190/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0083 - root_mean_squared_error: 0.0794 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0937 - learning_rate: 1.0000e-04
# Epoch 191/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 345ms/step - loss: 0.0083 - root_mean_squared_error: 0.0797 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0936 - learning_rate: 1.0000e-04
# Epoch 192/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 339ms/step - loss: 0.0084 - root_mean_squared_error: 0.0805 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0949 - learning_rate: 1.0000e-04
# Epoch 193/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - loss: 0.0080 - root_mean_squared_error: 0.0781 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0943 - learning_rate: 1.0000e-04
# Epoch 194/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0081 - root_mean_squared_error: 0.0788 - val_loss: 0.0107 - val_root_mean_squared_error: 0.0939 - learning_rate: 1.0000e-04
# Epoch 195/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0080 - root_mean_squared_error: 0.0780 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0930 - learning_rate: 1.0000e-04
# Epoch 196/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.0079 - root_mean_squared_error: 0.0776 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0930 - learning_rate: 1.0000e-04
# Epoch 197/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0082 - root_mean_squared_error: 0.0792 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0923 - learning_rate: 1.0000e-04
# Epoch 198/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0081 - root_mean_squared_error: 0.0792 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0933 - learning_rate: 1.0000e-04
# Epoch 199/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0078 - root_mean_squared_error: 0.0771 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0921 - learning_rate: 1.0000e-04
# Epoch 200/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.0081 - root_mean_squared_error: 0.0789 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0924 - learning_rate: 1.0000e-04
# Epoch 201/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.0080 - root_mean_squared_error: 0.0784 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0917 - learning_rate: 1.0000e-04
# Epoch 202/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - loss: 0.0078 - root_mean_squared_error: 0.0773 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0916 - learning_rate: 1.0000e-04
# Epoch 203/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - loss: 0.0077 - root_mean_squared_error: 0.0771 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0919 - learning_rate: 1.0000e-04
# Epoch 204/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.0075 - root_mean_squared_error: 0.0753 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0935 - learning_rate: 1.0000e-04
# Epoch 205/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - loss: 0.0077 - root_mean_squared_error: 0.0770 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0924 - learning_rate: 1.0000e-04
# Epoch 206/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 298ms/step - loss: 0.0075 - root_mean_squared_error: 0.0760 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0917 - learning_rate: 1.0000e-04
# Epoch 207/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - loss: 0.0079 - root_mean_squared_error: 0.0784 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0914 - learning_rate: 1.0000e-04
# Epoch 208/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0076 - root_mean_squared_error: 0.0765 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0921 - learning_rate: 1.0000e-04
# Epoch 209/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0077 - root_mean_squared_error: 0.0775 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0916 - learning_rate: 1.0000e-04
# Epoch 210/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0074 - root_mean_squared_error: 0.0752 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0916 - learning_rate: 1.0000e-04
# Epoch 211/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0074 - root_mean_squared_error: 0.0757 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0911 - learning_rate: 1.0000e-04
# Epoch 212/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.0073 - root_mean_squared_error: 0.0748 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0913 - learning_rate: 1.0000e-04
# Epoch 213/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - loss: 0.0073 - root_mean_squared_error: 0.0749 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0905 - learning_rate: 1.0000e-04
# Epoch 214/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - loss: 0.0072 - root_mean_squared_error: 0.0744 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0906 - learning_rate: 1.0000e-04
# Epoch 215/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - loss: 0.0072 - root_mean_squared_error: 0.0741 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0906 - learning_rate: 1.0000e-04
# Epoch 216/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 345ms/step - loss: 0.0072 - root_mean_squared_error: 0.0748 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0902 - learning_rate: 1.0000e-04
# Epoch 217/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - loss: 0.0072 - root_mean_squared_error: 0.0746 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0911 - learning_rate: 1.0000e-04
# Epoch 218/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - loss: 0.0072 - root_mean_squared_error: 0.0748 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0906 - learning_rate: 1.0000e-04
# Epoch 219/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0073 - root_mean_squared_error: 0.0754 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0903 - learning_rate: 1.0000e-04
# Epoch 220/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.0071 - root_mean_squared_error: 0.0742 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0904 - learning_rate: 1.0000e-04
# Epoch 221/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0071 - root_mean_squared_error: 0.0739 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0906 - learning_rate: 1.0000e-04
# Epoch 222/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.0070 - root_mean_squared_error: 0.0737 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0908 - learning_rate: 1.0000e-04
# Epoch 223/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.0072 - root_mean_squared_error: 0.0753 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0901 - learning_rate: 1.0000e-04
# Epoch 224/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.0070 - root_mean_squared_error: 0.0736 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0913 - learning_rate: 1.0000e-04
# Epoch 225/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0069 - root_mean_squared_error: 0.0730 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0897 - learning_rate: 1.0000e-04
# Epoch 226/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - loss: 0.0071 - root_mean_squared_error: 0.0744 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0900 - learning_rate: 1.0000e-04
# Epoch 227/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step - loss: 0.0069 - root_mean_squared_error: 0.0732 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0903 - learning_rate: 1.0000e-04
# Epoch 228/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - loss: 0.0068 - root_mean_squared_error: 0.0727 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0894 - learning_rate: 1.0000e-04
# Epoch 229/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.0069 - root_mean_squared_error: 0.0733 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0907 - learning_rate: 1.0000e-04
# Epoch 230/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.0069 - root_mean_squared_error: 0.0737 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0896 - learning_rate: 1.0000e-04
# Epoch 231/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - loss: 0.0066 - root_mean_squared_error: 0.0713 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0890 - learning_rate: 1.0000e-04
# Epoch 232/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.0067 - root_mean_squared_error: 0.0722 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0908 - learning_rate: 1.0000e-04
# Epoch 233/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0068 - root_mean_squared_error: 0.0730 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0883 - learning_rate: 1.0000e-04
# Epoch 234/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0064 - root_mean_squared_error: 0.0707 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0898 - learning_rate: 1.0000e-04
# Epoch 235/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.0067 - root_mean_squared_error: 0.0723 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0886 - learning_rate: 1.0000e-04
# Epoch 236/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0065 - root_mean_squared_error: 0.0714 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0887 - learning_rate: 1.0000e-04
# Epoch 237/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0065 - root_mean_squared_error: 0.0714 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0885 - learning_rate: 1.0000e-04
# Epoch 238/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - loss: 0.0066 - root_mean_squared_error: 0.0723 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0892 - learning_rate: 1.0000e-04
# Epoch 239/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0065 - root_mean_squared_error: 0.0713 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0896 - learning_rate: 1.0000e-04
# Epoch 240/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - loss: 0.0064 - root_mean_squared_error: 0.0705 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0899 - learning_rate: 1.0000e-04
# Epoch 241/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.0066 - root_mean_squared_error: 0.0725 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0887 - learning_rate: 1.0000e-04
# Epoch 242/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0063 - root_mean_squared_error: 0.0704 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0904 - learning_rate: 1.0000e-04
# Epoch 243/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0068 - root_mean_squared_error: 0.0740 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0906 - learning_rate: 1.0000e-04
# Epoch 244/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0069 - root_mean_squared_error: 0.0746 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0891 - learning_rate: 1.0000e-04
# Epoch 245/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.0064 - root_mean_squared_error: 0.0714 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0901 - learning_rate: 1.0000e-04
# Epoch 246/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - loss: 0.0067 - root_mean_squared_error: 0.0730 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0892 - learning_rate: 1.0000e-04
# Epoch 247/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - loss: 0.0065 - root_mean_squared_error: 0.0721 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0885 - learning_rate: 1.0000e-04
# Epoch 248/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.0065 - root_mean_squared_error: 0.0722 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0894 - learning_rate: 1.0000e-04
# Epoch 249/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0066 - root_mean_squared_error: 0.0729 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0890 - learning_rate: 1.0000e-04
# Epoch 250/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - loss: 0.0066 - root_mean_squared_error: 0.0727 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0896 - learning_rate: 1.0000e-04
# Epoch 251/100000
# ...
# Epoch 285/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0058 - root_mean_squared_error: 0.0689 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0878 - learning_rate: 1.0000e-04
# Epoch 286/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.0058 - root_mean_squared_error: 0.0692 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0866 - learning_rate: 1.0000e-04
# Epoch 287/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0057 - root_mean_squared_error: 0.0681 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0861 - learning_rate: 1.0000e-04
# Epoch 288/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.0055 - root_mean_squared_error: 0.0668 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0852 - learning_rate: 1.0000e-04
# Epoch 289/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0054 - root_mean_squared_error: 0.0661 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0870 - learning_rate: 1.0000e-04
# Epoch 290/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0057 - root_mean_squared_error: 0.0685 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0854 - learning_rate: 1.0000e-04
# Epoch 291/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0057 - root_mean_squared_error: 0.0681 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0894 - learning_rate: 1.0000e-04
# Epoch 292/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.0056 - root_mean_squared_error: 0.0678 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0863 - learning_rate: 1.0000e-04
# Epoch 293/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0056 - root_mean_squared_error: 0.0674 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0860 - learning_rate: 1.0000e-04
# Epoch 294/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0055 - root_mean_squared_error: 0.0673 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0849 - learning_rate: 1.0000e-04
# Epoch 295/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.0055 - root_mean_squared_error: 0.0673 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0859 - learning_rate: 1.0000e-04
# Epoch 296/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.0055 - root_mean_squared_error: 0.0667 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0853 - learning_rate: 1.0000e-04
# Epoch 297/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.0054 - root_mean_squared_error: 0.0661 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0853 - learning_rate: 1.0000e-04
# Epoch 298/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - loss: 0.0055 - root_mean_squared_error: 0.0669 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0857 - learning_rate: 1.0000e-04
# Epoch 299/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0052 - root_mean_squared_error: 0.0648 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0853 - learning_rate: 1.0000e-04
# Epoch 300/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0053 - root_mean_squared_error: 0.0654 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0848 - learning_rate: 1.0000e-04
# Epoch 301/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0054 - root_mean_squared_error: 0.0663 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0850 - learning_rate: 1.0000e-04
# Epoch 302/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0052 - root_mean_squared_error: 0.0647 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0850 - learning_rate: 1.0000e-04
# Epoch 303/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0055 - root_mean_squared_error: 0.0671 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0851 - learning_rate: 1.0000e-04
# Epoch 304/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0053 - root_mean_squared_error: 0.0659 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0858 - learning_rate: 1.0000e-04
# Epoch 305/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0055 - root_mean_squared_error: 0.0675 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0854 - learning_rate: 1.0000e-04
# Epoch 306/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0052 - root_mean_squared_error: 0.0655 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0848 - learning_rate: 1.0000e-04
# Epoch 307/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0053 - root_mean_squared_error: 0.0660 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0852 - learning_rate: 1.0000e-04
# Epoch 308/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - loss: 0.0052 - root_mean_squared_error: 0.0653 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0844 - learning_rate: 1.0000e-04
# Epoch 309/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 355ms/step - loss: 0.0052 - root_mean_squared_error: 0.0650 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0839 - learning_rate: 1.0000e-04
# Epoch 310/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - loss: 0.0054 - root_mean_squared_error: 0.0668 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0864 - learning_rate: 1.0000e-04
# Epoch 311/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0053 - root_mean_squared_error: 0.0659 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0860 - learning_rate: 1.0000e-04
# Epoch 312/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.0054 - root_mean_squared_error: 0.0672 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0848 - learning_rate: 1.0000e-04
# Epoch 313/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.0052 - root_mean_squared_error: 0.0656 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0843 - learning_rate: 1.0000e-04
# Epoch 314/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0050 - root_mean_squared_error: 0.0642 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0849 - learning_rate: 1.0000e-04
# Epoch 315/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0053 - root_mean_squared_error: 0.0661 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0848 - learning_rate: 1.0000e-04
# Epoch 316/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.0051 - root_mean_squared_error: 0.0645 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0847 - learning_rate: 1.0000e-04
# Epoch 317/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0052 - root_mean_squared_error: 0.0655 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0846 - learning_rate: 1.0000e-04
# Epoch 318/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0052 - root_mean_squared_error: 0.0652 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0847 - learning_rate: 1.0000e-04
# Epoch 319/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0051 - root_mean_squared_error: 0.0645 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0836 - learning_rate: 1.0000e-04
# Epoch 320/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.0052 - root_mean_squared_error: 0.0652 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0838 - learning_rate: 1.0000e-04
# Epoch 321/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0050 - root_mean_squared_error: 0.0640 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0837 - learning_rate: 1.0000e-04
# Epoch 322/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.0050 - root_mean_squared_error: 0.0644 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0837 - learning_rate: 1.0000e-04
# Epoch 323/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0049 - root_mean_squared_error: 0.0636 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0839 - learning_rate: 1.0000e-04
# Epoch 324/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0049 - root_mean_squared_error: 0.0638 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0838 - learning_rate: 1.0000e-04
# Epoch 325/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.0050 - root_mean_squared_error: 0.0643 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0843 - learning_rate: 1.0000e-04
# Epoch 326/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - loss: 0.0049 - root_mean_squared_error: 0.0633 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0840 - learning_rate: 1.0000e-04
# Epoch 327/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - loss: 0.0049 - root_mean_squared_error: 0.0634 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0830 - learning_rate: 1.0000e-04
# Epoch 328/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - loss: 0.0049 - root_mean_squared_error: 0.0636 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0831 - learning_rate: 1.0000e-04
# Epoch 329/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.0051 - root_mean_squared_error: 0.0651 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0839 - learning_rate: 1.0000e-04
# Epoch 330/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0048 - root_mean_squared_error: 0.0627 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0850 - learning_rate: 1.0000e-04
# Epoch 331/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - loss: 0.0050 - root_mean_squared_error: 0.0642 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0857 - learning_rate: 1.0000e-04
# Epoch 332/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - loss: 0.0049 - root_mean_squared_error: 0.0637 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0828 - learning_rate: 1.0000e-04
# Epoch 333/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.0048 - root_mean_squared_error: 0.0627 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0841 - learning_rate: 1.0000e-04
# Epoch 334/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.0051 - root_mean_squared_error: 0.0651 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0837 - learning_rate: 1.0000e-04
# Epoch 335/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.0050 - root_mean_squared_error: 0.0644 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0836 - learning_rate: 1.0000e-04
# Epoch 336/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.0048 - root_mean_squared_error: 0.0633 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0849 - learning_rate: 1.0000e-04
# Epoch 337/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 282ms/step - loss: 0.0050 - root_mean_squared_error: 0.0644 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0830 - learning_rate: 1.0000e-04
# Epoch 338/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.0047 - root_mean_squared_error: 0.0619 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0848 - learning_rate: 1.0000e-04
# Epoch 339/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0050 - root_mean_squared_error: 0.0645 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0841 - learning_rate: 1.0000e-04
# Epoch 340/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0047 - root_mean_squared_error: 0.0623 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0830 - learning_rate: 1.0000e-04
# Epoch 341/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0046 - root_mean_squared_error: 0.0614 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0836 - learning_rate: 1.0000e-04
# Epoch 342/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0047 - root_mean_squared_error: 0.0627 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0828 - learning_rate: 1.0000e-04
# Epoch 343/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0048 - root_mean_squared_error: 0.0630 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0837 - learning_rate: 1.0000e-04
# Epoch 344/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - loss: 0.0048 - root_mean_squared_error: 0.0635 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0832 - learning_rate: 1.0000e-04
# Epoch 345/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - loss: 0.0049 - root_mean_squared_error: 0.0637 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0847 - learning_rate: 1.0000e-04
# Epoch 346/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0046 - root_mean_squared_error: 0.0617 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0839 - learning_rate: 1.0000e-04
# Epoch 347/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.0048 - root_mean_squared_error: 0.0635 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0842 - learning_rate: 1.0000e-04
# Epoch 348/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.0049 - root_mean_squared_error: 0.0645 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0841 - learning_rate: 1.0000e-04
# Epoch 349/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0050 - root_mean_squared_error: 0.0653 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0834 - learning_rate: 1.0000e-04
# Epoch 350/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - loss: 0.0047 - root_mean_squared_error: 0.0629 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0850 - learning_rate: 1.0000e-04
# Epoch 351/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - loss: 0.0049 - root_mean_squared_error: 0.0644 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0830 - learning_rate: 1.0000e-04
# Epoch 352/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - loss: 0.0044 - root_mean_squared_error: 0.0605 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0820 - learning_rate: 1.0000e-04
# Epoch 353/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0047 - root_mean_squared_error: 0.0625 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0833 - learning_rate: 1.0000e-04
# Epoch 354/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.0045 - root_mean_squared_error: 0.0614 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0825 - learning_rate: 1.0000e-04
# Epoch 355/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.0046 - root_mean_squared_error: 0.0624 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0838 - learning_rate: 1.0000e-04
# Epoch 356/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0048 - root_mean_squared_error: 0.0634 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0822 - learning_rate: 1.0000e-04
# Epoch 357/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0044 - root_mean_squared_error: 0.0604 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0817 - learning_rate: 1.0000e-04
# Epoch 358/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0045 - root_mean_squared_error: 0.0613 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0825 - learning_rate: 1.0000e-04
# Epoch 359/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0046 - root_mean_squared_error: 0.0624 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0829 - learning_rate: 1.0000e-04
# Epoch 360/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0045 - root_mean_squared_error: 0.0610 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0833 - learning_rate: 1.0000e-04
# Epoch 361/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0046 - root_mean_squared_error: 0.0625 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0824 - learning_rate: 1.0000e-04
# Epoch 362/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 202ms/step - loss: 0.0043 - root_mean_squared_error: 0.0599 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0825 - learning_rate: 1.0000e-04
# Epoch 363/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - loss: 0.0043 - root_mean_squared_error: 0.0601 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0824 - learning_rate: 1.0000e-04
# Epoch 364/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.0045 - root_mean_squared_error: 0.0614 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0829 - learning_rate: 1.0000e-04
# Epoch 365/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0043 - root_mean_squared_error: 0.0597 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0835 - learning_rate: 1.0000e-04
# Epoch 366/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0044 - root_mean_squared_error: 0.0607 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0821 - learning_rate: 1.0000e-04
# Epoch 367/100000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - loss: 0.0044 - root_mean_squared_error: 0.0609 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0839 - learning_rate: 1.0000e-04

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test_final, y_test_final)
print(f'Test Loss: {test_loss}')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0095 - root_mean_squared_error: 0.0934
# Test Loss: [0.00892413780093193, 0.09042338281869888]

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_test2\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 4))
    
    # Plot the true and predicted values on the first subplot
    axs[0].plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    axs[0].plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    axs[0].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[0].set_title(f'True vs Predicted Values for {coordinate_name}')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel(f'{coordinate_name} Value')
    axs[0].legend()
    
    # Example of another plot (e.g., residuals or difference between predicted and true values)
    original_timeseries = np.array(row[coordinate_name])
    axs[1].plot(range(len(original_timeseries)), original_timeseries, label="Timeseries")
    axs[1].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[1].set_title(f'Original {coordinate_name} trajectory')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel(f'{coordinate_name} Value')
    axs[1].legend()

        # Extract the initial sequence from the DataFrame

# %%
# Assuming model is trained and X_train, y_train are defined
def scale_with(sequence, y_scaler):
    print(f"Shape: {sequence.shape}")
    return y_scaler.transform(sequence)

# %%
# One coordinate prediction
sample_index = 1
predictions_scaled = model.predict(X_test_scaled)

if y_train.shape[-1] == 1:
    #predictions_scaled = model.predict(X_test_scaled)
    #print(predictions_scaled.shape)
    #print(predictions_scaled[0])
    initial_seq = X_test[sample_index, :, -2]
    print(f"initial seq shape: {initial_seq.shape}")
    initial_seq = initial_seq.reshape((75, 1))
    print(f"initial seq shape: {initial_seq.shape}")
    initial_seq_scaled = scale_with(initial_seq, y_scaler)
    true_values = y_test_scaled[sample_index, :, :]  # True values
    predicted_values = predictions_scaled[sample_index, :, :]  # Predicted values
    # # Plot for Head_X_Coordinate
    plot_predictions3(initial_seq_scaled[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_Y_Coordinate', test_df.iloc[sample_index])
else:
    X_test_inv_scaled = inverse_transform_data(X_test_scaled, x_scaler)
    X_test_inv_rel = revert_relative_change_y(X_test_inv_scaled, X_test[sample_index][0])

    y_test_inv_scaled = inverse_transform_data(y_test_scaled, y_scaler)
    y_test_inv_rel = revert_relative_change_y(y_test_inv_scaled, y_test[sample_index][0])

    prediction_inv_scaled = inverse_transform_data(predictions_scaled, y_scaler)
    predictions_inv_rel = revert_relative_change_y(prediction_inv_scaled, y_test[sample_index][0])

    plot_predictions3(X_test_inv_rel[sample_index, :, -3], y_test_inv_rel[sample_index, :, 0], predictions_inv_rel[sample_index, :, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])
    # # # # Plot for Head_Y_Coordinate
    plot_predictions3(X_test_inv_rel[sample_index, :, -2], y_test_inv_rel[sample_index, :, 1], predictions_inv_rel[sample_index, :, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])
    # # # # Plot for Head_Z_Coordinate
    plot_predictions3(X_test_inv_rel[sample_index, :, -1], y_test_inv_rel[sample_index, :, 2], predictions_inv_rel[sample_index, :, 2], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
