# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - η διαφορα του με το 5_XYZ_only_norm ειναι οτι to normalization εχει boundaries για καθε row.
# - Σε αυτο θα βρω τα συνολικα xminmax, yminmax, zminmax και θα χρησιμοποιησω αυτα.

# %% [markdown]
# # Check 5_XYZ_only_norm2_1. I Use linear there as activation function of the last layer....
# # I should also research about using tanh and the normalization to be between [-1, 1] :)

# %%
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 10977.19row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0              220.000           -288.045           1575.416
# 1              220.000           -288.045           1575.411
# 2              220.000           -288.045           1575.396
# 3              220.000           -288.045           1575.391
# 4              220.000           -288.045           1575.377
# ..                 ...                ...                ...
# 296           2724.310           -409.036            947.462
# 297           2738.592           -410.063            948.136
# 298           2752.923           -411.087            948.848
# 299           2767.306           -412.109            949.599
# 300           2781.744           -413.132            950.386
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
train_df.shape
# Out:
# (711, 11)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 125

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Reshape to 2D (flatten the last dimension)

X_train_reshaped = X_train.reshape(-1, X_train.shape[2])

# Apply the scaler (you can also use MinMaxScaler here)
x_scaler = StandardScaler()
X_train_scaled = x_scaler.fit_transform(X_train_reshaped)
# Reshape back to 3D (711, 75, 11)
X_train_scaled = X_train_scaled.reshape(X_train.shape)
# Now X_train_scaled is normalized
X_train_scaled.shape
# Out:
# (711, 75, 11)

# %%
import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_1\\x_scaler.save"
joblib.dump(x_scaler, scaler_filename)
# Out:
# ['C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_1\\x_scaler.save']

# %%
X_val_reshaped = X_val.reshape(-1, X_val.shape[2])
X_val_scaled = x_scaler.transform(X_val_reshaped)
X_val_scaled = X_val_scaled.reshape(X_val.shape)

X_test_reshaped = X_test.reshape(-1, X_test.shape[2])
X_test_scaled = x_scaler.transform(X_test_reshaped)
X_test_scaled = X_test_scaled.reshape(X_test.shape)

# %%
# Scaling test values

y_train_reshaped = y_train.reshape(-1, y_train.shape[2])

# Apply the scaler (you can also use MinMaxScaler here)
y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train_reshaped)
# Reshape back to 3D (711, 75, 11)
y_train_scaled = y_train_scaled.reshape(y_train.shape)
# Now X_train_scaled is normalized

import joblib
scaler_filename = "C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_1\\y_scaler.save"
joblib.dump(y_scaler, scaler_filename)

y_val_reshaped = y_val.reshape(-1, y_val.shape[2])
y_val_scaled = y_scaler.transform(y_val_reshaped)
y_val_scaled = y_val_scaled.reshape(y_val.shape)

y_test_reshaped = y_test.reshape(-1, y_test.shape[2])
y_test_scaled = y_scaler.transform(y_test_reshaped)
y_test_scaled = y_test_scaled.reshape(y_test.shape)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 3, activation="linear"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional) │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 375)            │        12,375 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 125, 3)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,607 (623.46 KB)
#  Trainable params: 159,607 (623.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_1\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train_scaled, y_train_scaled, validation_data=(X_val_scaled, y_val_scaled), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - loss: 1.0129 - root_mean_squared_error: 0.9802 - val_loss: 1.0933 - val_root_mean_squared_error: 1.0213
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 1.0436 - root_mean_squared_error: 0.9968 - val_loss: 1.0689 - val_root_mean_squared_error: 1.0099
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 1.0099 - root_mean_squared_error: 0.9803 - val_loss: 1.0083 - val_root_mean_squared_error: 0.9799
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.9463 - root_mean_squared_error: 0.9477 - val_loss: 0.9200 - val_root_mean_squared_error: 0.9341
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.8801 - root_mean_squared_error: 0.9121 - val_loss: 0.8245 - val_root_mean_squared_error: 0.8818
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.7657 - root_mean_squared_error: 0.8477 - val_loss: 0.7315 - val_root_mean_squared_error: 0.8275
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.6669 - root_mean_squared_error: 0.7875 - val_loss: 0.6481 - val_root_mean_squared_error: 0.7757
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.6193 - root_mean_squared_error: 0.7568 - val_loss: 0.5788 - val_root_mean_squared_error: 0.7298
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.5457 - root_mean_squared_error: 0.7067 - val_loss: 0.5212 - val_root_mean_squared_error: 0.6894
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.4783 - root_mean_squared_error: 0.6576 - val_loss: 0.4742 - val_root_mean_squared_error: 0.6547
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.4401 - root_mean_squared_error: 0.6281 - val_loss: 0.4361 - val_root_mean_squared_error: 0.6251
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.4231 - root_mean_squared_error: 0.6145 - val_loss: 0.4056 - val_root_mean_squared_error: 0.6005
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.3636 - root_mean_squared_error: 0.5643 - val_loss: 0.3810 - val_root_mean_squared_error: 0.5798
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.3884 - root_mean_squared_error: 0.5858 - val_loss: 0.3568 - val_root_mean_squared_error: 0.5589
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - loss: 0.3662 - root_mean_squared_error: 0.5668 - val_loss: 0.3361 - val_root_mean_squared_error: 0.5402
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.3334 - root_mean_squared_error: 0.5376 - val_loss: 0.3198 - val_root_mean_squared_error: 0.5252
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.3016 - root_mean_squared_error: 0.5076 - val_loss: 0.3045 - val_root_mean_squared_error: 0.5107
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.2856 - root_mean_squared_error: 0.4916 - val_loss: 0.2889 - val_root_mean_squared_error: 0.4955
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.2723 - root_mean_squared_error: 0.4785 - val_loss: 0.2750 - val_root_mean_squared_error: 0.4815
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - loss: 0.2627 - root_mean_squared_error: 0.4685 - val_loss: 0.2621 - val_root_mean_squared_error: 0.4682
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.2748 - root_mean_squared_error: 0.4811 - val_loss: 0.2543 - val_root_mean_squared_error: 0.4601
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.2425 - root_mean_squared_error: 0.4470 - val_loss: 0.2439 - val_root_mean_squared_error: 0.4489
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.2346 - root_mean_squared_error: 0.4385 - val_loss: 0.2347 - val_root_mean_squared_error: 0.4389
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.2293 - root_mean_squared_error: 0.4327 - val_loss: 0.2272 - val_root_mean_squared_error: 0.4306
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.2254 - root_mean_squared_error: 0.4286 - val_loss: 0.2201 - val_root_mean_squared_error: 0.4226
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.2144 - root_mean_squared_error: 0.4158 - val_loss: 0.2129 - val_root_mean_squared_error: 0.4143
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.2114 - root_mean_squared_error: 0.4126 - val_loss: 0.2098 - val_root_mean_squared_error: 0.4110
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - loss: 0.2165 - root_mean_squared_error: 0.4190 - val_loss: 0.2045 - val_root_mean_squared_error: 0.4048
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - loss: 0.2124 - root_mean_squared_error: 0.4145 - val_loss: 0.2085 - val_root_mean_squared_error: 0.4101
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.2024 - root_mean_squared_error: 0.4026 - val_loss: 0.2011 - val_root_mean_squared_error: 0.4014
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.2025 - root_mean_squared_error: 0.4031 - val_loss: 0.1960 - val_root_mean_squared_error: 0.3953
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.2011 - root_mean_squared_error: 0.4017 - val_loss: 0.1924 - val_root_mean_squared_error: 0.3911
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1921 - root_mean_squared_error: 0.3908 - val_loss: 0.1888 - val_root_mean_squared_error: 0.3869
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1939 - root_mean_squared_error: 0.3935 - val_loss: 0.1892 - val_root_mean_squared_error: 0.3878
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1865 - root_mean_squared_error: 0.3844 - val_loss: 0.1871 - val_root_mean_squared_error: 0.3855
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1894 - root_mean_squared_error: 0.3885 - val_loss: 0.1842 - val_root_mean_squared_error: 0.3820
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.1904 - root_mean_squared_error: 0.3901 - val_loss: 0.1797 - val_root_mean_squared_error: 0.3765
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.1807 - root_mean_squared_error: 0.3780 - val_loss: 0.1760 - val_root_mean_squared_error: 0.3720
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.1820 - root_mean_squared_error: 0.3799 - val_loss: 0.1755 - val_root_mean_squared_error: 0.3716
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.1762 - root_mean_squared_error: 0.3726 - val_loss: 0.1720 - val_root_mean_squared_error: 0.3672
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1731 - root_mean_squared_error: 0.3689 - val_loss: 0.1726 - val_root_mean_squared_error: 0.3684
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1783 - root_mean_squared_error: 0.3761 - val_loss: 0.1684 - val_root_mean_squared_error: 0.3631
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1723 - root_mean_squared_error: 0.3685 - val_loss: 0.1664 - val_root_mean_squared_error: 0.3608
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1670 - root_mean_squared_error: 0.3616 - val_loss: 0.1651 - val_root_mean_squared_error: 0.3593
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.1721 - root_mean_squared_error: 0.3690 - val_loss: 0.1611 - val_root_mean_squared_error: 0.3541
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.1676 - root_mean_squared_error: 0.3633 - val_loss: 0.1605 - val_root_mean_squared_error: 0.3535
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.1674 - root_mean_squared_error: 0.3634 - val_loss: 0.1589 - val_root_mean_squared_error: 0.3516
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.1579 - root_mean_squared_error: 0.3503 - val_loss: 0.1571 - val_root_mean_squared_error: 0.3495
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.1609 - root_mean_squared_error: 0.3549 - val_loss: 0.1552 - val_root_mean_squared_error: 0.3471
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.1618 - root_mean_squared_error: 0.3566 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3439
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.1612 - root_mean_squared_error: 0.3560 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3443
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.1529 - root_mean_squared_error: 0.3445 - val_loss: 0.1480 - val_root_mean_squared_error: 0.3377
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - loss: 0.1512 - root_mean_squared_error: 0.3425 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3362
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.1493 - root_mean_squared_error: 0.3400 - val_loss: 0.1432 - val_root_mean_squared_error: 0.3313
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1482 - root_mean_squared_error: 0.3388 - val_loss: 0.1413 - val_root_mean_squared_error: 0.3288
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1483 - root_mean_squared_error: 0.3390 - val_loss: 0.1384 - val_root_mean_squared_error: 0.3247
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1431 - root_mean_squared_error: 0.3318 - val_loss: 0.1364 - val_root_mean_squared_error: 0.3220
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1394 - root_mean_squared_error: 0.3267 - val_loss: 0.1343 - val_root_mean_squared_error: 0.3190
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.1434 - root_mean_squared_error: 0.3331 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3190
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1381 - root_mean_squared_error: 0.3253 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3153
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1331 - root_mean_squared_error: 0.3180 - val_loss: 0.1261 - val_root_mean_squared_error: 0.3070
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 318ms/step - loss: 0.1316 - root_mean_squared_error: 0.3159 - val_loss: 0.1251 - val_root_mean_squared_error: 0.3057
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1340 - root_mean_squared_error: 0.3198 - val_loss: 0.1225 - val_root_mean_squared_error: 0.3019
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1293 - root_mean_squared_error: 0.3129 - val_loss: 0.1197 - val_root_mean_squared_error: 0.2975
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1222 - root_mean_squared_error: 0.3017 - val_loss: 0.1160 - val_root_mean_squared_error: 0.2916
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1192 - root_mean_squared_error: 0.2971 - val_loss: 0.1144 - val_root_mean_squared_error: 0.2891
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.1183 - root_mean_squared_error: 0.2959 - val_loss: 0.1140 - val_root_mean_squared_error: 0.2889
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.1174 - root_mean_squared_error: 0.2947 - val_loss: 0.1092 - val_root_mean_squared_error: 0.2809
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.1123 - root_mean_squared_error: 0.2863 - val_loss: 0.1066 - val_root_mean_squared_error: 0.2765
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.1099 - root_mean_squared_error: 0.2824 - val_loss: 0.1050 - val_root_mean_squared_error: 0.2739
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1077 - root_mean_squared_error: 0.2788 - val_loss: 0.1023 - val_root_mean_squared_error: 0.2694
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1072 - root_mean_squared_error: 0.2784 - val_loss: 0.1043 - val_root_mean_squared_error: 0.2734
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1100 - root_mean_squared_error: 0.2837 - val_loss: 0.0980 - val_root_mean_squared_error: 0.2620
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1029 - root_mean_squared_error: 0.2714 - val_loss: 0.0946 - val_root_mean_squared_error: 0.2558
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.1027 - root_mean_squared_error: 0.2712 - val_loss: 0.0955 - val_root_mean_squared_error: 0.2580
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1041 - root_mean_squared_error: 0.2741 - val_loss: 0.1118 - val_root_mean_squared_error: 0.2882
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.1145 - root_mean_squared_error: 0.2928 - val_loss: 0.1009 - val_root_mean_squared_error: 0.2688
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1048 - root_mean_squared_error: 0.2761 - val_loss: 0.0902 - val_root_mean_squared_error: 0.2486
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.0969 - root_mean_squared_error: 0.2617 - val_loss: 0.0876 - val_root_mean_squared_error: 0.2437
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.0911 - root_mean_squared_error: 0.2507 - val_loss: 0.0854 - val_root_mean_squared_error: 0.2396
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0915 - root_mean_squared_error: 0.2520 - val_loss: 0.0826 - val_root_mean_squared_error: 0.2340
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0916 - root_mean_squared_error: 0.2526 - val_loss: 0.0821 - val_root_mean_squared_error: 0.2332
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.0902 - root_mean_squared_error: 0.2502 - val_loss: 0.0796 - val_root_mean_squared_error: 0.2282
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0848 - root_mean_squared_error: 0.2393 - val_loss: 0.0787 - val_root_mean_squared_error: 0.2266
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0888 - root_mean_squared_error: 0.2479 - val_loss: 0.0780 - val_root_mean_squared_error: 0.2254
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.0841 - root_mean_squared_error: 0.2386 - val_loss: 0.0749 - val_root_mean_squared_error: 0.2188
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0817 - root_mean_squared_error: 0.2339 - val_loss: 0.0749 - val_root_mean_squared_error: 0.2194
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0826 - root_mean_squared_error: 0.2364 - val_loss: 0.0743 - val_root_mean_squared_error: 0.2184
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0808 - root_mean_squared_error: 0.2328 - val_loss: 0.0726 - val_root_mean_squared_error: 0.2150
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0833 - root_mean_squared_error: 0.2383 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2159
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0813 - root_mean_squared_error: 0.2348 - val_loss: 0.0705 - val_root_mean_squared_error: 0.2108
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0785 - root_mean_squared_error: 0.2291 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2093
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0754 - root_mean_squared_error: 0.2226 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2097
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0797 - root_mean_squared_error: 0.2325 - val_loss: 0.0695 - val_root_mean_squared_error: 0.2097
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0774 - root_mean_squared_error: 0.2276 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2067
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0777 - root_mean_squared_error: 0.2289 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2077
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0743 - root_mean_squared_error: 0.2219 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2044
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0752 - root_mean_squared_error: 0.2241 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2053
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0738 - root_mean_squared_error: 0.2214 - val_loss: 0.0650 - val_root_mean_squared_error: 0.2009
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0714 - root_mean_squared_error: 0.2163 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2031
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0727 - root_mean_squared_error: 0.2197 - val_loss: 0.0653 - val_root_mean_squared_error: 0.2027
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0734 - root_mean_squared_error: 0.2216 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2010
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0729 - root_mean_squared_error: 0.2210 - val_loss: 0.0649 - val_root_mean_squared_error: 0.2025
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0692 - root_mean_squared_error: 0.2129 - val_loss: 0.0633 - val_root_mean_squared_error: 0.1989
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0695 - root_mean_squared_error: 0.2140 - val_loss: 0.0632 - val_root_mean_squared_error: 0.1991
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0697 - root_mean_squared_error: 0.2149 - val_loss: 0.0625 - val_root_mean_squared_error: 0.1978
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0686 - root_mean_squared_error: 0.2127 - val_loss: 0.0625 - val_root_mean_squared_error: 0.1984
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0672 - root_mean_squared_error: 0.2097 - val_loss: 0.0631 - val_root_mean_squared_error: 0.2003
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0676 - root_mean_squared_error: 0.2111 - val_loss: 0.0616 - val_root_mean_squared_error: 0.1970
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0689 - root_mean_squared_error: 0.2148 - val_loss: 0.0612 - val_root_mean_squared_error: 0.1964
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0665 - root_mean_squared_error: 0.2095 - val_loss: 0.0613 - val_root_mean_squared_error: 0.1970
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0668 - root_mean_squared_error: 0.2106 - val_loss: 0.0609 - val_root_mean_squared_error: 0.1965
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0658 - root_mean_squared_error: 0.2086 - val_loss: 0.0598 - val_root_mean_squared_error: 0.1939
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0675 - root_mean_squared_error: 0.2129 - val_loss: 0.0589 - val_root_mean_squared_error: 0.1920
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0652 - root_mean_squared_error: 0.2080 - val_loss: 0.0586 - val_root_mean_squared_error: 0.1917
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.0630 - root_mean_squared_error: 0.2028 - val_loss: 0.0587 - val_root_mean_squared_error: 0.1925
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - loss: 0.0648 - root_mean_squared_error: 0.2077 - val_loss: 0.0575 - val_root_mean_squared_error: 0.1897
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0640 - root_mean_squared_error: 0.2062 - val_loss: 0.0579 - val_root_mean_squared_error: 0.1911
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - loss: 0.0671 - root_mean_squared_error: 0.2138 - val_loss: 0.0582 - val_root_mean_squared_error: 0.1923
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.0632 - root_mean_squared_error: 0.2051 - val_loss: 0.0565 - val_root_mean_squared_error: 0.1882
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0635 - root_mean_squared_error: 0.2059 - val_loss: 0.0561 - val_root_mean_squared_error: 0.1877
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0654 - root_mean_squared_error: 0.2111 - val_loss: 0.0563 - val_root_mean_squared_error: 0.1886
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.0629 - root_mean_squared_error: 0.2054 - val_loss: 0.0560 - val_root_mean_squared_error: 0.1882
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0626 - root_mean_squared_error: 0.2050 - val_loss: 0.0560 - val_root_mean_squared_error: 0.1886
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0639 - root_mean_squared_error: 0.2086 - val_loss: 0.0571 - val_root_mean_squared_error: 0.1919
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0662 - root_mean_squared_error: 0.2142 - val_loss: 0.0592 - val_root_mean_squared_error: 0.1977
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0606 - root_mean_squared_error: 0.2014 - val_loss: 0.0556 - val_root_mean_squared_error: 0.1889
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0600 - root_mean_squared_error: 0.2001 - val_loss: 0.0558 - val_root_mean_squared_error: 0.1897
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.0602 - root_mean_squared_error: 0.2009 - val_loss: 0.0554 - val_root_mean_squared_error: 0.1889
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0579 - root_mean_squared_error: 0.1956 - val_loss: 0.0544 - val_root_mean_squared_error: 0.1867
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0612 - root_mean_squared_error: 0.2042 - val_loss: 0.0541 - val_root_mean_squared_error: 0.1863
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0596 - root_mean_squared_error: 0.2006 - val_loss: 0.0541 - val_root_mean_squared_error: 0.1868
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0589 - root_mean_squared_error: 0.1993 - val_loss: 0.0542 - val_root_mean_squared_error: 0.1875
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0580 - root_mean_squared_error: 0.1973 - val_loss: 0.0541 - val_root_mean_squared_error: 0.1874
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0590 - root_mean_squared_error: 0.2002 - val_loss: 0.0533 - val_root_mean_squared_error: 0.1857
# Epoch 136/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0561 - root_mean_squared_error: 0.1932 - val_loss: 0.0539 - val_root_mean_squared_error: 0.1877
# Epoch 137/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0586 - root_mean_squared_error: 0.1999 - val_loss: 0.0523 - val_root_mean_squared_error: 0.1838
# Epoch 138/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0593 - root_mean_squared_error: 0.2019 - val_loss: 0.0548 - val_root_mean_squared_error: 0.1907
# Epoch 139/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.0580 - root_mean_squared_error: 0.1991 - val_loss: 0.0514 - val_root_mean_squared_error: 0.1819
# Epoch 140/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0556 - root_mean_squared_error: 0.1933 - val_loss: 0.0523 - val_root_mean_squared_error: 0.1847
# Epoch 141/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0556 - root_mean_squared_error: 0.1935 - val_loss: 0.0524 - val_root_mean_squared_error: 0.1855
# Epoch 142/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0552 - root_mean_squared_error: 0.1929 - val_loss: 0.0522 - val_root_mean_squared_error: 0.1853
# Epoch 143/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0565 - root_mean_squared_error: 0.1966 - val_loss: 0.0521 - val_root_mean_squared_error: 0.1854
# Epoch 144/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0546 - root_mean_squared_error: 0.1920 - val_loss: 0.0509 - val_root_mean_squared_error: 0.1824
# Epoch 145/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.0547 - root_mean_squared_error: 0.1927 - val_loss: 0.0511 - val_root_mean_squared_error: 0.1833
# Epoch 146/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0544 - root_mean_squared_error: 0.1921 - val_loss: 0.0499 - val_root_mean_squared_error: 0.1802
# Epoch 147/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 418ms/step - loss: 0.0557 - root_mean_squared_error: 0.1957 - val_loss: 0.0518 - val_root_mean_squared_error: 0.1859
# Epoch 148/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 353ms/step - loss: 0.0557 - root_mean_squared_error: 0.1963 - val_loss: 0.0511 - val_root_mean_squared_error: 0.1842
# Epoch 149/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - loss: 0.0534 - root_mean_squared_error: 0.1905 - val_loss: 0.0505 - val_root_mean_squared_error: 0.1831
# Epoch 150/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - loss: 0.0538 - root_mean_squared_error: 0.1919 - val_loss: 0.0503 - val_root_mean_squared_error: 0.1828
# Epoch 151/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - loss: 0.0545 - root_mean_squared_error: 0.1939 - val_loss: 0.0499 - val_root_mean_squared_error: 0.1822
# Epoch 152/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0555 - root_mean_squared_error: 0.1969 - val_loss: 0.0481 - val_root_mean_squared_error: 0.1774
# Epoch 153/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.0529 - root_mean_squared_error: 0.1904 - val_loss: 0.0495 - val_root_mean_squared_error: 0.1817
# Epoch 154/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0528 - root_mean_squared_error: 0.1906 - val_loss: 0.0501 - val_root_mean_squared_error: 0.1837
# Epoch 155/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0525 - root_mean_squared_error: 0.1899 - val_loss: 0.0488 - val_root_mean_squared_error: 0.1804
# Epoch 156/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0540 - root_mean_squared_error: 0.1943 - val_loss: 0.0484 - val_root_mean_squared_error: 0.1794
# Epoch 157/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0543 - root_mean_squared_error: 0.1954 - val_loss: 0.0487 - val_root_mean_squared_error: 0.1806
# Epoch 158/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 375ms/step - loss: 0.0520 - root_mean_squared_error: 0.1896 - val_loss: 0.0489 - val_root_mean_squared_error: 0.1817
# Epoch 159/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 493ms/step - loss: 0.0521 - root_mean_squared_error: 0.1903 - val_loss: 0.0480 - val_root_mean_squared_error: 0.1794
# Epoch 160/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 454ms/step - loss: 0.0518 - root_mean_squared_error: 0.1899 - val_loss: 0.0475 - val_root_mean_squared_error: 0.1783
# Epoch 161/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - loss: 0.0512 - root_mean_squared_error: 0.1885 - val_loss: 0.0478 - val_root_mean_squared_error: 0.1794
# Epoch 162/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - loss: 0.0522 - root_mean_squared_error: 0.1912 - val_loss: 0.0467 - val_root_mean_squared_error: 0.1767
# Epoch 163/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0516 - root_mean_squared_error: 0.1901 - val_loss: 0.0478 - val_root_mean_squared_error: 0.1799
# Epoch 164/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0526 - root_mean_squared_error: 0.1930 - val_loss: 0.0477 - val_root_mean_squared_error: 0.1800
# Epoch 165/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0524 - root_mean_squared_error: 0.1925 - val_loss: 0.0478 - val_root_mean_squared_error: 0.1807
# Epoch 166/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0499 - root_mean_squared_error: 0.1864 - val_loss: 0.0487 - val_root_mean_squared_error: 0.1834
# Epoch 167/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0517 - root_mean_squared_error: 0.1914 - val_loss: 0.0470 - val_root_mean_squared_error: 0.1791
# Epoch 168/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.0508 - root_mean_squared_error: 0.1892 - val_loss: 0.0485 - val_root_mean_squared_error: 0.1833
# Epoch 169/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.0509 - root_mean_squared_error: 0.1898 - val_loss: 0.0471 - val_root_mean_squared_error: 0.1798
# Epoch 170/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.0499 - root_mean_squared_error: 0.1874 - val_loss: 0.0471 - val_root_mean_squared_error: 0.1801
# Epoch 171/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - loss: 0.0513 - root_mean_squared_error: 0.1915 - val_loss: 0.0458 - val_root_mean_squared_error: 0.1768
# Epoch 172/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0504 - root_mean_squared_error: 0.1893 - val_loss: 0.0470 - val_root_mean_squared_error: 0.1803
# Epoch 173/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0483 - root_mean_squared_error: 0.1838 - val_loss: 0.0471 - val_root_mean_squared_error: 0.1810
# Epoch 174/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.0493 - root_mean_squared_error: 0.1869 - val_loss: 0.0450 - val_root_mean_squared_error: 0.1753
# Epoch 175/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - loss: 0.0483 - root_mean_squared_error: 0.1844 - val_loss: 0.0461 - val_root_mean_squared_error: 0.1786
# Epoch 176/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.0490 - root_mean_squared_error: 0.1867 - val_loss: 0.0441 - val_root_mean_squared_error: 0.1733
# Epoch 177/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.0472 - root_mean_squared_error: 0.1821 - val_loss: 0.0451 - val_root_mean_squared_error: 0.1763
# Epoch 178/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0496 - root_mean_squared_error: 0.1886 - val_loss: 0.0452 - val_root_mean_squared_error: 0.1768
# Epoch 179/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0475 - root_mean_squared_error: 0.1831 - val_loss: 0.0451 - val_root_mean_squared_error: 0.1767
# Epoch 180/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0487 - root_mean_squared_error: 0.1866 - val_loss: 0.0445 - val_root_mean_squared_error: 0.1754
# Epoch 181/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.0484 - root_mean_squared_error: 0.1863 - val_loss: 0.0440 - val_root_mean_squared_error: 0.1742
# Epoch 182/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0485 - root_mean_squared_error: 0.1866 - val_loss: 0.0436 - val_root_mean_squared_error: 0.1733
# Epoch 183/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0474 - root_mean_squared_error: 0.1839 - val_loss: 0.0441 - val_root_mean_squared_error: 0.1750
# Epoch 184/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0460 - root_mean_squared_error: 0.1805 - val_loss: 0.0453 - val_root_mean_squared_error: 0.1786
# Epoch 185/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0474 - root_mean_squared_error: 0.1845 - val_loss: 0.0441 - val_root_mean_squared_error: 0.1754
# Epoch 186/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.0473 - root_mean_squared_error: 0.1845 - val_loss: 0.0433 - val_root_mean_squared_error: 0.1732
# Epoch 187/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step - loss: 0.0483 - root_mean_squared_error: 0.1874 - val_loss: 0.0418 - val_root_mean_squared_error: 0.1693
# Epoch 188/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 374ms/step - loss: 0.0459 - root_mean_squared_error: 0.1811 - val_loss: 0.0431 - val_root_mean_squared_error: 0.1732
# Epoch 189/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - loss: 0.0456 - root_mean_squared_error: 0.1803 - val_loss: 0.0452 - val_root_mean_squared_error: 0.1797
# Epoch 190/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 282ms/step - loss: 0.0479 - root_mean_squared_error: 0.1868 - val_loss: 0.0425 - val_root_mean_squared_error: 0.1720
# Epoch 191/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - loss: 0.0470 - root_mean_squared_error: 0.1845 - val_loss: 0.0419 - val_root_mean_squared_error: 0.1704
# Epoch 192/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.0470 - root_mean_squared_error: 0.1847 - val_loss: 0.0428 - val_root_mean_squared_error: 0.1734
# Epoch 193/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0448 - root_mean_squared_error: 0.1791 - val_loss: 0.0425 - val_root_mean_squared_error: 0.1728
# Epoch 194/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0468 - root_mean_squared_error: 0.1848 - val_loss: 0.0443 - val_root_mean_squared_error: 0.1780
# Epoch 195/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0456 - root_mean_squared_error: 0.1815 - val_loss: 0.0420 - val_root_mean_squared_error: 0.1715
# Epoch 196/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0449 - root_mean_squared_error: 0.1798 - val_loss: 0.0437 - val_root_mean_squared_error: 0.1766
# Epoch 197/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0470 - root_mean_squared_error: 0.1859 - val_loss: 0.0433 - val_root_mean_squared_error: 0.1759
# Epoch 198/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0456 - root_mean_squared_error: 0.1823 - val_loss: 0.0426 - val_root_mean_squared_error: 0.1740
# Epoch 199/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0451 - root_mean_squared_error: 0.1811 - val_loss: 0.0426 - val_root_mean_squared_error: 0.1741
# Epoch 200/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0444 - root_mean_squared_error: 0.1794 - val_loss: 0.0429 - val_root_mean_squared_error: 0.1754
# Epoch 201/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.0450 - root_mean_squared_error: 0.1811 - val_loss: 0.0403 - val_root_mean_squared_error: 0.1680
# Epoch 202/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - loss: 0.0436 - root_mean_squared_error: 0.1775 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1715
# Epoch 203/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0440 - root_mean_squared_error: 0.1789 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1666
# Epoch 204/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0423 - root_mean_squared_error: 0.1743 - val_loss: 0.0409 - val_root_mean_squared_error: 0.1702
# Epoch 205/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0424 - root_mean_squared_error: 0.1748 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1720
# Epoch 206/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.0439 - root_mean_squared_error: 0.1792 - val_loss: 0.0435 - val_root_mean_squared_error: 0.1781
# Epoch 207/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0456 - root_mean_squared_error: 0.1840 - val_loss: 0.0407 - val_root_mean_squared_error: 0.1704
# Epoch 208/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0433 - root_mean_squared_error: 0.1780 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1725
# Epoch 209/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0423 - root_mean_squared_error: 0.1752 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1668
# Epoch 210/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - loss: 0.0431 - root_mean_squared_error: 0.1776 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1678
# Epoch 211/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0426 - root_mean_squared_error: 0.1765 - val_loss: 0.0402 - val_root_mean_squared_error: 0.1696
# Epoch 212/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0420 - root_mean_squared_error: 0.1749 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1679
# Epoch 213/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.0427 - root_mean_squared_error: 0.1770 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1685
# Epoch 214/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0415 - root_mean_squared_error: 0.1739 - val_loss: 0.0402 - val_root_mean_squared_error: 0.1702
# Epoch 215/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.0409 - root_mean_squared_error: 0.1723 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1656
# Epoch 216/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0403 - root_mean_squared_error: 0.1707 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1664
# Epoch 217/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0393 - root_mean_squared_error: 0.1678 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1664
# Epoch 218/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.0401 - root_mean_squared_error: 0.1704 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1688
# Epoch 219/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0422 - root_mean_squared_error: 0.1765 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1665
# Epoch 220/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0420 - root_mean_squared_error: 0.1763 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1675
# Epoch 221/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0409 - root_mean_squared_error: 0.1731 - val_loss: 0.0392 - val_root_mean_squared_error: 0.1685
# Epoch 222/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0407 - root_mean_squared_error: 0.1729 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1676
# Epoch 223/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.0407 - root_mean_squared_error: 0.1730 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1692
# Epoch 224/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.0386 - root_mean_squared_error: 0.1669 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1626
# Epoch 225/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0405 - root_mean_squared_error: 0.1727 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1628
# Epoch 226/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0403 - root_mean_squared_error: 0.1724 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1677
# Epoch 227/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0404 - root_mean_squared_error: 0.1729 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1677
# Epoch 228/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.0393 - root_mean_squared_error: 0.1697 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1651
# Epoch 229/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0395 - root_mean_squared_error: 0.1706 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1652
# Epoch 230/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.0403 - root_mean_squared_error: 0.1729 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1694
# Epoch 231/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - loss: 0.0404 - root_mean_squared_error: 0.1734 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1650
# Epoch 232/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0402 - root_mean_squared_error: 0.1730 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1705
# Epoch 233/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.0386 - root_mean_squared_error: 0.1686 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1633
# Epoch 234/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.0390 - root_mean_squared_error: 0.1698 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1645
# Epoch 235/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 234ms/step - loss: 0.0366 - root_mean_squared_error: 0.1627 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1651
# Epoch 236/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0373 - root_mean_squared_error: 0.1648 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1622
# Epoch 237/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - loss: 0.0372 - root_mean_squared_error: 0.1649 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1636
# Epoch 238/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0387 - root_mean_squared_error: 0.1694 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1642
# Epoch 239/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0368 - root_mean_squared_error: 0.1637 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1637
# Epoch 240/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0377 - root_mean_squared_error: 0.1668 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1589
# Epoch 241/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.0378 - root_mean_squared_error: 0.1673 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1618
# Epoch 242/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - loss: 0.0359 - root_mean_squared_error: 0.1615 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1640
# Epoch 243/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0370 - root_mean_squared_error: 0.1650 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1642
# Epoch 244/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0394 - root_mean_squared_error: 0.1722 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1650
# Epoch 245/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0365 - root_mean_squared_error: 0.1639 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1670
# Epoch 246/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.0361 - root_mean_squared_error: 0.1629 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1631
# Epoch 247/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0387 - root_mean_squared_error: 0.1707 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1612
# Epoch 248/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.0367 - root_mean_squared_error: 0.1648 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1641
# Epoch 249/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0365 - root_mean_squared_error: 0.1644 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1640
# Epoch 250/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0364 - root_mean_squared_error: 0.1641 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1590
# Epoch 251/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0363 - root_mean_squared_error: 0.1639 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1616
# Epoch 252/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0379 - root_mean_squared_error: 0.1689 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1623
# Epoch 253/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0362 - root_mean_squared_error: 0.1640 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1584
# Epoch 254/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0361 - root_mean_squared_error: 0.1638 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1590
# Epoch 255/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0364 - root_mean_squared_error: 0.1648 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1619
# Epoch 256/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0367 - root_mean_squared_error: 0.1658 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1636
# Epoch 257/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0375 - root_mean_squared_error: 0.1683 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1641
# Epoch 258/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.0379 - root_mean_squared_error: 0.1697 - val_loss: 0.0405 - val_root_mean_squared_error: 0.1773
# Epoch 259/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - loss: 0.0419 - root_mean_squared_error: 0.1809 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1674
# Epoch 260/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0378 - root_mean_squared_error: 0.1697 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1583
# Epoch 261/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.0356 - root_mean_squared_error: 0.1633 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1619
# Epoch 262/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0378 - root_mean_squared_error: 0.1699 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1609
# Epoch 263/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0361 - root_mean_squared_error: 0.1648 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1606
# Epoch 264/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0347 - root_mean_squared_error: 0.1607 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1571
# Epoch 265/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0375 - root_mean_squared_error: 0.1693 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1605
# Epoch 266/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0356 - root_mean_squared_error: 0.1637 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1592
# Epoch 267/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0361 - root_mean_squared_error: 0.1654 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1549
# Epoch 268/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - loss: 0.0350 - root_mean_squared_error: 0.1623 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1645
# Epoch 269/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0379 - root_mean_squared_error: 0.1709 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1634
# Epoch 270/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.0356 - root_mean_squared_error: 0.1642 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1604
# Epoch 271/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.0331 - root_mean_squared_error: 0.1566 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1601
# Epoch 272/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0360 - root_mean_squared_error: 0.1657 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1562
# Epoch 273/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 0.0336 - root_mean_squared_error: 0.1585 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1550
# Epoch 274/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0343 - root_mean_squared_error: 0.1605 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1572
# Epoch 275/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0348 - root_mean_squared_error: 0.1622 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1552
# Epoch 276/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0341 - root_mean_squared_error: 0.1604 - val_loss: 0.0317 - val_root_mean_squared_error: 0.1526
# Epoch 277/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0333 - root_mean_squared_error: 0.1578 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1573
# Epoch 278/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0319 - root_mean_squared_error: 0.1534 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1573
# Epoch 279/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0332 - root_mean_squared_error: 0.1578 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1549
# Epoch 280/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0338 - root_mean_squared_error: 0.1596 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1578
# Epoch 281/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.0333 - root_mean_squared_error: 0.1582 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1571
# Epoch 282/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0331 - root_mean_squared_error: 0.1577 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1564
# Epoch 283/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0326 - root_mean_squared_error: 0.1560 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1574
# Epoch 284/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.0337 - root_mean_squared_error: 0.1598 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1581
# Epoch 285/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.0340 - root_mean_squared_error: 0.1607 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1572
# Epoch 286/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.0329 - root_mean_squared_error: 0.1574 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1547
# Epoch 287/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - loss: 0.0333 - root_mean_squared_error: 0.1589 - val_loss: 0.0317 - val_root_mean_squared_error: 0.1539
# Epoch 288/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.0322 - root_mean_squared_error: 0.1555 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1568
# Epoch 289/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - loss: 0.0327 - root_mean_squared_error: 0.1571 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1546
# Epoch 290/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - loss: 0.0325 - root_mean_squared_error: 0.1565 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1570
# Epoch 291/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - loss: 0.0315 - root_mean_squared_error: 0.1535 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1538
# Epoch 292/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 490ms/step - loss: 0.0327 - root_mean_squared_error: 0.1572 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1548
# Epoch 293/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 511ms/step - loss: 0.0329 - root_mean_squared_error: 0.1583 - val_loss: 0.0314 - val_root_mean_squared_error: 0.1534
# Epoch 294/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - loss: 0.0329 - root_mean_squared_error: 0.1581 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1533
# Epoch 295/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - loss: 0.0326 - root_mean_squared_error: 0.1573 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1552
# Epoch 296/10000
# ...
# Epoch 370/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0264 - root_mean_squared_error: 0.1425 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1418
# Epoch 371/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0268 - root_mean_squared_error: 0.1439 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1450
# Epoch 372/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 351ms/step - loss: 0.0274 - root_mean_squared_error: 0.1461 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1495
# Epoch 373/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - loss: 0.0276 - root_mean_squared_error: 0.1469 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1466
# Epoch 374/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0269 - root_mean_squared_error: 0.1447 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1449
# Epoch 375/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0265 - root_mean_squared_error: 0.1433 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1439
# Epoch 376/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0267 - root_mean_squared_error: 0.1439 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1419
# Epoch 377/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0261 - root_mean_squared_error: 0.1422 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1432
# Epoch 378/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0257 - root_mean_squared_error: 0.1406 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1445
# Epoch 379/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0267 - root_mean_squared_error: 0.1442 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1416
# Epoch 380/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.0266 - root_mean_squared_error: 0.1440 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1436
# Epoch 381/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - loss: 0.0268 - root_mean_squared_error: 0.1448 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1436
# Epoch 382/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0261 - root_mean_squared_error: 0.1424 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1426
# Epoch 383/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.0258 - root_mean_squared_error: 0.1414 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1455
# Epoch 384/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.0255 - root_mean_squared_error: 0.1402 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1449
# Epoch 385/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0261 - root_mean_squared_error: 0.1425 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1402
# Epoch 386/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.0261 - root_mean_squared_error: 0.1425 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1455
# Epoch 387/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0257 - root_mean_squared_error: 0.1411 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1396
# Epoch 388/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0261 - root_mean_squared_error: 0.1425 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1416
# Epoch 389/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.0297 - root_mean_squared_error: 0.1548 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1414
# Epoch 390/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.0267 - root_mean_squared_error: 0.1449 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1435
# Epoch 391/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.0262 - root_mean_squared_error: 0.1432 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1471
# Epoch 392/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0252 - root_mean_squared_error: 0.1398 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1445
# Epoch 393/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0264 - root_mean_squared_error: 0.1440 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1425
# Epoch 394/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.0253 - root_mean_squared_error: 0.1403 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1418
# Epoch 395/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0246 - root_mean_squared_error: 0.1375 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1447
# Epoch 396/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.0258 - root_mean_squared_error: 0.1421 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1450
# Epoch 397/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.0254 - root_mean_squared_error: 0.1406 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1409
# Epoch 398/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0248 - root_mean_squared_error: 0.1386 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1427
# Epoch 399/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0251 - root_mean_squared_error: 0.1397 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1404
# Epoch 400/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0259 - root_mean_squared_error: 0.1425 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1382
# Epoch 401/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.0255 - root_mean_squared_error: 0.1415 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1389
# Epoch 402/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.0245 - root_mean_squared_error: 0.1379 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1425
# Epoch 403/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - loss: 0.0249 - root_mean_squared_error: 0.1394 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1425
# Epoch 404/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - loss: 0.0245 - root_mean_squared_error: 0.1379 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1467
# Epoch 405/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.0249 - root_mean_squared_error: 0.1395 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1405
# Epoch 406/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.0257 - root_mean_squared_error: 0.1423 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1457
# Epoch 407/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.0242 - root_mean_squared_error: 0.1371 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1420
# Epoch 408/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0244 - root_mean_squared_error: 0.1377 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1429
# Epoch 409/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0259 - root_mean_squared_error: 0.1431 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1422
# Epoch 410/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0258 - root_mean_squared_error: 0.1430 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1385
# Epoch 411/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.0254 - root_mean_squared_error: 0.1415 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1379
# Epoch 412/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0250 - root_mean_squared_error: 0.1399 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1425
# Epoch 413/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0245 - root_mean_squared_error: 0.1385 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1418
# Epoch 414/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.0258 - root_mean_squared_error: 0.1431 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1423
# Epoch 415/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.0230 - root_mean_squared_error: 0.1331 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1445
# Epoch 416/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - loss: 0.0242 - root_mean_squared_error: 0.1375 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1433
# Epoch 417/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - loss: 0.0235 - root_mean_squared_error: 0.1350 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1402
# Epoch 418/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.0257 - root_mean_squared_error: 0.1431 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1442
# Epoch 419/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0254 - root_mean_squared_error: 0.1421 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1490
# Epoch 420/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0261 - root_mean_squared_error: 0.1445 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1388
# Epoch 421/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.0239 - root_mean_squared_error: 0.1368 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1377
# Epoch 422/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0243 - root_mean_squared_error: 0.1381 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1418
# Epoch 423/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0239 - root_mean_squared_error: 0.1368 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1407
# Epoch 424/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0244 - root_mean_squared_error: 0.1386 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1400
# Epoch 425/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 0.0232 - root_mean_squared_error: 0.1342 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1414
# Epoch 426/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - loss: 0.0248 - root_mean_squared_error: 0.1401 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1438
# Epoch 427/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - loss: 0.0231 - root_mean_squared_error: 0.1340 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1400
# Epoch 428/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0249 - root_mean_squared_error: 0.1406 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1399
# Epoch 429/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - loss: 0.0233 - root_mean_squared_error: 0.1349 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1423
# Epoch 430/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.0226 - root_mean_squared_error: 0.1321 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1364
# Epoch 431/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0236 - root_mean_squared_error: 0.1358 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1385
# Epoch 432/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - loss: 0.0235 - root_mean_squared_error: 0.1357 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1392
# Epoch 433/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0255 - root_mean_squared_error: 0.1428 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1497
# Epoch 434/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.0248 - root_mean_squared_error: 0.1406 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1414
# Epoch 435/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - loss: 0.0242 - root_mean_squared_error: 0.1384 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1436
# Epoch 436/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 450ms/step - loss: 0.0269 - root_mean_squared_error: 0.1478 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1450
# Epoch 437/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.0254 - root_mean_squared_error: 0.1426 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1456
# Epoch 438/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.0248 - root_mean_squared_error: 0.1407 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1441
# Epoch 439/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0243 - root_mean_squared_error: 0.1391 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1398
# Epoch 440/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0239 - root_mean_squared_error: 0.1377 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1421
# Epoch 441/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.0238 - root_mean_squared_error: 0.1371 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1433
# Epoch 442/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - loss: 0.0245 - root_mean_squared_error: 0.1399 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1431
# Epoch 443/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0237 - root_mean_squared_error: 0.1371 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1396
# Epoch 444/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0230 - root_mean_squared_error: 0.1343 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1402
# Epoch 445/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.0228 - root_mean_squared_error: 0.1337 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1394
# Epoch 446/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.0241 - root_mean_squared_error: 0.1385 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1411
# Epoch 447/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - loss: 0.0235 - root_mean_squared_error: 0.1365 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1347
# Epoch 448/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - loss: 0.0240 - root_mean_squared_error: 0.1382 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1437
# Epoch 449/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.0240 - root_mean_squared_error: 0.1383 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1380
# Epoch 450/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - loss: 0.0222 - root_mean_squared_error: 0.1317 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1389
# Epoch 451/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 514ms/step - loss: 0.0231 - root_mean_squared_error: 0.1352 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1389
# Epoch 452/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 387ms/step - loss: 0.0234 - root_mean_squared_error: 0.1361 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1393
# Epoch 453/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - loss: 0.0242 - root_mean_squared_error: 0.1390 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1405
# Epoch 454/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - loss: 0.0224 - root_mean_squared_error: 0.1327 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1401
# Epoch 455/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 284ms/step - loss: 0.0225 - root_mean_squared_error: 0.1330 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1376
# Epoch 456/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0232 - root_mean_squared_error: 0.1357 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1356
# Epoch 457/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0230 - root_mean_squared_error: 0.1349 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1424
# Epoch 458/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0235 - root_mean_squared_error: 0.1367 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1389
# Epoch 459/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.0220 - root_mean_squared_error: 0.1314 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1385
# Epoch 460/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.0230 - root_mean_squared_error: 0.1353 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1381
# Epoch 461/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0245 - root_mean_squared_error: 0.1407 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1626
# Epoch 462/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.0321 - root_mean_squared_error: 0.1655 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1740
# Epoch 463/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.0283 - root_mean_squared_error: 0.1535 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1536
# Epoch 464/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - loss: 0.0250 - root_mean_squared_error: 0.1424 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1499
# Epoch 465/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0247 - root_mean_squared_error: 0.1415 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1389
# Epoch 466/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.0240 - root_mean_squared_error: 0.1390 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1425
# Epoch 467/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0230 - root_mean_squared_error: 0.1354 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1396

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test_scaled, y_test_scaled)
print(f'Test Loss: {test_loss}')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0329 - root_mean_squared_error: 0.1671
# Test Loss: [0.033835168927907944, 0.17013709247112274]

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm2_1\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 4))
    
    # Plot the true and predicted values on the first subplot
    axs[0].plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    axs[0].plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    axs[0].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[0].set_title(f'True vs Predicted Values for {coordinate_name}')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel(f'{coordinate_name} Value')
    axs[0].legend()
    
    # Example of another plot (e.g., residuals or difference between predicted and true values)
    original_timeseries = np.array(row[coordinate_name])
    axs[1].plot(range(len(original_timeseries)), original_timeseries, label="Timeseries")
    axs[1].axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    axs[1].set_title(f'Original {coordinate_name} trajectory')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel(f'{coordinate_name} Value')
    axs[1].legend()

        # Extract the initial sequence from the DataFrame

# %%
# Assuming model is trained and X_train, y_train are defined
def scale_with(sequence, y_scaler):
    print(sequence.shape)
    return y_scaler.transform(sequence)

# Make predictions
predictions_scaled = model.predict(X_test_scaled)

# Example for the first sample in the dataset
sample_index = 3
initial_seq = X_test[sample_index, :, -3:]  # Last 3 features are the coordinates
print(initial_seq.shape)
initial_seq_scaled = scale_with(initial_seq, y_scaler)
true_values = y_test_scaled[sample_index, :, :]  # True values
predicted_values_scaled = predictions_scaled[sample_index, :, :]  # Predicted values
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq_scaled[:, 0], true_values[:, 0], predicted_values_scaled[:, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq_scaled[:, 1], true_values[:, 1], predicted_values_scaled[:, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq_scaled[:, 2], true_values[:, 2], predicted_values_scaled[:, 2], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# (75, 3)
# (75, 3)

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
