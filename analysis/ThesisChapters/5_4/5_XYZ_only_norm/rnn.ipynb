# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
             "Hood_Length", 
             "Back_Hood_Height",  
             "Head_X_Coordinate", 
             "Head_Y_Coordinate", 
             "Head_Z_Coordinate"]
df = df[new_order]
#df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [round(2 * value - 1, 5) for value in scaled_values]
    
    return mapped_values

def calculate_trajectory_relative_change(trajectory):
    relative_change = []
    for i in range(1, len(trajectory)):
        delta = trajectory[i] - trajectory[i - 1]
        relative_change.append(round(delta, 5))
    return relative_change


##### RELATIVE CHANGE!@!!
def calculate_relative_change(row):
    #row["Head_X_Coordinate"] = calculate_trajectory_relative_change(row["Head_X_Coordinate"])
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])

    #row["Head_Y_Coordinate"] = calculate_trajectory_relative_change(row["Head_Y_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])

    #row["Head_Z_Coordinate"] = calculate_trajectory_relative_change(row["Head_Z_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])

    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -200         0            770                740
# 1          100         -200       120            770                740
# 2          100         -200       150            770                740
# 3          100         -200       180            770                740
# 4          100         -200       210            770                740
# ...        ...          ...       ...            ...                ...
# 1181        80          400       300            580                900
# 1182        80          400        30            580                900
# 1183        80          400       330            580                900
# 1184        80          400        60            580                900
# 1185        80          400        90            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    16         1150               980
# 2                    16         1150               980
# 3                    16         1150               980
# 4                    16         1150               980
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 11         1160              1130
# 1183                 11         1160              1130
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [-0.96601, -0.96601, -0.96601, -0.96601, -0.96...
# 1     [-0.79166, -0.79166, -0.79166, -0.79166, -0.79...
# 2     [-0.91302, -0.91302, -0.91302, -0.91302, -0.91...
# 3     [-0.96412, -0.96412, -0.96412, -0.96412, -0.96...
# 4     [-0.94902, -0.94902, -0.94902, -0.94902, -0.94...
# ...                                                 ...
# 1181  [-0.98443, -0.98443, -0.98443, -0.98443, -0.98...
# 1182  [-0.97882, -0.97882, -0.97882, -0.97882, -0.97...
# 1183  [-0.96914, -0.96914, -0.96914, -0.96914, -0.96...
# 1184  [-0.88976, -0.88976, -0.88976, -0.88976, -0.88...
# 1185  [-0.86404, -0.86404, -0.86404, -0.86404, -0.86...
#
#                                       Head_Y_Coordinate  \
# 0     [0.16954, 0.16954, 0.16954, 0.16954, 0.16954, ...
# 1     [0.99884, 0.99884, 0.99884, 0.99884, 0.99884, ...
# 2     [0.99961, 0.99961, 0.99961, 0.99961, 0.99961, ...
# 3     [0.66934, 0.66934, 0.66934, 0.66934, 0.66934, ...
# 4     [-0.41876, -0.41876, -0.41876, -0.41876, -0.41...
# ...                                                 ...
# 1181  [-0.99958, -0.99958, -0.99958, -0.99958, -0.99...
# 1182  [-0.99948, -0.99948, -0.99948, -0.99948, -0.99...
# 1183  [0.6108, 0.6108, 0.6108, 0.6108, 0.6108, 0.610...
# 1184  [-0.99874, -0.99874, -0.99874, -0.99874, -0.99...
# 1185  [-0.17884, -0.17884, -0.17884, -0.17884, -0.17...
#
#                                       Head_Z_Coordinate
# 0     [1.0, 0.99998, 0.99994, 0.99992, 0.99988, 0.99...
# 1     [1.0, 0.99998, 0.99993, 0.99992, 0.99987, 0.99...
# 2     [1.0, 0.99998, 0.99993, 0.99991, 0.99986, 0.99...
# 3     [1.0, 0.99998, 0.99993, 0.99992, 0.99987, 0.99...
# 4     [1.0, 0.99998, 0.99993, 0.99992, 0.99987, 0.99...
# ...                                                 ...
# 1181  [0.99966, 0.99964, 0.99958, 0.99956, 0.9995, 0...
# 1182  [1.0, 0.99998, 0.99991, 0.99989, 0.99982, 0.99...
# 1183  [1.0, 0.99998, 0.99991, 0.99989, 0.99983, 0.99...
# 1184  [1.0, 0.99998, 0.99991, 0.99989, 0.99983, 0.99...
# 1185  [1.0, 0.99998, 0.99992, 0.9999, 0.99984, 0.999...
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 4656.07row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0             -0.96601            0.16954            1.00000
# 1             -0.96601            0.16954            0.99998
# 2             -0.96601            0.16954            0.99994
# 3             -0.96601            0.16954            0.99992
# 4             -0.96601            0.16954            0.99988
# ..                 ...                ...                ...
# 296            0.95592           -0.96170           -0.97077
# 297            0.96688           -0.97131           -0.96865
# 298            0.97788           -0.98088           -0.96642
# 299            0.98892           -0.99044           -0.96406
# 300            1.00000           -1.00000           -0.96159
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 75, 11) (711, 75, 3)
# (237, 75, 11) (237, 75, 3)
# (238, 75, 11) (238, 75, 3)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 3, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 225)            │         7,425 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 3)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,657 (604.13 KB)
#  Trainable params: 154,657 (604.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step - loss: 0.5560 - root_mean_squared_error: 0.7107 - val_loss: 0.5516 - val_root_mean_squared_error: 0.7082
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 0.5218 - root_mean_squared_error: 0.6870 - val_loss: 0.4987 - val_root_mean_squared_error: 0.6705
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.4709 - root_mean_squared_error: 0.6496 - val_loss: 0.4542 - val_root_mean_squared_error: 0.6372
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 0.4337 - root_mean_squared_error: 0.6211 - val_loss: 0.4136 - val_root_mean_squared_error: 0.6053
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.3945 - root_mean_squared_error: 0.5896 - val_loss: 0.3764 - val_root_mean_squared_error: 0.5746
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - loss: 0.3579 - root_mean_squared_error: 0.5585 - val_loss: 0.3433 - val_root_mean_squared_error: 0.5459
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - loss: 0.3296 - root_mean_squared_error: 0.5334 - val_loss: 0.3165 - val_root_mean_squared_error: 0.5216
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.2961 - root_mean_squared_error: 0.5018 - val_loss: 0.2919 - val_root_mean_squared_error: 0.4982
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.2796 - root_mean_squared_error: 0.4859 - val_loss: 0.2744 - val_root_mean_squared_error: 0.4811
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.2638 - root_mean_squared_error: 0.4701 - val_loss: 0.2618 - val_root_mean_squared_error: 0.4687
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.2560 - root_mean_squared_error: 0.4626 - val_loss: 0.2540 - val_root_mean_squared_error: 0.4611
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.2497 - root_mean_squared_error: 0.4565 - val_loss: 0.2475 - val_root_mean_squared_error: 0.4548
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.2356 - root_mean_squared_error: 0.4417 - val_loss: 0.2426 - val_root_mean_squared_error: 0.4502
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.2357 - root_mean_squared_error: 0.4427 - val_loss: 0.2388 - val_root_mean_squared_error: 0.4467
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.2248 - root_mean_squared_error: 0.4309 - val_loss: 0.2359 - val_root_mean_squared_error: 0.4442
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.2300 - root_mean_squared_error: 0.4377 - val_loss: 0.2321 - val_root_mean_squared_error: 0.4408
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.2344 - root_mean_squared_error: 0.4433 - val_loss: 0.2293 - val_root_mean_squared_error: 0.4383
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.2230 - root_mean_squared_error: 0.4312 - val_loss: 0.2275 - val_root_mean_squared_error: 0.4370
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.2204 - root_mean_squared_error: 0.4290 - val_loss: 0.2250 - val_root_mean_squared_error: 0.4349
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.2139 - root_mean_squared_error: 0.4221 - val_loss: 0.2209 - val_root_mean_squared_error: 0.4309
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.2169 - root_mean_squared_error: 0.4264 - val_loss: 0.2183 - val_root_mean_squared_error: 0.4286
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.2049 - root_mean_squared_error: 0.4128 - val_loss: 0.2161 - val_root_mean_squared_error: 0.4268
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.2094 - root_mean_squared_error: 0.4188 - val_loss: 0.2141 - val_root_mean_squared_error: 0.4251
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.2017 - root_mean_squared_error: 0.4103 - val_loss: 0.2122 - val_root_mean_squared_error: 0.4235
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.2092 - root_mean_squared_error: 0.4201 - val_loss: 0.2094 - val_root_mean_squared_error: 0.4209
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.2045 - root_mean_squared_error: 0.4151 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4182
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1967 - root_mean_squared_error: 0.4063 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4188
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.1978 - root_mean_squared_error: 0.4084 - val_loss: 0.2042 - val_root_mean_squared_error: 0.4166
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1903 - root_mean_squared_error: 0.3996 - val_loss: 0.2028 - val_root_mean_squared_error: 0.4156
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1863 - root_mean_squared_error: 0.3954 - val_loss: 0.2053 - val_root_mean_squared_error: 0.4192
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.2010 - root_mean_squared_error: 0.4140 - val_loss: 0.1986 - val_root_mean_squared_error: 0.4118
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1917 - root_mean_squared_error: 0.4034 - val_loss: 0.1960 - val_root_mean_squared_error: 0.4092
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.1904 - root_mean_squared_error: 0.4024 - val_loss: 0.1926 - val_root_mean_squared_error: 0.4055
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.1832 - root_mean_squared_error: 0.3939 - val_loss: 0.1964 - val_root_mean_squared_error: 0.4108
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.1904 - root_mean_squared_error: 0.4036 - val_loss: 0.1947 - val_root_mean_squared_error: 0.4093
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1843 - root_mean_squared_error: 0.3965 - val_loss: 0.1907 - val_root_mean_squared_error: 0.4049
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1815 - root_mean_squared_error: 0.3935 - val_loss: 0.1863 - val_root_mean_squared_error: 0.4001
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1831 - root_mean_squared_error: 0.3961 - val_loss: 0.2009 - val_root_mean_squared_error: 0.4184
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1887 - root_mean_squared_error: 0.4037 - val_loss: 0.1852 - val_root_mean_squared_error: 0.3998
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.1806 - root_mean_squared_error: 0.3940 - val_loss: 0.1878 - val_root_mean_squared_error: 0.4035
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1768 - root_mean_squared_error: 0.3898 - val_loss: 0.1850 - val_root_mean_squared_error: 0.4005
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1802 - root_mean_squared_error: 0.3945 - val_loss: 0.1827 - val_root_mean_squared_error: 0.3981
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1785 - root_mean_squared_error: 0.3928 - val_loss: 0.1802 - val_root_mean_squared_error: 0.3954
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1731 - root_mean_squared_error: 0.3864 - val_loss: 0.1880 - val_root_mean_squared_error: 0.4057
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1788 - root_mean_squared_error: 0.3942 - val_loss: 0.1863 - val_root_mean_squared_error: 0.4040
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1759 - root_mean_squared_error: 0.3910 - val_loss: 0.1768 - val_root_mean_squared_error: 0.3926
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1667 - root_mean_squared_error: 0.3795 - val_loss: 0.1838 - val_root_mean_squared_error: 0.4018
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1732 - root_mean_squared_error: 0.3884 - val_loss: 0.1773 - val_root_mean_squared_error: 0.3941
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.1658 - root_mean_squared_error: 0.3793 - val_loss: 0.1758 - val_root_mean_squared_error: 0.3927
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1627 - root_mean_squared_error: 0.3757 - val_loss: 0.1759 - val_root_mean_squared_error: 0.3931
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.1627 - root_mean_squared_error: 0.3761 - val_loss: 0.1706 - val_root_mean_squared_error: 0.3868
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.1627 - root_mean_squared_error: 0.3765 - val_loss: 0.1722 - val_root_mean_squared_error: 0.3893
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1642 - root_mean_squared_error: 0.3790 - val_loss: 0.1689 - val_root_mean_squared_error: 0.3854
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.1594 - root_mean_squared_error: 0.3729 - val_loss: 0.1703 - val_root_mean_squared_error: 0.3877
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1513 - root_mean_squared_error: 0.3624 - val_loss: 0.1664 - val_root_mean_squared_error: 0.3829
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1570 - root_mean_squared_error: 0.3705 - val_loss: 0.1667 - val_root_mean_squared_error: 0.3837
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1475 - root_mean_squared_error: 0.3579 - val_loss: 0.1658 - val_root_mean_squared_error: 0.3829
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1523 - root_mean_squared_error: 0.3649 - val_loss: 0.1702 - val_root_mean_squared_error: 0.3889
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1560 - root_mean_squared_error: 0.3703 - val_loss: 0.1715 - val_root_mean_squared_error: 0.3910
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.1539 - root_mean_squared_error: 0.3678 - val_loss: 0.1659 - val_root_mean_squared_error: 0.3841
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1555 - root_mean_squared_error: 0.3699 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3764
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.1386 - root_mean_squared_error: 0.3470 - val_loss: 0.1570 - val_root_mean_squared_error: 0.3730
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1402 - root_mean_squared_error: 0.3498 - val_loss: 0.1573 - val_root_mean_squared_error: 0.3737
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1425 - root_mean_squared_error: 0.3534 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3716
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1452 - root_mean_squared_error: 0.3575 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3649
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1415 - root_mean_squared_error: 0.3526 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3658
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.1317 - root_mean_squared_error: 0.3386 - val_loss: 0.1560 - val_root_mean_squared_error: 0.3732
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1382 - root_mean_squared_error: 0.3485 - val_loss: 0.1530 - val_root_mean_squared_error: 0.3694
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1422 - root_mean_squared_error: 0.3545 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3607
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.1360 - root_mean_squared_error: 0.3460 - val_loss: 0.1505 - val_root_mean_squared_error: 0.3666
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1343 - root_mean_squared_error: 0.3439 - val_loss: 0.1460 - val_root_mean_squared_error: 0.3608
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.1356 - root_mean_squared_error: 0.3461 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3624
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.1332 - root_mean_squared_error: 0.3429 - val_loss: 0.1483 - val_root_mean_squared_error: 0.3644
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.1345 - root_mean_squared_error: 0.3450 - val_loss: 0.1500 - val_root_mean_squared_error: 0.3670
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.1388 - root_mean_squared_error: 0.3514 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3671
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1251 - root_mean_squared_error: 0.3317 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3643
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1280 - root_mean_squared_error: 0.3363 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3631
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.1225 - root_mean_squared_error: 0.3282 - val_loss: 0.1452 - val_root_mean_squared_error: 0.3614
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.1289 - root_mean_squared_error: 0.3381 - val_loss: 0.1474 - val_root_mean_squared_error: 0.3647
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1293 - root_mean_squared_error: 0.3390 - val_loss: 0.1478 - val_root_mean_squared_error: 0.3655
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1191 - root_mean_squared_error: 0.3238 - val_loss: 0.1440 - val_root_mean_squared_error: 0.3605
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.1255 - root_mean_squared_error: 0.3339 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3595
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 0.1226 - root_mean_squared_error: 0.3298 - val_loss: 0.1430 - val_root_mean_squared_error: 0.3596
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.1216 - root_mean_squared_error: 0.3284 - val_loss: 0.1444 - val_root_mean_squared_error: 0.3617
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.1230 - root_mean_squared_error: 0.3308 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3594
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.1299 - root_mean_squared_error: 0.3413 - val_loss: 0.1462 - val_root_mean_squared_error: 0.3646
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.1288 - root_mean_squared_error: 0.3399 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3498
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.1314 - root_mean_squared_error: 0.3440 - val_loss: 0.1424 - val_root_mean_squared_error: 0.3599
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.1255 - root_mean_squared_error: 0.3356 - val_loss: 0.1409 - val_root_mean_squared_error: 0.3580
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - loss: 0.1216 - root_mean_squared_error: 0.3299 - val_loss: 0.1441 - val_root_mean_squared_error: 0.3625
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.1339 - root_mean_squared_error: 0.3482 - val_loss: 0.1463 - val_root_mean_squared_error: 0.3659
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.1341 - root_mean_squared_error: 0.3485 - val_loss: 0.1350 - val_root_mean_squared_error: 0.3502
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.1261 - root_mean_squared_error: 0.3373 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3564
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.1220 - root_mean_squared_error: 0.3314 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3511
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.1260 - root_mean_squared_error: 0.3373 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3448
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.1159 - root_mean_squared_error: 0.3224 - val_loss: 0.1325 - val_root_mean_squared_error: 0.3474
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1126 - root_mean_squared_error: 0.3174 - val_loss: 0.1296 - val_root_mean_squared_error: 0.3434
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - loss: 0.1163 - root_mean_squared_error: 0.3235 - val_loss: 0.1330 - val_root_mean_squared_error: 0.3484
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.1318 - root_mean_squared_error: 0.3467 - val_loss: 0.1314 - val_root_mean_squared_error: 0.3463
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1253 - root_mean_squared_error: 0.3375 - val_loss: 0.1256 - val_root_mean_squared_error: 0.3381
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.1166 - root_mean_squared_error: 0.3245 - val_loss: 0.1278 - val_root_mean_squared_error: 0.3415
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.1226 - root_mean_squared_error: 0.3339 - val_loss: 0.1254 - val_root_mean_squared_error: 0.3381
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - loss: 0.1151 - root_mean_squared_error: 0.3225 - val_loss: 0.1288 - val_root_mean_squared_error: 0.3432
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1201 - root_mean_squared_error: 0.3302 - val_loss: 0.1279 - val_root_mean_squared_error: 0.3421
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1222 - root_mean_squared_error: 0.3337 - val_loss: 0.1271 - val_root_mean_squared_error: 0.3411
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.1186 - root_mean_squared_error: 0.3283 - val_loss: 0.1273 - val_root_mean_squared_error: 0.3416
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.1141 - root_mean_squared_error: 0.3215 - val_loss: 0.1243 - val_root_mean_squared_error: 0.3373
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1156 - root_mean_squared_error: 0.3242 - val_loss: 0.1246 - val_root_mean_squared_error: 0.3379
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1150 - root_mean_squared_error: 0.3234 - val_loss: 0.1250 - val_root_mean_squared_error: 0.3386
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.1112 - root_mean_squared_error: 0.3177 - val_loss: 0.1260 - val_root_mean_squared_error: 0.3402
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1190 - root_mean_squared_error: 0.3297 - val_loss: 0.1219 - val_root_mean_squared_error: 0.3344
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1088 - root_mean_squared_error: 0.3141 - val_loss: 0.1228 - val_root_mean_squared_error: 0.3357
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1230 - root_mean_squared_error: 0.3358 - val_loss: 0.1203 - val_root_mean_squared_error: 0.3322
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1044 - root_mean_squared_error: 0.3072 - val_loss: 0.1207 - val_root_mean_squared_error: 0.3328
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.1218 - root_mean_squared_error: 0.3345 - val_loss: 0.1297 - val_root_mean_squared_error: 0.3462
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.1145 - root_mean_squared_error: 0.3236 - val_loss: 0.1196 - val_root_mean_squared_error: 0.3315
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.1066 - root_mean_squared_error: 0.3113 - val_loss: 0.1215 - val_root_mean_squared_error: 0.3345
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1133 - root_mean_squared_error: 0.3219 - val_loss: 0.1239 - val_root_mean_squared_error: 0.3382
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.1140 - root_mean_squared_error: 0.3231 - val_loss: 0.1229 - val_root_mean_squared_error: 0.3367
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1127 - root_mean_squared_error: 0.3212 - val_loss: 0.1207 - val_root_mean_squared_error: 0.3336
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.1060 - root_mean_squared_error: 0.3107 - val_loss: 0.1175 - val_root_mean_squared_error: 0.3289
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.1080 - root_mean_squared_error: 0.3141 - val_loss: 0.1214 - val_root_mean_squared_error: 0.3348
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.1044 - root_mean_squared_error: 0.3083 - val_loss: 0.1221 - val_root_mean_squared_error: 0.3360
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.1060 - root_mean_squared_error: 0.3110 - val_loss: 0.1248 - val_root_mean_squared_error: 0.3402
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.1065 - root_mean_squared_error: 0.3120 - val_loss: 0.1208 - val_root_mean_squared_error: 0.3343
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1065 - root_mean_squared_error: 0.3122 - val_loss: 0.1193 - val_root_mean_squared_error: 0.3322
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.1024 - root_mean_squared_error: 0.3057 - val_loss: 0.1191 - val_root_mean_squared_error: 0.3320
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0970 - root_mean_squared_error: 0.2967 - val_loss: 0.1218 - val_root_mean_squared_error: 0.3361
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1011 - root_mean_squared_error: 0.3038 - val_loss: 0.1181 - val_root_mean_squared_error: 0.3307
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1018 - root_mean_squared_error: 0.3049 - val_loss: 0.1187 - val_root_mean_squared_error: 0.3317
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - loss: 0.1023 - root_mean_squared_error: 0.3058 - val_loss: 0.1159 - val_root_mean_squared_error: 0.3274
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.1003 - root_mean_squared_error: 0.3026 - val_loss: 0.1201 - val_root_mean_squared_error: 0.3339
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1024 - root_mean_squared_error: 0.3063 - val_loss: 0.1184 - val_root_mean_squared_error: 0.3315
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0998 - root_mean_squared_error: 0.3020 - val_loss: 0.1221 - val_root_mean_squared_error: 0.3371
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1019 - root_mean_squared_error: 0.3055 - val_loss: 0.1181 - val_root_mean_squared_error: 0.3313
# Epoch 136/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.1122 - root_mean_squared_error: 0.3221 - val_loss: 0.1232 - val_root_mean_squared_error: 0.3390
# Epoch 137/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1061 - root_mean_squared_error: 0.3126 - val_loss: 0.1159 - val_root_mean_squared_error: 0.3281
# Epoch 138/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0967 - root_mean_squared_error: 0.2973 - val_loss: 0.1130 - val_root_mean_squared_error: 0.3236
# Epoch 139/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0990 - root_mean_squared_error: 0.3012 - val_loss: 0.1137 - val_root_mean_squared_error: 0.3248
# Epoch 140/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0958 - root_mean_squared_error: 0.2959 - val_loss: 0.1125 - val_root_mean_squared_error: 0.3231
# Epoch 141/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0947 - root_mean_squared_error: 0.2941 - val_loss: 0.1146 - val_root_mean_squared_error: 0.3264
# Epoch 142/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0991 - root_mean_squared_error: 0.3017 - val_loss: 0.1184 - val_root_mean_squared_error: 0.3321
# Epoch 143/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.0996 - root_mean_squared_error: 0.3026 - val_loss: 0.1147 - val_root_mean_squared_error: 0.3266
# Epoch 144/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0901 - root_mean_squared_error: 0.2864 - val_loss: 0.1119 - val_root_mean_squared_error: 0.3225
# Epoch 145/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0940 - root_mean_squared_error: 0.2934 - val_loss: 0.1123 - val_root_mean_squared_error: 0.3230
# Epoch 146/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0914 - root_mean_squared_error: 0.2888 - val_loss: 0.1150 - val_root_mean_squared_error: 0.3274
# Epoch 147/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0926 - root_mean_squared_error: 0.2910 - val_loss: 0.1109 - val_root_mean_squared_error: 0.3212
# Epoch 148/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0928 - root_mean_squared_error: 0.2916 - val_loss: 0.1120 - val_root_mean_squared_error: 0.3229
# Epoch 149/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0952 - root_mean_squared_error: 0.2956 - val_loss: 0.1186 - val_root_mean_squared_error: 0.3330
# Epoch 150/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.0971 - root_mean_squared_error: 0.2989 - val_loss: 0.1112 - val_root_mean_squared_error: 0.3218
# Epoch 151/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0963 - root_mean_squared_error: 0.2976 - val_loss: 0.1094 - val_root_mean_squared_error: 0.3191
# Epoch 152/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0905 - root_mean_squared_error: 0.2879 - val_loss: 0.1092 - val_root_mean_squared_error: 0.3187
# Epoch 153/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0894 - root_mean_squared_error: 0.2861 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3176
# Epoch 154/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0892 - root_mean_squared_error: 0.2857 - val_loss: 0.1075 - val_root_mean_squared_error: 0.3162
# Epoch 155/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0853 - root_mean_squared_error: 0.2788 - val_loss: 0.1105 - val_root_mean_squared_error: 0.3211
# Epoch 156/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0881 - root_mean_squared_error: 0.2840 - val_loss: 0.1068 - val_root_mean_squared_error: 0.3153
# Epoch 157/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - loss: 0.0915 - root_mean_squared_error: 0.2900 - val_loss: 0.1097 - val_root_mean_squared_error: 0.3199
# Epoch 158/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0865 - root_mean_squared_error: 0.2812 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3180
# Epoch 159/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1007 - root_mean_squared_error: 0.3056 - val_loss: 0.1180 - val_root_mean_squared_error: 0.3328
# Epoch 160/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0966 - root_mean_squared_error: 0.2987 - val_loss: 0.1184 - val_root_mean_squared_error: 0.3334
# Epoch 161/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0944 - root_mean_squared_error: 0.2953 - val_loss: 0.1096 - val_root_mean_squared_error: 0.3200
# Epoch 162/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0886 - root_mean_squared_error: 0.2852 - val_loss: 0.1085 - val_root_mean_squared_error: 0.3183
# Epoch 163/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0914 - root_mean_squared_error: 0.2903 - val_loss: 0.1124 - val_root_mean_squared_error: 0.3245
# Epoch 164/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0891 - root_mean_squared_error: 0.2863 - val_loss: 0.1049 - val_root_mean_squared_error: 0.3128
# Epoch 165/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0873 - root_mean_squared_error: 0.2831 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3155
# Epoch 166/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0864 - root_mean_squared_error: 0.2816 - val_loss: 0.1065 - val_root_mean_squared_error: 0.3154
# Epoch 167/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0859 - root_mean_squared_error: 0.2807 - val_loss: 0.1044 - val_root_mean_squared_error: 0.3122
# Epoch 168/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0824 - root_mean_squared_error: 0.2747 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3138
# Epoch 169/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0862 - root_mean_squared_error: 0.2816 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3158
# Epoch 170/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0821 - root_mean_squared_error: 0.2741 - val_loss: 0.1102 - val_root_mean_squared_error: 0.3214
# Epoch 171/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0856 - root_mean_squared_error: 0.2805 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3125
# Epoch 172/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0834 - root_mean_squared_error: 0.2765 - val_loss: 0.1078 - val_root_mean_squared_error: 0.3177
# Epoch 173/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0846 - root_mean_squared_error: 0.2787 - val_loss: 0.1186 - val_root_mean_squared_error: 0.3343
# Epoch 174/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0875 - root_mean_squared_error: 0.2840 - val_loss: 0.1156 - val_root_mean_squared_error: 0.3298
# Epoch 175/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0879 - root_mean_squared_error: 0.2847 - val_loss: 0.1095 - val_root_mean_squared_error: 0.3206
# Epoch 176/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0817 - root_mean_squared_error: 0.2737 - val_loss: 0.1124 - val_root_mean_squared_error: 0.3251
# Epoch 177/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1247 - root_mean_squared_error: 0.3430 - val_loss: 0.1534 - val_root_mean_squared_error: 0.3831
# Epoch 178/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.1215 - root_mean_squared_error: 0.3389 - val_loss: 0.1379 - val_root_mean_squared_error: 0.3624
# Epoch 179/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1110 - root_mean_squared_error: 0.3229 - val_loss: 0.1358 - val_root_mean_squared_error: 0.3596
# Epoch 180/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1047 - root_mean_squared_error: 0.3132 - val_loss: 0.1232 - val_root_mean_squared_error: 0.3417
# Epoch 181/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.1025 - root_mean_squared_error: 0.3098 - val_loss: 0.1213 - val_root_mean_squared_error: 0.3389
# Epoch 182/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1029 - root_mean_squared_error: 0.3106 - val_loss: 0.1188 - val_root_mean_squared_error: 0.3353
# Epoch 183/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.1041 - root_mean_squared_error: 0.3126 - val_loss: 0.1159 - val_root_mean_squared_error: 0.3311
# Epoch 184/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0904 - root_mean_squared_error: 0.2898 - val_loss: 0.1119 - val_root_mean_squared_error: 0.3250
# Epoch 185/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0895 - root_mean_squared_error: 0.2884 - val_loss: 0.1103 - val_root_mean_squared_error: 0.3225
# Epoch 186/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0876 - root_mean_squared_error: 0.2850 - val_loss: 0.1096 - val_root_mean_squared_error: 0.3214
# Epoch 187/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0851 - root_mean_squared_error: 0.2805 - val_loss: 0.1097 - val_root_mean_squared_error: 0.3215

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0963 - root_mean_squared_error: 0.2988
# Test Loss: [0.10512233525514603, 0.31330230832099915]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_XYZ_only_norm\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()

# %%
# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_test)

# Example for the first sample in the dataset
sample_index = 3
initial_seq = X_test[sample_index, :, -3:]  # Last 3 features are the coordinates
print(initial_seq.shape)
true_values = y_test[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', test_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', test_df.iloc[sample_index])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# (75, 3)

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
