# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           40         -200       330            500                680
# 1           40         -400       240            580                900
# 2           80         -200       120            580                900
# 3          100         -200        30            500                680
# 4           20            0        60            500                680
# ...        ...          ...       ...            ...                ...
# 1181        80            0       300            580                900
# 1182        40            0       330            770                740
# 1183        20            0        30            600                880
# 1184        80         -400        30            500                680
# 1185        80          200       270            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    11         1160              1130
# 2                    11         1160              1130
# 3                    20         1200               920
# 4                    20         1200               920
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 16         1150               980
# 1183                 30          760              1070
# 1184                 20         1200               920
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 1     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 2     [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 3     [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 4     [326.04, 326.04, 326.04, 326.04, 326.04, 326.0...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [154.159, 154.159, 154.159, 154.159, 154.159, ...
# 1183  [288.841, 288.841, 288.841, 288.841, 288.841, ...
# 1184  [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1185  [91.318, 91.318, 91.318, 91.318, 91.318, 91.31...
#
#                                       Head_Y_Coordinate  \
# 0     [-270.403, -270.403, -270.403, -270.403, -270....
# 1     [-290.522, -290.522, -290.522, -290.522, -290....
# 2     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 3     [-270.403, -270.403, -270.403, -270.403, -270....
# 4     [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# ...                                                 ...
# 1181  [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# 1182  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
# 1183  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
# 1184  [-470.403, -470.403, -470.403, -470.403, -470....
# 1185  [243.637, 243.637, 243.637, 243.637, 243.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           40         -200       330            500                680
# 1           40         -400       240            580                900
# 2           80         -200       120            580                900
# 3          100         -200        30            500                680
# 4           20            0        60            500                680
# ...        ...          ...       ...            ...                ...
# 1181        80            0       300            580                900
# 1182        40            0       330            770                740
# 1183        20            0        30            600                880
# 1184        80         -400        30            500                680
# 1185        80          200       270            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    11         1160              1130
# 2                    11         1160              1130
# 3                    20         1200               920
# 4                    20         1200               920
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 16         1150               980
# 1183                 30          760              1070
# 1184                 20         1200               920
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 1     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 2     [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 3     [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 4     [326.04, 326.04, 326.04, 326.04, 326.04, 326.0...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [154.159, 154.159, 154.159, 154.159, 154.159, ...
# 1183  [288.841, 288.841, 288.841, 288.841, 288.841, ...
# 1184  [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1185  [91.318, 91.318, 91.318, 91.318, 91.318, 91.31...
#
#                                       Head_Y_Coordinate  \
# 0     [-270.403, -270.403, -270.403, -270.403, -270....
# 1     [-290.522, -290.522, -290.522, -290.522, -290....
# 2     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 3     [-270.403, -270.403, -270.403, -270.403, -270....
# 4     [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# ...                                                 ...
# 1181  [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# 1182  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
# 1183  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
# 1184  [-470.403, -470.403, -470.403, -470.403, -470....
# 1185  [243.637, 243.637, 243.637, 243.637, 243.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 13523.02row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.937658           0.371616           1.000000
# 1            -0.937658           0.371616           0.999984
# 2            -0.937658           0.371616           0.999936
# 3            -0.937658           0.371616           0.999921
# 4            -0.937658           0.371616           0.999876
# ..                 ...                ...                ...
# 296           0.957768          -0.916054          -0.770504
# 297           0.968330          -0.936693          -0.769271
# 298           0.978888          -0.957570          -0.768071
# 299           0.989446          -0.978710          -0.766902
# 300           1.000000          -1.000000          -0.765768
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 75, 11) (711, 75, 1)
# (237, 75, 11) (237, 75, 1)
# (238, 75, 11) (238, 75, 1)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 1, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 1)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional) │ (None, 75, 64)         │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 75, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 75)             │         2,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 75, 1)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,707 (584.79 KB)
#  Trainable params: 149,707 (584.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_val
# Out:
# array([[[-0.99892558],
#         [-0.99907654],
#         [-0.99923682],
#         ...,
#         [-0.52820738],
#         [-0.5177698 ],
#         [-0.50742167]],
#
#        [[-0.99854473],
#         [-0.99775419],
#         [-0.99677636],
#         ...,
#         [-0.55621285],
#         [-0.54715801],
#         [-0.53809491]],
#
#        [[-0.9314161 ],
#         [-0.92608379],
#         [-0.92054265],
#         ...,
#         [-0.38265845],
#         [-0.37431592],
#         [-0.36598194]],
#
#        ...,
#
#        [[-0.9999419 ],
#         [-0.99998219],
#         [-1.        ],
#         ...,
#         [-0.50685916],
#         [-0.49809942],
#         [-0.48942214]],
#
#        [[-0.84564944],
#         [-0.85057064],
#         [-0.85559831],
#         ...,
#         [-0.71108896],
#         [-0.70121344],
#         [-0.69148934]],
#
#        [[-0.99669521],
#         [-0.99468608],
#         [-0.99216886],
#         ...,
#         [-0.4460002 ],
#         [-0.43787618],
#         [-0.42975841]]])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_X\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - loss: 0.5819 - root_mean_squared_error: 0.7272 - val_loss: 0.1718 - val_root_mean_squared_error: 0.3569
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.1259 - root_mean_squared_error: 0.2846 - val_loss: 0.0615 - val_root_mean_squared_error: 0.1498
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0589 - root_mean_squared_error: 0.1456 - val_loss: 0.0482 - val_root_mean_squared_error: 0.1213
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0478 - root_mean_squared_error: 0.1250 - val_loss: 0.0403 - val_root_mean_squared_error: 0.1087
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0409 - root_mean_squared_error: 0.1158 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1052
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0365 - root_mean_squared_error: 0.1136 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1002
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0312 - root_mean_squared_error: 0.1041 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0996
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0288 - root_mean_squared_error: 0.1054 - val_loss: 0.0237 - val_root_mean_squared_error: 0.0883
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0247 - root_mean_squared_error: 0.0961 - val_loss: 0.0209 - val_root_mean_squared_error: 0.0834
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0211 - root_mean_squared_error: 0.0864 - val_loss: 0.0210 - val_root_mean_squared_error: 0.0927
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0205 - root_mean_squared_error: 0.0920 - val_loss: 0.0184 - val_root_mean_squared_error: 0.0865
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0194 - root_mean_squared_error: 0.0937 - val_loss: 0.0160 - val_root_mean_squared_error: 0.0796
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0165 - root_mean_squared_error: 0.0846 - val_loss: 0.0162 - val_root_mean_squared_error: 0.0869
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0157 - root_mean_squared_error: 0.0850 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0733
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0138 - root_mean_squared_error: 0.0792 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0782
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0123 - root_mean_squared_error: 0.0745 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0695
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0116 - root_mean_squared_error: 0.0748 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0666
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0101 - root_mean_squared_error: 0.0687 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0745
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0091 - root_mean_squared_error: 0.0656 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0626
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0084 - root_mean_squared_error: 0.0633 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0650
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0082 - root_mean_squared_error: 0.0653 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0705
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0086 - root_mean_squared_error: 0.0711 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0745
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0110 - root_mean_squared_error: 0.0877 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1013
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0124 - root_mean_squared_error: 0.0978 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0976
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0116 - root_mean_squared_error: 0.0947 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0828
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0088 - root_mean_squared_error: 0.0793 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1057
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0115 - root_mean_squared_error: 0.0962 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0915
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0089 - root_mean_squared_error: 0.0831 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0690
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0071 - root_mean_squared_error: 0.0718 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0809
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0078 - root_mean_squared_error: 0.0779 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0909
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0074 - root_mean_squared_error: 0.0767 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0835
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0074 - root_mean_squared_error: 0.0769 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0589
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0049 - root_mean_squared_error: 0.0594 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0586
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0044 - root_mean_squared_error: 0.0562 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0611
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0047 - root_mean_squared_error: 0.0600 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0578
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0042 - root_mean_squared_error: 0.0562 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0569
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0045 - root_mean_squared_error: 0.0596 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0581
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0040 - root_mean_squared_error: 0.0552 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0568
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0043 - root_mean_squared_error: 0.0584 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0574
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0043 - root_mean_squared_error: 0.0592 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0559
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0039 - root_mean_squared_error: 0.0560 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0577
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0039 - root_mean_squared_error: 0.0559 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0570
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0038 - root_mean_squared_error: 0.0560 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0586
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0040 - root_mean_squared_error: 0.0574 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0584
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0037 - root_mean_squared_error: 0.0549 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0575
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0039 - root_mean_squared_error: 0.0577 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0645
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0039 - root_mean_squared_error: 0.0580 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0582
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0038 - root_mean_squared_error: 0.0569 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0585
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0040 - root_mean_squared_error: 0.0586 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0609
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0039 - root_mean_squared_error: 0.0582 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0581
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0039 - root_mean_squared_error: 0.0581 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0571
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0038 - root_mean_squared_error: 0.0579 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0567
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0039 - root_mean_squared_error: 0.0589 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0634
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0045 - root_mean_squared_error: 0.0632 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0574
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0036 - root_mean_squared_error: 0.0560 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0699
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0062 - root_mean_squared_error: 0.0754 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0894
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0066 - root_mean_squared_error: 0.0787 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1027
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0102 - root_mean_squared_error: 0.0992 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1006
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0094 - root_mean_squared_error: 0.0945 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1056
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0094 - root_mean_squared_error: 0.0952 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0998
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0093 - root_mean_squared_error: 0.0948 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0973
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0085 - root_mean_squared_error: 0.0899 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0935
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0068 - root_mean_squared_error: 0.0796 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0699
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0094 - root_mean_squared_error: 0.0947 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0999
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0089 - root_mean_squared_error: 0.0925 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0969
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0080 - root_mean_squared_error: 0.0875 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0891
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0067 - root_mean_squared_error: 0.0796 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0850
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0064 - root_mean_squared_error: 0.0773 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0657
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0047 - root_mean_squared_error: 0.0652 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0615
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0037 - root_mean_squared_error: 0.0570 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0563
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0038 - root_mean_squared_error: 0.0584 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0575
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0036 - root_mean_squared_error: 0.0567 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0567
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0037 - root_mean_squared_error: 0.0581 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0567
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0035 - root_mean_squared_error: 0.0562 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0575
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0034 - root_mean_squared_error: 0.0548 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0564
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0036 - root_mean_squared_error: 0.0574 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0576
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0035 - root_mean_squared_error: 0.0565 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0563
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0036 - root_mean_squared_error: 0.0575 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0558
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0035 - root_mean_squared_error: 0.0567 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0565
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0034 - root_mean_squared_error: 0.0561 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0561
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0036 - root_mean_squared_error: 0.0574 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0593
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0034 - root_mean_squared_error: 0.0559 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0557
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0036 - root_mean_squared_error: 0.0575 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0562
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0032 - root_mean_squared_error: 0.0537 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0565
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0033 - root_mean_squared_error: 0.0553 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0566
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0045 - root_mean_squared_error: 0.0646 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0641
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0038 - root_mean_squared_error: 0.0589 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0558
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0034 - root_mean_squared_error: 0.0555 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0558
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0035 - root_mean_squared_error: 0.0566 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0561
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0037 - root_mean_squared_error: 0.0585 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0562
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0032 - root_mean_squared_error: 0.0547 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0549
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0035 - root_mean_squared_error: 0.0565 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0578
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 0.0031 - root_mean_squared_error: 0.0533 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0579
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0036 - root_mean_squared_error: 0.0580 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0557
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0033 - root_mean_squared_error: 0.0552 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0551
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - loss: 0.0033 - root_mean_squared_error: 0.0556 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0552
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.0033 - root_mean_squared_error: 0.0555 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0557
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0033 - root_mean_squared_error: 0.0547 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0561
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.0037 - root_mean_squared_error: 0.0583 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0568
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.0032 - root_mean_squared_error: 0.0547 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0560
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0034 - root_mean_squared_error: 0.0562 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0561
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0035 - root_mean_squared_error: 0.0572 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0560
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0032 - root_mean_squared_error: 0.0547 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0562
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0034 - root_mean_squared_error: 0.0564 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0560
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0036 - root_mean_squared_error: 0.0584 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0558
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0036 - root_mean_squared_error: 0.0577 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0572
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.0035 - root_mean_squared_error: 0.0574 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0585
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - loss: 0.0036 - root_mean_squared_error: 0.0581 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0558
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.0033 - root_mean_squared_error: 0.0552 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0567
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.0035 - root_mean_squared_error: 0.0576 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0571
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0034 - root_mean_squared_error: 0.0563 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0555
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - loss: 0.0034 - root_mean_squared_error: 0.0569 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0555
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - loss: 0.0035 - root_mean_squared_error: 0.0578 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0589
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 0.0035 - root_mean_squared_error: 0.0574 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0560
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.0033 - root_mean_squared_error: 0.0553 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0555
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 283ms/step - loss: 0.0033 - root_mean_squared_error: 0.0557 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0558
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0033 - root_mean_squared_error: 0.0562 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0585
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.0037 - root_mean_squared_error: 0.0590 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0564
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.0033 - root_mean_squared_error: 0.0556 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0580
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0034 - root_mean_squared_error: 0.0572 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0569
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - loss: 0.0035 - root_mean_squared_error: 0.0574 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0600
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - loss: 0.0034 - root_mean_squared_error: 0.0567 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0561
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0040 - root_mean_squared_error: 0.0615 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1006
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - loss: 0.0086 - root_mean_squared_error: 0.0918 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0869
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0054 - root_mean_squared_error: 0.0726 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0711
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0040 - root_mean_squared_error: 0.0612 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0652
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.0043 - root_mean_squared_error: 0.0636 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0680
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - loss: 0.0043 - root_mean_squared_error: 0.0637 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0691
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.0054 - root_mean_squared_error: 0.0718 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0699
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0039 - root_mean_squared_error: 0.0603 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0588
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.0036 - root_mean_squared_error: 0.0576 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0585
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - loss: 0.0037 - root_mean_squared_error: 0.0592 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0596
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.0038 - root_mean_squared_error: 0.0596 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0566
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0036 - root_mean_squared_error: 0.0580 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0559
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0030 - root_mean_squared_error: 0.0528 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0570

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0030 - root_mean_squared_error: 0.0532
# Test Loss: [0.0030840649269521236, 0.05386066064238548]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_X\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 32 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026DDFAE5AB0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
#plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
#plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
