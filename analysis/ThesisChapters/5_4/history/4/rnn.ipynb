# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           60          400       270            580                900
# 1           60         -400       240            770                740
# 2           80          200       240            580                900
# 3          100          200       180            500                680
# 4           60         -200         0            580                900
# ...        ...          ...       ...            ...                ...
# 1181        20          400       240            770                740
# 1182        20         -200       240            770                740
# 1183        40          200       120            770                740
# 1184        20          200       240            500                680
# 1185        20         -200         0            770                740
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    11         1160              1130
# 1                    16         1150               980
# 2                    11         1160              1130
# 3                    20         1200               920
# 4                    11         1160              1130
# ...                 ...          ...               ...
# 1181                 16         1150               980
# 1182                 16         1150               980
# 1183                 16         1150               980
# 1184                 20         1200               920
# 1185                 16         1150               980
#
#                                       Head_X_Coordinate  \
# 0     [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
# 1     [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 2     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 3     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# 4     [228.0, 228.0, 228.0, 228.0, 228.0, 227.999, 2...
# ...                                                 ...
# 1181  [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1182  [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1183  [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 1184  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1185  [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
#
#                                       Head_Y_Coordinate  \
# 0     [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 1     [-290.522, -290.522, -290.522, -290.522, -290....
# 2     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 3     [375.319, 375.319, 375.319, 375.319, 375.319, ...
# 4     [-288.045, -288.045, -288.045, -288.045, -288....
# ...                                                 ...
# 1181  [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 1182  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 1183  [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1184  [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1185  [-288.045, -288.045, -288.045, -288.045, -288....
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           60          400       270            580                900
# 1           60         -400       240            770                740
# 2           80          200       240            580                900
# 3          100          200       180            500                680
# 4           60         -200         0            580                900
# ...        ...          ...       ...            ...                ...
# 1181        20          400       240            770                740
# 1182        20         -200       240            770                740
# 1183        40          200       120            770                740
# 1184        20          200       240            500                680
# 1185        20         -200         0            770                740
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    11         1160              1130
# 1                    16         1150               980
# 2                    11         1160              1130
# 3                    20         1200               920
# 4                    11         1160              1130
# ...                 ...          ...               ...
# 1181                 16         1150               980
# 1182                 16         1150               980
# 1183                 16         1150               980
# 1184                 20         1200               920
# 1185                 16         1150               980
#
#                                       Head_X_Coordinate  \
# 0     [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
# 1     [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 2     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 3     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# 4     [228.0, 228.0, 228.0, 228.0, 228.0, 227.999, 2...
# ...                                                 ...
# 1181  [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1182  [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1183  [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 1184  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1185  [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
#
#                                       Head_Y_Coordinate  \
# 0     [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 1     [-290.522, -290.522, -290.522, -290.522, -290....
# 2     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 3     [375.319, 375.319, 375.319, 375.319, 375.319, ...
# 4     [-288.045, -288.045, -288.045, -288.045, -288....
# ...                                                 ...
# 1181  [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 1182  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 1183  [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1184  [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1185  [-288.045, -288.045, -288.045, -288.045, -288....
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 15803.73row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.992826          -0.248856           0.996894
# 1            -0.992826          -0.248856           0.996874
# 2            -0.992826          -0.248856           0.996812
# 3            -0.992826          -0.248856           0.996791
# 4            -0.992826          -0.248856           0.996733
# ..                 ...                ...                ...
# 296           0.959329           0.958166          -0.729958
# 297           0.969485           0.956835          -0.730244
# 298           0.979649           0.955545          -0.730526
# 299           0.989822           0.954297          -0.730816
# 300           1.000000           0.953103          -0.731111
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 100
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 3)
# (237, 100, 11) (237, 75, 3)
# (238, 100, 11) (238, 75, 3)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 3, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional) │ (None, 100, 64)        │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 225)            │         7,425 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 75, 3)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,657 (604.13 KB)
#  Trainable params: 154,657 (604.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_val
# Out:
# array([[[-0.94455179, -1.        , -0.95041309],
#         [-0.93725631, -0.99970084, -0.97345047],
#         [-0.92963706, -0.9891446 , -0.9903327 ],
#         ...,
#         [-0.26866506, -0.38805906, -0.67800657],
#         [-0.25887732, -0.39947005, -0.67279166],
#         [-0.24911629, -0.4111161 , -0.6676446 ]],
#
#        [[-0.9993998 ,  0.99971899, -0.3378551 ],
#         [-0.99981869,  0.99898687, -0.37545159],
#         [-1.        ,  0.99778147, -0.4137434 ],
#         ...,
#         [-0.40361857,  0.26071829, -0.66924733],
#         [-0.39285752,  0.25247274, -0.66121179],
#         [-0.38209523,  0.24420501, -0.65326153]],
#
#        [[-0.84376832,  0.99438514,  0.07715899],
#         [-0.83745625,  0.99678984,  0.05783733],
#         [-0.83108051,  0.99849414,  0.03864175],
#         ...,
#         [-0.28304061,  0.52212968, -0.7672512 ],
#         [-0.27403364,  0.51118011, -0.7697066 ],
#         [-0.2650301 ,  0.50002043, -0.77216515]],
#
#        ...,
#
#        [[-0.95695697,  0.19125851, -0.34257718],
#         [-0.95224188,  0.17030674, -0.38371161],
#         [-0.94728156,  0.14963086, -0.42497649],
#         ...,
#         [-0.27366241, -0.29911582, -0.25665147],
#         [-0.26323859, -0.30086136, -0.24876544],
#         [-0.2528795 , -0.30261751, -0.24101407]],
#
#        [[-0.82224825, -0.43283826, -0.33884414],
#         [-0.81416456, -0.45722002, -0.36621387],
#         [-0.806001  , -0.4809062 , -0.39328525],
#         ...,
#         [-0.2164195 , -0.99946773, -0.88739272],
#         [-0.20829761, -0.9997883 , -0.88002159],
#         [-0.20019222, -0.99996371, -0.87254076]],
#
#        [[-0.664756  ,  0.98793344,  0.5394719 ],
#         [-0.65828604,  0.99109527,  0.54992594],
#         [-0.65175302,  0.99370861,  0.56059868],
#         ...,
#         [-0.07389378,  0.43703369,  0.93494634],
#         [-0.06614557,  0.42109551,  0.92983032],
#         [-0.05847083,  0.40514119,  0.92433987]]])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\4\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 208ms/step - loss: 0.4676 - root_mean_squared_error: 0.6483 - val_loss: 0.2912 - val_root_mean_squared_error: 0.5023
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2716 - root_mean_squared_error: 0.4842 - val_loss: 0.2026 - val_root_mean_squared_error: 0.4142
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.2132 - root_mean_squared_error: 0.4287 - val_loss: 0.1887 - val_root_mean_squared_error: 0.4048
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1994 - root_mean_squared_error: 0.4192 - val_loss: 0.1782 - val_root_mean_squared_error: 0.3976
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1850 - root_mean_squared_error: 0.4072 - val_loss: 0.1709 - val_root_mean_squared_error: 0.3929
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1747 - root_mean_squared_error: 0.3983 - val_loss: 0.1658 - val_root_mean_squared_error: 0.3898
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1606 - root_mean_squared_error: 0.3836 - val_loss: 0.1581 - val_root_mean_squared_error: 0.3822
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1732 - root_mean_squared_error: 0.4019 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3836
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1613 - root_mean_squared_error: 0.3886 - val_loss: 0.1621 - val_root_mean_squared_error: 0.3909
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.1496 - root_mean_squared_error: 0.3746 - val_loss: 0.1521 - val_root_mean_squared_error: 0.3793
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1549 - root_mean_squared_error: 0.3830 - val_loss: 0.1532 - val_root_mean_squared_error: 0.3817
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1660 - root_mean_squared_error: 0.3983 - val_loss: 0.1572 - val_root_mean_squared_error: 0.3880
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1673 - root_mean_squared_error: 0.4009 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3779
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1583 - root_mean_squared_error: 0.3902 - val_loss: 0.1518 - val_root_mean_squared_error: 0.3823
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1543 - root_mean_squared_error: 0.3856 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3824
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - loss: 0.1708 - root_mean_squared_error: 0.4072 - val_loss: 0.1537 - val_root_mean_squared_error: 0.3859
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.1573 - root_mean_squared_error: 0.3906 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3850
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.1660 - root_mean_squared_error: 0.4016 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3852
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.1556 - root_mean_squared_error: 0.3891 - val_loss: 0.1567 - val_root_mean_squared_error: 0.3908
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1537 - root_mean_squared_error: 0.3870 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3823
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1638 - root_mean_squared_error: 0.4000 - val_loss: 0.1478 - val_root_mean_squared_error: 0.3797
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1570 - root_mean_squared_error: 0.3915 - val_loss: 0.1538 - val_root_mean_squared_error: 0.3877
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1652 - root_mean_squared_error: 0.4021 - val_loss: 0.1572 - val_root_mean_squared_error: 0.3923
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1628 - root_mean_squared_error: 0.3993 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3831
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.1503 - root_mean_squared_error: 0.3833 - val_loss: 0.1486 - val_root_mean_squared_error: 0.3815
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1524 - root_mean_squared_error: 0.3865 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3795
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1509 - root_mean_squared_error: 0.3846 - val_loss: 0.1560 - val_root_mean_squared_error: 0.3913
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1660 - root_mean_squared_error: 0.4037 - val_loss: 0.1541 - val_root_mean_squared_error: 0.3893
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1697 - root_mean_squared_error: 0.4086 - val_loss: 0.1536 - val_root_mean_squared_error: 0.3887
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1596 - root_mean_squared_error: 0.3961 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3843
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1415 - root_mean_squared_error: 0.3724 - val_loss: 0.1486 - val_root_mean_squared_error: 0.3824
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1438 - root_mean_squared_error: 0.3759 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3800
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1709 - root_mean_squared_error: 0.4104 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3851
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1636 - root_mean_squared_error: 0.4012 - val_loss: 0.1473 - val_root_mean_squared_error: 0.3808
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1694 - root_mean_squared_error: 0.4088 - val_loss: 0.1544 - val_root_mean_squared_error: 0.3904
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1693 - root_mean_squared_error: 0.4089 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3881
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.1621 - root_mean_squared_error: 0.3999 - val_loss: 0.1560 - val_root_mean_squared_error: 0.3924
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1635 - root_mean_squared_error: 0.4018 - val_loss: 0.1617 - val_root_mean_squared_error: 0.3996
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.1603 - root_mean_squared_error: 0.3978 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3902
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.1540 - root_mean_squared_error: 0.3897 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3891
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1630 - root_mean_squared_error: 0.4013 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3835
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.1601 - root_mean_squared_error: 0.3978 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3853
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1582 - root_mean_squared_error: 0.3952 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3837
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1619 - root_mean_squared_error: 0.4000 - val_loss: 0.1517 - val_root_mean_squared_error: 0.3871
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1536 - root_mean_squared_error: 0.3895 - val_loss: 0.1460 - val_root_mean_squared_error: 0.3799
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1515 - root_mean_squared_error: 0.3868 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3808
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.1418 - root_mean_squared_error: 0.3740 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3845
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1565 - root_mean_squared_error: 0.3935 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3845
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.1584 - root_mean_squared_error: 0.3960 - val_loss: 0.1469 - val_root_mean_squared_error: 0.3813
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1639 - root_mean_squared_error: 0.4028 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3869
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1557 - root_mean_squared_error: 0.3926 - val_loss: 0.1440 - val_root_mean_squared_error: 0.3775
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - loss: 0.1543 - root_mean_squared_error: 0.3909 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3895
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.1589 - root_mean_squared_error: 0.3964 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3954
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1748 - root_mean_squared_error: 0.4161 - val_loss: 0.1483 - val_root_mean_squared_error: 0.3832
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.1588 - root_mean_squared_error: 0.3965 - val_loss: 0.1481 - val_root_mean_squared_error: 0.3829
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.1539 - root_mean_squared_error: 0.3904 - val_loss: 0.1486 - val_root_mean_squared_error: 0.3836
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.1526 - root_mean_squared_error: 0.3887 - val_loss: 0.1460 - val_root_mean_squared_error: 0.3803
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.1575 - root_mean_squared_error: 0.3950 - val_loss: 0.1523 - val_root_mean_squared_error: 0.3885
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1604 - root_mean_squared_error: 0.3986 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3848
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1432 - root_mean_squared_error: 0.3765 - val_loss: 0.1493 - val_root_mean_squared_error: 0.3846
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1625 - root_mean_squared_error: 0.4012 - val_loss: 0.1540 - val_root_mean_squared_error: 0.3908
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.1596 - root_mean_squared_error: 0.3978 - val_loss: 0.1538 - val_root_mean_squared_error: 0.3906
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1581 - root_mean_squared_error: 0.3960 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3892
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - loss: 0.1529 - root_mean_squared_error: 0.3891 - val_loss: 0.1516 - val_root_mean_squared_error: 0.3877
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1667 - root_mean_squared_error: 0.4066 - val_loss: 0.1516 - val_root_mean_squared_error: 0.3877
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1579 - root_mean_squared_error: 0.3957 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3861
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1489 - root_mean_squared_error: 0.3840 - val_loss: 0.1483 - val_root_mean_squared_error: 0.3835
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1514 - root_mean_squared_error: 0.3875 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3843
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.1484 - root_mean_squared_error: 0.3833 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3843
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - loss: 0.1655 - root_mean_squared_error: 0.4047 - val_loss: 0.1483 - val_root_mean_squared_error: 0.3834
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1629 - root_mean_squared_error: 0.4018 - val_loss: 0.1482 - val_root_mean_squared_error: 0.3834

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1632 - root_mean_squared_error: 0.4020
# Test Loss: [0.16018176078796387, 0.39836156368255615]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\4\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 32 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028D538615A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
