# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           80          400       330            500                680
# 1           80          200        60            600                880
# 2           60          400       120            600                880
# 3          100            0        90            600                880
# 4           80         -200       330            580                900
# ...        ...          ...       ...            ...                ...
# 1181        80         -400        30            600                880
# 1182        40         -200        90            600                880
# 1183        80         -400       300            600                880
# 1184        40          400       240            500                680
# 1185        80         -200       150            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    30          760              1070
# 2                    30          760              1070
# 3                    30          760              1070
# 4                    11         1160              1130
# ...                 ...          ...               ...
# 1181                 30          760              1070
# 1182                 30          760              1070
# 1183                 30          760              1070
# 1184                 20         1200               920
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 1     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 2     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 3     [354.682, 354.682, 354.682, 354.682, 354.682, ...
# 4     [162.159, 162.159, 162.159, 162.159, 162.159, ...
# ...                                                 ...
# 1181  [288.841, 288.841, 288.841, 288.841, 288.841, ...
# 1182  [354.682, 354.682, 354.682, 354.682, 354.682, ...
# 1183  [108.96, 108.96, 108.96, 108.96, 108.96, 108.9...
# 1184  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1185  [288.841, 288.841, 288.841, 288.841, 288.841, ...
#
#                                       Head_Y_Coordinate  \
# 0     [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1     [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 2     [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 3     [43.637, 43.637, 43.637, 43.637, 43.637, 43.63...
# 4     [-270.403, -270.403, -270.403, -270.403, -270....
# ...                                                 ...
# 1181  [-470.403, -470.403, -470.403, -470.403, -470....
# 1182  [-156.363, -156.363, -156.363, -156.363, -156....
# 1183  [-422.204, -422.204, -422.204, -422.204, -422....
# 1184  [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 1185  [-42.323, -42.323, -42.323, -42.323, -42.323, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           80          400       330            500                680
# 1           80          200        60            600                880
# 2           60          400       120            600                880
# 3          100            0        90            600                880
# 4           80         -200       330            580                900
# ...        ...          ...       ...            ...                ...
# 1181        80         -400        30            600                880
# 1182        40         -200        90            600                880
# 1183        80         -400       300            600                880
# 1184        40          400       240            500                680
# 1185        80         -200       150            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    30          760              1070
# 2                    30          760              1070
# 3                    30          760              1070
# 4                    11         1160              1130
# ...                 ...          ...               ...
# 1181                 30          760              1070
# 1182                 30          760              1070
# 1183                 30          760              1070
# 1184                 20         1200               920
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 1     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 2     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 3     [354.682, 354.682, 354.682, 354.682, 354.682, ...
# 4     [162.159, 162.159, 162.159, 162.159, 162.159, ...
# ...                                                 ...
# 1181  [288.841, 288.841, 288.841, 288.841, 288.841, ...
# 1182  [354.682, 354.682, 354.682, 354.682, 354.682, ...
# 1183  [108.96, 108.96, 108.96, 108.96, 108.96, 108.9...
# 1184  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1185  [288.841, 288.841, 288.841, 288.841, 288.841, ...
#
#                                       Head_Y_Coordinate  \
# 0     [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1     [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 2     [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 3     [43.637, 43.637, 43.637, 43.637, 43.637, 43.63...
# 4     [-270.403, -270.403, -270.403, -270.403, -270....
# ...                                                 ...
# 1181  [-470.403, -470.403, -470.403, -470.403, -470....
# 1182  [-156.363, -156.363, -156.363, -156.363, -156....
# 1183  [-422.204, -422.204, -422.204, -422.204, -422....
# 1184  [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 1185  [-42.323, -42.323, -42.323, -42.323, -42.323, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 17425.09row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.958847           0.076000           1.000000
# 1            -0.958847           0.076000           0.999984
# 2            -0.958847           0.076000           0.999937
# 3            -0.958847           0.076000           0.999921
# 4            -0.958847           0.076000           0.999877
# ..                 ...                ...                ...
# 296           0.953152          -0.290624          -0.855115
# 297           0.964907          -0.323845          -0.854398
# 298           0.976628          -0.356763          -0.853668
# 299           0.988323          -0.389597          -0.852935
# 300           1.000000          -0.422431          -0.852182
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        #df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 1)
# (237, 100, 11) (237, 75, 1)
# (238, 100, 11) (238, 75, 1)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 1, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 1)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 100, 64)        │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 75)             │         2,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 1)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,707 (584.79 KB)
#  Trainable params: 149,707 (584.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_val
# Out:
# array([[[ 0.41532179],
#         [ 0.42038062],
#         [ 0.42566197],
#         ...,
#         [ 0.73140077],
#         [ 0.72927383],
#         [ 0.72688512]],
#
#        [[-0.99911555],
#         [-0.99985051],
#         [-1.        ],
#         ...,
#         [-0.81207633],
#         [-0.80965135],
#         [-0.80727619]],
#
#        [[-0.8387593 ],
#         [-0.90456224],
#         [-0.97035615],
#         ...,
#         [ 0.57863347],
#         [ 0.5886503 ],
#         [ 0.59859032]],
#
#        ...,
#
#        [[ 0.45027157],
#         [ 0.45562107],
#         [ 0.46123248],
#         ...,
#         [ 0.71449571],
#         [ 0.7107635 ],
#         [ 0.70687087]],
#
#        [[-0.1984171 ],
#         [-0.23613669],
#         [-0.27432739],
#         ...,
#         [ 0.01508649],
#         [ 0.02524436],
#         [ 0.0347696 ]],
#
#        [[-0.27235547],
#         [-0.30716002],
#         [-0.34252598],
#         ...,
#         [-0.74307695],
#         [-0.7357818 ],
#         [-0.72860743]]])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Z\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 203ms/step - loss: 0.5805 - root_mean_squared_error: 0.7287 - val_loss: 0.3746 - val_root_mean_squared_error: 0.5766
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.3446 - root_mean_squared_error: 0.5510 - val_loss: 0.2166 - val_root_mean_squared_error: 0.4262
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.2190 - root_mean_squared_error: 0.4304 - val_loss: 0.1806 - val_root_mean_squared_error: 0.3890
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1792 - root_mean_squared_error: 0.3887 - val_loss: 0.1634 - val_root_mean_squared_error: 0.3727
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.1622 - root_mean_squared_error: 0.3716 - val_loss: 0.1754 - val_root_mean_squared_error: 0.3934
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1789 - root_mean_squared_error: 0.3973 - val_loss: 0.1635 - val_root_mean_squared_error: 0.3818
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.1720 - root_mean_squared_error: 0.3934 - val_loss: 0.1525 - val_root_mean_squared_error: 0.3700
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1558 - root_mean_squared_error: 0.3738 - val_loss: 0.1568 - val_root_mean_squared_error: 0.3782
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1589 - root_mean_squared_error: 0.3812 - val_loss: 0.1509 - val_root_mean_squared_error: 0.3724
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.1575 - root_mean_squared_error: 0.3809 - val_loss: 0.1496 - val_root_mean_squared_error: 0.3724
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1557 - root_mean_squared_error: 0.3800 - val_loss: 0.1396 - val_root_mean_squared_error: 0.3600
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.1655 - root_mean_squared_error: 0.3941 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3790
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.1509 - root_mean_squared_error: 0.3759 - val_loss: 0.1436 - val_root_mean_squared_error: 0.3679
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1562 - root_mean_squared_error: 0.3847 - val_loss: 0.1465 - val_root_mean_squared_error: 0.3727
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1367 - root_mean_squared_error: 0.3579 - val_loss: 0.1373 - val_root_mean_squared_error: 0.3609
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1416 - root_mean_squared_error: 0.3664 - val_loss: 0.1428 - val_root_mean_squared_error: 0.3693
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1519 - root_mean_squared_error: 0.3807 - val_loss: 0.1352 - val_root_mean_squared_error: 0.3595
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1302 - root_mean_squared_error: 0.3505 - val_loss: 0.1575 - val_root_mean_squared_error: 0.3897
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1528 - root_mean_squared_error: 0.3836 - val_loss: 0.1457 - val_root_mean_squared_error: 0.3747
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1346 - root_mean_squared_error: 0.3594 - val_loss: 0.1446 - val_root_mean_squared_error: 0.3737
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1385 - root_mean_squared_error: 0.3653 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3596
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1228 - root_mean_squared_error: 0.3425 - val_loss: 0.1407 - val_root_mean_squared_error: 0.3692
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1468 - root_mean_squared_error: 0.3770 - val_loss: 0.1377 - val_root_mean_squared_error: 0.3654
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1348 - root_mean_squared_error: 0.3608 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3929
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1671 - root_mean_squared_error: 0.4032 - val_loss: 0.1371 - val_root_mean_squared_error: 0.3649
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1645 - root_mean_squared_error: 0.4000 - val_loss: 0.1473 - val_root_mean_squared_error: 0.3790
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1339 - root_mean_squared_error: 0.3595 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3785
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1386 - root_mean_squared_error: 0.3670 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3731
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1583 - root_mean_squared_error: 0.3927 - val_loss: 0.1423 - val_root_mean_squared_error: 0.3729
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1499 - root_mean_squared_error: 0.3826 - val_loss: 0.1413 - val_root_mean_squared_error: 0.3719
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - loss: 0.1646 - root_mean_squared_error: 0.4011 - val_loss: 0.1323 - val_root_mean_squared_error: 0.3597
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1346 - root_mean_squared_error: 0.3615 - val_loss: 0.1436 - val_root_mean_squared_error: 0.3754
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1372 - root_mean_squared_error: 0.3665 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3611
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1469 - root_mean_squared_error: 0.3790 - val_loss: 0.1361 - val_root_mean_squared_error: 0.3655
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1084 - root_mean_squared_error: 0.3229 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3745
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1508 - root_mean_squared_error: 0.3844 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3647
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1308 - root_mean_squared_error: 0.3583 - val_loss: 0.1403 - val_root_mean_squared_error: 0.3714
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1341 - root_mean_squared_error: 0.3619 - val_loss: 0.1405 - val_root_mean_squared_error: 0.3719
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1523 - root_mean_squared_error: 0.3872 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3681
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1453 - root_mean_squared_error: 0.3783 - val_loss: 0.1424 - val_root_mean_squared_error: 0.3745
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1670 - root_mean_squared_error: 0.4052 - val_loss: 0.1390 - val_root_mean_squared_error: 0.3699
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1314 - root_mean_squared_error: 0.3589 - val_loss: 0.1318 - val_root_mean_squared_error: 0.3601
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1478 - root_mean_squared_error: 0.3814 - val_loss: 0.1375 - val_root_mean_squared_error: 0.3680
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1569 - root_mean_squared_error: 0.3924 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3706
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.1450 - root_mean_squared_error: 0.3778 - val_loss: 0.1430 - val_root_mean_squared_error: 0.3755
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1828 - root_mean_squared_error: 0.4217 - val_loss: 0.1316 - val_root_mean_squared_error: 0.3602
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1439 - root_mean_squared_error: 0.3768 - val_loss: 0.1369 - val_root_mean_squared_error: 0.3676
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1340 - root_mean_squared_error: 0.3633 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3592
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1386 - root_mean_squared_error: 0.3696 - val_loss: 0.1374 - val_root_mean_squared_error: 0.3684
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.1297 - root_mean_squared_error: 0.3557 - val_loss: 0.1249 - val_root_mean_squared_error: 0.3510
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1363 - root_mean_squared_error: 0.3653 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3623
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1415 - root_mean_squared_error: 0.3737 - val_loss: 0.1332 - val_root_mean_squared_error: 0.3628
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1437 - root_mean_squared_error: 0.3767 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3666
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1446 - root_mean_squared_error: 0.3775 - val_loss: 0.1344 - val_root_mean_squared_error: 0.3646
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1513 - root_mean_squared_error: 0.3865 - val_loss: 0.1371 - val_root_mean_squared_error: 0.3682
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1401 - root_mean_squared_error: 0.3720 - val_loss: 0.1347 - val_root_mean_squared_error: 0.3650
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1327 - root_mean_squared_error: 0.3619 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3667
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1650 - root_mean_squared_error: 0.4028 - val_loss: 0.1334 - val_root_mean_squared_error: 0.3634
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1134 - root_mean_squared_error: 0.3312 - val_loss: 0.1299 - val_root_mean_squared_error: 0.3586
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.1368 - root_mean_squared_error: 0.3676 - val_loss: 0.1279 - val_root_mean_squared_error: 0.3557
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1340 - root_mean_squared_error: 0.3640 - val_loss: 0.1351 - val_root_mean_squared_error: 0.3658
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.1507 - root_mean_squared_error: 0.3854 - val_loss: 0.1421 - val_root_mean_squared_error: 0.3751
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1344 - root_mean_squared_error: 0.3643 - val_loss: 0.1346 - val_root_mean_squared_error: 0.3651
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1287 - root_mean_squared_error: 0.3562 - val_loss: 0.1347 - val_root_mean_squared_error: 0.3653
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.1196 - root_mean_squared_error: 0.3426 - val_loss: 0.1373 - val_root_mean_squared_error: 0.3690
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.1324 - root_mean_squared_error: 0.3619 - val_loss: 0.1379 - val_root_mean_squared_error: 0.3696
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.1252 - root_mean_squared_error: 0.3500 - val_loss: 0.1388 - val_root_mean_squared_error: 0.3708
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.1235 - root_mean_squared_error: 0.3484 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3742
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.1789 - root_mean_squared_error: 0.4189 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3599
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.1459 - root_mean_squared_error: 0.3788 - val_loss: 0.1283 - val_root_mean_squared_error: 0.3567

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1072 - root_mean_squared_error: 0.3245
# Test Loss: [0.11038146167993546, 0.32970234751701355]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Z\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
#plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
#plot_predictions3(initial_seq[:, 1], true_values[:, 0], predicted_values[:, 0], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 0], predicted_values[:, 0], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
