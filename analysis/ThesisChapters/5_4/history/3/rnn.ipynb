# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           60          200       240            580                900
# 1           20          400       270            500                680
# 2          100         -200       210            500                680
# 3           20         -200       240            600                880
# 4           40            0        60            600                880
# ...        ...          ...       ...            ...                ...
# 1181        60          200        60            580                900
# 1182        40          200        30            770                740
# 1183        80         -200       120            500                680
# 1184       100          400       180            600                880
# 1185       100          200       180            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    11         1160              1130
# 1                    20         1200               920
# 2                    20         1200               920
# 3                    30          760              1070
# 4                    30          760              1070
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 16         1150               980
# 1183                 20         1200               920
# 1184                 30          760              1070
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1     [80.318, 80.318, 80.318, 80.318, 80.318, 80.31...
# 2     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 3     [108.96, 108.96, 108.96, 108.96, 108.96, 108.9...
# 4     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# ...                                                 ...
# 1181  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1182  [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 1183  [326.04, 326.04, 326.04, 326.04, 326.04, 326.0...
# 1184  [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
# 1185  [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
#
#                                       Head_Y_Coordinate  \
# 0     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1     [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 4     [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# ...                                                 ...
# 1181  [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 1182  [129.597, 129.597, 129.597, 129.597, 129.597, ...
# 1183  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 1184  [575.319, 575.319, 575.319, 575.319, 575.319, ...
# 1185  [375.319, 375.319, 375.319, 375.319, 375.319, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           60          200       240            580                900
# 1           20          400       270            500                680
# 2          100         -200       210            500                680
# 3           20         -200       240            600                880
# 4           40            0        60            600                880
# ...        ...          ...       ...            ...                ...
# 1181        60          200        60            580                900
# 1182        40          200        30            770                740
# 1183        80         -200       120            500                680
# 1184       100          400       180            600                880
# 1185       100          200       180            600                880
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    11         1160              1130
# 1                    20         1200               920
# 2                    20         1200               920
# 3                    30          760              1070
# 4                    30          760              1070
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 16         1150               980
# 1183                 20         1200               920
# 1184                 30          760              1070
# 1185                 30          760              1070
#
#                                       Head_X_Coordinate  \
# 0     [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1     [80.318, 80.318, 80.318, 80.318, 80.318, 80.31...
# 2     [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 3     [108.96, 108.96, 108.96, 108.96, 108.96, 108.9...
# 4     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# ...                                                 ...
# 1181  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1182  [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 1183  [326.04, 326.04, 326.04, 326.04, 326.04, 326.0...
# 1184  [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
# 1185  [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
#
#                                       Head_Y_Coordinate  \
# 0     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1     [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 4     [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# ...                                                 ...
# 1181  [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 1182  [129.597, 129.597, 129.597, 129.597, 129.597, ...
# 1183  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 1184  [575.319, 575.319, 575.319, 575.319, 575.319, ...
# 1185  [375.319, 375.319, 375.319, 375.319, 375.319, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 9202.00row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.984437          -0.626844           0.997081
# 1            -0.984437          -0.626844           0.997060
# 2            -0.984437          -0.626844           0.996998
# 3            -0.984437          -0.626844           0.996978
# 4            -0.984437          -0.626844           0.996920
# ..                 ...                ...                ...
# 296           0.961978           0.973654          -0.041934
# 297           0.971492           0.980292          -0.038012
# 298           0.981002           0.986879          -0.034070
# 299           0.990503           0.993454          -0.030096
# 300           1.000000           1.000000          -0.026105
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 100
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 3)
# (237, 100, 11) (237, 75, 3)
# (238, 100, 11) (238, 75, 3)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 3, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 100, 64)        │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 225)            │         7,425 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 3)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,657 (604.13 KB)
#  Trainable params: 154,657 (604.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_val
# Out:
# array([[[-0.99963024,  0.37502257, -0.25788366],
#         [-1.        ,  0.41663853, -0.30686459],
#         [-0.9995545 ,  0.45897688, -0.35698486],
#         ...,
#         [-0.38969615,  0.59748734, -0.77350106],
#         [-0.37978647,  0.5863374 , -0.76975994],
#         [-0.36992563,  0.57499902, -0.76616208]],
#
#        [[-0.90251119,  0.8361215 , -0.82800119],
#         [-0.8964778 ,  0.81261246, -0.86815642],
#         [-0.89027803,  0.78785822, -0.9079577 ],
#         ...,
#         [-0.26572239,  0.37049789, -0.70974455],
#         [-0.25724534,  0.38562686, -0.71058894],
#         [-0.24870416,  0.40049434, -0.71157832]],
#
#        [[-0.89573067,  0.98781473,  0.05903228],
#         [-0.8898792 ,  0.99337255,  0.03733119],
#         [-0.8839092 ,  0.99723157,  0.01583601],
#         ...,
#         [-0.34072712, -0.39264479, -0.89437413],
#         [-0.33143544, -0.40881492, -0.89616968],
#         [-0.32213191, -0.42515284, -0.89781384]],
#
#        ...,
#
#        [[-0.94031416, -0.99675301, -0.94788022],
#         [-0.93319076, -1.        , -0.97291373],
#         [-0.92570554, -0.99488968, -0.99159038],
#         ...,
#         [-0.26704108, -0.40897351, -0.57347928],
#         [-0.25706387, -0.42063316, -0.56688545],
#         [-0.24711354, -0.43247731, -0.56037168]],
#
#        [[-0.99105543, -0.65853416,  0.32321425],
#         [-0.98895622, -0.64668071,  0.30071861],
#         [-0.98661328, -0.63491726,  0.27788435],
#         ...,
#         [-0.3000513 , -0.05727619,  0.24524053],
#         [-0.28617451, -0.04803614,  0.25399931],
#         [-0.27237764, -0.03876195,  0.26211576]],
#
#        [[-0.91534983,  0.82362974, -0.49659271],
#         [-0.91009117,  0.80477415, -0.52947692],
#         [-0.90468784,  0.78515482, -0.56224293],
#         ...,
#         [-0.2879886 ,  0.33290904, -0.91229528],
#         [-0.27867484,  0.33903584, -0.91057981],
#         [-0.2694301 ,  0.3455445 , -0.9088576 ]]])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\3\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=1000, 
          callbacks=[cp, 
                     #es
                     ])
# Out:
# Epoch 1/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - loss: 0.4603 - root_mean_squared_error: 0.6413 - val_loss: 0.3049 - val_root_mean_squared_error: 0.5137
# Epoch 2/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - loss: 0.2575 - root_mean_squared_error: 0.4669 - val_loss: 0.2400 - val_root_mean_squared_error: 0.4541
# Epoch 3/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2081 - root_mean_squared_error: 0.4191 - val_loss: 0.2279 - val_root_mean_squared_error: 0.4472
# Epoch 4/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 0.1866 - root_mean_squared_error: 0.4000 - val_loss: 0.2097 - val_root_mean_squared_error: 0.4319
# Epoch 5/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1805 - root_mean_squared_error: 0.3978 - val_loss: 0.2087 - val_root_mean_squared_error: 0.4352
# Epoch 6/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - loss: 0.1650 - root_mean_squared_error: 0.3826 - val_loss: 0.1992 - val_root_mean_squared_error: 0.4274
# Epoch 7/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - loss: 0.1691 - root_mean_squared_error: 0.3914 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4387
# Epoch 8/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - loss: 0.1673 - root_mean_squared_error: 0.3920 - val_loss: 0.1932 - val_root_mean_squared_error: 0.4254
# Epoch 9/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - loss: 0.1596 - root_mean_squared_error: 0.3844 - val_loss: 0.1882 - val_root_mean_squared_error: 0.4212
# Epoch 10/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.1551 - root_mean_squared_error: 0.3803 - val_loss: 0.1795 - val_root_mean_squared_error: 0.4123
# Epoch 11/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1445 - root_mean_squared_error: 0.3677 - val_loss: 0.1895 - val_root_mean_squared_error: 0.4256
# Epoch 12/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - loss: 0.1589 - root_mean_squared_error: 0.3882 - val_loss: 0.1853 - val_root_mean_squared_error: 0.4214
# Epoch 13/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - loss: 0.1462 - root_mean_squared_error: 0.3723 - val_loss: 0.1770 - val_root_mean_squared_error: 0.4121
# Epoch 14/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.1368 - root_mean_squared_error: 0.3603 - val_loss: 0.1691 - val_root_mean_squared_error: 0.4032
# Epoch 15/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.1349 - root_mean_squared_error: 0.3584 - val_loss: 0.1799 - val_root_mean_squared_error: 0.4170
# Epoch 16/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.1473 - root_mean_squared_error: 0.3759 - val_loss: 0.1816 - val_root_mean_squared_error: 0.4196
# Epoch 17/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.1465 - root_mean_squared_error: 0.3755 - val_loss: 0.1746 - val_root_mean_squared_error: 0.4115
# Epoch 18/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1385 - root_mean_squared_error: 0.3651 - val_loss: 0.1825 - val_root_mean_squared_error: 0.4215
# Epoch 19/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1335 - root_mean_squared_error: 0.3586 - val_loss: 0.1664 - val_root_mean_squared_error: 0.4022
# Epoch 20/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.1300 - root_mean_squared_error: 0.3541 - val_loss: 0.1663 - val_root_mean_squared_error: 0.4025
# Epoch 21/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - loss: 0.1285 - root_mean_squared_error: 0.3524 - val_loss: 0.1679 - val_root_mean_squared_error: 0.4046
# Epoch 22/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - loss: 0.1273 - root_mean_squared_error: 0.3509 - val_loss: 0.1655 - val_root_mean_squared_error: 0.4020
# Epoch 23/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - loss: 0.1257 - root_mean_squared_error: 0.3489 - val_loss: 0.1584 - val_root_mean_squared_error: 0.3931
# Epoch 24/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - loss: 0.1299 - root_mean_squared_error: 0.3550 - val_loss: 0.1670 - val_root_mean_squared_error: 0.4042
# Epoch 25/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.1326 - root_mean_squared_error: 0.3591 - val_loss: 0.1666 - val_root_mean_squared_error: 0.4038
# Epoch 26/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1367 - root_mean_squared_error: 0.3650 - val_loss: 0.1606 - val_root_mean_squared_error: 0.3965
# Epoch 27/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.1299 - root_mean_squared_error: 0.3556 - val_loss: 0.1569 - val_root_mean_squared_error: 0.3920
# Epoch 28/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1261 - root_mean_squared_error: 0.3504 - val_loss: 0.1539 - val_root_mean_squared_error: 0.3884
# Epoch 29/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.1276 - root_mean_squared_error: 0.3528 - val_loss: 0.1622 - val_root_mean_squared_error: 0.3990
# Epoch 30/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - loss: 0.1138 - root_mean_squared_error: 0.3327 - val_loss: 0.1580 - val_root_mean_squared_error: 0.3939
# Epoch 31/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.1321 - root_mean_squared_error: 0.3595 - val_loss: 0.1628 - val_root_mean_squared_error: 0.3999
# Epoch 32/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - loss: 0.1253 - root_mean_squared_error: 0.3499 - val_loss: 0.1693 - val_root_mean_squared_error: 0.4080
# Epoch 33/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.1355 - root_mean_squared_error: 0.3643 - val_loss: 0.1600 - val_root_mean_squared_error: 0.3965
# Epoch 34/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.1179 - root_mean_squared_error: 0.3392 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3825
# Epoch 35/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - loss: 0.1152 - root_mean_squared_error: 0.3354 - val_loss: 0.1443 - val_root_mean_squared_error: 0.3765
# Epoch 36/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.1224 - root_mean_squared_error: 0.3460 - val_loss: 0.1524 - val_root_mean_squared_error: 0.3871
# Epoch 37/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - loss: 0.1164 - root_mean_squared_error: 0.3373 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3793
# Epoch 38/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - loss: 0.1232 - root_mean_squared_error: 0.3472 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3793
# Epoch 39/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.1094 - root_mean_squared_error: 0.3262 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3897
# Epoch 40/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.1150 - root_mean_squared_error: 0.3353 - val_loss: 0.1447 - val_root_mean_squared_error: 0.3773
# Epoch 41/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - loss: 0.1217 - root_mean_squared_error: 0.3455 - val_loss: 0.1534 - val_root_mean_squared_error: 0.3887
# Epoch 42/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1144 - root_mean_squared_error: 0.3347 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3852
# Epoch 43/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1139 - root_mean_squared_error: 0.3340 - val_loss: 0.1406 - val_root_mean_squared_error: 0.3719
# Epoch 44/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1093 - root_mean_squared_error: 0.3267 - val_loss: 0.1448 - val_root_mean_squared_error: 0.3776
# Epoch 45/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1185 - root_mean_squared_error: 0.3409 - val_loss: 0.1465 - val_root_mean_squared_error: 0.3798
# Epoch 46/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1236 - root_mean_squared_error: 0.3482 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3830
# Epoch 47/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1242 - root_mean_squared_error: 0.3490 - val_loss: 0.1580 - val_root_mean_squared_error: 0.3947
# Epoch 48/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1283 - root_mean_squared_error: 0.3550 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3971
# Epoch 49/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1203 - root_mean_squared_error: 0.3436 - val_loss: 0.1556 - val_root_mean_squared_error: 0.3918
# Epoch 50/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1150 - root_mean_squared_error: 0.3358 - val_loss: 0.1502 - val_root_mean_squared_error: 0.3848
# Epoch 51/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1184 - root_mean_squared_error: 0.3408 - val_loss: 0.1610 - val_root_mean_squared_error: 0.3985
# Epoch 52/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.1173 - root_mean_squared_error: 0.3392 - val_loss: 0.1694 - val_root_mean_squared_error: 0.4088
# Epoch 53/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1215 - root_mean_squared_error: 0.3453 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3832
# Epoch 54/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1205 - root_mean_squared_error: 0.3439 - val_loss: 0.1508 - val_root_mean_squared_error: 0.3855
# Epoch 55/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1176 - root_mean_squared_error: 0.3397 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3779
# Epoch 56/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.1104 - root_mean_squared_error: 0.3289 - val_loss: 0.1440 - val_root_mean_squared_error: 0.3766
# Epoch 57/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1120 - root_mean_squared_error: 0.3314 - val_loss: 0.1500 - val_root_mean_squared_error: 0.3845
# Epoch 58/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1104 - root_mean_squared_error: 0.3289 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3870
# Epoch 59/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1143 - root_mean_squared_error: 0.3349 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3763
# Epoch 60/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.1078 - root_mean_squared_error: 0.3251 - val_loss: 0.1492 - val_root_mean_squared_error: 0.3834
# Epoch 61/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1090 - root_mean_squared_error: 0.3267 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3765
# Epoch 62/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1129 - root_mean_squared_error: 0.3328 - val_loss: 0.1419 - val_root_mean_squared_error: 0.3739
# Epoch 63/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1126 - root_mean_squared_error: 0.3323 - val_loss: 0.1426 - val_root_mean_squared_error: 0.3748
# Epoch 64/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1087 - root_mean_squared_error: 0.3263 - val_loss: 0.1424 - val_root_mean_squared_error: 0.3745
# Epoch 65/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.1054 - root_mean_squared_error: 0.3212 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3732
# Epoch 66/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1065 - root_mean_squared_error: 0.3230 - val_loss: 0.1441 - val_root_mean_squared_error: 0.3767
# Epoch 67/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1076 - root_mean_squared_error: 0.3246 - val_loss: 0.1422 - val_root_mean_squared_error: 0.3742
# Epoch 68/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1059 - root_mean_squared_error: 0.3221 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3856
# Epoch 69/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1055 - root_mean_squared_error: 0.3217 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3763
# Epoch 70/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.1120 - root_mean_squared_error: 0.3315 - val_loss: 0.1392 - val_root_mean_squared_error: 0.3704
# Epoch 71/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1185 - root_mean_squared_error: 0.3412 - val_loss: 0.1421 - val_root_mean_squared_error: 0.3744
# Epoch 72/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1021 - root_mean_squared_error: 0.3160 - val_loss: 0.1378 - val_root_mean_squared_error: 0.3687
# Epoch 73/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.1028 - root_mean_squared_error: 0.3175 - val_loss: 0.1365 - val_root_mean_squared_error: 0.3667
# Epoch 74/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.1018 - root_mean_squared_error: 0.3159 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3661
# Epoch 75/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1049 - root_mean_squared_error: 0.3208 - val_loss: 0.1477 - val_root_mean_squared_error: 0.3818
# Epoch 76/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.1051 - root_mean_squared_error: 0.3210 - val_loss: 0.1415 - val_root_mean_squared_error: 0.3735
# Epoch 77/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1107 - root_mean_squared_error: 0.3297 - val_loss: 0.1434 - val_root_mean_squared_error: 0.3760
# Epoch 78/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.1026 - root_mean_squared_error: 0.3172 - val_loss: 0.1413 - val_root_mean_squared_error: 0.3733
# Epoch 79/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1126 - root_mean_squared_error: 0.3325 - val_loss: 0.1495 - val_root_mean_squared_error: 0.3842
# Epoch 80/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1048 - root_mean_squared_error: 0.3208 - val_loss: 0.1380 - val_root_mean_squared_error: 0.3689
# Epoch 81/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0943 - root_mean_squared_error: 0.3038 - val_loss: 0.1335 - val_root_mean_squared_error: 0.3628
# Epoch 82/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.1011 - root_mean_squared_error: 0.3150 - val_loss: 0.1405 - val_root_mean_squared_error: 0.3723
# Epoch 83/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.1043 - root_mean_squared_error: 0.3201 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3792
# Epoch 84/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.1016 - root_mean_squared_error: 0.3158 - val_loss: 0.1391 - val_root_mean_squared_error: 0.3706
# Epoch 85/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1017 - root_mean_squared_error: 0.3160 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3758
# Epoch 86/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1058 - root_mean_squared_error: 0.3224 - val_loss: 0.1398 - val_root_mean_squared_error: 0.3714
# Epoch 87/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.1044 - root_mean_squared_error: 0.3201 - val_loss: 0.1328 - val_root_mean_squared_error: 0.3618
# Epoch 88/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.1064 - root_mean_squared_error: 0.3233 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3770
# Epoch 89/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1087 - root_mean_squared_error: 0.3268 - val_loss: 0.1481 - val_root_mean_squared_error: 0.3827
# Epoch 90/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.1091 - root_mean_squared_error: 0.3276 - val_loss: 0.1531 - val_root_mean_squared_error: 0.3891
# Epoch 91/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.1117 - root_mean_squared_error: 0.3316 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3850
# Epoch 92/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1067 - root_mean_squared_error: 0.3239 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3753
# Epoch 93/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.1195 - root_mean_squared_error: 0.3431 - val_loss: 0.1480 - val_root_mean_squared_error: 0.3827
# Epoch 94/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.1134 - root_mean_squared_error: 0.3343 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3922
# Epoch 95/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.1161 - root_mean_squared_error: 0.3381 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3950
# Epoch 96/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.1132 - root_mean_squared_error: 0.3339 - val_loss: 0.1472 - val_root_mean_squared_error: 0.3814
# Epoch 97/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - loss: 0.1058 - root_mean_squared_error: 0.3227 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3807
# Epoch 98/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.1057 - root_mean_squared_error: 0.3225 - val_loss: 0.1403 - val_root_mean_squared_error: 0.3722
# Epoch 99/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 0.1078 - root_mean_squared_error: 0.3255 - val_loss: 0.1510 - val_root_mean_squared_error: 0.3865
# Epoch 100/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.1014 - root_mean_squared_error: 0.3157 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3760
# Epoch 101/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - loss: 0.1042 - root_mean_squared_error: 0.3203 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3859
# Epoch 102/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.1038 - root_mean_squared_error: 0.3195 - val_loss: 0.1345 - val_root_mean_squared_error: 0.3644
# Epoch 103/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - loss: 0.1065 - root_mean_squared_error: 0.3238 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3809
# Epoch 104/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1087 - root_mean_squared_error: 0.3272 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3813
# Epoch 105/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - loss: 0.1096 - root_mean_squared_error: 0.3285 - val_loss: 0.1468 - val_root_mean_squared_error: 0.3811
# Epoch 106/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - loss: 0.1073 - root_mean_squared_error: 0.3252 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3856
# Epoch 107/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - loss: 0.1098 - root_mean_squared_error: 0.3287 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3795
# Epoch 108/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - loss: 0.1043 - root_mean_squared_error: 0.3204 - val_loss: 0.1518 - val_root_mean_squared_error: 0.3875
# Epoch 109/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 319ms/step - loss: 0.1142 - root_mean_squared_error: 0.3355 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3808
# Epoch 110/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - loss: 0.1046 - root_mean_squared_error: 0.3207 - val_loss: 0.1331 - val_root_mean_squared_error: 0.3625
# Epoch 111/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - loss: 0.1014 - root_mean_squared_error: 0.3156 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3792
# Epoch 112/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - loss: 0.1096 - root_mean_squared_error: 0.3284 - val_loss: 0.1662 - val_root_mean_squared_error: 0.4056
# Epoch 113/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.1188 - root_mean_squared_error: 0.3421 - val_loss: 0.1399 - val_root_mean_squared_error: 0.3718
# Epoch 114/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - loss: 0.1090 - root_mean_squared_error: 0.3276 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3711
# Epoch 115/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - loss: 0.1039 - root_mean_squared_error: 0.3197 - val_loss: 0.1444 - val_root_mean_squared_error: 0.3778
# Epoch 116/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 282ms/step - loss: 0.1060 - root_mean_squared_error: 0.3228 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3768
# Epoch 117/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.1052 - root_mean_squared_error: 0.3216 - val_loss: 0.1375 - val_root_mean_squared_error: 0.3685
# Epoch 118/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - loss: 0.1006 - root_mean_squared_error: 0.3144 - val_loss: 0.1395 - val_root_mean_squared_error: 0.3711
# Epoch 119/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.0986 - root_mean_squared_error: 0.3112 - val_loss: 0.1418 - val_root_mean_squared_error: 0.3741
# Epoch 120/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0984 - root_mean_squared_error: 0.3107 - val_loss: 0.1377 - val_root_mean_squared_error: 0.3687
# Epoch 121/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1051 - root_mean_squared_error: 0.3214 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3887
# Epoch 122/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - loss: 0.1048 - root_mean_squared_error: 0.3210 - val_loss: 0.1451 - val_root_mean_squared_error: 0.3788
# Epoch 123/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.1108 - root_mean_squared_error: 0.3302 - val_loss: 0.1383 - val_root_mean_squared_error: 0.3697
# Epoch 124/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1025 - root_mean_squared_error: 0.3175 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3738
# Epoch 125/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - loss: 0.1058 - root_mean_squared_error: 0.3227 - val_loss: 0.1350 - val_root_mean_squared_error: 0.3652
# Epoch 126/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0947 - root_mean_squared_error: 0.3048 - val_loss: 0.1335 - val_root_mean_squared_error: 0.3630
# Epoch 127/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0991 - root_mean_squared_error: 0.3121 - val_loss: 0.1496 - val_root_mean_squared_error: 0.3846
# Epoch 128/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0951 - root_mean_squared_error: 0.3054 - val_loss: 0.1349 - val_root_mean_squared_error: 0.3652
# Epoch 129/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - loss: 0.0998 - root_mean_squared_error: 0.3134 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3766
# Epoch 130/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 0.0973 - root_mean_squared_error: 0.3090 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3649
# Epoch 131/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - loss: 0.1058 - root_mean_squared_error: 0.3226 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3647
# Epoch 132/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0932 - root_mean_squared_error: 0.3022 - val_loss: 0.1446 - val_root_mean_squared_error: 0.3780
# Epoch 133/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.1031 - root_mean_squared_error: 0.3184 - val_loss: 0.1410 - val_root_mean_squared_error: 0.3732
# Epoch 134/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - loss: 0.1064 - root_mean_squared_error: 0.3234 - val_loss: 0.1356 - val_root_mean_squared_error: 0.3659
# Epoch 135/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0970 - root_mean_squared_error: 0.3085 - val_loss: 0.1411 - val_root_mean_squared_error: 0.3734
# Epoch 136/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 272ms/step - loss: 0.1064 - root_mean_squared_error: 0.3235 - val_loss: 0.1322 - val_root_mean_squared_error: 0.3611
# Epoch 137/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - loss: 0.1039 - root_mean_squared_error: 0.3193 - val_loss: 0.1312 - val_root_mean_squared_error: 0.3598
# Epoch 138/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - loss: 0.1047 - root_mean_squared_error: 0.3205 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3709
# Epoch 139/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.1008 - root_mean_squared_error: 0.3144 - val_loss: 0.1365 - val_root_mean_squared_error: 0.3672
# Epoch 140/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1112 - root_mean_squared_error: 0.3309 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3820
# Epoch 141/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1062 - root_mean_squared_error: 0.3233 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3758
# Epoch 142/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - loss: 0.1075 - root_mean_squared_error: 0.3253 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3712
# Epoch 143/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0929 - root_mean_squared_error: 0.3019 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3767
# Epoch 144/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1035 - root_mean_squared_error: 0.3191 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3650
# Epoch 145/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1015 - root_mean_squared_error: 0.3161 - val_loss: 0.1318 - val_root_mean_squared_error: 0.3608
# Epoch 146/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.0908 - root_mean_squared_error: 0.2985 - val_loss: 0.1323 - val_root_mean_squared_error: 0.3615
# Epoch 147/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.0902 - root_mean_squared_error: 0.2972 - val_loss: 0.1406 - val_root_mean_squared_error: 0.3728
# Epoch 148/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.1100 - root_mean_squared_error: 0.3288 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3896
# Epoch 149/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1140 - root_mean_squared_error: 0.3352 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3895
# Epoch 150/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - loss: 0.1152 - root_mean_squared_error: 0.3370 - val_loss: 0.1453 - val_root_mean_squared_error: 0.3791
# Epoch 151/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1059 - root_mean_squared_error: 0.3228 - val_loss: 0.1472 - val_root_mean_squared_error: 0.3817
# Epoch 152/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.0956 - root_mean_squared_error: 0.3065 - val_loss: 0.1449 - val_root_mean_squared_error: 0.3786
# Epoch 153/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1054 - root_mean_squared_error: 0.3220 - val_loss: 0.1496 - val_root_mean_squared_error: 0.3846
# Epoch 154/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.1139 - root_mean_squared_error: 0.3351 - val_loss: 0.1463 - val_root_mean_squared_error: 0.3805
# Epoch 155/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - loss: 0.1081 - root_mean_squared_error: 0.3263 - val_loss: 0.1457 - val_root_mean_squared_error: 0.3797
# Epoch 156/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.0995 - root_mean_squared_error: 0.3128 - val_loss: 0.1324 - val_root_mean_squared_error: 0.3617
# Epoch 157/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.0992 - root_mean_squared_error: 0.3122 - val_loss: 0.1475 - val_root_mean_squared_error: 0.3820
# Epoch 158/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1012 - root_mean_squared_error: 0.3156 - val_loss: 0.1413 - val_root_mean_squared_error: 0.3738
# Epoch 159/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.1015 - root_mean_squared_error: 0.3161 - val_loss: 0.1287 - val_root_mean_squared_error: 0.3565
# Epoch 160/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - loss: 0.0943 - root_mean_squared_error: 0.3043 - val_loss: 0.1396 - val_root_mean_squared_error: 0.3716
# Epoch 161/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - loss: 0.1045 - root_mean_squared_error: 0.3206 - val_loss: 0.1600 - val_root_mean_squared_error: 0.3981
# Epoch 162/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.1108 - root_mean_squared_error: 0.3305 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3925
# Epoch 163/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1052 - root_mean_squared_error: 0.3218 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3807
# Epoch 164/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1077 - root_mean_squared_error: 0.3259 - val_loss: 0.1540 - val_root_mean_squared_error: 0.3906
# Epoch 165/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1080 - root_mean_squared_error: 0.3264 - val_loss: 0.1410 - val_root_mean_squared_error: 0.3736
# Epoch 166/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.1098 - root_mean_squared_error: 0.3290 - val_loss: 0.1452 - val_root_mean_squared_error: 0.3791
# Epoch 167/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - loss: 0.1017 - root_mean_squared_error: 0.3166 - val_loss: 0.1428 - val_root_mean_squared_error: 0.3759
# Epoch 168/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1055 - root_mean_squared_error: 0.3225 - val_loss: 0.1391 - val_root_mean_squared_error: 0.3709
# Epoch 169/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1116 - root_mean_squared_error: 0.3319 - val_loss: 0.1487 - val_root_mean_squared_error: 0.3838
# Epoch 170/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.1038 - root_mean_squared_error: 0.3200 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3678
# Epoch 171/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 277ms/step - loss: 0.1008 - root_mean_squared_error: 0.3152 - val_loss: 0.1420 - val_root_mean_squared_error: 0.3750
# Epoch 172/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 284ms/step - loss: 0.1111 - root_mean_squared_error: 0.3312 - val_loss: 0.1471 - val_root_mean_squared_error: 0.3817
# Epoch 173/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1079 - root_mean_squared_error: 0.3262 - val_loss: 0.1432 - val_root_mean_squared_error: 0.3765
# Epoch 174/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - loss: 0.1108 - root_mean_squared_error: 0.3304 - val_loss: 0.1386 - val_root_mean_squared_error: 0.3703
# Epoch 175/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 280ms/step - loss: 0.1055 - root_mean_squared_error: 0.3224 - val_loss: 0.1505 - val_root_mean_squared_error: 0.3860
# Epoch 176/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.1079 - root_mean_squared_error: 0.3260 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3807
# Epoch 177/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.1037 - root_mean_squared_error: 0.3197 - val_loss: 0.1441 - val_root_mean_squared_error: 0.3777
# Epoch 178/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.0969 - root_mean_squared_error: 0.3087 - val_loss: 0.1462 - val_root_mean_squared_error: 0.3805
# Epoch 179/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.1079 - root_mean_squared_error: 0.3261 - val_loss: 0.1474 - val_root_mean_squared_error: 0.3820
# Epoch 180/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.1106 - root_mean_squared_error: 0.3302 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3796
# Epoch 181/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - loss: 0.1030 - root_mean_squared_error: 0.3186 - val_loss: 0.1397 - val_root_mean_squared_error: 0.3718
# Epoch 182/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0957 - root_mean_squared_error: 0.3068 - val_loss: 0.1427 - val_root_mean_squared_error: 0.3757
# Epoch 183/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1003 - root_mean_squared_error: 0.3140 - val_loss: 0.1386 - val_root_mean_squared_error: 0.3703
# Epoch 184/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.1056 - root_mean_squared_error: 0.3225 - val_loss: 0.1520 - val_root_mean_squared_error: 0.3879
# Epoch 185/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - loss: 0.1109 - root_mean_squared_error: 0.3308 - val_loss: 0.1461 - val_root_mean_squared_error: 0.3804
# Epoch 186/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - loss: 0.0998 - root_mean_squared_error: 0.3135 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3772
# Epoch 187/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1057 - root_mean_squared_error: 0.3228 - val_loss: 0.1514 - val_root_mean_squared_error: 0.3872
# Epoch 188/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 0.0988 - root_mean_squared_error: 0.3117 - val_loss: 0.1442 - val_root_mean_squared_error: 0.3779
# Epoch 189/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - loss: 0.1051 - root_mean_squared_error: 0.3219 - val_loss: 0.1372 - val_root_mean_squared_error: 0.3686
# Epoch 190/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - loss: 0.1048 - root_mean_squared_error: 0.3215 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3773
# Epoch 191/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - loss: 0.1085 - root_mean_squared_error: 0.3270 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3860
# Epoch 192/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 284ms/step - loss: 0.1006 - root_mean_squared_error: 0.3149 - val_loss: 0.1449 - val_root_mean_squared_error: 0.3789
# Epoch 193/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1137 - root_mean_squared_error: 0.3346 - val_loss: 0.1493 - val_root_mean_squared_error: 0.3846
# Epoch 194/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - loss: 0.0983 - root_mean_squared_error: 0.3114 - val_loss: 0.1433 - val_root_mean_squared_error: 0.3767
# Epoch 195/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - loss: 0.1101 - root_mean_squared_error: 0.3296 - val_loss: 0.1332 - val_root_mean_squared_error: 0.3631
# Epoch 196/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.1170 - root_mean_squared_error: 0.3398 - val_loss: 0.1355 - val_root_mean_squared_error: 0.3661
# Epoch 197/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 284ms/step - loss: 0.1048 - root_mean_squared_error: 0.3214 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3898
# Epoch 198/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1082 - root_mean_squared_error: 0.3268 - val_loss: 0.1575 - val_root_mean_squared_error: 0.3951
# Epoch 199/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 298ms/step - loss: 0.1054 - root_mean_squared_error: 0.3224 - val_loss: 0.1451 - val_root_mean_squared_error: 0.3792
# Epoch 200/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - loss: 0.1102 - root_mean_squared_error: 0.3300 - val_loss: 0.1446 - val_root_mean_squared_error: 0.3785
# Epoch 201/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1013 - root_mean_squared_error: 0.3159 - val_loss: 0.1374 - val_root_mean_squared_error: 0.3688
# Epoch 202/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.1070 - root_mean_squared_error: 0.3249 - val_loss: 0.1445 - val_root_mean_squared_error: 0.3783
# Epoch 203/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1087 - root_mean_squared_error: 0.3276 - val_loss: 0.1474 - val_root_mean_squared_error: 0.3822
# Epoch 204/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1047 - root_mean_squared_error: 0.3214 - val_loss: 0.1384 - val_root_mean_squared_error: 0.3703
# Epoch 205/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.0985 - root_mean_squared_error: 0.3116 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3898
# Epoch 206/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.1028 - root_mean_squared_error: 0.3184 - val_loss: 0.1472 - val_root_mean_squared_error: 0.3819
# Epoch 207/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0942 - root_mean_squared_error: 0.3043 - val_loss: 0.1422 - val_root_mean_squared_error: 0.3752
# Epoch 208/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - loss: 0.1002 - root_mean_squared_error: 0.3140 - val_loss: 0.1468 - val_root_mean_squared_error: 0.3813
# Epoch 209/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.1030 - root_mean_squared_error: 0.3180 - val_loss: 0.1521 - val_root_mean_squared_error: 0.3881
# Epoch 210/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.1048 - root_mean_squared_error: 0.3206 - val_loss: 0.1666 - val_root_mean_squared_error: 0.4065
# Epoch 211/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.1159 - root_mean_squared_error: 0.3384 - val_loss: 0.1427 - val_root_mean_squared_error: 0.3760
# Epoch 212/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.1072 - root_mean_squared_error: 0.3252 - val_loss: 0.1486 - val_root_mean_squared_error: 0.3837
# Epoch 213/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.1092 - root_mean_squared_error: 0.3283 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3742
# Epoch 214/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1006 - root_mean_squared_error: 0.3146 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3706
# Epoch 215/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.1076 - root_mean_squared_error: 0.3258 - val_loss: 0.1415 - val_root_mean_squared_error: 0.3743
# Epoch 216/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - loss: 0.0941 - root_mean_squared_error: 0.3037 - val_loss: 0.1369 - val_root_mean_squared_error: 0.3681
# Epoch 217/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1028 - root_mean_squared_error: 0.3184 - val_loss: 0.1347 - val_root_mean_squared_error: 0.3652
# Epoch 218/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1009 - root_mean_squared_error: 0.3153 - val_loss: 0.1352 - val_root_mean_squared_error: 0.3658
# Epoch 219/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.0940 - root_mean_squared_error: 0.3043 - val_loss: 0.1358 - val_root_mean_squared_error: 0.3666
# Epoch 220/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.0899 - root_mean_squared_error: 0.2972 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3651
# Epoch 221/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0993 - root_mean_squared_error: 0.3126 - val_loss: 0.1442 - val_root_mean_squared_error: 0.3779
# Epoch 222/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1113 - root_mean_squared_error: 0.3314 - val_loss: 0.1438 - val_root_mean_squared_error: 0.3774
# Epoch 223/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.1083 - root_mean_squared_error: 0.3270 - val_loss: 0.1383 - val_root_mean_squared_error: 0.3701
# Epoch 224/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.1027 - root_mean_squared_error: 0.3182 - val_loss: 0.1383 - val_root_mean_squared_error: 0.3702
# Epoch 225/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1117 - root_mean_squared_error: 0.3318 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3668
# Epoch 226/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.1018 - root_mean_squared_error: 0.3169 - val_loss: 0.1372 - val_root_mean_squared_error: 0.3687
# Epoch 227/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0989 - root_mean_squared_error: 0.3123 - val_loss: 0.1419 - val_root_mean_squared_error: 0.3749
# Epoch 228/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1000 - root_mean_squared_error: 0.3140 - val_loss: 0.1407 - val_root_mean_squared_error: 0.3734
# Epoch 229/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1059 - root_mean_squared_error: 0.3234 - val_loss: 0.1388 - val_root_mean_squared_error: 0.3708
# Epoch 230/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.1101 - root_mean_squared_error: 0.3293 - val_loss: 0.1428 - val_root_mean_squared_error: 0.3762
# Epoch 231/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1059 - root_mean_squared_error: 0.3233 - val_loss: 0.1424 - val_root_mean_squared_error: 0.3758
# Epoch 232/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1053 - root_mean_squared_error: 0.3223 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3814
# Epoch 233/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.1076 - root_mean_squared_error: 0.3261 - val_loss: 0.1405 - val_root_mean_squared_error: 0.3732
# Epoch 234/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1127 - root_mean_squared_error: 0.3338 - val_loss: 0.1649 - val_root_mean_squared_error: 0.4047
# Epoch 235/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.1312 - root_mean_squared_error: 0.3605 - val_loss: 0.1479 - val_root_mean_squared_error: 0.3830
# Epoch 236/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.1138 - root_mean_squared_error: 0.3354 - val_loss: 0.1373 - val_root_mean_squared_error: 0.3689
# Epoch 237/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.1078 - root_mean_squared_error: 0.3261 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3777
# Epoch 238/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.1095 - root_mean_squared_error: 0.3288 - val_loss: 0.1537 - val_root_mean_squared_error: 0.3904
# Epoch 239/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1144 - root_mean_squared_error: 0.3362 - val_loss: 0.1423 - val_root_mean_squared_error: 0.3756
# Epoch 240/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.1084 - root_mean_squared_error: 0.3270 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3725
# Epoch 241/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.0967 - root_mean_squared_error: 0.3086 - val_loss: 0.1327 - val_root_mean_squared_error: 0.3623
# Epoch 242/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.1083 - root_mean_squared_error: 0.3269 - val_loss: 0.1497 - val_root_mean_squared_error: 0.3851
# Epoch 243/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.1136 - root_mean_squared_error: 0.3346 - val_loss: 0.1406 - val_root_mean_squared_error: 0.3730
# Epoch 244/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1067 - root_mean_squared_error: 0.3243 - val_loss: 0.1361 - val_root_mean_squared_error: 0.3669
# Epoch 245/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 236ms/step - loss: 0.1097 - root_mean_squared_error: 0.3287 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3712
# Epoch 246/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1043 - root_mean_squared_error: 0.3204 - val_loss: 0.1379 - val_root_mean_squared_error: 0.3694
# Epoch 247/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.1013 - root_mean_squared_error: 0.3159 - val_loss: 0.1368 - val_root_mean_squared_error: 0.3679
# Epoch 248/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1042 - root_mean_squared_error: 0.3202 - val_loss: 0.1388 - val_root_mean_squared_error: 0.3706
# Epoch 249/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.1045 - root_mean_squared_error: 0.3208 - val_loss: 0.1386 - val_root_mean_squared_error: 0.3703
# Epoch 250/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - loss: 0.1151 - root_mean_squared_error: 0.3370 - val_loss: 0.1530 - val_root_mean_squared_error: 0.3893
# Epoch 251/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.1164 - root_mean_squared_error: 0.3390 - val_loss: 0.1550 - val_root_mean_squared_error: 0.3919
# Epoch 252/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1148 - root_mean_squared_error: 0.3367 - val_loss: 0.1420 - val_root_mean_squared_error: 0.3750
# Epoch 253/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 0.1197 - root_mean_squared_error: 0.3437 - val_loss: 0.1463 - val_root_mean_squared_error: 0.3808
# Epoch 254/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.1119 - root_mean_squared_error: 0.3323 - val_loss: 0.1436 - val_root_mean_squared_error: 0.3772
# Epoch 255/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.1036 - root_mean_squared_error: 0.3196 - val_loss: 0.1510 - val_root_mean_squared_error: 0.3868
# Epoch 256/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.1088 - root_mean_squared_error: 0.3278 - val_loss: 0.1518 - val_root_mean_squared_error: 0.3880
# Epoch 257/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 241ms/step - loss: 0.1091 - root_mean_squared_error: 0.3284 - val_loss: 0.1460 - val_root_mean_squared_error: 0.3805
# Epoch 258/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1068 - root_mean_squared_error: 0.3247 - val_loss: 0.1458 - val_root_mean_squared_error: 0.3801
# Epoch 259/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1137 - root_mean_squared_error: 0.3352 - val_loss: 0.1465 - val_root_mean_squared_error: 0.3811
# Epoch 260/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - loss: 0.1134 - root_mean_squared_error: 0.3347 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3790
# Epoch 261/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1037 - root_mean_squared_error: 0.3197 - val_loss: 0.1422 - val_root_mean_squared_error: 0.3753
# Epoch 262/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0994 - root_mean_squared_error: 0.3129 - val_loss: 0.1483 - val_root_mean_squared_error: 0.3834
# Epoch 263/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.1076 - root_mean_squared_error: 0.3257 - val_loss: 0.1411 - val_root_mean_squared_error: 0.3739
# Epoch 264/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - loss: 0.1034 - root_mean_squared_error: 0.3193 - val_loss: 0.1420 - val_root_mean_squared_error: 0.3750
# Epoch 265/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1059 - root_mean_squared_error: 0.3231 - val_loss: 0.1420 - val_root_mean_squared_error: 0.3751
# Epoch 266/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.1038 - root_mean_squared_error: 0.3201 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3799
# Epoch 267/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1031 - root_mean_squared_error: 0.3191 - val_loss: 0.1365 - val_root_mean_squared_error: 0.3677
# Epoch 268/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - loss: 0.1011 - root_mean_squared_error: 0.3158 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3708
# Epoch 269/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - loss: 0.1012 - root_mean_squared_error: 0.3160 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3707
# Epoch 270/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.1057 - root_mean_squared_error: 0.3232 - val_loss: 0.1565 - val_root_mean_squared_error: 0.3941
# Epoch 271/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.1249 - root_mean_squared_error: 0.3514 - val_loss: 0.1534 - val_root_mean_squared_error: 0.3901
# Epoch 272/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.1231 - root_mean_squared_error: 0.3489 - val_loss: 0.1369 - val_root_mean_squared_error: 0.3683
# Epoch 273/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1077 - root_mean_squared_error: 0.3261 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3758
# Epoch 274/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.1066 - root_mean_squared_error: 0.3243 - val_loss: 0.1452 - val_root_mean_squared_error: 0.3794
# Epoch 275/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1160 - root_mean_squared_error: 0.3387 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3866
# Epoch 276/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.1121 - root_mean_squared_error: 0.3330 - val_loss: 0.1460 - val_root_mean_squared_error: 0.3805
# Epoch 277/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.1068 - root_mean_squared_error: 0.3248 - val_loss: 0.1400 - val_root_mean_squared_error: 0.3725
# Epoch 278/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1084 - root_mean_squared_error: 0.3272 - val_loss: 0.1390 - val_root_mean_squared_error: 0.3712
# Epoch 279/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0999 - root_mean_squared_error: 0.3141 - val_loss: 0.1395 - val_root_mean_squared_error: 0.3718
# Epoch 280/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.1010 - root_mean_squared_error: 0.3155 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3662
# Epoch 281/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.1025 - root_mean_squared_error: 0.3179 - val_loss: 0.1430 - val_root_mean_squared_error: 0.3765
# Epoch 282/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - loss: 0.1015 - root_mean_squared_error: 0.3166 - val_loss: 0.1326 - val_root_mean_squared_error: 0.3624
# Epoch 283/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0961 - root_mean_squared_error: 0.3074 - val_loss: 0.1468 - val_root_mean_squared_error: 0.3815
# Epoch 284/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.0969 - root_mean_squared_error: 0.3088 - val_loss: 0.1461 - val_root_mean_squared_error: 0.3805
# Epoch 285/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.1020 - root_mean_squared_error: 0.3171 - val_loss: 0.1408 - val_root_mean_squared_error: 0.3735
# Epoch 286/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - loss: 0.0961 - root_mean_squared_error: 0.3077 - val_loss: 0.1383 - val_root_mean_squared_error: 0.3701
# Epoch 287/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1065 - root_mean_squared_error: 0.3243 - val_loss: 0.1412 - val_root_mean_squared_error: 0.3741
# Epoch 288/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.1073 - root_mean_squared_error: 0.3254 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3861
# Epoch 289/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.1102 - root_mean_squared_error: 0.3301 - val_loss: 0.1380 - val_root_mean_squared_error: 0.3698
# Epoch 290/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - loss: 0.1014 - root_mean_squared_error: 0.3164 - val_loss: 0.1343 - val_root_mean_squared_error: 0.3647
# Epoch 291/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - loss: 0.0990 - root_mean_squared_error: 0.3126 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3638
# Epoch 292/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1056 - root_mean_squared_error: 0.3229 - val_loss: 0.1374 - val_root_mean_squared_error: 0.3691
# Epoch 293/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.1104 - root_mean_squared_error: 0.3303 - val_loss: 0.1389 - val_root_mean_squared_error: 0.3710
# Epoch 294/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - loss: 0.1037 - root_mean_squared_error: 0.3199 - val_loss: 0.1339 - val_root_mean_squared_error: 0.3642
# Epoch 295/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.0963 - root_mean_squared_error: 0.3082 - val_loss: 0.1364 - val_root_mean_squared_error: 0.3676
# Epoch 296/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.0920 - root_mean_squared_error: 0.3012 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3728
# Epoch 297/1000
# ...
# Epoch 903/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1226 - root_mean_squared_error: 0.3492 - val_loss: 0.1565 - val_root_mean_squared_error: 0.3948
# Epoch 904/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1228 - root_mean_squared_error: 0.3495 - val_loss: 0.1558 - val_root_mean_squared_error: 0.3939
# Epoch 905/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - loss: 0.1257 - root_mean_squared_error: 0.3535 - val_loss: 0.1584 - val_root_mean_squared_error: 0.3972
# Epoch 906/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.1169 - root_mean_squared_error: 0.3404 - val_loss: 0.1559 - val_root_mean_squared_error: 0.3940
# Epoch 907/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1306 - root_mean_squared_error: 0.3604 - val_loss: 0.1578 - val_root_mean_squared_error: 0.3965
# Epoch 908/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1263 - root_mean_squared_error: 0.3545 - val_loss: 0.1578 - val_root_mean_squared_error: 0.3965
# Epoch 909/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1254 - root_mean_squared_error: 0.3532 - val_loss: 0.1592 - val_root_mean_squared_error: 0.3983
# Epoch 910/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.1270 - root_mean_squared_error: 0.3555 - val_loss: 0.1611 - val_root_mean_squared_error: 0.4006
# Epoch 911/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - loss: 0.1268 - root_mean_squared_error: 0.3551 - val_loss: 0.1589 - val_root_mean_squared_error: 0.3979
# Epoch 912/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1223 - root_mean_squared_error: 0.3489 - val_loss: 0.1588 - val_root_mean_squared_error: 0.3978
# Epoch 913/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.1212 - root_mean_squared_error: 0.3474 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3975
# Epoch 914/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.1293 - root_mean_squared_error: 0.3587 - val_loss: 0.1569 - val_root_mean_squared_error: 0.3954
# Epoch 915/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1229 - root_mean_squared_error: 0.3496 - val_loss: 0.1587 - val_root_mean_squared_error: 0.3976
# Epoch 916/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1251 - root_mean_squared_error: 0.3527 - val_loss: 0.1567 - val_root_mean_squared_error: 0.3951
# Epoch 917/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.1312 - root_mean_squared_error: 0.3613 - val_loss: 0.1632 - val_root_mean_squared_error: 0.4031
# Epoch 918/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1361 - root_mean_squared_error: 0.3678 - val_loss: 0.1576 - val_root_mean_squared_error: 0.3962
# Epoch 919/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1220 - root_mean_squared_error: 0.3481 - val_loss: 0.1582 - val_root_mean_squared_error: 0.3968
# Epoch 920/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1319 - root_mean_squared_error: 0.3620 - val_loss: 0.1563 - val_root_mean_squared_error: 0.3944
# Epoch 921/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1280 - root_mean_squared_error: 0.3568 - val_loss: 0.1583 - val_root_mean_squared_error: 0.3970
# Epoch 922/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1227 - root_mean_squared_error: 0.3492 - val_loss: 0.1608 - val_root_mean_squared_error: 0.4001
# Epoch 923/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1335 - root_mean_squared_error: 0.3643 - val_loss: 0.1615 - val_root_mean_squared_error: 0.4010
# Epoch 924/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1356 - root_mean_squared_error: 0.3671 - val_loss: 0.1620 - val_root_mean_squared_error: 0.4017
# Epoch 925/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.1290 - root_mean_squared_error: 0.3581 - val_loss: 0.1608 - val_root_mean_squared_error: 0.4002
# Epoch 926/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1283 - root_mean_squared_error: 0.3573 - val_loss: 0.1619 - val_root_mean_squared_error: 0.4016
# Epoch 927/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1307 - root_mean_squared_error: 0.3606 - val_loss: 0.1623 - val_root_mean_squared_error: 0.4021
# Epoch 928/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1268 - root_mean_squared_error: 0.3549 - val_loss: 0.1622 - val_root_mean_squared_error: 0.4020
# Epoch 929/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1291 - root_mean_squared_error: 0.3584 - val_loss: 0.1619 - val_root_mean_squared_error: 0.4016
# Epoch 930/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1242 - root_mean_squared_error: 0.3514 - val_loss: 0.1596 - val_root_mean_squared_error: 0.3987
# Epoch 931/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1265 - root_mean_squared_error: 0.3548 - val_loss: 0.1591 - val_root_mean_squared_error: 0.3981
# Epoch 932/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1277 - root_mean_squared_error: 0.3564 - val_loss: 0.1593 - val_root_mean_squared_error: 0.3984
# Epoch 933/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1227 - root_mean_squared_error: 0.3494 - val_loss: 0.1597 - val_root_mean_squared_error: 0.3989
# Epoch 934/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1275 - root_mean_squared_error: 0.3561 - val_loss: 0.1681 - val_root_mean_squared_error: 0.4092
# Epoch 935/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1311 - root_mean_squared_error: 0.3611 - val_loss: 0.1569 - val_root_mean_squared_error: 0.3953
# Epoch 936/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 0.1214 - root_mean_squared_error: 0.3472 - val_loss: 0.1575 - val_root_mean_squared_error: 0.3960
# Epoch 937/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - loss: 0.1303 - root_mean_squared_error: 0.3597 - val_loss: 0.1588 - val_root_mean_squared_error: 0.3976
# Epoch 938/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.1272 - root_mean_squared_error: 0.3557 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3974
# Epoch 939/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1232 - root_mean_squared_error: 0.3501 - val_loss: 0.1569 - val_root_mean_squared_error: 0.3953
# Epoch 940/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1265 - root_mean_squared_error: 0.3546 - val_loss: 0.1559 - val_root_mean_squared_error: 0.3940
# Epoch 941/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.1261 - root_mean_squared_error: 0.3541 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3974
# Epoch 942/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1214 - root_mean_squared_error: 0.3475 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3947
# Epoch 943/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.1238 - root_mean_squared_error: 0.3509 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3974
# Epoch 944/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.1218 - root_mean_squared_error: 0.3480 - val_loss: 0.1558 - val_root_mean_squared_error: 0.3939
# Epoch 945/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.1269 - root_mean_squared_error: 0.3553 - val_loss: 0.1587 - val_root_mean_squared_error: 0.3977
# Epoch 946/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.1281 - root_mean_squared_error: 0.3569 - val_loss: 0.1587 - val_root_mean_squared_error: 0.3976
# Epoch 947/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.1369 - root_mean_squared_error: 0.3687 - val_loss: 0.1578 - val_root_mean_squared_error: 0.3964
# Epoch 948/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.1304 - root_mean_squared_error: 0.3601 - val_loss: 0.1612 - val_root_mean_squared_error: 0.4008
# Epoch 949/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.1285 - root_mean_squared_error: 0.3577 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3975
# Epoch 950/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - loss: 0.1244 - root_mean_squared_error: 0.3518 - val_loss: 0.1573 - val_root_mean_squared_error: 0.3959
# Epoch 951/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.1247 - root_mean_squared_error: 0.3522 - val_loss: 0.1588 - val_root_mean_squared_error: 0.3978
# Epoch 952/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - loss: 0.1329 - root_mean_squared_error: 0.3636 - val_loss: 0.1548 - val_root_mean_squared_error: 0.3927
# Epoch 953/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1282 - root_mean_squared_error: 0.3571 - val_loss: 0.1576 - val_root_mean_squared_error: 0.3962
# Epoch 954/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1248 - root_mean_squared_error: 0.3525 - val_loss: 0.1544 - val_root_mean_squared_error: 0.3922
# Epoch 955/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - loss: 0.1272 - root_mean_squared_error: 0.3557 - val_loss: 0.1549 - val_root_mean_squared_error: 0.3928
# Epoch 956/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1211 - root_mean_squared_error: 0.3471 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3991
# Epoch 957/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1273 - root_mean_squared_error: 0.3560 - val_loss: 0.1567 - val_root_mean_squared_error: 0.3951
# Epoch 958/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1219 - root_mean_squared_error: 0.3480 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3947
# Epoch 959/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.1186 - root_mean_squared_error: 0.3434 - val_loss: 0.1546 - val_root_mean_squared_error: 0.3924
# Epoch 960/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1214 - root_mean_squared_error: 0.3476 - val_loss: 0.1561 - val_root_mean_squared_error: 0.3944
# Epoch 961/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1224 - root_mean_squared_error: 0.3490 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3936
# Epoch 962/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - loss: 0.1261 - root_mean_squared_error: 0.3542 - val_loss: 0.1557 - val_root_mean_squared_error: 0.3938
# Epoch 963/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 282ms/step - loss: 0.1265 - root_mean_squared_error: 0.3547 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3880
# Epoch 964/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.1259 - root_mean_squared_error: 0.3540 - val_loss: 0.1544 - val_root_mean_squared_error: 0.3922
# Epoch 965/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.1278 - root_mean_squared_error: 0.3567 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3922
# Epoch 966/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1225 - root_mean_squared_error: 0.3491 - val_loss: 0.1719 - val_root_mean_squared_error: 0.4139
# Epoch 967/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - loss: 0.1373 - root_mean_squared_error: 0.3697 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3882
# Epoch 968/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.1343 - root_mean_squared_error: 0.3654 - val_loss: 0.1515 - val_root_mean_squared_error: 0.3884
# Epoch 969/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 276ms/step - loss: 0.1245 - root_mean_squared_error: 0.3519 - val_loss: 0.1511 - val_root_mean_squared_error: 0.3879
# Epoch 970/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.1298 - root_mean_squared_error: 0.3594 - val_loss: 0.1485 - val_root_mean_squared_error: 0.3845
# Epoch 971/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1282 - root_mean_squared_error: 0.3571 - val_loss: 0.1522 - val_root_mean_squared_error: 0.3894
# Epoch 972/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.1243 - root_mean_squared_error: 0.3518 - val_loss: 0.1498 - val_root_mean_squared_error: 0.3863
# Epoch 973/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.1205 - root_mean_squared_error: 0.3463 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3870
# Epoch 974/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.1263 - root_mean_squared_error: 0.3545 - val_loss: 0.1520 - val_root_mean_squared_error: 0.3892
# Epoch 975/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 0.1209 - root_mean_squared_error: 0.3468 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3858
# Epoch 976/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - loss: 0.1220 - root_mean_squared_error: 0.3485 - val_loss: 0.1535 - val_root_mean_squared_error: 0.3911
# Epoch 977/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.1231 - root_mean_squared_error: 0.3499 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3908
# Epoch 978/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - loss: 0.1259 - root_mean_squared_error: 0.3541 - val_loss: 0.1515 - val_root_mean_squared_error: 0.3885
# Epoch 979/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1255 - root_mean_squared_error: 0.3535 - val_loss: 0.1523 - val_root_mean_squared_error: 0.3896
# Epoch 980/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - loss: 0.1309 - root_mean_squared_error: 0.3609 - val_loss: 0.1538 - val_root_mean_squared_error: 0.3915
# Epoch 981/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - loss: 0.1227 - root_mean_squared_error: 0.3495 - val_loss: 0.1552 - val_root_mean_squared_error: 0.3932
# Epoch 982/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - loss: 0.1259 - root_mean_squared_error: 0.3541 - val_loss: 0.1549 - val_root_mean_squared_error: 0.3929
# Epoch 983/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.1250 - root_mean_squared_error: 0.3527 - val_loss: 0.1532 - val_root_mean_squared_error: 0.3907
# Epoch 984/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 0.1240 - root_mean_squared_error: 0.3514 - val_loss: 0.1526 - val_root_mean_squared_error: 0.3900
# Epoch 985/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - loss: 0.1220 - root_mean_squared_error: 0.3485 - val_loss: 0.1542 - val_root_mean_squared_error: 0.3920
# Epoch 986/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1273 - root_mean_squared_error: 0.3558 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3921
# Epoch 987/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 284ms/step - loss: 0.1090 - root_mean_squared_error: 0.3289 - val_loss: 0.1581 - val_root_mean_squared_error: 0.3970
# Epoch 988/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - loss: 0.1250 - root_mean_squared_error: 0.3528 - val_loss: 0.1547 - val_root_mean_squared_error: 0.3927
# Epoch 989/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1170 - root_mean_squared_error: 0.3409 - val_loss: 0.1550 - val_root_mean_squared_error: 0.3930
# Epoch 990/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1257 - root_mean_squared_error: 0.3538 - val_loss: 0.1553 - val_root_mean_squared_error: 0.3934
# Epoch 991/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1258 - root_mean_squared_error: 0.3540 - val_loss: 0.1613 - val_root_mean_squared_error: 0.4010
# Epoch 992/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.1179 - root_mean_squared_error: 0.3425 - val_loss: 0.1607 - val_root_mean_squared_error: 0.4002
# Epoch 993/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - loss: 0.1237 - root_mean_squared_error: 0.3508 - val_loss: 0.1578 - val_root_mean_squared_error: 0.3966
# Epoch 994/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1253 - root_mean_squared_error: 0.3531 - val_loss: 0.1546 - val_root_mean_squared_error: 0.3924
# Epoch 995/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - loss: 0.1244 - root_mean_squared_error: 0.3517 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3883
# Epoch 996/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - loss: 0.1263 - root_mean_squared_error: 0.3545 - val_loss: 0.1497 - val_root_mean_squared_error: 0.3863
# Epoch 997/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - loss: 0.1261 - root_mean_squared_error: 0.3542 - val_loss: 0.1514 - val_root_mean_squared_error: 0.3884
# Epoch 998/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 256ms/step - loss: 0.1245 - root_mean_squared_error: 0.3520 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3902
# Epoch 999/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - loss: 0.1114 - root_mean_squared_error: 0.3326 - val_loss: 0.1518 - val_root_mean_squared_error: 0.3889
# Epoch 1000/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - loss: 0.1189 - root_mean_squared_error: 0.3438 - val_loss: 0.1540 - val_root_mean_squared_error: 0.3917

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\3\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
