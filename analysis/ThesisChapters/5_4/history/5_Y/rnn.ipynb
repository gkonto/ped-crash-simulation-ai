# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           20          200       240            770                740
# 1          100          400       180            580                900
# 2          100          200         0            500                680
# 3          100            0       150            770                740
# 4           60         -200        60            600                880
# ...        ...          ...       ...            ...                ...
# 1181        20          400        60            770                740
# 1182        20            0       300            500                680
# 1183        40         -200       330            580                900
# 1184        60          400        90            500                680
# 1185        60         -200       120            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    11         1160              1130
# 2                    20         1200               920
# 3                    16         1150               980
# 4                    30          760              1070
# ...                 ...          ...               ...
# 1181                 16         1150               980
# 1182                 20         1200               920
# 1183                 11         1160              1130
# 1184                 20         1200               920
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1     [228.0, 228.0, 228.0, 228.0, 228.0, 228.0, 228...
# 2     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# 3     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 4     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# ...                                                 ...
# 1181  [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 1182  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [343.682, 343.682, 343.682, 343.682, 343.682, ...
# 1185  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
#
#                                       Head_Y_Coordinate  \
# 0     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1     [575.319, 575.319, 575.319, 575.319, 575.319, ...
# 2     [111.955, 111.955, 111.955, 111.955, 111.955, ...
# 3     [157.677, 157.677, 157.677, 157.677, 157.677, ...
# 4     [-222.204, -222.204, -222.204, -222.204, -222....
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# 1183  [-270.403, -270.403, -270.403, -270.403, -270....
# 1184  [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 1185  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0           20          200       240            770                740
# 1          100          400       180            580                900
# 2          100          200         0            500                680
# 3          100            0       150            770                740
# 4           60         -200        60            600                880
# ...        ...          ...       ...            ...                ...
# 1181        20          400        60            770                740
# 1182        20            0       300            500                680
# 1183        40         -200       330            580                900
# 1184        60          400        90            500                680
# 1185        60         -200       120            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    11         1160              1130
# 2                    20         1200               920
# 3                    16         1150               980
# 4                    30          760              1070
# ...                 ...          ...               ...
# 1181                 16         1150               980
# 1182                 20         1200               920
# 1183                 11         1160              1130
# 1184                 20         1200               920
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [105.96, 105.96, 105.96, 105.96, 105.96, 105.9...
# 1     [228.0, 228.0, 228.0, 228.0, 228.0, 228.0, 228...
# 2     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# 3     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 4     [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# ...                                                 ...
# 1181  [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 1182  [97.96, 97.96, 97.96, 97.96, 97.96, 97.96, 97....
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [343.682, 343.682, 343.682, 343.682, 343.682, ...
# 1185  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
#
#                                       Head_Y_Coordinate  \
# 0     [309.478, 309.478, 309.478, 309.478, 309.478, ...
# 1     [575.319, 575.319, 575.319, 575.319, 575.319, ...
# 2     [111.955, 111.955, 111.955, 111.955, 111.955, ...
# 3     [157.677, 157.677, 157.677, 157.677, 157.677, ...
# 4     [-222.204, -222.204, -222.204, -222.204, -222....
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [-22.204, -22.204, -22.204, -22.204, -22.204, ...
# 1183  [-270.403, -270.403, -270.403, -270.403, -270....
# 1184  [443.637, 443.637, 443.637, 443.637, 443.637, ...
# 1185  [-90.522, -90.522, -90.522, -90.522, -90.522, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 16714.53row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.973492          -0.577856           1.000000
# 1            -0.973492          -0.577856           0.999984
# 2            -0.973492          -0.577856           0.999935
# 3            -0.973492          -0.577856           0.999918
# 4            -0.973492          -0.577856           0.999873
# ..                 ...                ...                ...
# 296           0.959777           0.431412          -0.168861
# 297           0.969857           0.427763          -0.167084
# 298           0.979923           0.424428          -0.165394
# 299           0.989971           0.421421          -0.163783
# 300           1.000000           0.418719          -0.162250
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array(
        [
            df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
            df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()
            ])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([
        #df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
        #df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()
                    ])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 75
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 1)
# (237, 100, 11) (237, 75, 1)
# (238, 100, 11) (238, 75, 1)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))  # First LSTM layer
model.add(LSTM(64, return_sequences=True))  # Second LSTM layer
model.add(LSTM(128))  # Third LSTM layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))  # Dense layer with L2 regularization
model.add(Dense(next_steps * 1, activation="tanh"))  # Output layer with tanh activation
model.add(Reshape((next_steps, 1)))  # Reshape to match the target output shape (10, 3)


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 100, 64)        │        11,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 75)             │         2,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 1)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,707 (584.79 KB)
#  Trainable params: 149,707 (584.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_val
# Out:
# array([[[ 0.82880196],
#         [ 0.81243256],
#         [ 0.79762373],
#         ...,
#         [ 0.88657632],
#         [ 0.87499931],
#         [ 0.86304599]],
#
#        [[ 0.75339805],
#         [ 0.73764432],
#         [ 0.72232916],
#         ...,
#         [-0.02534311],
#         [-0.03036927],
#         [-0.03524924]],
#
#        [[ 0.97546054],
#         [ 0.97815977],
#         [ 0.98077303],
#         ...,
#         [ 0.52956683],
#         [ 0.51615667],
#         [ 0.50272358]],
#
#        ...,
#
#        [[-0.22883029],
#         [-0.17868746],
#         [-0.13094756],
#         ...,
#         [ 0.89552147],
#         [ 0.88387461],
#         [ 0.8718109 ]],
#
#        [[ 0.99971899],
#         [ 0.99898687],
#         [ 0.99778147],
#         ...,
#         [ 0.26071829],
#         [ 0.25247274],
#         [ 0.24420501]],
#
#        [[ 0.41170326],
#         [ 0.42333453],
#         [ 0.43401775],
#         ...,
#         [ 0.41621531],
#         [ 0.41790075],
#         [ 0.41985832]]])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Y\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
          epochs=10000, 
          callbacks=[cp, 
                     es
                     ])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 208ms/step - loss: 0.4167 - root_mean_squared_error: 0.6069 - val_loss: 0.3904 - val_root_mean_squared_error: 0.5923
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.3720 - root_mean_squared_error: 0.5784 - val_loss: 0.3524 - val_root_mean_squared_error: 0.5666
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.3475 - root_mean_squared_error: 0.5636 - val_loss: 0.3373 - val_root_mean_squared_error: 0.5583
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.3302 - root_mean_squared_error: 0.5529 - val_loss: 0.3310 - val_root_mean_squared_error: 0.5564
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.3196 - root_mean_squared_error: 0.5468 - val_loss: 0.3069 - val_root_mean_squared_error: 0.5376
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.2905 - root_mean_squared_error: 0.5224 - val_loss: 0.2953 - val_root_mean_squared_error: 0.5288
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.2720 - root_mean_squared_error: 0.5066 - val_loss: 0.2847 - val_root_mean_squared_error: 0.5204
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2781 - root_mean_squared_error: 0.5143 - val_loss: 0.2973 - val_root_mean_squared_error: 0.5341
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2733 - root_mean_squared_error: 0.5113 - val_loss: 0.2675 - val_root_mean_squared_error: 0.5064
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.2610 - root_mean_squared_error: 0.5000 - val_loss: 0.2789 - val_root_mean_squared_error: 0.5183
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.2694 - root_mean_squared_error: 0.5092 - val_loss: 0.2539 - val_root_mean_squared_error: 0.4946
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.2740 - root_mean_squared_error: 0.5145 - val_loss: 0.2783 - val_root_mean_squared_error: 0.5195
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2671 - root_mean_squared_error: 0.5085 - val_loss: 0.2728 - val_root_mean_squared_error: 0.5150
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2748 - root_mean_squared_error: 0.5169 - val_loss: 0.2571 - val_root_mean_squared_error: 0.4999
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.2696 - root_mean_squared_error: 0.5121 - val_loss: 0.2804 - val_root_mean_squared_error: 0.5233
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.2858 - root_mean_squared_error: 0.5285 - val_loss: 0.2641 - val_root_mean_squared_error: 0.5077
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.2736 - root_mean_squared_error: 0.5169 - val_loss: 0.2712 - val_root_mean_squared_error: 0.5151
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2511 - root_mean_squared_error: 0.4951 - val_loss: 0.2600 - val_root_mean_squared_error: 0.5043
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.2456 - root_mean_squared_error: 0.4895 - val_loss: 0.2716 - val_root_mean_squared_error: 0.5161
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.2601 - root_mean_squared_error: 0.5047 - val_loss: 0.2384 - val_root_mean_squared_error: 0.4829
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.2399 - root_mean_squared_error: 0.4845 - val_loss: 0.2337 - val_root_mean_squared_error: 0.4781
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.2456 - root_mean_squared_error: 0.4903 - val_loss: 0.2428 - val_root_mean_squared_error: 0.4879
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2399 - root_mean_squared_error: 0.4847 - val_loss: 0.2237 - val_root_mean_squared_error: 0.4681
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.2475 - root_mean_squared_error: 0.4928 - val_loss: 0.2453 - val_root_mean_squared_error: 0.4908
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2326 - root_mean_squared_error: 0.4777 - val_loss: 0.2307 - val_root_mean_squared_error: 0.4759
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.2244 - root_mean_squared_error: 0.4691 - val_loss: 0.2396 - val_root_mean_squared_error: 0.4854
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.2376 - root_mean_squared_error: 0.4833 - val_loss: 0.2215 - val_root_mean_squared_error: 0.4665
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.2228 - root_mean_squared_error: 0.4678 - val_loss: 0.2436 - val_root_mean_squared_error: 0.4898
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.2241 - root_mean_squared_error: 0.4693 - val_loss: 0.2354 - val_root_mean_squared_error: 0.4813
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - loss: 0.2356 - root_mean_squared_error: 0.4813 - val_loss: 0.2343 - val_root_mean_squared_error: 0.4805
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.2506 - root_mean_squared_error: 0.4965 - val_loss: 0.2356 - val_root_mean_squared_error: 0.4818
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.2379 - root_mean_squared_error: 0.4842 - val_loss: 0.2339 - val_root_mean_squared_error: 0.4802
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2445 - root_mean_squared_error: 0.4911 - val_loss: 0.2386 - val_root_mean_squared_error: 0.4853
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2409 - root_mean_squared_error: 0.4876 - val_loss: 0.2367 - val_root_mean_squared_error: 0.4834
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2311 - root_mean_squared_error: 0.4774 - val_loss: 0.2521 - val_root_mean_squared_error: 0.4990
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.2329 - root_mean_squared_error: 0.4791 - val_loss: 0.2139 - val_root_mean_squared_error: 0.4592
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.2235 - root_mean_squared_error: 0.4694 - val_loss: 0.2223 - val_root_mean_squared_error: 0.4684
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.2222 - root_mean_squared_error: 0.4680 - val_loss: 0.2309 - val_root_mean_squared_error: 0.4773
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.2088 - root_mean_squared_error: 0.4530 - val_loss: 0.2245 - val_root_mean_squared_error: 0.4710
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2280 - root_mean_squared_error: 0.4745 - val_loss: 0.2182 - val_root_mean_squared_error: 0.4642
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.2017 - root_mean_squared_error: 0.4458 - val_loss: 0.2149 - val_root_mean_squared_error: 0.4605
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.1972 - root_mean_squared_error: 0.4407 - val_loss: 0.2109 - val_root_mean_squared_error: 0.4563
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.2171 - root_mean_squared_error: 0.4629 - val_loss: 0.2185 - val_root_mean_squared_error: 0.4646
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2412 - root_mean_squared_error: 0.4885 - val_loss: 0.2603 - val_root_mean_squared_error: 0.5079
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.2422 - root_mean_squared_error: 0.4895 - val_loss: 0.2419 - val_root_mean_squared_error: 0.4893
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.2772 - root_mean_squared_error: 0.5238 - val_loss: 0.2662 - val_root_mean_squared_error: 0.5139
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.2407 - root_mean_squared_error: 0.4883 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5070
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - loss: 0.2366 - root_mean_squared_error: 0.4835 - val_loss: 0.2470 - val_root_mean_squared_error: 0.4946
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.2300 - root_mean_squared_error: 0.4770 - val_loss: 0.2242 - val_root_mean_squared_error: 0.4709
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2158 - root_mean_squared_error: 0.4617 - val_loss: 0.2478 - val_root_mean_squared_error: 0.4953
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.2223 - root_mean_squared_error: 0.4688 - val_loss: 0.2396 - val_root_mean_squared_error: 0.4869
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2165 - root_mean_squared_error: 0.4623 - val_loss: 0.2393 - val_root_mean_squared_error: 0.4867
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.2086 - root_mean_squared_error: 0.4539 - val_loss: 0.2159 - val_root_mean_squared_error: 0.4620
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.1977 - root_mean_squared_error: 0.4418 - val_loss: 0.2102 - val_root_mean_squared_error: 0.4557
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1985 - root_mean_squared_error: 0.4427 - val_loss: 0.2337 - val_root_mean_squared_error: 0.4809
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.1946 - root_mean_squared_error: 0.4380 - val_loss: 0.2122 - val_root_mean_squared_error: 0.4581
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.2050 - root_mean_squared_error: 0.4500 - val_loss: 0.2262 - val_root_mean_squared_error: 0.4732
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.2131 - root_mean_squared_error: 0.4592 - val_loss: 0.2249 - val_root_mean_squared_error: 0.4719
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.2147 - root_mean_squared_error: 0.4609 - val_loss: 0.2249 - val_root_mean_squared_error: 0.4719
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.2256 - root_mean_squared_error: 0.4726 - val_loss: 0.2147 - val_root_mean_squared_error: 0.4611
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - loss: 0.2044 - root_mean_squared_error: 0.4496 - val_loss: 0.2098 - val_root_mean_squared_error: 0.4557
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 0.1994 - root_mean_squared_error: 0.4440 - val_loss: 0.2343 - val_root_mean_squared_error: 0.4818
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2033 - root_mean_squared_error: 0.4485 - val_loss: 0.2235 - val_root_mean_squared_error: 0.4706
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.2099 - root_mean_squared_error: 0.4557 - val_loss: 0.2111 - val_root_mean_squared_error: 0.4573
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - loss: 0.2062 - root_mean_squared_error: 0.4512 - val_loss: 0.2182 - val_root_mean_squared_error: 0.4651
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.2118 - root_mean_squared_error: 0.4578 - val_loss: 0.1996 - val_root_mean_squared_error: 0.4444
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.1737 - root_mean_squared_error: 0.4134 - val_loss: 0.2259 - val_root_mean_squared_error: 0.4733
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - loss: 0.2135 - root_mean_squared_error: 0.4600 - val_loss: 0.2467 - val_root_mean_squared_error: 0.4949
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.2332 - root_mean_squared_error: 0.4807 - val_loss: 0.2510 - val_root_mean_squared_error: 0.4993
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.2126 - root_mean_squared_error: 0.4590 - val_loss: 0.2362 - val_root_mean_squared_error: 0.4841
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.2252 - root_mean_squared_error: 0.4725 - val_loss: 0.2290 - val_root_mean_squared_error: 0.4768
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.2122 - root_mean_squared_error: 0.4587 - val_loss: 0.2442 - val_root_mean_squared_error: 0.4924
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.1956 - root_mean_squared_error: 0.4401 - val_loss: 0.2514 - val_root_mean_squared_error: 0.4995
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 0.1920 - root_mean_squared_error: 0.4359 - val_loss: 0.2188 - val_root_mean_squared_error: 0.4658
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - loss: 0.2154 - root_mean_squared_error: 0.4618 - val_loss: 0.2465 - val_root_mean_squared_error: 0.4947
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.1948 - root_mean_squared_error: 0.4391 - val_loss: 0.2265 - val_root_mean_squared_error: 0.4740
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - loss: 0.2003 - root_mean_squared_error: 0.4454 - val_loss: 0.2185 - val_root_mean_squared_error: 0.4654
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.2055 - root_mean_squared_error: 0.4511 - val_loss: 0.2118 - val_root_mean_squared_error: 0.4583
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1951 - root_mean_squared_error: 0.4396 - val_loss: 0.2238 - val_root_mean_squared_error: 0.4713
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - loss: 0.1875 - root_mean_squared_error: 0.4306 - val_loss: 0.2284 - val_root_mean_squared_error: 0.4760
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - loss: 0.1993 - root_mean_squared_error: 0.4444 - val_loss: 0.2231 - val_root_mean_squared_error: 0.4704
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - loss: 0.1860 - root_mean_squared_error: 0.4290 - val_loss: 0.2215 - val_root_mean_squared_error: 0.4687
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 322ms/step - loss: 0.1862 - root_mean_squared_error: 0.4292 - val_loss: 0.2077 - val_root_mean_squared_error: 0.4537
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - loss: 0.1763 - root_mean_squared_error: 0.4175 - val_loss: 0.2250 - val_root_mean_squared_error: 0.4724
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - loss: 0.1861 - root_mean_squared_error: 0.4292 - val_loss: 0.2265 - val_root_mean_squared_error: 0.4740
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - loss: 0.1830 - root_mean_squared_error: 0.4256 - val_loss: 0.2369 - val_root_mean_squared_error: 0.4851

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}')

# Make predictions
y_pred = model.predict(X_test)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.1902 - root_mean_squared_error: 0.4332
# Test Loss: [0.18252335488796234, 0.42485588788986206]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\5_Y\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
#plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 0], predicted_values[:, 0], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
#plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
