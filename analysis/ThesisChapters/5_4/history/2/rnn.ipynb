# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - Σε αυτη την περιπτωση θελω να υπολογισω τη σχετικη μετατοπισω της κινησης.
#  σε σχεση με την προηγουμενη...

# %%
import tensorflow as tf
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -400       150            500                680
# 1           40          400       120            770                740
# 2           20          200        60            580                900
# 3           20          200       180            600                880
# 4           40          200         0            500                680
# ...        ...          ...       ...            ...                ...
# 1181        80          200       270            580                900
# 1182        40          200        60            600                880
# 1183        80            0       180            770                740
# 1184        60          200        90            580                900
# 1185        60         -200       270            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    16         1150               980
# 2                    11         1160              1130
# 3                    30          760              1070
# 4                    20         1200               920
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 30          760              1070
# 1183                 16         1150               980
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 3     [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
# 4     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# ...                                                 ...
# 1181  [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
# 1182  [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 1183  [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1184  [359.682, 359.682, 359.682, 359.682, 359.682, ...
# 1185  [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
#
#                                       Head_Y_Coordinate  \
# 0     [-242.323, -242.323, -242.323, -242.323, -242....
# 1     [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 2     [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 3     [375.319, 375.319, 375.319, 375.319, 375.319, ...
# 4     [111.955, 111.955, 111.955, 111.955, 111.955, ...
# ...                                                 ...
# 1181  [243.637, 243.637, 243.637, 243.637, 243.637, ...
# 1182  [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 1183  [175.319, 175.319, 175.319, 175.319, 175.319, ...
# 1184  [243.637, 243.637, 243.637, 243.637, 243.637, ...
# 1185  [-156.363, -156.363, -156.363, -156.363, -156....
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
def normalize_to_minus_one_to_one(values):
    min_val = min(values)
    max_val = max(values)
    
    # Handle the edge case where all values are the same
    if min_val == max_val:
        return [0 for _ in values]
    
    # Normalization to [0, 1]
    scaled_values = [(value - min_val) / (max_val - min_val) for value in values]
    
    # Mapping to [-1, 1]
    mapped_values = [2 * value - 1 for value in scaled_values]
    
    return mapped_values


def calculate_relative_change(row):
    row["Head_X_Coordinate"] = normalize_to_minus_one_to_one(row["Head_X_Coordinate"])
    row["Head_Y_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Y_Coordinate"])
    row["Head_Z_Coordinate"] = normalize_to_minus_one_to_one(row["Head_Z_Coordinate"])
    return row

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100         -400       150            500                680
# 1           40          400       120            770                740
# 2           20          200        60            580                900
# 3           20          200       180            600                880
# 4           40          200         0            500                680
# ...        ...          ...       ...            ...                ...
# 1181        80          200       270            580                900
# 1182        40          200        60            600                880
# 1183        80            0       180            770                740
# 1184        60          200        90            580                900
# 1185        60         -200       270            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    20         1200               920
# 1                    16         1150               980
# 2                    11         1160              1130
# 3                    30          760              1070
# 4                    20         1200               920
# ...                 ...          ...               ...
# 1181                 11         1160              1130
# 1182                 30          760              1070
# 1183                 16         1150               980
# 1184                 11         1160              1130
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 3     [223.0, 223.0, 223.0, 223.0, 223.0, 223.0, 223...
# 4     [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# ...                                                 ...
# 1181  [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
# 1182  [337.04, 337.04, 337.04, 337.04, 337.04, 337.0...
# 1183  [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1184  [359.682, 359.682, 359.682, 359.682, 359.682, ...
# 1185  [96.318, 96.318, 96.318, 96.318, 96.318, 96.31...
#
#                                       Head_Y_Coordinate  \
# 0     [-242.323, -242.323, -242.323, -242.323, -242....
# 1     [509.478, 509.478, 509.478, 509.478, 509.478, ...
# 2     [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 3     [375.319, 375.319, 375.319, 375.319, 375.319, ...
# 4     [111.955, 111.955, 111.955, 111.955, 111.955, ...
# ...                                                 ...
# 1181  [243.637, 243.637, 243.637, 243.637, 243.637, ...
# 1182  [177.796, 177.796, 177.796, 177.796, 177.796, ...
# 1183  [175.319, 175.319, 175.319, 175.319, 175.319, ...
# 1184  [243.637, 243.637, 243.637, 243.637, 243.637, ...
# 1185  [-156.363, -156.363, -156.363, -156.363, -156....
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
df = df.apply(calculate_relative_change, axis=1)

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 7762.64row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0            -0.883991           0.999980           1.000000
# 1            -0.883991           0.999980           0.999984
# 2            -0.883991           0.999980           0.999936
# 3            -0.883991           0.999980           0.999920
# 4            -0.883991           0.999980           0.999875
# ..                 ...                ...                ...
# 296           0.956327          -0.969553          -0.389934
# 297           0.967185          -0.977136          -0.397108
# 298           0.978080          -0.984728          -0.404321
# 299           0.989017          -0.992357          -0.411579
# 300           1.000000          -1.000000          -0.418878
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 100
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 3)
# (237, 100, 11) (237, 75, 3)
# (238, 100, 11) (238, 75, 3)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(LSTM(32, return_sequences=True))  # First LSTM layer
model.add(LSTM(64))  # Second LSTM layer
model.add(Dense(32, activation="relu"))  # Dense layer with more units for better processing
model.add(Dense(next_steps * 3, activation="linear"))  # Output: 10 timesteps * 3 coordinates = 30 values
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 32)        │         5,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 225)            │         7,425 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 3)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,969 (156.13 KB)
#  Trainable params: 39,969 (156.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\2\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10000, callbacks=[cp, es])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 0.4599 - root_mean_squared_error: 0.6782 - val_loss: 0.4622 - val_root_mean_squared_error: 0.6799
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4473 - root_mean_squared_error: 0.6688 - val_loss: 0.4445 - val_root_mean_squared_error: 0.6667
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.4272 - root_mean_squared_error: 0.6536 - val_loss: 0.4130 - val_root_mean_squared_error: 0.6426
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.3930 - root_mean_squared_error: 0.6269 - val_loss: 0.3719 - val_root_mean_squared_error: 0.6099
# Epoch 5/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.3557 - root_mean_squared_error: 0.5963 - val_loss: 0.3318 - val_root_mean_squared_error: 0.5761
# Epoch 6/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.3234 - root_mean_squared_error: 0.5686 - val_loss: 0.2970 - val_root_mean_squared_error: 0.5450
# Epoch 7/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.2842 - root_mean_squared_error: 0.5331 - val_loss: 0.2679 - val_root_mean_squared_error: 0.5176
# Epoch 8/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.2612 - root_mean_squared_error: 0.5111 - val_loss: 0.2450 - val_root_mean_squared_error: 0.4950
# Epoch 9/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.2419 - root_mean_squared_error: 0.4917 - val_loss: 0.2268 - val_root_mean_squared_error: 0.4763
# Epoch 10/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.2174 - root_mean_squared_error: 0.4662 - val_loss: 0.2130 - val_root_mean_squared_error: 0.4615
# Epoch 11/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.2023 - root_mean_squared_error: 0.4497 - val_loss: 0.2026 - val_root_mean_squared_error: 0.4501
# Epoch 12/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.1928 - root_mean_squared_error: 0.4390 - val_loss: 0.1949 - val_root_mean_squared_error: 0.4414
# Epoch 13/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.1844 - root_mean_squared_error: 0.4293 - val_loss: 0.1897 - val_root_mean_squared_error: 0.4356
# Epoch 14/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1906 - root_mean_squared_error: 0.4365 - val_loss: 0.1866 - val_root_mean_squared_error: 0.4319
# Epoch 15/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1826 - root_mean_squared_error: 0.4272 - val_loss: 0.1834 - val_root_mean_squared_error: 0.4282
# Epoch 16/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1826 - root_mean_squared_error: 0.4271 - val_loss: 0.1815 - val_root_mean_squared_error: 0.4260
# Epoch 17/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1686 - root_mean_squared_error: 0.4105 - val_loss: 0.1809 - val_root_mean_squared_error: 0.4253
# Epoch 18/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1870 - root_mean_squared_error: 0.4322 - val_loss: 0.1794 - val_root_mean_squared_error: 0.4236
# Epoch 19/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1753 - root_mean_squared_error: 0.4183 - val_loss: 0.1788 - val_root_mean_squared_error: 0.4229
# Epoch 20/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.1761 - root_mean_squared_error: 0.4195 - val_loss: 0.1787 - val_root_mean_squared_error: 0.4228
# Epoch 21/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1779 - root_mean_squared_error: 0.4217 - val_loss: 0.1784 - val_root_mean_squared_error: 0.4223
# Epoch 22/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.1758 - root_mean_squared_error: 0.4192 - val_loss: 0.1784 - val_root_mean_squared_error: 0.4224
# Epoch 23/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1710 - root_mean_squared_error: 0.4135 - val_loss: 0.1780 - val_root_mean_squared_error: 0.4220
# Epoch 24/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.1761 - root_mean_squared_error: 0.4196 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4218
# Epoch 25/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.1788 - root_mean_squared_error: 0.4226 - val_loss: 0.1784 - val_root_mean_squared_error: 0.4224
# Epoch 26/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1669 - root_mean_squared_error: 0.4084 - val_loss: 0.1781 - val_root_mean_squared_error: 0.4220
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1720 - root_mean_squared_error: 0.4147 - val_loss: 0.1778 - val_root_mean_squared_error: 0.4216
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1778 - root_mean_squared_error: 0.4215 - val_loss: 0.1775 - val_root_mean_squared_error: 0.4214
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1735 - root_mean_squared_error: 0.4165 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4218
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.1800 - root_mean_squared_error: 0.4241 - val_loss: 0.1771 - val_root_mean_squared_error: 0.4209
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1707 - root_mean_squared_error: 0.4132 - val_loss: 0.1773 - val_root_mean_squared_error: 0.4211
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1671 - root_mean_squared_error: 0.4086 - val_loss: 0.1773 - val_root_mean_squared_error: 0.4211
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.1679 - root_mean_squared_error: 0.4097 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4217
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1685 - root_mean_squared_error: 0.4105 - val_loss: 0.1767 - val_root_mean_squared_error: 0.4203
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1702 - root_mean_squared_error: 0.4125 - val_loss: 0.1766 - val_root_mean_squared_error: 0.4203
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.1722 - root_mean_squared_error: 0.4149 - val_loss: 0.1766 - val_root_mean_squared_error: 0.4203
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.1698 - root_mean_squared_error: 0.4120 - val_loss: 0.1764 - val_root_mean_squared_error: 0.4200
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.1675 - root_mean_squared_error: 0.4092 - val_loss: 0.1766 - val_root_mean_squared_error: 0.4203
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1657 - root_mean_squared_error: 0.4069 - val_loss: 0.1767 - val_root_mean_squared_error: 0.4203
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1629 - root_mean_squared_error: 0.4036 - val_loss: 0.1762 - val_root_mean_squared_error: 0.4197
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1706 - root_mean_squared_error: 0.4129 - val_loss: 0.1754 - val_root_mean_squared_error: 0.4188
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1667 - root_mean_squared_error: 0.4082 - val_loss: 0.1754 - val_root_mean_squared_error: 0.4188
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1594 - root_mean_squared_error: 0.3990 - val_loss: 0.1751 - val_root_mean_squared_error: 0.4185
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1666 - root_mean_squared_error: 0.4081 - val_loss: 0.1755 - val_root_mean_squared_error: 0.4189
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1669 - root_mean_squared_error: 0.4085 - val_loss: 0.1761 - val_root_mean_squared_error: 0.4196
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1653 - root_mean_squared_error: 0.4065 - val_loss: 0.1762 - val_root_mean_squared_error: 0.4198
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1569 - root_mean_squared_error: 0.3960 - val_loss: 0.1749 - val_root_mean_squared_error: 0.4183
# Epoch 48/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.1670 - root_mean_squared_error: 0.4086 - val_loss: 0.1724 - val_root_mean_squared_error: 0.4152
# Epoch 49/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1574 - root_mean_squared_error: 0.3966 - val_loss: 0.1737 - val_root_mean_squared_error: 0.4167
# Epoch 50/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1554 - root_mean_squared_error: 0.3942 - val_loss: 0.1692 - val_root_mean_squared_error: 0.4114
# Epoch 51/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1548 - root_mean_squared_error: 0.3933 - val_loss: 0.1682 - val_root_mean_squared_error: 0.4101
# Epoch 52/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.1586 - root_mean_squared_error: 0.3981 - val_loss: 0.1697 - val_root_mean_squared_error: 0.4119
# Epoch 53/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.1463 - root_mean_squared_error: 0.3823 - val_loss: 0.1664 - val_root_mean_squared_error: 0.4079
# Epoch 54/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.1495 - root_mean_squared_error: 0.3865 - val_loss: 0.1746 - val_root_mean_squared_error: 0.4178
# Epoch 55/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1520 - root_mean_squared_error: 0.3896 - val_loss: 0.1684 - val_root_mean_squared_error: 0.4103
# Epoch 56/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.1608 - root_mean_squared_error: 0.4007 - val_loss: 0.1636 - val_root_mean_squared_error: 0.4045
# Epoch 57/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1579 - root_mean_squared_error: 0.3972 - val_loss: 0.1621 - val_root_mean_squared_error: 0.4027
# Epoch 58/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1583 - root_mean_squared_error: 0.3977 - val_loss: 0.1679 - val_root_mean_squared_error: 0.4097
# Epoch 59/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1616 - root_mean_squared_error: 0.4017 - val_loss: 0.1637 - val_root_mean_squared_error: 0.4045
# Epoch 60/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.1514 - root_mean_squared_error: 0.3890 - val_loss: 0.1655 - val_root_mean_squared_error: 0.4069
# Epoch 61/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1541 - root_mean_squared_error: 0.3925 - val_loss: 0.1672 - val_root_mean_squared_error: 0.4089
# Epoch 62/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1529 - root_mean_squared_error: 0.3908 - val_loss: 0.1620 - val_root_mean_squared_error: 0.4024
# Epoch 63/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1508 - root_mean_squared_error: 0.3883 - val_loss: 0.1657 - val_root_mean_squared_error: 0.4071
# Epoch 64/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.1495 - root_mean_squared_error: 0.3864 - val_loss: 0.1609 - val_root_mean_squared_error: 0.4011
# Epoch 65/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1541 - root_mean_squared_error: 0.3925 - val_loss: 0.1627 - val_root_mean_squared_error: 0.4034
# Epoch 66/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1462 - root_mean_squared_error: 0.3823 - val_loss: 0.1643 - val_root_mean_squared_error: 0.4054
# Epoch 67/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.1526 - root_mean_squared_error: 0.3905 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3981
# Epoch 68/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1348 - root_mean_squared_error: 0.3666 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3982
# Epoch 69/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1459 - root_mean_squared_error: 0.3819 - val_loss: 0.1604 - val_root_mean_squared_error: 0.4005
# Epoch 70/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1477 - root_mean_squared_error: 0.3841 - val_loss: 0.1609 - val_root_mean_squared_error: 0.4012
# Epoch 71/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1429 - root_mean_squared_error: 0.3779 - val_loss: 0.1593 - val_root_mean_squared_error: 0.3991
# Epoch 72/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - val_loss: 0.1592 - val_root_mean_squared_error: 0.3990
# Epoch 73/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.1459 - root_mean_squared_error: 0.3819 - val_loss: 0.1614 - val_root_mean_squared_error: 0.4017
# Epoch 74/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.1459 - root_mean_squared_error: 0.3819 - val_loss: 0.1532 - val_root_mean_squared_error: 0.3915
# Epoch 75/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.1491 - root_mean_squared_error: 0.3860 - val_loss: 0.1569 - val_root_mean_squared_error: 0.3961
# Epoch 76/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1373 - root_mean_squared_error: 0.3704 - val_loss: 0.1566 - val_root_mean_squared_error: 0.3957
# Epoch 77/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1415 - root_mean_squared_error: 0.3761 - val_loss: 0.1645 - val_root_mean_squared_error: 0.4056
# Epoch 78/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1475 - root_mean_squared_error: 0.3840 - val_loss: 0.1618 - val_root_mean_squared_error: 0.4023
# Epoch 79/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1460 - root_mean_squared_error: 0.3819 - val_loss: 0.1542 - val_root_mean_squared_error: 0.3927
# Epoch 80/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1455 - root_mean_squared_error: 0.3814 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3971
# Epoch 81/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.1405 - root_mean_squared_error: 0.3748 - val_loss: 0.1557 - val_root_mean_squared_error: 0.3946
# Epoch 82/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1504 - root_mean_squared_error: 0.3876 - val_loss: 0.1604 - val_root_mean_squared_error: 0.4005
# Epoch 83/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1439 - root_mean_squared_error: 0.3793 - val_loss: 0.1584 - val_root_mean_squared_error: 0.3980
# Epoch 84/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.1415 - root_mean_squared_error: 0.3760 - val_loss: 0.1571 - val_root_mean_squared_error: 0.3964
# Epoch 85/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1368 - root_mean_squared_error: 0.3697 - val_loss: 0.1573 - val_root_mean_squared_error: 0.3966
# Epoch 86/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1408 - root_mean_squared_error: 0.3752 - val_loss: 0.1537 - val_root_mean_squared_error: 0.3921
# Epoch 87/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1388 - root_mean_squared_error: 0.3725 - val_loss: 0.1539 - val_root_mean_squared_error: 0.3923
# Epoch 88/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1420 - root_mean_squared_error: 0.3766 - val_loss: 0.1522 - val_root_mean_squared_error: 0.3901
# Epoch 89/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1430 - root_mean_squared_error: 0.3780 - val_loss: 0.1606 - val_root_mean_squared_error: 0.4007
# Epoch 90/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1439 - root_mean_squared_error: 0.3791 - val_loss: 0.1603 - val_root_mean_squared_error: 0.4003
# Epoch 91/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.1457 - root_mean_squared_error: 0.3816 - val_loss: 0.1560 - val_root_mean_squared_error: 0.3950
# Epoch 92/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1401 - root_mean_squared_error: 0.3739 - val_loss: 0.1514 - val_root_mean_squared_error: 0.3891
# Epoch 93/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.1419 - root_mean_squared_error: 0.3767 - val_loss: 0.1573 - val_root_mean_squared_error: 0.3967
# Epoch 94/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1372 - root_mean_squared_error: 0.3703 - val_loss: 0.1535 - val_root_mean_squared_error: 0.3918
# Epoch 95/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1320 - root_mean_squared_error: 0.3631 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3954
# Epoch 96/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1477 - root_mean_squared_error: 0.3842 - val_loss: 0.1540 - val_root_mean_squared_error: 0.3925
# Epoch 97/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1407 - root_mean_squared_error: 0.3751 - val_loss: 0.1533 - val_root_mean_squared_error: 0.3915
# Epoch 98/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1322 - root_mean_squared_error: 0.3631 - val_loss: 0.1580 - val_root_mean_squared_error: 0.3974
# Epoch 99/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1393 - root_mean_squared_error: 0.3732 - val_loss: 0.1568 - val_root_mean_squared_error: 0.3959
# Epoch 100/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.1387 - root_mean_squared_error: 0.3723 - val_loss: 0.1557 - val_root_mean_squared_error: 0.3946
# Epoch 101/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1372 - root_mean_squared_error: 0.3704 - val_loss: 0.1529 - val_root_mean_squared_error: 0.3910
# Epoch 102/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.1439 - root_mean_squared_error: 0.3789 - val_loss: 0.1527 - val_root_mean_squared_error: 0.3908
# Epoch 103/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1431 - root_mean_squared_error: 0.3780 - val_loss: 0.1544 - val_root_mean_squared_error: 0.3929
# Epoch 104/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1361 - root_mean_squared_error: 0.3688 - val_loss: 0.1559 - val_root_mean_squared_error: 0.3948
# Epoch 105/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1467 - root_mean_squared_error: 0.3827 - val_loss: 0.1536 - val_root_mean_squared_error: 0.3919
# Epoch 106/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1283 - root_mean_squared_error: 0.3580 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3944
# Epoch 107/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1390 - root_mean_squared_error: 0.3726 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3908
# Epoch 108/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1257 - root_mean_squared_error: 0.3542 - val_loss: 0.1523 - val_root_mean_squared_error: 0.3902
# Epoch 109/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1338 - root_mean_squared_error: 0.3658 - val_loss: 0.1520 - val_root_mean_squared_error: 0.3898
# Epoch 110/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1361 - root_mean_squared_error: 0.3688 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3881
# Epoch 111/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.1367 - root_mean_squared_error: 0.3696 - val_loss: 0.1522 - val_root_mean_squared_error: 0.3901
# Epoch 112/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1359 - root_mean_squared_error: 0.3682 - val_loss: 0.1502 - val_root_mean_squared_error: 0.3876
# Epoch 113/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.1380 - root_mean_squared_error: 0.3713 - val_loss: 0.1516 - val_root_mean_squared_error: 0.3894
# Epoch 114/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.1368 - root_mean_squared_error: 0.3698 - val_loss: 0.1529 - val_root_mean_squared_error: 0.3910
# Epoch 115/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.1343 - root_mean_squared_error: 0.3664 - val_loss: 0.1546 - val_root_mean_squared_error: 0.3932
# Epoch 116/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1389 - root_mean_squared_error: 0.3725 - val_loss: 0.1510 - val_root_mean_squared_error: 0.3886
# Epoch 117/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1344 - root_mean_squared_error: 0.3666 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3888
# Epoch 118/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1262 - root_mean_squared_error: 0.3549 - val_loss: 0.1570 - val_root_mean_squared_error: 0.3963
# Epoch 119/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3908
# Epoch 120/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.1407 - root_mean_squared_error: 0.3749 - val_loss: 0.1525 - val_root_mean_squared_error: 0.3905
# Epoch 121/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1341 - root_mean_squared_error: 0.3662 - val_loss: 0.1516 - val_root_mean_squared_error: 0.3893
# Epoch 122/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1391 - root_mean_squared_error: 0.3727 - val_loss: 0.1509 - val_root_mean_squared_error: 0.3884
# Epoch 123/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1294 - root_mean_squared_error: 0.3596 - val_loss: 0.1515 - val_root_mean_squared_error: 0.3892
# Epoch 124/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1251 - root_mean_squared_error: 0.3536 - val_loss: 0.1517 - val_root_mean_squared_error: 0.3895
# Epoch 125/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.1274 - root_mean_squared_error: 0.3565 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3889
# Epoch 126/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1271 - root_mean_squared_error: 0.3563 - val_loss: 0.1521 - val_root_mean_squared_error: 0.3900
# Epoch 127/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1328 - root_mean_squared_error: 0.3643 - val_loss: 0.1511 - val_root_mean_squared_error: 0.3887
# Epoch 128/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1327 - root_mean_squared_error: 0.3642 - val_loss: 0.1498 - val_root_mean_squared_error: 0.3871
# Epoch 129/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.1331 - root_mean_squared_error: 0.3647 - val_loss: 0.1521 - val_root_mean_squared_error: 0.3899
# Epoch 130/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1343 - root_mean_squared_error: 0.3665 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3897
# Epoch 131/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1298 - root_mean_squared_error: 0.3602 - val_loss: 0.1515 - val_root_mean_squared_error: 0.3892
# Epoch 132/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1292 - root_mean_squared_error: 0.3593 - val_loss: 0.1524 - val_root_mean_squared_error: 0.3903
# Epoch 133/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1334 - root_mean_squared_error: 0.3652 - val_loss: 0.1505 - val_root_mean_squared_error: 0.3879
# Epoch 134/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1334 - root_mean_squared_error: 0.3651 - val_loss: 0.1488 - val_root_mean_squared_error: 0.3857
# Epoch 135/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1354 - root_mean_squared_error: 0.3678 - val_loss: 0.1511 - val_root_mean_squared_error: 0.3887
# Epoch 136/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1362 - root_mean_squared_error: 0.3689 - val_loss: 0.1514 - val_root_mean_squared_error: 0.3892
# Epoch 137/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.1427 - root_mean_squared_error: 0.3777 - val_loss: 0.1491 - val_root_mean_squared_error: 0.3861
# Epoch 138/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1285 - root_mean_squared_error: 0.3580 - val_loss: 0.1501 - val_root_mean_squared_error: 0.3875
# Epoch 139/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1313 - root_mean_squared_error: 0.3622 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3878
# Epoch 140/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.1302 - root_mean_squared_error: 0.3606 - val_loss: 0.1488 - val_root_mean_squared_error: 0.3858
# Epoch 141/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1318 - root_mean_squared_error: 0.3630 - val_loss: 0.1568 - val_root_mean_squared_error: 0.3959
# Epoch 142/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1302 - root_mean_squared_error: 0.3608 - val_loss: 0.1501 - val_root_mean_squared_error: 0.3875
# Epoch 143/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1262 - root_mean_squared_error: 0.3549 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3878
# Epoch 144/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1336 - root_mean_squared_error: 0.3655 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3872
# Epoch 145/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1314 - root_mean_squared_error: 0.3624 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3860
# Epoch 146/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1311 - root_mean_squared_error: 0.3621 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3890
# Epoch 147/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1316 - root_mean_squared_error: 0.3626 - val_loss: 0.1505 - val_root_mean_squared_error: 0.3880
# Epoch 148/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1331 - root_mean_squared_error: 0.3647 - val_loss: 0.1497 - val_root_mean_squared_error: 0.3869
# Epoch 149/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1366 - root_mean_squared_error: 0.3694 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3866
# Epoch 150/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1306 - root_mean_squared_error: 0.3613 - val_loss: 0.1501 - val_root_mean_squared_error: 0.3874
# Epoch 151/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.1285 - root_mean_squared_error: 0.3582 - val_loss: 0.1482 - val_root_mean_squared_error: 0.3850
# Epoch 152/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1257 - root_mean_squared_error: 0.3545 - val_loss: 0.1475 - val_root_mean_squared_error: 0.3840
# Epoch 153/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1334 - root_mean_squared_error: 0.3652 - val_loss: 0.1502 - val_root_mean_squared_error: 0.3875
# Epoch 154/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1330 - root_mean_squared_error: 0.3646 - val_loss: 0.1485 - val_root_mean_squared_error: 0.3854
# Epoch 155/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.1280 - root_mean_squared_error: 0.3574 - val_loss: 0.1487 - val_root_mean_squared_error: 0.3857
# Epoch 156/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1329 - root_mean_squared_error: 0.3645 - val_loss: 0.1485 - val_root_mean_squared_error: 0.3854
# Epoch 157/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1265 - root_mean_squared_error: 0.3556 - val_loss: 0.1491 - val_root_mean_squared_error: 0.3861
# Epoch 158/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.1321 - root_mean_squared_error: 0.3634 - val_loss: 0.1468 - val_root_mean_squared_error: 0.3832
# Epoch 159/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.1349 - root_mean_squared_error: 0.3673 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3882
# Epoch 160/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1235 - root_mean_squared_error: 0.3513 - val_loss: 0.1611 - val_root_mean_squared_error: 0.4014
# Epoch 161/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.1306 - root_mean_squared_error: 0.3613 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3860
# Epoch 162/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1266 - root_mean_squared_error: 0.3556 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3888
# Epoch 163/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1334 - root_mean_squared_error: 0.3652 - val_loss: 0.1487 - val_root_mean_squared_error: 0.3856
# Epoch 164/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1304 - root_mean_squared_error: 0.3611 - val_loss: 0.1484 - val_root_mean_squared_error: 0.3853
# Epoch 165/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1309 - root_mean_squared_error: 0.3614 - val_loss: 0.1480 - val_root_mean_squared_error: 0.3847
# Epoch 166/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1266 - root_mean_squared_error: 0.3558 - val_loss: 0.1480 - val_root_mean_squared_error: 0.3848
# Epoch 167/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1262 - root_mean_squared_error: 0.3549 - val_loss: 0.1495 - val_root_mean_squared_error: 0.3867
# Epoch 168/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1292 - root_mean_squared_error: 0.3594 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3808
# Epoch 169/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1247 - root_mean_squared_error: 0.3530 - val_loss: 0.1449 - val_root_mean_squared_error: 0.3807
# Epoch 170/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1285 - root_mean_squared_error: 0.3585 - val_loss: 0.1480 - val_root_mean_squared_error: 0.3847
# Epoch 171/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1297 - root_mean_squared_error: 0.3600 - val_loss: 0.1458 - val_root_mean_squared_error: 0.3818
# Epoch 172/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1393 - root_mean_squared_error: 0.3728 - val_loss: 0.1452 - val_root_mean_squared_error: 0.3810
# Epoch 173/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1337 - root_mean_squared_error: 0.3655 - val_loss: 0.1469 - val_root_mean_squared_error: 0.3833
# Epoch 174/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.1266 - root_mean_squared_error: 0.3555 - val_loss: 0.1472 - val_root_mean_squared_error: 0.3837
# Epoch 175/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1279 - root_mean_squared_error: 0.3576 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3814
# Epoch 176/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1325 - root_mean_squared_error: 0.3640 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3841
# Epoch 177/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1339 - root_mean_squared_error: 0.3657 - val_loss: 0.1457 - val_root_mean_squared_error: 0.3818
# Epoch 178/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.1312 - root_mean_squared_error: 0.3620 - val_loss: 0.1447 - val_root_mean_squared_error: 0.3804
# Epoch 179/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1372 - root_mean_squared_error: 0.3703 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3889
# Epoch 180/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1290 - root_mean_squared_error: 0.3588 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3816
# Epoch 181/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1312 - root_mean_squared_error: 0.3621 - val_loss: 0.1458 - val_root_mean_squared_error: 0.3818
# Epoch 182/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.1282 - root_mean_squared_error: 0.3578 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3808
# Epoch 183/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1357 - root_mean_squared_error: 0.3683 - val_loss: 0.1448 - val_root_mean_squared_error: 0.3806
# Epoch 184/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1389 - root_mean_squared_error: 0.3725 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3860
# Epoch 185/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.1347 - root_mean_squared_error: 0.3668 - val_loss: 0.1457 - val_root_mean_squared_error: 0.3817
# Epoch 186/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.1273 - root_mean_squared_error: 0.3566 - val_loss: 0.1453 - val_root_mean_squared_error: 0.3812
# Epoch 187/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1296 - root_mean_squared_error: 0.3598 - val_loss: 0.1448 - val_root_mean_squared_error: 0.3805
# Epoch 188/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.1251 - root_mean_squared_error: 0.3536 - val_loss: 0.1444 - val_root_mean_squared_error: 0.3801
# Epoch 189/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1248 - root_mean_squared_error: 0.3532 - val_loss: 0.1445 - val_root_mean_squared_error: 0.3801
# Epoch 190/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.1246 - root_mean_squared_error: 0.3529 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3808
# Epoch 191/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1257 - root_mean_squared_error: 0.3545 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3816
# Epoch 192/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1218 - root_mean_squared_error: 0.3487 - val_loss: 0.1485 - val_root_mean_squared_error: 0.3854
# Epoch 193/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.1332 - root_mean_squared_error: 0.3649 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3828
# Epoch 194/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1372 - root_mean_squared_error: 0.3695 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3814
# Epoch 195/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1277 - root_mean_squared_error: 0.3573 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3815
# Epoch 196/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.1232 - root_mean_squared_error: 0.3508 - val_loss: 0.1435 - val_root_mean_squared_error: 0.3788
# Epoch 197/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1379 - root_mean_squared_error: 0.3708 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3830
# Epoch 198/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1352 - root_mean_squared_error: 0.3677 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3807
# Epoch 199/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1366 - root_mean_squared_error: 0.3693 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3815
# Epoch 200/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.1246 - root_mean_squared_error: 0.3529 - val_loss: 0.1475 - val_root_mean_squared_error: 0.3841
# Epoch 201/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1282 - root_mean_squared_error: 0.3579 - val_loss: 0.1503 - val_root_mean_squared_error: 0.3877
# Epoch 202/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1240 - root_mean_squared_error: 0.3520 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3834
# Epoch 203/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1247 - root_mean_squared_error: 0.3529 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3841
# Epoch 204/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1222 - root_mean_squared_error: 0.3493 - val_loss: 0.1498 - val_root_mean_squared_error: 0.3870
# Epoch 205/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1332 - root_mean_squared_error: 0.3648 - val_loss: 0.1456 - val_root_mean_squared_error: 0.3815
# Epoch 206/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.1213 - root_mean_squared_error: 0.3480 - val_loss: 0.1467 - val_root_mean_squared_error: 0.3830
# Epoch 207/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.1204 - root_mean_squared_error: 0.3468 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3794
# Epoch 208/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1322 - root_mean_squared_error: 0.3636 - val_loss: 0.1478 - val_root_mean_squared_error: 0.3845
# Epoch 209/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.1256 - root_mean_squared_error: 0.3544 - val_loss: 0.1458 - val_root_mean_squared_error: 0.3818
# Epoch 210/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.1195 - root_mean_squared_error: 0.3453 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3842
# Epoch 211/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1338 - root_mean_squared_error: 0.3657 - val_loss: 0.1474 - val_root_mean_squared_error: 0.3839
# Epoch 212/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1336 - root_mean_squared_error: 0.3654 - val_loss: 0.1475 - val_root_mean_squared_error: 0.3841
# Epoch 213/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1225 - root_mean_squared_error: 0.3499 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3828
# Epoch 214/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1311 - root_mean_squared_error: 0.3617 - val_loss: 0.1485 - val_root_mean_squared_error: 0.3854
# Epoch 215/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1246 - root_mean_squared_error: 0.3529 - val_loss: 0.1510 - val_root_mean_squared_error: 0.3886
# Epoch 216/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1370 - root_mean_squared_error: 0.3699 - val_loss: 0.1477 - val_root_mean_squared_error: 0.3843

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\2\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# This is why it is not working... i think.
