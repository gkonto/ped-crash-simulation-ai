# %% [markdown]
# Se auto to notebook prospathisa na problepso tin troxia tou X Coordinate!!!!
# - dinontas tin [x-5:target-1] + data_panels kai prospathontas na problepso to target.
# - No Normalization!
# - Input (XYZ coord timeseries + panel data: Velocity, Translation etc)
# - Output X coord timeseries
# - Not Acceleration! Coordinate!
# - The output will be X coordinates!
# - Copied  from https://www.youtube.com/watch?v=kGdbPnMCdOg&t=3483s
# - Den kano feed ta predicted dedomena gia na upologiso ta epomena!

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
from pathlib import Path
import sys
sys.path.insert(0, "C:\\Users\\geork\\projects\\AIThesis\\src\\src")

from  dataset_reader import DatasetFromFiles

# %% [markdown]
# # Preprocessing on dataset

# %%
path = Path("C:\\Users\\geork\\projects\\AIThesis\\datasets\\20240510\\mlres")
out_path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
# Check if out_path already exists
if out_path.exists():
    print(f"The file or directory {out_path} already exists.")
    # Handle the case where the file already exists, if needed
else:
    # Proceed with your operations
    r = DatasetFromFiles(path)
    r.setTimeSeriesLabel("Head_X_Coordinate")
    r.setTimeSeriesLabel("Head_Y_Coordinate")
    r.setTimeSeriesLabel("Head_Z_Coordinate")
    r.setOutputPath(out_path, True)
    r.read()
# Out:
# The file or directory C:\Users\geork\projects\AIThesis\src\analysis\ThesisChapters\5_4\1\crash_xyz_coordinate_timeseries.csv already exists.

# %%
from dataset_reader import DatasetReaderCSV
path = Path("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\crash_xyz_coordinate_timeseries.csv")
reader = DatasetReaderCSV(path)
reader.read()
df = reader.convert_to_dataframe()
df
# Out:
#         Id                                               Path CarProfile  \
# 0        0  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 1        1  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 2        2  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 3        3  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# 4        4  C:\Users\geork\projects\AIThesis\datasets\2024...        FCR
# ...    ...                                                ...        ...
# 1181  1181  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1182  1182  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1183  1183  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1184  1184  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
# 1185  1185  C:\Users\geork\projects\AIThesis\datasets\2024...        SUV
#
#       Velocity  Translation  Rotation Position  HIC15_max  HIC36_max  \
# 0          100         -200         0  initial     86.843    136.373
# 1          100         -200       120  initial   2361.697   2866.369
# 2          100         -200       150  initial    573.455    573.455
# 3          100         -200       180  initial     84.702    153.528
# 4          100         -200       210  initial    592.965    592.965
# ...        ...          ...       ...      ...        ...        ...
# 1181        80          400       300  initial    623.367    805.513
# 1182        80          400        30  initial    140.360    140.360
# 1183        80          400       330  initial    367.018    367.018
# 1184        80          400        60  initial   1317.014   1744.307
# 1185        80          400        90  initial   1861.807   2323.377
#
#       Head_Z_Acceleration_abs_max  Head_X_Acceleration_abs_max  \
# 0                          36.081                        7.578
# 1                         103.348                      179.802
# 2                          74.161                       77.655
# 3                          35.330                       13.216
# 4                          42.322                      138.277
# ...                           ...                          ...
# 1181                       60.709                      102.335
# 1182                       56.352                       21.859
# 1183                       40.335                      106.179
# 1184                      106.903                      122.473
# 1185                      112.927                      200.791
#
#       Head_Y_Acceleration_abs_max  BrIC_abs_max  \
# 0                          17.539         0.920
# 1                          54.333         1.718
# 2                          72.795         0.936
# 3                          13.956         0.905
# 4                          19.926         0.965
# ...                           ...           ...
# 1181                       33.421         1.185
# 1182                       48.887         1.206
# 1183                       14.131         1.146
# 1184                       96.965         1.594
# 1185                       18.946         1.844
#
#       Chest_Resultant_Acceleration_max  \
# 0                               34.882
# 1                               36.302
# 2                               24.091
# 3                               49.501
# 4                               25.420
# ...                                ...
# 1181                            57.473
# 1182                            55.691
# 1183                            38.706
# 1184                            52.806
# 1185                            48.806
#
#       Chest_Resultant_Acceleration_CLIP3ms_max  \
# 0                                       28.117
# 1                                       19.450
# 2                                       19.183
# 3                                       28.255
# 4                                       18.131
# ...                                        ...
# 1181                                    54.938
# 1182                                    40.446
# 1183                                    35.552
# 1184                                    42.759
# 1185                                    41.785
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 18 columns]

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

df["Head_X_Coordinate"] = df["Head_X_Coordinate"].apply(str_to_list)
df["Head_Y_Coordinate"] = df["Head_Y_Coordinate"].apply(str_to_list)
df["Head_Z_Coordinate"] = df["Head_Z_Coordinate"].apply(str_to_list)

# %%
df = df.drop(columns=["Path", "Id", "HIC15_max", "HIC36_max",
                      "Head_X_Acceleration_abs_max",
                      "Head_Y_Acceleration_abs_max",
                      "Head_Z_Acceleration_abs_max",
                      "BrIC_abs_max",
                      "Chest_Resultant_Acceleration_max",
                      "Chest_Resultant_Acceleration_CLIP3ms_max",
                      "Position"],
                    errors="ignore")
df = df.reset_index(drop=True)
df
# Out:
#      CarProfile  Velocity  Translation  Rotation  \
# 0           FCR       100         -200         0
# 1           FCR       100         -200       120
# 2           FCR       100         -200       150
# 3           FCR       100         -200       180
# 4           FCR       100         -200       210
# ...         ...       ...          ...       ...
# 1181        SUV        80          400       300
# 1182        SUV        80          400        30
# 1183        SUV        80          400       330
# 1184        SUV        80          400        60
# 1185        SUV        80          400        90
#
#                                       Head_X_Coordinate  \
# 0     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 1     [334.04, 334.04, 334.04, 334.04, 334.04, 334.0...
# 2     [285.841, 285.841, 285.841, 285.841, 285.841, ...
# 3     [220.0, 220.0, 220.0, 220.0, 220.0, 220.0, 220...
# 4     [154.159, 154.159, 154.159, 154.159, 154.159, ...
# ...                                                 ...
# 1181  [113.96, 113.96, 113.96, 113.96, 113.96, 113.9...
# 1182  [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 1183  [162.159, 162.159, 162.159, 162.159, 162.159, ...
# 1184  [342.04, 342.04, 342.04, 342.04, 342.04, 342.0...
# 1185  [359.682, 359.682, 359.682, 359.682, 359.682, ...
#
#                                       Head_Y_Coordinate  \
# 0     [-288.045, -288.045, -288.045, -288.045, -288....
# 1     [-90.522, -90.522, -90.522, -90.522, -90.522, ...
# 2     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# 3     [-24.681, -24.681, -24.681, -24.681, -24.681, ...
# 4     [-42.323, -42.323, -42.323, -42.323, -42.323, ...
# ...                                                 ...
# 1181  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1182  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1183  [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 1184  [377.796, 377.796, 377.796, 377.796, 377.796, ...
# 1185  [443.637, 443.637, 443.637, 443.637, 443.637, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 7 columns]

# %%
from car_profile_expand import expand_car_profiles
try:
    df = df.apply(expand_car_profiles, axis=1)
except:
    pass

df = df.drop(columns="CarProfile", errors="ignore")
new_order = ["Velocity", 
             "Translation", 
             "Rotation", 
             "Bumber_Height",
             "Front_Hood_Height", 
             "Bumber_Hood_Angle",
            "Hood_Length", 
            "Back_Hood_Height",  
            "Head_X_Coordinate", 
            "Head_Y_Coordinate", 
            "Head_Z_Coordinate"]
df = df[new_order]
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Velocity  Translation  Rotation  Bumber_Height  Front_Hood_Height  \
# 0          100            0       270            770                740
# 1           60          400        30            580                900
# 2           80         -400        30            600                880
# 3           60         -400       270            500                680
# 4          100          400       210            600                880
# ...        ...          ...       ...            ...                ...
# 1181        20         -400        30            500                680
# 1182        40            0        30            500                680
# 1183        20         -200       330            500                680
# 1184        80         -200         0            500                680
# 1185        20            0        30            580                900
#
#       Bumber_Hood_Angle  Hood_Length  Back_Hood_Height  \
# 0                    16         1150               980
# 1                    11         1160              1130
# 2                    30          760              1070
# 3                    20         1200               920
# 4                    30          760              1070
# ...                 ...          ...               ...
# 1181                 20         1200               920
# 1182                 20         1200               920
# 1183                 20         1200               920
# 1184                 20         1200               920
# 1185                 11         1160              1130
#
#                                       Head_X_Coordinate  \
# 0     [88.318, 88.318, 88.318, 88.318, 88.318, 88.31...
# 1     [293.841, 293.841, 293.841, 293.841, 293.841, ...
# 2     [288.841, 288.841, 288.841, 288.841, 288.841, ...
# 3     [80.318, 80.318, 80.318, 80.318, 80.318, 80.31...
# 4     [157.159, 157.159, 157.159, 157.159, 157.159, ...
# ...                                                 ...
# 1181  [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1182  [277.841, 277.841, 277.841, 277.841, 277.841, ...
# 1183  [146.159, 146.159, 146.159, 146.159, 146.159, ...
# 1184  [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 212...
# 1185  [293.841, 293.841, 293.841, 293.841, 293.841, ...
#
#                                       Head_Y_Coordinate  \
# 0     [43.637, 43.637, 43.637, 43.637, 43.637, 43.63...
# 1     [329.597, 329.597, 329.597, 329.597, 329.597, ...
# 2     [-470.403, -470.403, -470.403, -470.403, -470....
# 3     [-356.363, -356.363, -356.363, -356.363, -356....
# 4     [557.677, 557.677, 557.677, 557.677, 557.677, ...
# ...                                                 ...
# 1181  [-470.403, -470.403, -470.403, -470.403, -470....
# 1182  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
# 1183  [-270.403, -270.403, -270.403, -270.403, -270....
# 1184  [-288.045, -288.045, -288.045, -288.045, -288....
# 1185  [-70.403, -70.403, -70.403, -70.403, -70.403, ...
#
#                                       Head_Z_Coordinate
# 0     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 2     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 3     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 4     [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# ...                                                 ...
# 1181  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1182  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1183  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1184  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
# 1185  [1575.416, 1575.411, 1575.396, 1575.391, 1575....
#
# [1186 rows x 11 columns]

# %%
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Checking rows", unit="row"):
    if (len(row["Head_X_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Y_Coordinate"]) != 301): print("Error!!")
    if (len(row["Head_Z_Coordinate"]) != 301): print("Error!!")
# Out:
# Checking rows: 100%|██████████| 1186/1186 [00:00<00:00, 14257.67row/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random 

def print_plot(df, labels, start, end):
    expanded_data = {label: [] for label in labels}
    
    for label in labels:
        for idx, sublist in enumerate(df[label]):
            for item in sublist:
                expanded_data[label].append(item)
    
    expanded_df = pd.DataFrame(expanded_data)
    print("\nExpanded DataFrame:")
    print(expanded_df[start:end])
    
    fig, axes = plt.subplots(1, len(labels), figsize=(15, 5))
    
    for i, label in enumerate(labels):
        expanded_df[label][start:end].plot(ax=axes[i], title=label)
        axes[i].set_ylabel(label)
        axes[i].set_xlabel('Index')
    
    plt.tight_layout()
    plt.show()

def print_plot_simulation(df, labels, sim_index):
    start = 301 * sim_index
    end   = 301 * sim_index + 301
    print_plot(df, labels, start, end)

def print_plot_random_simulation(df, labels):
    rand_int = random.randint(0, int(df.shape[0]))
    print_plot_simulation(df, labels, rand_int)
    
labels = ["Head_X_Coordinate", "Head_Y_Coordinate", "Head_Z_Coordinate"]
#print_plot_random_simulation(df, labels)
print_plot_simulation(df, labels, 0)
# Out:
# Expanded DataFrame:
#      Head_X_Coordinate  Head_Y_Coordinate  Head_Z_Coordinate
# 0               88.318             43.637           1575.416
# 1               88.318             43.637           1575.411
# 2               88.318             43.637           1575.396
# 3               88.318             43.637           1575.391
# 4               88.318             43.637           1575.377
# ..                 ...                ...                ...
# 296           1879.065            116.524           1120.556
# 297           1888.990            116.955           1121.367
# 298           1898.816            117.393           1122.166
# 299           1908.498            117.836           1122.937
# 300           1918.101            118.281           1123.702
#
# [301 rows x 3 columns]

# %%
# split the df in train, test val.
# I want to split it before converting the compact lists into another df,
# so that each simulation will remain unchanged.
import pandas as pd
from sklearn.model_selection import train_test_split

train_size = 0.6
val_size = 0.2
test_size = 0.2

train_df, temp_df = train_test_split(df, train_size=train_size, random_state=13)
val_df, test_df = train_test_split(temp_df, test_size=test_size/(test_size + val_size), random_state=14)

# %%
def split_dataframe(df, scalar_columns, input_first, output_next):
    # Extract scalar features
    X_scalar = df[scalar_columns].values

    # Extract sequence features (first 75 values)
    X_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[:input_first]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[:input_first]).values.tolist()])

    # Transpose X_seq to have shape (num_samples, input_first, 3)
    X_seq = np.transpose(X_seq, (1, 2, 0))

    # Extract target sequences (next 'output_next' values)
    y_seq = np.array([df['Head_X_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Y_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist(),
                    df['Head_Z_Coordinate'].apply(lambda x: x[input_first:input_first + output_next]).values.tolist()])

    # Transpose y_seq to have shape (num_samples, 10, 3)
    y_seq = np.transpose(y_seq, (1, 2, 0))

    # Concatenate scalar features with sequence features
    # Expanding X_scalar to have shape (num_samples, 1, num_features) to concatenate with X_seq
    X_scalar_expanded = np.expand_dims(X_scalar, axis=1)

    # Repeat scalar features to match the sequence length (input_first timesteps)
    X_scalar_repeated = np.repeat(X_scalar_expanded, input_first, axis=1)

    # Concatenate along the feature dimension
    X = np.concatenate([X_scalar_repeated, X_seq], axis=-1)

    # y_train is just the target sequences (y_seq)
    y = y_seq
    return X, y

# %%
scalar_columns = ['Velocity', 'Translation', 'Rotation', 'Bumber_Height', 
                'Front_Hood_Height', 'Bumber_Hood_Angle', 
                'Hood_Length', 'Back_Hood_Height']

first_steps = 100
next_steps = 75

X_train, y_train = split_dataframe(train_df, scalar_columns, first_steps, next_steps)
X_test, y_test = split_dataframe(test_df, scalar_columns, first_steps, next_steps)
X_val, y_val = split_dataframe(val_df, scalar_columns, first_steps, next_steps)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (711, 100, 11) (711, 75, 3)
# (237, 100, 11) (237, 75, 3)
# (238, 100, 11) (238, 75, 3)

# %%
train_df.columns
# Out:
# Index(['Velocity', 'Translation', 'Rotation', 'Bumber_Height',
#        'Front_Hood_Height', 'Bumber_Hood_Angle', 'Hood_Length',
#        'Back_Hood_Height', 'Head_X_Coordinate', 'Head_Y_Coordinate',
#        'Head_Z_Coordinate'],
#       dtype='object')

# %%
# Velocity											
V_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Velocity")])
V_tr_std   = np.std(X_train[:, :, train_df.columns.get_loc("Velocity")])

# Translation
T_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Translation")])
T_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Translation")])

# Rotation
R_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Rotation")])
R_tr_std  = np.std(X_train[:, :, train_df.columns.get_loc("Rotation")])

# Front_Height
BH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])
BH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Bumber_Height")])

# Hood_Front_Width
FHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])
FHH_tr_std = np.std(X_train[:, :, train_df.columns.get_loc("Front_Hood_Height")])

# Hood_Back_Width
BHA_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])
BHA_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Bumber_Hood_Angle")])

# Hood_Length
HL_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])
HL_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Hood_Length")])

# Hood_Angle
BHH_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])
BHH_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Back_Hood_Height")])

# Windscreen_Length
HXC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])
HXC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_X_Coordinate")])

# Windscreen_Angle
HYC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])
HYC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Y_Coordinate")])

# Head_X_Coordinate
HZC_tr_mean = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])
HZC_tr_std = np.mean(X_train[:, :, train_df.columns.get_loc("Head_Z_Coordinate")])


def preprocess(X):
    X[:, :, 0] = (X[:, :, 0] - V_tr_mean) / V_tr_std
    X[:, :, 1] = (X[:, :, 1] - T_tr_mean) / T_tr_std
    X[:, :, 2] = (X[:, :, 2] - R_tr_mean) / R_tr_std
    X[:, :, 3] = (X[:, :, 3] - BH_tr_mean) / BH_tr_std
    X[:, :, 4] = (X[:, :, 4] - FHH_tr_mean) / FHH_tr_std
    X[:, :, 5] = (X[:, :, 5] - BHA_tr_mean) / BHA_tr_std
    X[:, :, 6] = (X[:, :, 6] - HL_tr_mean) / HL_tr_std
    X[:, :, 7] = (X[:, :, 7] - BHH_tr_mean) / BHH_tr_std
    X[:, :, 8] = (X[:, :, 8] - HXC_tr_mean) / HXC_tr_std
    X[:, :, 9] = (X[:, :, 9] - HYC_tr_mean) / HYC_tr_std
    X[:, :, 10] = (X[:, :, 10] - HZC_tr_mean) / HZC_tr_std

# %%
# preprocess(X_train)
# preprocess(X_val)
# preprocess(X_test)

# %%
X_train = X_train.astype(np.float32)
X_val = X_val.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((first_steps, 11)))
model.add(LSTM(32, return_sequences=True))  # First LSTM layer
model.add(LSTM(64))  # Second LSTM layer
model.add(Dense(32, activation="relu"))  # Dense layer with more units for better processing
model.add(Dense(next_steps * 3, activation="linear"))  # Output: 10 timesteps * 3 coordinates = 30 values
model.add(Reshape((next_steps, 3)))  # Reshape to match the target output shape (10, 3))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 32)        │         5,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 225)            │         7,425 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 3)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,969 (156.13 KB)
#  Trainable params: 39,969 (156.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

cp = ModelCheckpoint("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\model12.keras", save_best_only=True)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10000, callbacks=[cp, es])
# Out:
# Epoch 1/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - loss: 594547.9375 - root_mean_squared_error: 771.0609 - val_loss: 592497.1875 - val_root_mean_squared_error: 769.7383
# Epoch 2/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 587867.7500 - root_mean_squared_error: 766.6909 - val_loss: 592458.3125 - val_root_mean_squared_error: 769.7131
# Epoch 3/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 589831.5625 - root_mean_squared_error: 767.9949 - val_loss: 592377.6250 - val_root_mean_squared_error: 769.6607
# Epoch 4/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 580119.8125 - root_mean_squared_error: 761.6357 - val_loss: 572696.8750 - val_root_mean_squared_error: 756.7674
# Epoch 27/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 570364.0000 - root_mean_squared_error: 755.2197 - val_loss: 571329.5625 - val_root_mean_squared_error: 755.8635
# Epoch 28/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 571516.1250 - root_mean_squared_error: 755.9675 - val_loss: 569925.8750 - val_root_mean_squared_error: 754.9343
# Epoch 29/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 572945.6250 - root_mean_squared_error: 756.8911 - val_loss: 568484.0625 - val_root_mean_squared_error: 753.9789
# Epoch 30/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 564434.6875 - root_mean_squared_error: 751.2736 - val_loss: 566999.0625 - val_root_mean_squared_error: 752.9934
# Epoch 31/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 565025.5625 - root_mean_squared_error: 751.6689 - val_loss: 565497.3125 - val_root_mean_squared_error: 751.9955
# Epoch 32/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 568536.5625 - root_mean_squared_error: 753.9633 - val_loss: 563954.5000 - val_root_mean_squared_error: 750.9691
# Epoch 33/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 568216.9375 - root_mean_squared_error: 753.7753 - val_loss: 562372.6250 - val_root_mean_squared_error: 749.9151
# Epoch 34/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 557372.5000 - root_mean_squared_error: 746.5627 - val_loss: 560767.9375 - val_root_mean_squared_error: 748.8444
# Epoch 35/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 552474.4375 - root_mean_squared_error: 743.2434 - val_loss: 559121.7500 - val_root_mean_squared_error: 747.7444
# Epoch 36/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 560314.8125 - root_mean_squared_error: 748.5107 - val_loss: 557447.2500 - val_root_mean_squared_error: 746.6240
# Epoch 37/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 555243.4375 - root_mean_squared_error: 745.1430 - val_loss: 555745.9375 - val_root_mean_squared_error: 745.4837
# Epoch 38/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 558279.1875 - root_mean_squared_error: 747.1580 - val_loss: 554013.3125 - val_root_mean_squared_error: 744.3207
# Epoch 39/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 562187.2500 - root_mean_squared_error: 749.7405 - val_loss: 552251.3125 - val_root_mean_squared_error: 743.1361
# Epoch 40/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 548011.5000 - root_mean_squared_error: 740.2572 - val_loss: 550450.0000 - val_root_mean_squared_error: 741.9232
# Epoch 41/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 548441.0625 - root_mean_squared_error: 740.5552 - val_loss: 548627.7500 - val_root_mean_squared_error: 740.6941
# Epoch 42/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 550588.1875 - root_mean_squared_error: 741.9826 - val_loss: 546772.8750 - val_root_mean_squared_error: 739.4409
# Epoch 43/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 548078.0625 - root_mean_squared_error: 740.3193 - val_loss: 544894.0625 - val_root_mean_squared_error: 738.1694
# Epoch 44/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 546557.9375 - root_mean_squared_error: 739.2770 - val_loss: 542987.3125 - val_root_mean_squared_error: 736.8767
# Epoch 45/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 542340.8125 - root_mean_squared_error: 736.4232 - val_loss: 541051.6875 - val_root_mean_squared_error: 735.5621
# Epoch 46/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 541462.6875 - root_mean_squared_error: 735.8329 - val_loss: 539098.1875 - val_root_mean_squared_error: 734.2330
# Epoch 47/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s
10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 51798.6367 - root_mean_squared_error: 227.5867 - val_loss: 45995.6445 - val_root_mean_squared_error: 214.4660
# Epoch 359/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 50259.8906 - root_mean_squared_error: 224.1427 - val_loss: 45941.9844 - val_root_mean_squared_error: 214.3408
# Epoch 360/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 49292.6562 - root_mean_squared_error: 221.9885 - val_loss: 45897.7539 - val_root_mean_squared_error: 214.2376
# Epoch 361/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 52262.2422 - root_mean_squared_error: 228.5298 - val_loss: 45851.0898 - val_root_mean_squared_error: 214.1287
# Epoch 362/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 51201.3438 - root_mean_squared_error: 226.2579 - val_loss: 45805.0430 - val_root_mean_squared_error: 214.0211
# Epoch 363/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 50038.6719 - root_mean_squared_error: 223.6395 - val_loss: 45762.1797 - val_root_mean_squared_error: 213.9210
# Epoch 364/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 53083.1758 - root_mean_squared_error: 230.3350 - val_loss: 45721.8594 - val_root_mean_squared_error: 213.8267
# Epoch 365/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 50358.6641 - root_mean_squared_error: 224.3917 - val_loss: 45678.4883 - val_root_mean_squared_error: 213.7253
# Epoch 366/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 52983.3633 - root_mean_squared_error: 230.1296 - val_loss: 45643.3242 - val_root_mean_squared_error: 213.6430
# Epoch 367/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 53485.5195 - root_mean_squared_error: 231.1819 - val_loss: 45610.3359 - val_root_mean_squared_error: 213.5658
# Epoch 368/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 49483.2227 - root_mean_squared_error: 222.3911 - val_loss: 45581.7148 - val_root_mean_squared_error: 213.4987
# Epoch 369/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 49631.6172 - root_mean_squared_error: 222.7482 - val_loss: 45550.9883 - val_root_mean_squared_error: 213.4268
# Epoch 370/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 49166.4531 - root_mean_squared_error: 221.6892 - val_loss: 45518.7539 - val_root_mean_squared_error: 213.3512
# Epoch 371/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 48657.9180 - root_mean_squared_error: 220.5119 - val_loss: 45484.0391 - val_root_mean_squared_error: 213.2699
# Epoch 372/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 51637.8281 - root_mean_squared_error: 227.1999 - val_loss: 45456.8203 - val_root_mean_squared_error: 213.2061
# Epoch 373/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 50999.1328 - root_mean_squared_error: 225.7671 - val_loss: 45436.2344 - val_root_mean_squared_error: 213.1578
# Epoch 374/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 50036.0039 - root_mean_squared_error: 223.6272 - val_loss: 45414.0430 - val_root_mean_squared_error: 213.1057
# Epoch 375/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 51596.6094 - root_mean_squared_error: 227.1320 - val_loss: 45395.2617 - val_root_mean_squared_error: 213.0616
# Epoch 376/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 50692.2734 - root_mean_squared_error: 225.1258 - val_loss: 45375.3047 - val_root_mean_squared_error: 213.0148
# Epoch 377/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 54152.8594 - root_mean_squared_error: 232.5484 - val_loss: 45358.7812 - val_root_mean_squared_error: 212.9760
# Epoch 378/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 50844.5039 - root_mean_squared_error: 225.4778 - val_loss: 45345.9648 - val_root_mean_squared_error: 212.9459
# Epoch 379/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 50318.1641 - root_mean_squared_error: 224.3084 - val_loss: 45328.6211 - val_root_mean_squared_error: 212.9052
# Epoch 380/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 50371.4727 - root_mean_squared_error: 224.4099 - val_loss: 45316.1992 - val_root_mean_squared_error: 212.8760
# Epoch 381/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 50130.1797 - root_mean_squared_error: 223.8914 - val_loss: 45299.4258 - val_root_mean_squared_error: 212.8366
# Epoch 382/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 49239.9961 - root_mean_squared_error: 221.8513 - val_loss: 45283.3828 - val_root_mean_squared_error: 212.7989
# Epoch 383/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 48858.5820 - root_mean_squared_error: 220.9953 - val_loss: 45273.1992 - val_root_mean_squared_error: 212.7750
# Epoch 384/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 53243.2734 - root_mean_squared_error: 230.5795 - val_loss: 45263.6211 - val_root_mean_squared_error: 212.7525
# Epoch 385/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 51306.1289 - root_mean_squared_error: 226.4752 - val_loss: 45255.1680 - val_root_mean_squared_error: 212.7326
# Epoch 386/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 48975.0547 - root_mean_squared_error: 221.2040 - val_loss: 45247.6797 - val_root_mean_squared_error: 212.7150
# Epoch 387/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 49729.7188 - root_mean_squared_error: 222.9671 - val_loss: 45239.9688 - val_root_mean_squared_error: 212.6969
# Epoch 388/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 50034.8945 - root_mean_squared_error: 223.6640 - val_loss: 45228.3789 - val_root_mean_squared_error: 212.6696
# Epoch 389/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 50079.5586 - root_mean_squared_error: 223.7558 - val_loss: 45216.4883 - val_root_mean_squared_error: 212.6417
# Epoch 390/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 50973.1484 - root_mean_squared_error: 225.7660 - val_loss: 45204.9375 - val_root_mean_squared_error: 212.6145
# Epoch 391/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 50979.0078 - root_mean_squared_error: 225.7420 - val_loss: 45196.0664 - val_root_mean_squared_error: 212.5937
# Epoch 392/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 51435.0078 - root_mean_squared_error: 226.7389 - val_loss: 45189.7031 - val_root_mean_squared_error: 212.5787
# Epoch 393/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 49271.1250 - root_mean_squared_error: 221.9554 - val_loss: 45183.7891 - val_root_mean_squared_error: 212.5648
# Epoch 394/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 51487.1914 - root_mean_squared_error: 226.8898 - val_loss: 45181.8867 - val_root_mean_squared_error: 212.5603
# Epoch 395/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 50328.4258 - root_mean_squared_error: 224.3151 - val_loss: 45173.5938 - val_root_mean_squared_error: 212.5408
# Epoch 396/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 48591.6875 - root_mean_squared_error: 220.3929 - val_loss: 45168.0312 - val_root_mean_squared_error: 212.5277
# Epoch 397/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 49999.1094 - root_mean_squared_error: 223.5873 - val_loss: 45167.6602 - val_root_mean_squared_error: 212.5269
# Epoch 398/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 50341.1406 - root_mean_squared_error: 224.3400 - val_loss: 45164.5156 - val_root_mean_squared_error: 212.5195
# Epoch 399/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 47653.4688 - root_mean_squared_error: 218.1710 - val_loss: 45162.2031 - val_root_mean_squared_error: 212.5140
# Epoch 400/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 49543.5703 - root_mean_squared_error: 222.5395 - val_loss: 45159.3828 - val_root_mean_squared_error: 212.5074
# Epoch 401/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 48914.9453 - root_mean_squared_error: 221.1217 - val_loss: 45158.1562 - val_root_mean_squared_error: 212.5045
# Epoch 402/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 49620.3008 - root_mean_squared_error: 222.7116 - val_loss: 45153.7461 - val_root_mean_squared_error: 212.4941
# Epoch 403/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 50255.8398 - root_mean_squared_error: 224.0449 - val_loss: 45148.6172 - val_root_mean_squared_error: 212.4821
# Epoch 404/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 52169.4961 - root_mean_squared_error: 228.3163 - val_loss: 45144.8398 - val_root_mean_squared_error: 212.4731
# Epoch 405/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 49588.6172 - root_mean_squared_error: 222.6768 - val_loss: 45140.8867 - val_root_mean_squared_error: 212.4639
# Epoch 406/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 53601.7188 - root_mean_squared_error: 231.1547 - val_loss: 45136.2773 - val_root_mean_squared_error: 212.4530
# Epoch 407/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 50639.4141 - root_mean_squared_error: 225.0192 - val_loss: 45137.3906 - val_root_mean_squared_error: 212.4556
# Epoch 408/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 49892.1172 - root_mean_squared_error: 223.3292 - val_loss: 45137.7344 - val_root_mean_squared_error: 212.4564
# Epoch 409/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 50089.1836 - root_mean_squared_error: 223.7823 - val_loss: 45136.4180 - val_root_mean_squared_error: 212.4533
# Epoch 410/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 50681.6094 - root_mean_squared_error: 225.1116 - val_loss: 45132.3984 - val_root_mean_squared_error: 212.4439
# Epoch 411/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 49251.1953 - root_mean_squared_error: 221.8941 - val_loss: 45133.3867 - val_root_mean_squared_error: 212.4462
# Epoch 412/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 47969.9258 - root_mean_squared_error: 218.9690 - val_loss: 45133.9688 - val_root_mean_squared_error: 212.4476
# Epoch 413/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 50073.5000 - root_mean_squared_error: 223.7486 - val_loss: 45130.9023 - val_root_mean_squared_error: 212.4404
# Epoch 414/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 50235.7852 - root_mean_squared_error: 224.0966 - val_loss: 45131.3477 - val_root_mean_squared_error: 212.4414
# Epoch 415/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 51169.8516 - root_mean_squared_error: 226.1976 - val_loss: 45128.2422 - val_root_mean_squared_error: 212.4341
# Epoch 416/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 49549.2109 - root_mean_squared_error: 222.5485 - val_loss: 45126.8477 - val_root_mean_squared_error: 212.4308
# Epoch 417/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 52732.8359 - root_mean_squared_error: 229.4894 - val_loss: 45125.4023 - val_root_mean_squared_error: 212.4274
# Epoch 418/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 52214.4570 - root_mean_squared_error: 228.4781 - val_loss: 45122.8320 - val_root_mean_squared_error: 212.4214
# Epoch 419/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s
10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 47463.3242 - root_mean_squared_error: 217.6073 - val_loss: 45116.5117 - val_root_mean_squared_error: 212.4065
# Epoch 441/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 48744.7266 - root_mean_squared_error: 220.6744 - val_loss: 45122.2852 - val_root_mean_squared_error: 212.4201
# Epoch 442/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 49022.0469 - root_mean_squared_error: 221.3891 - val_loss: 45122.3672 - val_root_mean_squared_error: 212.4203
# Epoch 443/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 49136.3281 - root_mean_squared_error: 221.6508 - val_loss: 45124.3984 - val_root_mean_squared_error: 212.4250
# Epoch 444/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 50347.2812 - root_mean_squared_error: 224.3388 - val_loss: 45123.6523 - val_root_mean_squared_error: 212.4233
# Epoch 445/10000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 48515.2969 - root_mean_squared_error: 220.1721 - val_loss: 45123.4453 - val_root_mean_squared_error: 212.4228

# %%
from tensorflow.keras.models import load_model
model = load_model("C:\\Users\\geork\\projects\\AIThesis\\src\\analysis\\ThesisChapters\\5_4\\1\\model12.keras")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming model is trained and X_train, y_train are defined

# Make predictions
predictions = model.predict(X_train)


def plot_predictions3(initial_seq, true_values, predicted_values, coordinate_name, row):
    # Extract the initial sequence from the DataFrame
    whole_timeseries = np.array(row[coordinate_name])
    
    # Concatenate the sequences
    initial_and_true = np.concatenate([initial_seq, true_values], axis=0)
    initial_and_pred = np.concatenate([initial_seq, predicted_values], axis=0)
    
    # Plot the true and predicted values
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(initial_and_true)), initial_and_true, label='True Values', marker='o')
    plt.plot(range(len(initial_and_pred)), initial_and_pred, label='Predicted Values', marker='x')
    plt.plot(range(len(whole_timeseries)), whole_timeseries, label="Timeseries")
    # Highlight where the prediction starts
    plt.axvline(x=len(initial_seq)-1, color='r', linestyle='--', label='Prediction Start')
    
    plt.title(f'True vs Predicted Values for {coordinate_name}')
    plt.xlabel('Timesteps')
    plt.ylabel(f'{coordinate_name} Value')
    plt.legend()
    plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step

# %%
# Example for the first sample in the dataset
sample_index = 1
initial_seq = X_val[sample_index, :, -3:]  # Last 3 features are the coordinates
true_values = y_val[sample_index, :, :]  # True values
predicted_values = predictions[sample_index, :, :]  # Predicted values
df.iloc[5]
# Plot for Head_X_Coordinate
plot_predictions3(initial_seq[:, 0], true_values[:, 0], predicted_values[:, 0], 'Head_X_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Y_Coordinate
plot_predictions3(initial_seq[:, 1], true_values[:, 1], predicted_values[:, 1], 'Head_Y_Coordinate', val_df.iloc[sample_index])

# Plot for Head_Z_Coordinate
plot_predictions3(initial_seq[:, 2], true_values[:, 2], predicted_values[:, 2], 'Head_Z_Coordinate', val_df.iloc[sample_index])

# %% [markdown]
# ## Conclusion
#
# The Y is 0 because i have activation function relu.
# αφου η τελευταια ειναι liner τοτε μηπως μπορει να βγει αρνητικη τιμη ?
# απλα δε το αφηνει το training ?
# ας το ψαξω και ας ρωτησω αν και θα επρεπε να το ξερω.
